# %%
import os 
os.chdir("/backup/dev/ipython/build_machine_learning_system_with_python/data/ch06")

# %% [markdown]
# twitter문서 가져와서 감성 분석 하기

# %% [markdown]
# 1. twitter 수집기 설정

# %% [markdown]
# dev.twitter.com/apps/new 접속, 어플리케이션 생성

# %% [markdown]
# 어플리케이션 생성 후, Consumer Key, Consumer Secret, Access TOken Key, Access Token Secret 생성.|
# 해당 내용은 다음 "twitterauth.py"에 해당 내용을 수정

# %%
# %load twitterauth.py

# %%
def imgshow(filename):
    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib.image as mpimg

    fname = filename
    image = mpimg.imread(fname)
    imgplot = plt.imshow(image)
    plt.show()

# %%
# This code is supporting material for the book
# Building Machine Learning Systems with Python
# by Willi Richert and Luis Pedro Coelho
# published by PACKT Publishing
#
# It is made available under the MIT License

import sys

CONSUMER_KEY = u'GcRkL0gdhohaKsn0FqQLWEp8y'
CONSUMER_SECRET = u'Nbfq73KPq27u5Js0IxqQMrJz2ntuZMJmGyayz3fQhycFRhh1YV' 

ACCESS_TOKEN_KEY = u'50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz'
ACCESS_TOKEN_SECRET = u'kJ9dbaSTlVPdlK3VBtBD0sds4vLe5VjSHBydaw93LpcZ0' 

if CONSUMER_KEY is None or CONSUMER_SECRET is None or ACCESS_TOKEN_KEY is None or ACCESS_TOKEN_SECRET is None:
    print("""\
When doing last code sanity checks for the book, Twitter
was using the API 1.0, which did not require authentication.
With its switch to version 1.1, this has now changed.

It seems that you don't have already created your personal Twitter
access keys and tokens. Please do so at
https://dev.twitter.com/docs/auth/tokens-devtwittercom
and paste the keys/secrets into twitterauth.py

Sorry for the inconvenience,
The authors.""")

    sys.exit(1)

# %%
# This code is supporting material for the book
# Building Machine Learning Systems with Python
# by Willi Richert and Luis Pedro Coelho
# published by PACKT Publishing
#
# It is made available under the MIT License

import sys

CONSUMER_KEY = u'GcRkL0gdhohaKsn0FqQLWEp8y'
CONSUMER_SECRET = u'Nbfq73KPq27u5Js0IxqQMrJz2ntuZMJmGyayz3fQhycFRhh1YV'

ACCESS_TOKEN_KEY = u'50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz'
ACCESS_TOKEN_SECRET = u'kJ9dbaSTlVPdlK3VBtBD0sds4vLe5VjSHBydaw93LpcZ0'

if CONSUMER_KEY is None or CONSUMER_SECRET is None or ACCESS_TOKEN_KEY is None or ACCESS_TOKEN_SECRET is None:
    print("""\
When doing last code sanity checks for the book, Twitter
was using the API 1.0, which did not require authentication.
With its switch to version 1.1, this has now changed.

It seems that you don't have already created your personal Twitter
access keys and tokens. Please do so at
https://dev.twitter.com/docs/auth/tokens-devtwittercom
and paste the keys/secrets into twitterauth.py

Sorry for the inconvenience,
The authors.""")

    sys.exit(1)

# %%
import os 
os.chdir("/home/python/notebook_root/build_machine_learning_system_with_python/data/ch06") 
# !ls -al
# Out:
# 합계 72
# drwxr-xr-x  3 root root  4096 12월  1 20:47 .
# drwxr-xr-x 15 root root  4096 12월  1 20:56 ..
# -rw-r--r--  1 root root  3955 12월  1 20:47 01_start.py
# -rw-r--r--  1 root root  5484 12월  1 20:47 02_tuning.py
# -rw-r--r--  1 root root  5972 12월  1 20:47 03_clean.py
# -rw-r--r--  1 root root 10125 12월  1 20:47 04_sent.py
# -rw-r--r--  1 root root  1023 12월  1 20:47 README.md
# drwxr-xr-x  2 root root  4096 12월  1 20:47 data
# -rw-r--r--  1 root root  9264 12월  1 20:47 install.py
# -rw-r--r--  1 root root   897 12월  1 20:47 twitterauth.py
# -rw-r--r--  1 root root  6937 12월  1 20:47 utils.py

# %%
# %load install.py

# %%
# This code is supporting material for the book
# Building Machine Learning Systems with Python
# by Willi Richert and Luis Pedro Coelho
# published by PACKT Publishing
#
# It is made available under the MIT License

#
# Sanders-Twitter Sentiment Corpus Install Script
# Version 0.1
#
# Pulls tweet data from Twitter because ToS prevents distributing it directly.
#
#   - Niek Sanders
#     njs@sananalytics.com
#     October 20, 2011
#
#

# In Sanders' original form, the code was using Twitter API 1.0.
# Now that Twitter moved to 1.1, we had to make a few changes.
# Cf. twitterauth.py for the details.

# Regarding rate limiting, please check
# https://dev.twitter.com/rest/public/rate-limiting

import sys
import csv
import json
import os
import time

try:
    import twitter
except ImportError:
    print("""\
You need to ...
    pip install twitter
If pip is not found you might have to install it using easy_install.
If it does not work on your system, you might want to follow instructions
at https://github.com/sixohsix/twitter, most likely:
  $ git clone https://github.com/sixohsix/twitter
  $ cd twitter
  $ sudo python setup.py install
""")

    sys.exit(1)

from twitterauth import CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN_KEY, ACCESS_TOKEN_SECRET
api = twitter.Twitter(auth=twitter.OAuth(consumer_key=CONSUMER_KEY, consumer_secret=CONSUMER_SECRET,
                                         token=ACCESS_TOKEN_KEY, token_secret=ACCESS_TOKEN_SECRET))

DATA_PATH = "data"

# for some reasons TWeets disappear. In this file we collect those
MISSING_ID_FILE = os.path.join(DATA_PATH, "missing.tsv")
NOT_AUTHORIZED_ID_FILE = os.path.join(DATA_PATH, "not_authorized.tsv")


def get_user_params(DATA_PATH):

    user_params = {}

    # get user input params
    user_params['inList'] = os.path.join(DATA_PATH, 'corpus.csv')
    user_params['outList'] = os.path.join(DATA_PATH, 'full-corpus.csv')
    user_params['rawDir'] = os.path.join(DATA_PATH, 'rawdata/')

    # apply defaults
    if user_params['inList'] == '':
        user_params['inList'] = './corpus.csv'
    if user_params['outList'] == '':
        user_params['outList'] = './full-corpus.csv'
    if user_params['rawDir'] == '':
        user_params['rawDir'] = './rawdata/'

    return user_params


def dump_user_params(user_params):

    # dump user params for confirmation
    print('Input:    ' + user_params['inList'])
    print('Output:   ' + user_params['outList'])
    print('Raw data: ' + user_params['rawDir'])


def read_total_list(in_filename):

    # read total fetch list csv
    fp = open(in_filename, 'rt')
    reader = csv.reader(fp, delimiter=',', quotechar='"')

    if os.path.exists(MISSING_ID_FILE):
        missing_ids = [line.strip()
                       for line in open(MISSING_ID_FILE, "r").readlines()]
    else:
        missing_ids = []

    if os.path.exists(NOT_AUTHORIZED_ID_FILE):
        not_authed_ids = [line.strip()
                          for line in open(NOT_AUTHORIZED_ID_FILE, "r").readlines()]
    else:
        not_authed_ids = []

    print("We will skip %i tweets that are not available or visible any more on twitter" % (
        len(missing_ids) + len(not_authed_ids)))

    ignore_ids = set(missing_ids + not_authed_ids)
    total_list = []

    for row in reader:
        if row[2] not in ignore_ids:
            total_list.append(row)

    return total_list


def purge_already_fetched(fetch_list, raw_dir):

    # list of tweet ids that still need downloading
    rem_list = []
    count_done = 0

    # check each tweet to see if we have it
    for item in fetch_list:

        # check if json file exists
        tweet_file = os.path.join(raw_dir, item[2] + '.json')
        if os.path.exists(tweet_file):

            # attempt to parse json file
            try:
                parse_tweet_json(tweet_file)
                count_done += 1
            except RuntimeError:
                print("Error parsing", item)
                rem_list.append(item)
        else:
            rem_list.append(item)

    print("We have already downloaded %i tweets." % count_done)

    return rem_list


def download_tweets(fetch_list, raw_dir):

    # ensure raw data directory exists
    if not os.path.exists(raw_dir):
        os.mkdir(raw_dir)

    # download tweets
    for idx in range(0, len(fetch_list)):
        # current item
        item = fetch_list[idx]
        print(item)

        print('--> downloading tweet #%s (%d of %d)' %
              (item[2], idx + 1, len(fetch_list)))

        try:
            #import pdb;pdb.set_trace()
            response = api.statuses.show(_id=item[2])

            if response.rate_limit_remaining <= 0:
                wait_seconds = response.rate_limit_reset - time.time()
                print("Rate limiting requests us to wait %f seconds" %
                      wait_seconds)
                time.sleep(wait_seconds+5)

        except twitter.TwitterError as e:
            fatal = True
            print(e)
            for m in json.loads(e.response_data.decode())['errors']:
                if m['code'] == 34:
                    print("Tweet missing: ", item)
                    with open(MISSING_ID_FILE, "at") as f:
                        f.write(item[2] + "\n")

                    fatal = False
                    break
                elif m['code'] == 63:
                    print("User of tweet '%s' has been suspended." % item)
                    with open(MISSING_ID_FILE, "at") as f:
                        f.write(item[2] + "\n")

                    fatal = False
                    break
                elif m['code'] == 88:
                    print("Rate limit exceeded.")
                    fatal = True
                    break
                elif m['code'] == 179:
                    print("Not authorized to view this tweet.")
                    with open(NOT_AUTHORIZED_ID_FILE, "at") as f:
                        f.write(item[2] + "\n")
                    fatal = False
                    break

            if fatal:
                raise
            else:
                continue

        with open(raw_dir + item[2] + '.json', "wt") as f:
            f.write(json.dumps(dict(response)) + "\n")

    return


def parse_tweet_json(filename):

    # read tweet
    fp = open(filename, 'r')

    # parse json
    try:
        tweet_json = json.load(fp)
    except ValueError as e:
        print(e)
        raise RuntimeError('error parsing json')

    # look for twitter api error msgs
    if 'error' in tweet_json or 'errors' in tweet_json:
        raise RuntimeError('error in downloaded tweet')

    # extract creation date and tweet text
    return [tweet_json['created_at'], tweet_json['text']]


def build_output_corpus(out_filename, raw_dir, total_list):

    # open csv output file
    fp = open(out_filename, 'wb')
    writer = csv.writer(fp, delimiter=',', quotechar='"', escapechar='\\',
                        quoting=csv.QUOTE_ALL)

    # write header row
    writer.writerow(
        ['Topic', 'Sentiment', 'TweetId', 'TweetDate', 'TweetText'])

    # parse all downloaded tweets
    missing_count = 0
    for item in total_list:

        # ensure tweet exists
        if os.path.exists(raw_dir + item[2] + '.json'):

            try:
                # parse tweet
                parsed_tweet = parse_tweet_json(raw_dir + item[2] + '.json')
                full_row = item + parsed_tweet

                # character encoding for output
                for i in range(0, len(full_row)):
                    full_row[i] = full_row[i].encode("utf-8")

                # write csv row
                writer.writerow(full_row)

            except RuntimeError:
                print('--> bad data in tweet #' + item[2])
                missing_count += 1

        else:
            print('--> missing tweet #' + item[2])
            missing_count += 1

    # indicate success
    if missing_count == 0:
        print('\nSuccessfully downloaded corpus!')
        print('Output in: ' + out_filename + '\n')
    else:
        print('\nMissing %d of %d tweets!' % (missing_count, len(total_list)))
        print('Partial output in: ' + out_filename + '\n')

    return


def main():
    # get user parameters
    user_params = get_user_params(DATA_PATH)
    print(user_params)
    dump_user_params(user_params)

    # get fetch list
    total_list = read_total_list(user_params['inList'])

    # remove already fetched or missing tweets
    fetch_list = purge_already_fetched(total_list, user_params['rawDir'])
    print("Fetching %i tweets..." % len(fetch_list))

    if fetch_list:
        # start fetching data from twitter
        download_tweets(fetch_list, user_params['rawDir'])

        # second pass for any failed downloads
        fetch_list = purge_already_fetched(total_list, user_params['rawDir'])
        if fetch_list:
            print('\nStarting second pass to retry %i failed downloads...' %
                  len(fetch_list))
            download_tweets(fetch_list, user_params['rawDir'])
    else:
        print("Nothing to fetch any more.")

    # build output corpus
    build_output_corpus(user_params['outList'], user_params['rawDir'],
                        total_list)


if __name__ == '__main__':
    main()
# Out:
# {'rawDir': 'data/rawdata/', 'inList': 'data/corpus.csv', 'outList': 'data/full-corpus.csv'}
# Input:    data/corpus.csv
# Output:   data/full-corpus.csv
# Raw data: data/rawdata/
# We will skip 1107 tweets that are not available or visible any more on twitter
# We have already downloaded 0 tweets.
# Fetching 4784 tweets...
# ['apple', 'positive', '126415614616154112']
# --> downloading tweet #126415614616154112 (1 of 4784)
# ['apple', 'positive', '126404574230740992']
# --> downloading tweet #126404574230740992 (2 of 4784)
# ['apple', 'positive', '126402758403305474']
# --> downloading tweet #126402758403305474 (3 of 4784)
# ['apple', 'positive', '126397179614068736']
# --> downloading tweet #126397179614068736 (4 of 4784)
# ['apple', 'positive', '126395626979196928']
# --> downloading tweet #126395626979196928 (5 of 4784)
# ['apple', 'positive', '126394830791254016']
# --> downloading tweet #126394830791254016 (6 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=126394830791254016&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=14419235663843390156&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168851&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=Zl3iINLfdtF1hv37oaiZCzGr8G8%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'positive', '126394830791254016'])
# ['apple', 'positive', '126379685453119488']
# --> downloading tweet #126379685453119488 (7 of 4784)
# ['apple', 'positive', '126377656416612353']
# --> downloading tweet #126377656416612353 (8 of 4784)
# ['apple', 'positive', '126373779483004928']
# --> downloading tweet #126373779483004928 (9 of 4784)
# ['apple', 'positive', '126366353757179904']
# --> downloading tweet #126366353757179904 (10 of 4784)
# ['apple', 'positive', '126365858481188864']
# --> downloading tweet #126365858481188864 (11 of 4784)
# ['apple', 'positive', '126360935509135362']
# --> downloading tweet #126360935509135362 (12 of 4784)
# ['apple', 'positive', '126360398885687296']
# --> downloading tweet #126360398885687296 (13 of 4784)
# ['apple', 'positive', '126358340220616704']
# --> downloading tweet #126358340220616704 (14 of 4784)
# ['apple', 'positive', '126357982685569024']
# --> downloading tweet #126357982685569024 (15 of 4784)
# ['apple', 'positive', '126352268705538048']
# --> downloading tweet #126352268705538048 (16 of 4784)
# ['apple', 'positive', '126350302113824769']
# --> downloading tweet #126350302113824769 (17 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=126350302113824769&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=13178040682828235317&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168866&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=1aSCjn1z98Cnr8L2TFngG%2BDKwvM%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'positive', '126349695676203009']
# --> downloading tweet #126349695676203009 (18 of 4784)
# ['apple', 'positive', '126342268603998208']
# --> downloading tweet #126342268603998208 (19 of 4784)
# ['apple', 'positive', '126325800080392193']
# --> downloading tweet #126325800080392193 (20 of 4784)
# ['apple', 'positive', '126324177501302784']
# --> downloading tweet #126324177501302784 (21 of 4784)
# ['apple', 'positive', '126323785145126912']
# --> downloading tweet #126323785145126912 (22 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=126323785145126912&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=10824427085360961426&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168874&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=zVLFA2XXd%2BSjYUGBuIIgLgrtI0U%3D)
# details: {"errors":[{"code":63,"message":"User has been suspended."}]}
# User of tweet '['apple', 'positive', '126323785145126912']' has been suspended.
# ['apple', 'positive', '126322063332999169']
# --> downloading tweet #126322063332999169 (23 of 4784)
# ['apple', 'positive', '126319186141130752']
# --> downloading tweet #126319186141130752 (24 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=126319186141130752&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=1634690667310181097&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168877&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=brZr3wiOdeyj7dszUrRO2zisSrM%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'positive', '126319186141130752'])
# ['apple', 'positive', '126318009647235072']
# --> downloading tweet #126318009647235072 (25 of 4784)
# ['apple', 'positive', '126315223060709376']
# --> downloading tweet #126315223060709376 (26 of 4784)
# ['apple', 'positive', '126315011600678913']
# --> downloading tweet #126315011600678913 (27 of 4784)
# ['apple', 'positive', '126314687116750849']
# --> downloading tweet #126314687116750849 (28 of 4784)
# ['apple', 'positive', '126311981564178432']
# --> downloading tweet #126311981564178432 (29 of 4784)
# ['apple', 'positive', '126307801046847488']
# --> downloading tweet #126307801046847488 (30 of 4784)
# ['apple', 'positive', '126302673820594176']
# --> downloading tweet #126302673820594176 (31 of 4784)
# ['apple', 'positive', '126301956951117826']
# --> downloading tweet #126301956951117826 (32 of 4784)
# ['apple', 'positive', '126287654093471745']
# --> downloading tweet #126287654093471745 (33 of 4784)
# ['apple', 'positive', '126284506360578049']
# --> downloading tweet #126284506360578049 (34 of 4784)
# ['apple', 'positive', '126263834968211456']
# --> downloading tweet #126263834968211456 (35 of 4784)
# ['apple', 'positive', '126256230397259776']
# --> downloading tweet #126256230397259776 (36 of 4784)
# ['apple', 'positive', '126195522691280896']
# --> downloading tweet #126195522691280896 (37 of 4784)
# ['apple', 'positive', '126183339945234432']
# --> downloading tweet #126183339945234432 (38 of 4784)
# ['apple', 'positive', '126180209501286400']
# --> downloading tweet #126180209501286400 (39 of 4784)
# ['apple', 'positive', '126164430546403328']
# --> downloading tweet #126164430546403328 (40 of 4784)
# ['apple', 'positive', '126148685737361408']
# --> downloading tweet #126148685737361408 (41 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=126148685737361408&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=9041488455282543509&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168901&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=Wap1xuDA628HFjF1P2A0F1jR%2ByQ%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'positive', '126140794078892033']
# --> downloading tweet #126140794078892033 (42 of 4784)
# ['apple', 'positive', '126134400466419712']
# --> downloading tweet #126134400466419712 (43 of 4784)
# ['apple', 'positive', '126130991365500928']
# --> downloading tweet #126130991365500928 (44 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=126130991365500928&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=11864289780453787564&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168906&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=YJXbSl71cIxlVWinTkZXnb%2BBv%2B0%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'positive', '126116898051076096']
# --> downloading tweet #126116898051076096 (45 of 4784)
# ['apple', 'positive', '126116614495154176']
# --> downloading tweet #126116614495154176 (46 of 4784)
# ['apple', 'positive', '126112836219973632']
# --> downloading tweet #126112836219973632 (47 of 4784)
# ['apple', 'positive', '126107965991297024']
# --> downloading tweet #126107965991297024 (48 of 4784)
# ['apple', 'positive', '126104732426186752']
# --> downloading tweet #126104732426186752 (49 of 4784)
# ['apple', 'positive', '126097426493878272']
# --> downloading tweet #126097426493878272 (50 of 4784)
# ['apple', 'positive', '126095744531832832']
# --> downloading tweet #126095744531832832 (51 of 4784)
# ['apple', 'positive', '126084907343691776']
# --> downloading tweet #126084907343691776 (52 of 4784)
# ['apple', 'positive', '126076238375817216']
# --> downloading tweet #126076238375817216 (53 of 4784)
# ['apple', 'positive', '126075534894571520']
# --> downloading tweet #126075534894571520 (54 of 4784)
# ['apple', 'positive', '126064519943426048']
# --> downloading tweet #126064519943426048 (55 of 4784)
# ['apple', 'positive', '126063569660936193']
# --> downloading tweet #126063569660936193 (56 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=126063569660936193&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=8314924398343136659&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168923&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=bwdC0dPkLrf545BPMqkh4%2BC%2FLXk%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'positive', '126063569660936193'])
# ['apple', 'positive', '126063358037340161']
# --> downloading tweet #126063358037340161 (57 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=126063358037340161&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=15016311833028563049&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168924&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=2mZgF9uOtzj%2Fhq4ae5iRvHxdQpw%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'positive', '126059405941809152']
# --> downloading tweet #126059405941809152 (58 of 4784)
# ['apple', 'positive', '126057030996852737']
# --> downloading tweet #126057030996852737 (59 of 4784)
# ['apple', 'positive', '126040352237961217']
# --> downloading tweet #126040352237961217 (60 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=126040352237961217&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=15198978529495675726&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168929&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=q2%2B%2B0HocNy%2BNukbHRrxE2HA6u0Y%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'positive', '126040074595999746']
# --> downloading tweet #126040074595999746 (61 of 4784)
# ['apple', 'positive', '126034495991328768']
# --> downloading tweet #126034495991328768 (62 of 4784)
# ['apple', 'positive', '126026756623831041']
# --> downloading tweet #126026756623831041 (63 of 4784)
# ['apple', 'positive', '126019393460244481']
# --> downloading tweet #126019393460244481 (64 of 4784)
# ['apple', 'positive', '126009748020658177']
# --> downloading tweet #126009748020658177 (65 of 4784)
# ['apple', 'positive', '126008369562652672']
# --> downloading tweet #126008369562652672 (66 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=126008369562652672&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=2945979867481464292&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168937&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=he%2BWM3%2BiJTmthK8Vq3SfrUVBFUs%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'positive', '126002597063696384']
# --> downloading tweet #126002597063696384 (67 of 4784)
# ['apple', 'positive', '125999676972470272']
# --> downloading tweet #125999676972470272 (68 of 4784)
# ['apple', 'positive', '125995158679461888']
# --> downloading tweet #125995158679461888 (69 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=125995158679461888&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=7109479327695662526&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168942&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=awj%2FuqjUH964EMuXUNm6bywKdNI%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'positive', '125978568726560768']
# --> downloading tweet #125978568726560768 (70 of 4784)
# ['apple', 'positive', '125974505385500672']
# --> downloading tweet #125974505385500672 (71 of 4784)
# ['apple', 'positive', '125960325437722624']
# --> downloading tweet #125960325437722624 (72 of 4784)
# ['apple', 'positive', '125959059957485569']
# --> downloading tweet #125959059957485569 (73 of 4784)
# ['apple', 'positive', '125947912306954240']
# --> downloading tweet #125947912306954240 (74 of 4784)
# ['apple', 'positive', '125947232359948288']
# --> downloading tweet #125947232359948288 (75 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=125947232359948288&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=1655722067992920338&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168950&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=MtzL%2BY0OVopdeeHbA369HZANlXk%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'positive', '125947232359948288'])
# ['apple', 'positive', '125943290288803841']
# --> downloading tweet #125943290288803841 (76 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=125943290288803841&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=14712505118660181678&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168952&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=VP0%2B5YAjfjgwlZxSjk9z7fASD7o%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'positive', '125943290288803841'])
# ['apple', 'positive', '125940394566483968']
# --> downloading tweet #125940394566483968 (77 of 4784)
# ['apple', 'positive', '125925618486489088']
# --> downloading tweet #125925618486489088 (78 of 4784)
# ['apple', 'positive', '125924446430183425']
# --> downloading tweet #125924446430183425 (79 of 4784)
# ['apple', 'positive', '125922999651139584']
# --> downloading tweet #125922999651139584 (80 of 4784)
# ['apple', 'positive', '125902301931126785']
# --> downloading tweet #125902301931126785 (81 of 4784)
# ['apple', 'positive', '125901202591461376']
# --> downloading tweet #125901202591461376 (82 of 4784)
# ['apple', 'positive', '125900497327636480']
# --> downloading tweet #125900497327636480 (83 of 4784)
# ['apple', 'positive', '125850288488841217']
# --> downloading tweet #125850288488841217 (84 of 4784)
# ['apple', 'positive', '125840039031738368']
# --> downloading tweet #125840039031738368 (85 of 4784)
# ['apple', 'positive', '125794931439702016']
# --> downloading tweet #125794931439702016 (86 of 4784)
# ['apple', 'positive', '125728717942161408']
# --> downloading tweet #125728717942161408 (87 of 4784)
# ['apple', 'positive', '125727629012770816']
# --> downloading tweet #125727629012770816 (88 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=125727629012770816&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=504875527854540228&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422168969&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=orYswrza8tKEuqzUnu%2BvNQTLTHU%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'positive', '125722746100531200']
# --> downloading tweet #125722746100531200 (89 of 4784)
# ['apple', 'positive', '125717622728818688']
# --> downloading tweet #125717622728818688 (90 of 4784)
# ['apple', 'positive', '125714253452812288']
# --> downloading tweet #125714253452812288 (91 of 4784)
# ['apple', 'positive', '125713935344214016']
# --> downloading tweet #125713935344214016 (92 of 4784)
# ['apple', 'positive', '125712433087123456']
# --> downloading tweet #125712433087123456 (93 of 4784)
# ['apple', 'positive', '125708639607599104']
# --> downloading tweet #125708639607599104 (94 of 4784)
# ['apple', 'positive', '125706813583798274']
# --> downloading tweet #125706813583798274 (95 of 4784)
# ['apple', 'positive', '125701161926930433']
# --> downloading tweet #125701161926930433 (96 of 4784)
# ['apple', 'positive', '125699573799845888']
# --> downloading tweet #125699573799845888 (97 of 4784)
# ['apple', 'positive', '125681742760771584']
# --> downloading tweet #125681742760771584 (98 of 4784)
# ['apple', 'positive', '125680049478316032']
# --> downloading tweet #125680049478316032 (99 of 4784)
# ['apple', 'positive', '125677424565424128']
# --> downloading tweet #125677424565424128 (100 of 4784)
# ['apple', 'positive', '125667241978114048']
# --> downloading tweet #125667241978114048 (101 of 4784)
# ['apple', 'positive', '125664375364255744']
# --> downloading tweet #125664375364255744 (102 of 4784)
# ['apple', 'positive', '125662399217930240']
# --> downloading tweet #125662399217930240 (103 of 4784)
# ['apple', 'positive', '125652668080336896']
# --> downloading tweet #125652668080336896 (104 of 4784)
# ['apple', 'positive', '125648027045199873']
# --> downloading tweet #125648027045199873 (105 of 4784)
# ['apple', 'positive', '125645258003464192']
# --> downloading tweet #125645258003464192 (106 of 4784)
# ['apple', 'positive', '125643107260829697']
# --> downloading tweet #125643107260829697 (107 of 4784)
# ['apple', 'positive', '125633677597229056']
# --> downloading tweet #125633677597229056 (108 of 4784)
# ['apple', 'positive', '125628199269961729']
# --> downloading tweet #125628199269961729 (109 of 4784)
# ['apple', 'positive', '125623745284018176']
# --> downloading tweet #125623745284018176 (110 of 4784)
# ['apple', 'positive', '125618466353983488']
# --> downloading tweet #125618466353983488 (111 of 4784)
# ['apple', 'positive', '125610372727193601']
# --> downloading tweet #125610372727193601 (112 of 4784)
# ['apple', 'positive', '125608381431025664']
# --> downloading tweet #125608381431025664 (113 of 4784)
# ['apple', 'positive', '125596541028282369']
# --> downloading tweet #125596541028282369 (114 of 4784)
# ['apple', 'positive', '125585606100267008']
# --> downloading tweet #125585606100267008 (115 of 4784)
# ['apple', 'positive', '125562428200202240']
# --> downloading tweet #125562428200202240 (116 of 4784)
# ['apple', 'positive', '125561950376701952']
# --> downloading tweet #125561950376701952 (117 of 4784)
# ['apple', 'positive', '125550135911518209']
# --> downloading tweet #125550135911518209 (118 of 4784)
# ['apple', 'positive', '125547297072357376']
# --> downloading tweet #125547297072357376 (119 of 4784)
# ['apple', 'positive', '125539788546781185']
# --> downloading tweet #125539788546781185 (120 of 4784)
# ['apple', 'positive', '125537993942515712']
# --> downloading tweet #125537993942515712 (121 of 4784)
# ['apple', 'positive', '125537578974851072']
# --> downloading tweet #125537578974851072 (122 of 4784)
# ['apple', 'positive', '125524107386302465']
# --> downloading tweet #125524107386302465 (123 of 4784)
# ['apple', 'positive', '125523414298533888']
# --> downloading tweet #125523414298533888 (124 of 4784)
# ['apple', 'positive', '125501576952553472']
# --> downloading tweet #125501576952553472 (125 of 4784)
# ['apple', 'positive', '125501281753251840']
# --> downloading tweet #125501281753251840 (126 of 4784)
# ['apple', 'positive', '125495491701125120']
# --> downloading tweet #125495491701125120 (127 of 4784)
# ['apple', 'positive', '125459338524499969']
# --> downloading tweet #125459338524499969 (128 of 4784)
# ['apple', 'positive', '125455260801179648']
# --> downloading tweet #125455260801179648 (129 of 4784)
# ['apple', 'positive', '125423290767507456']
# --> downloading tweet #125423290767507456 (130 of 4784)
# ['apple', 'positive', '125416879035658240']
# --> downloading tweet #125416879035658240 (131 of 4784)
# ['apple', 'positive', '125407532893224962']
# --> downloading tweet #125407532893224962 (132 of 4784)
# ['apple', 'positive', '125402412147146752']
# --> downloading tweet #125402412147146752 (133 of 4784)
# ['apple', 'positive', '125393816470568961']
# --> downloading tweet #125393816470568961 (134 of 4784)
# ['apple', 'positive', '125374540107886593']
# --> downloading tweet #125374540107886593 (135 of 4784)
# ['apple', 'positive', '125356807626559488']
# --> downloading tweet #125356807626559488 (136 of 4784)
# ['apple', 'positive', '125343429289984000']
# --> downloading tweet #125343429289984000 (137 of 4784)
# ['apple', 'positive', '125338216411828224']
# --> downloading tweet #125338216411828224 (138 of 4784)
# ['apple', 'positive', '125333598197911552']
# --> downloading tweet #125333598197911552 (139 of 4784)
# ['apple', 'positive', '125319163366473728']
# --> downloading tweet #125319163366473728 (140 of 4784)
# ['apple', 'positive', '125313088160411649']
# --> downloading tweet #125313088160411649 (141 of 4784)
# ['apple', 'positive', '125309946723188736']
# --> downloading tweet #125309946723188736 (142 of 4784)
# ['apple', 'positive', '125281706327552001']
# --> downloading tweet #125281706327552001 (143 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=125281706327552001&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=8186522430922344663&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422169049&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=E2LvDD5%2Bm9mlVfkTcBb1moU5PSI%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'positive', '125279987254300672']
# --> downloading tweet #125279987254300672 (144 of 4784)
# ['apple', 'positive', '125256305647693825']
# --> downloading tweet #125256305647693825 (145 of 4784)
# ['apple', 'positive', '125252188065902592']
# --> downloading tweet #125252188065902592 (146 of 4784)
# ['apple', 'positive', '125243911538098176']
# --> downloading tweet #125243911538098176 (147 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=125243911538098176&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=8684288590633720502&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422169055&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=Z3BpuX3b%2FP2PLaQG2KqJoGEyPf4%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'positive', '125243911538098176'])
# ['apple', 'positive', '125238977417580544']
# --> downloading tweet #125238977417580544 (148 of 4784)
# ['apple', 'positive', '125238017299451905']
# --> downloading tweet #125238017299451905 (149 of 4784)
# ['apple', 'positive', '125165176772247552']
# --> downloading tweet #125165176772247552 (150 of 4784)
# ['apple', 'negative', '126418790706712576']
# --> downloading tweet #126418790706712576 (151 of 4784)
# ['apple', 'negative', '126417285559762944']
# --> downloading tweet #126417285559762944 (152 of 4784)
# ['apple', 'negative', '126416915664084992']
# --> downloading tweet #126416915664084992 (153 of 4784)
# ['apple', 'negative', '126416109212680192']
# --> downloading tweet #126416109212680192 (154 of 4784)
# ['apple', 'negative', '126411162622496768']
# --> downloading tweet #126411162622496768 (155 of 4784)
# ['apple', 'negative', '126410591949697024']
# --> downloading tweet #126410591949697024 (156 of 4784)
# ['apple', 'negative', '126409696553861121']
# --> downloading tweet #126409696553861121 (157 of 4784)
# ['apple', 'negative', '126408864387182593']
# --> downloading tweet #126408864387182593 (158 of 4784)
# ['apple', 'negative', '126408052525105153']
# --> downloading tweet #126408052525105153 (159 of 4784)
# ['apple', 'negative', '126407767132078082']
# --> downloading tweet #126407767132078082 (160 of 4784)
# ['apple', 'negative', '126405405667627008']
# --> downloading tweet #126405405667627008 (161 of 4784)
# ['apple', 'negative', '126405185630253056']
# --> downloading tweet #126405185630253056 (162 of 4784)
# ['apple', 'negative', '126405040809312256']
# --> downloading tweet #126405040809312256 (163 of 4784)
# ['apple', 'negative', '126400637930979329']
# --> downloading tweet #126400637930979329 (164 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=126400637930979329&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=14965661987583288116&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422169079&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=QxNgYiet%2FI9DtkIRwO%2BPRkvOj0w%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'negative', '126394680903614465']
# --> downloading tweet #126394680903614465 (165 of 4784)
# ['apple', 'negative', '126393717421645825']
# --> downloading tweet #126393717421645825 (166 of 4784)
# ['apple', 'negative', '126393204550537216']
# --> downloading tweet #126393204550537216 (167 of 4784)
# ['apple', 'negative', '126392402083708928']
# --> downloading tweet #126392402083708928 (168 of 4784)
# ['apple', 'negative', '126391082308206593']
# --> downloading tweet #126391082308206593 (169 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=126391082308206593&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=8438321059682765105&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422169086&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=RX%2BzYK24dlgAaF8wbDJGd7dlF90%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'negative', '126389218284015616']
# --> downloading tweet #126389218284015616 (170 of 4784)
# ['apple', 'negative', '126388194194362369']
# --> downloading tweet #126388194194362369 (171 of 4784)
# ['apple', 'negative', '126388023725268992']
# --> downloading tweet #126388023725268992 (172 of 4784)
# ['apple', 'negative', '126385036441296896']
# --> downloading tweet #126385036441296896 (173 of 4784)
# ['apple', 'negative', '126382959711358976']
# --> downloading tweet #126382959711358976 (174 of 4784)
# ['apple', 'negative', '126382051661328385']
# --> downloading tweet #126382051661328385 (175 of 4784)
# ['apple', 'negative', '126381519513194497']
# --> downloading tweet #126381519513194497 (176 of 4784)
# ['apple', 'negative', '126380588822298625']
# --> downloading tweet #126380588822298625 (177 of 4784)
# ['apple', 'negative', '126380553464315904']
# --> downloading tweet #126380553464315904 (178 of 4784)
# ['apple', 'negative', '126377298650861568']
# --> downloading tweet #126377298650861568 (179 of 4784)
# ['apple', 'negative', '126375381249966080']
# --> downloading tweet #126375381249966080 (180 of 4784)
# Rate limiting requests us to wait 640.859477 seconds
# ['apple', 'negative', '126372694118768640']
# --> downloading tweet #126372694118768640 (181 of 4784)
# ['apple', 'negative', '126372040696541184']
# --> downloading tweet #126372040696541184 (182 of 4784)
# ['apple', 'negative', '126363154837020672']
# --> downloading tweet #126363154837020672 (183 of 4784)
# ['apple', 'negative', '126361483432038400']
# --> downloading tweet #126361483432038400 (184 of 4784)
# ['apple', 'negative', '126358781633368064']
# --> downloading tweet #126358781633368064 (185 of 4784)
# ['apple', 'negative', '126358301393956866']
# --> downloading tweet #126358301393956866 (186 of 4784)
# ['apple', 'negative', '126358272084152320']
# --> downloading tweet #126358272084152320 (187 of 4784)
# ['apple', 'negative', '126357580741226496']
# --> downloading tweet #126357580741226496 (188 of 4784)
# ['apple', 'negative', '126357227727626240']
# --> downloading tweet #126357227727626240 (189 of 4784)
# ['apple', 'negative', '126354628999778305']
# --> downloading tweet #126354628999778305 (190 of 4784)
# ['apple', 'negative', '126351972948393984']
# --> downloading tweet #126351972948393984 (191 of 4784)
# ['apple', 'negative', '126348169826148352']
# --> downloading tweet #126348169826148352 (192 of 4784)
# ['apple', 'negative', '126344426854416385']
# --> downloading tweet #126344426854416385 (193 of 4784)
# ['apple', 'negative', '126343931117047808']
# --> downloading tweet #126343931117047808 (194 of 4784)
# ['apple', 'negative', '126343679785959424']
# --> downloading tweet #126343679785959424 (195 of 4784)
# ['apple', 'negative', '126343214805426176']
# --> downloading tweet #126343214805426176 (196 of 4784)
# ['apple', 'negative', '126334597431697408']
# --> downloading tweet #126334597431697408 (197 of 4784)
# ['apple', 'negative', '126334188583530496']
# --> downloading tweet #126334188583530496 (198 of 4784)
# ['apple', 'negative', '126331480233353216']
# --> downloading tweet #126331480233353216 (199 of 4784)
# ['apple', 'negative', '126331327271284736']
# --> downloading tweet #126331327271284736 (200 of 4784)
# ['apple', 'negative', '126327808803880960']
# --> downloading tweet #126327808803880960 (201 of 4784)
# ['apple', 'negative', '126324573384871936']
# --> downloading tweet #126324573384871936 (202 of 4784)
# ['apple', 'negative', '126324389741473792']
# --> downloading tweet #126324389741473792 (203 of 4784)
# ['apple', 'negative', '126324077513293824']
# --> downloading tweet #126324077513293824 (204 of 4784)
# ['apple', 'negative', '126321169468100609']
# --> downloading tweet #126321169468100609 (205 of 4784)
# ['apple', 'negative', '126320033369563138']
# --> downloading tweet #126320033369563138 (206 of 4784)
# ['apple', 'negative', '126310645443461121']
# --> downloading tweet #126310645443461121 (207 of 4784)
# ['apple', 'negative', '126309616391950336']
# --> downloading tweet #126309616391950336 (208 of 4784)
# ['apple', 'negative', '126307071984545793']
# --> downloading tweet #126307071984545793 (209 of 4784)
# ['apple', 'negative', '126302386644975616']
# --> downloading tweet #126302386644975616 (210 of 4784)
# ['apple', 'negative', '126299379832336384']
# --> downloading tweet #126299379832336384 (211 of 4784)
# ['apple', 'negative', '126297326565330944']
# --> downloading tweet #126297326565330944 (212 of 4784)
# ['apple', 'negative', '126292335540699136']
# --> downloading tweet #126292335540699136 (213 of 4784)
# ['apple', 'negative', '126286814578348032']
# --> downloading tweet #126286814578348032 (214 of 4784)
# ['apple', 'negative', '126283602571964416']
# --> downloading tweet #126283602571964416 (215 of 4784)
# ['apple', 'negative', '126281019476291585']
# --> downloading tweet #126281019476291585 (216 of 4784)
# ['apple', 'negative', '126280555980529664']
# --> downloading tweet #126280555980529664 (217 of 4784)
# ['apple', 'negative', '126279811151831042']
# --> downloading tweet #126279811151831042 (218 of 4784)
# ['apple', 'negative', '126258214412091392']
# --> downloading tweet #126258214412091392 (219 of 4784)
# ['apple', 'negative', '126257645282799616']
# --> downloading tweet #126257645282799616 (220 of 4784)
# ['apple', 'negative', '126251052667375616']
# --> downloading tweet #126251052667375616 (221 of 4784)
# ['apple', 'negative', '126247557339947008']
# --> downloading tweet #126247557339947008 (222 of 4784)
# ['apple', 'negative', '126243680129523712']
# --> downloading tweet #126243680129523712 (223 of 4784)
# ['apple', 'negative', '126240605419487232']
# --> downloading tweet #126240605419487232 (224 of 4784)
# ['apple', 'negative', '126238223537152001']
# --> downloading tweet #126238223537152001 (225 of 4784)
# ['apple', 'negative', '126221894126022656']
# --> downloading tweet #126221894126022656 (226 of 4784)
# ['apple', 'negative', '126189036644728832']
# --> downloading tweet #126189036644728832 (227 of 4784)
# ['apple', 'negative', '126188946974720000']
# --> downloading tweet #126188946974720000 (228 of 4784)
# ['apple', 'negative', '126188717902802944']
# --> downloading tweet #126188717902802944 (229 of 4784)
# ['apple', 'negative', '126188686453907457']
# --> downloading tweet #126188686453907457 (230 of 4784)
# ['apple', 'negative', '126182880123695104']
# --> downloading tweet #126182880123695104 (231 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=126182880123695104&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=13388457365964653150&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422169822&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=2N0fDuUPBld%2FzlzzzkEAMrfdYgE%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'negative', '126182880123695104'])
# ['apple', 'negative', '126167083334643713']
# --> downloading tweet #126167083334643713 (232 of 4784)
# ['apple', 'negative', '126163315499081728']
# --> downloading tweet #126163315499081728 (233 of 4784)
# ['apple', 'negative', '126163250172801024']
# --> downloading tweet #126163250172801024 (234 of 4784)
# ['apple', 'negative', '126158846375903233']
# --> downloading tweet #126158846375903233 (235 of 4784)
# ['apple', 'negative', '126155291288023040']
# --> downloading tweet #126155291288023040 (236 of 4784)
# ['apple', 'negative', '126150581558591488']
# --> downloading tweet #126150581558591488 (237 of 4784)
# ['apple', 'negative', '126148955217203200']
# --> downloading tweet #126148955217203200 (238 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=126148955217203200&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=11317322485684594391&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422169832&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=pWHgOEd%2BPoKY3eJRzrzn%2Fik7Pew%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'negative', '126148955217203200'])
# ['apple', 'negative', '126148565302128640']
# --> downloading tweet #126148565302128640 (239 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=126148565302128640&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=5571397524341298397&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422169834&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=LU3lHnbR3AfSQjBGkQ%2FZ28nHeM8%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'negative', '126148565302128640'])
# ['apple', 'negative', '126143926523539457']
# --> downloading tweet #126143926523539457 (240 of 4784)
# ['apple', 'negative', '126141380409036800']
# --> downloading tweet #126141380409036800 (241 of 4784)
# ['apple', 'negative', '126141077131497472']
# --> downloading tweet #126141077131497472 (242 of 4784)
# ['apple', 'negative', '126132919117938689']
# --> downloading tweet #126132919117938689 (243 of 4784)
# ['apple', 'negative', '126131535211536384']
# --> downloading tweet #126131535211536384 (244 of 4784)
# ['apple', 'negative', '126129938247061504']
# --> downloading tweet #126129938247061504 (245 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=126129938247061504&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=980821873322406883&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422169842&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=wCIyZ%2FmZImZ%2BNB9mhU6N5intlIU%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'negative', '126129582326816769']
# --> downloading tweet #126129582326816769 (246 of 4784)
# ['apple', 'negative', '126128599030956032']
# --> downloading tweet #126128599030956032 (247 of 4784)
# ['apple', 'negative', '126127465155403777']
# --> downloading tweet #126127465155403777 (248 of 4784)
# ['apple', 'negative', '126118222746497025']
# --> downloading tweet #126118222746497025 (249 of 4784)
# ['apple', 'negative', '126106964420857857']
# --> downloading tweet #126106964420857857 (250 of 4784)
# ['apple', 'negative', '126099775417364480']
# --> downloading tweet #126099775417364480 (251 of 4784)
# ['apple', 'negative', '126096173198082048']
# --> downloading tweet #126096173198082048 (252 of 4784)
# ['apple', 'negative', '126094194312876032']
# --> downloading tweet #126094194312876032 (253 of 4784)
# ['apple', 'negative', '126089287660863488']
# --> downloading tweet #126089287660863488 (254 of 4784)
# ['apple', 'negative', '126088404084588546']
# --> downloading tweet #126088404084588546 (255 of 4784)
# ['apple', 'negative', '126085893353250816']
# --> downloading tweet #126085893353250816 (256 of 4784)
# ['apple', 'negative', '126084068298334208']
# --> downloading tweet #126084068298334208 (257 of 4784)
# ['apple', 'negative', '126082123743502336']
# --> downloading tweet #126082123743502336 (258 of 4784)
# ['apple', 'negative', '126079672386723840']
# --> downloading tweet #126079672386723840 (259 of 4784)
# ['apple', 'negative', '126075115686465536']
# --> downloading tweet #126075115686465536 (260 of 4784)
# ['apple', 'negative', '126073520504569858']
# --> downloading tweet #126073520504569858 (261 of 4784)
# ['apple', 'negative', '126072901144281088']
# --> downloading tweet #126072901144281088 (262 of 4784)
# ['apple', 'negative', '126069614181486593']
# --> downloading tweet #126069614181486593 (263 of 4784)
# ['apple', 'negative', '126068917012668416']
# --> downloading tweet #126068917012668416 (264 of 4784)
# ['apple', 'negative', '126063215842037760']
# --> downloading tweet #126063215842037760 (265 of 4784)
# ['apple', 'negative', '126054048972537856']
# --> downloading tweet #126054048972537856 (266 of 4784)
# ['apple', 'negative', '126053722966069248']
# --> downloading tweet #126053722966069248 (267 of 4784)
# ['apple', 'negative', '126050114518261760']
# --> downloading tweet #126050114518261760 (268 of 4784)
# ['apple', 'negative', '126044756320075776']
# --> downloading tweet #126044756320075776 (269 of 4784)
# ['apple', 'negative', '126044425964109824']
# --> downloading tweet #126044425964109824 (270 of 4784)
# ['apple', 'negative', '126037831301869568']
# --> downloading tweet #126037831301869568 (271 of 4784)
# ['apple', 'negative', '126036793970786304']
# --> downloading tweet #126036793970786304 (272 of 4784)
# ['apple', 'negative', '126034507475337216']
# --> downloading tweet #126034507475337216 (273 of 4784)
# ['apple', 'negative', '126031969166434304']
# --> downloading tweet #126031969166434304 (274 of 4784)
# ['apple', 'negative', '126030936084189184']
# --> downloading tweet #126030936084189184 (275 of 4784)
# ['apple', 'negative', '126029733325582336']
# --> downloading tweet #126029733325582336 (276 of 4784)
# ['apple', 'negative', '126021108641181696']
# --> downloading tweet #126021108641181696 (277 of 4784)
# ['apple', 'negative', '126018120983904256']
# --> downloading tweet #126018120983904256 (278 of 4784)
# ['apple', 'negative', '126016585348558848']
# --> downloading tweet #126016585348558848 (279 of 4784)
# ['apple', 'negative', '126014999444467712']
# --> downloading tweet #126014999444467712 (280 of 4784)
# ['apple', 'negative', '126014540721827840']
# --> downloading tweet #126014540721827840 (281 of 4784)
# ['apple', 'negative', '126012822936231936']
# --> downloading tweet #126012822936231936 (282 of 4784)
# ['apple', 'negative', '126008913400303616']
# --> downloading tweet #126008913400303616 (283 of 4784)
# ['apple', 'negative', '126006966312108032']
# --> downloading tweet #126006966312108032 (284 of 4784)
# ['apple', 'negative', '126006116168642560']
# --> downloading tweet #126006116168642560 (285 of 4784)
# ['apple', 'negative', '126003967552524288']
# --> downloading tweet #126003967552524288 (286 of 4784)
# ['apple', 'negative', '126001775626031105']
# --> downloading tweet #126001775626031105 (287 of 4784)
# ['apple', 'negative', '126001635162992640']
# --> downloading tweet #126001635162992640 (288 of 4784)
# ['apple', 'negative', '125999655011098624']
# --> downloading tweet #125999655011098624 (289 of 4784)
# ['apple', 'negative', '125996379913986048']
# --> downloading tweet #125996379913986048 (290 of 4784)
# ['apple', 'negative', '125995264325599233']
# --> downloading tweet #125995264325599233 (291 of 4784)
# ['apple', 'negative', '125994965183635456']
# --> downloading tweet #125994965183635456 (292 of 4784)
# ['apple', 'negative', '125994596336533504']
# --> downloading tweet #125994596336533504 (293 of 4784)
# ['apple', 'negative', '125989051101741056']
# --> downloading tweet #125989051101741056 (294 of 4784)
# ['apple', 'negative', '125987979784224770']
# --> downloading tweet #125987979784224770 (295 of 4784)
# ['apple', 'negative', '125987439692099584']
# --> downloading tweet #125987439692099584 (296 of 4784)
# ['apple', 'negative', '125982320917364736']
# --> downloading tweet #125982320917364736 (297 of 4784)
# ['apple', 'negative', '125980659415138304']
# --> downloading tweet #125980659415138304 (298 of 4784)
# ['apple', 'negative', '125978454146551808']
# --> downloading tweet #125978454146551808 (299 of 4784)
# ['apple', 'negative', '125976113657823232']
# --> downloading tweet #125976113657823232 (300 of 4784)
# ['apple', 'negative', '125974886006005760']
# --> downloading tweet #125974886006005760 (301 of 4784)
# ['apple', 'negative', '125974351035117568']
# --> downloading tweet #125974351035117568 (302 of 4784)
# ['apple', 'negative', '125973390283653120']
# --> downloading tweet #125973390283653120 (303 of 4784)
# ['apple', 'negative', '125969932285513728']
# --> downloading tweet #125969932285513728 (304 of 4784)
# ['apple', 'negative', '125966385259098112']
# --> downloading tweet #125966385259098112 (305 of 4784)
# ['apple', 'negative', '125965988146585601']
# --> downloading tweet #125965988146585601 (306 of 4784)
# ['apple', 'negative', '125965853769478144']
# --> downloading tweet #125965853769478144 (307 of 4784)
# ['apple', 'negative', '125964314220830722']
# --> downloading tweet #125964314220830722 (308 of 4784)
# ['apple', 'negative', '125963262733991936']
# --> downloading tweet #125963262733991936 (309 of 4784)
# ['apple', 'negative', '125961999791308800']
# --> downloading tweet #125961999791308800 (310 of 4784)
# ['apple', 'negative', '125961793926475776']
# --> downloading tweet #125961793926475776 (311 of 4784)
# ['apple', 'negative', '125960026891362304']
# --> downloading tweet #125960026891362304 (312 of 4784)
# ['apple', 'negative', '125958961269702656']
# --> downloading tweet #125958961269702656 (313 of 4784)
# ['apple', 'negative', '125958368773943296']
# --> downloading tweet #125958368773943296 (314 of 4784)
# ['apple', 'negative', '125956505768960000']
# --> downloading tweet #125956505768960000 (315 of 4784)
# ['apple', 'negative', '125956403574747137']
# --> downloading tweet #125956403574747137 (316 of 4784)
# ['apple', 'negative', '125956319344721920']
# --> downloading tweet #125956319344721920 (317 of 4784)
# ['apple', 'negative', '125953600861126656']
# --> downloading tweet #125953600861126656 (318 of 4784)
# ['apple', 'negative', '125950557310562305']
# --> downloading tweet #125950557310562305 (319 of 4784)
# ['apple', 'negative', '125945821240885248']
# --> downloading tweet #125945821240885248 (320 of 4784)
# ['apple', 'negative', '125943204943114240']
# --> downloading tweet #125943204943114240 (321 of 4784)
# ['apple', 'negative', '125937228328341504']
# --> downloading tweet #125937228328341504 (322 of 4784)
# ['apple', 'negative', '125930406125117440']
# --> downloading tweet #125930406125117440 (323 of 4784)
# ['apple', 'negative', '125929899071516676']
# --> downloading tweet #125929899071516676 (324 of 4784)
# ['apple', 'negative', '125929395264299009']
# --> downloading tweet #125929395264299009 (325 of 4784)
# ['apple', 'negative', '125920912171216896']
# --> downloading tweet #125920912171216896 (326 of 4784)
# ['apple', 'negative', '125876542600519681']
# --> downloading tweet #125876542600519681 (327 of 4784)
# ['apple', 'negative', '125863232249405440']
# --> downloading tweet #125863232249405440 (328 of 4784)
# ['apple', 'negative', '125846659182764032']
# --> downloading tweet #125846659182764032 (329 of 4784)
# ['apple', 'negative', '125845538926112768']
# --> downloading tweet #125845538926112768 (330 of 4784)
# ['apple', 'negative', '125826259048607744']
# --> downloading tweet #125826259048607744 (331 of 4784)
# ['apple', 'negative', '125824148579692544']
# --> downloading tweet #125824148579692544 (332 of 4784)
# ['apple', 'negative', '125822115155947520']
# --> downloading tweet #125822115155947520 (333 of 4784)
# ['apple', 'negative', '125819194049699840']
# --> downloading tweet #125819194049699840 (334 of 4784)
# ['apple', 'negative', '125815370513793024']
# --> downloading tweet #125815370513793024 (335 of 4784)
# ['apple', 'negative', '125807830363156480']
# --> downloading tweet #125807830363156480 (336 of 4784)
# ['apple', 'negative', '125806568389361664']
# --> downloading tweet #125806568389361664 (337 of 4784)
# ['apple', 'negative', '125806240138928128']
# --> downloading tweet #125806240138928128 (338 of 4784)
# ['apple', 'negative', '125794703819030528']
# --> downloading tweet #125794703819030528 (339 of 4784)
# ['apple', 'negative', '125731810733867011']
# --> downloading tweet #125731810733867011 (340 of 4784)
# ['apple', 'negative', '125729727653756928']
# --> downloading tweet #125729727653756928 (341 of 4784)
# ['apple', 'negative', '125722107710672896']
# --> downloading tweet #125722107710672896 (342 of 4784)
# ['apple', 'negative', '125717447276904448']
# --> downloading tweet #125717447276904448 (343 of 4784)
# ['apple', 'negative', '125717161531551744']
# --> downloading tweet #125717161531551744 (344 of 4784)
# ['apple', 'negative', '125713100782575616']
# --> downloading tweet #125713100782575616 (345 of 4784)
# ['apple', 'negative', '125712104253702146']
# --> downloading tweet #125712104253702146 (346 of 4784)
# ['apple', 'negative', '125710089716899840']
# --> downloading tweet #125710089716899840 (347 of 4784)
# ['apple', 'negative', '125708348237680640']
# --> downloading tweet #125708348237680640 (348 of 4784)
# ['apple', 'negative', '125706246056706049']
# --> downloading tweet #125706246056706049 (349 of 4784)
# ['apple', 'negative', '125701785540235264']
# --> downloading tweet #125701785540235264 (350 of 4784)
# ['apple', 'negative', '125691072398639104']
# --> downloading tweet #125691072398639104 (351 of 4784)
# ['apple', 'negative', '125689691927351296']
# --> downloading tweet #125689691927351296 (352 of 4784)
# ['apple', 'negative', '125681125376000000']
# --> downloading tweet #125681125376000000 (353 of 4784)
# ['apple', 'negative', '125679166015283203']
# --> downloading tweet #125679166015283203 (354 of 4784)
# ['apple', 'negative', '125665094561574913']
# --> downloading tweet #125665094561574913 (355 of 4784)
# ['apple', 'negative', '125664507757461504']
# --> downloading tweet #125664507757461504 (356 of 4784)
# ['apple', 'negative', '125663477573500930']
# --> downloading tweet #125663477573500930 (357 of 4784)
# ['apple', 'negative', '125661140939321344']
# --> downloading tweet #125661140939321344 (358 of 4784)
# ['apple', 'negative', '125657359841361920']
# --> downloading tweet #125657359841361920 (359 of 4784)
# ['apple', 'negative', '125656559190683651']
# --> downloading tweet #125656559190683651 (360 of 4784)
# Rate limiting requests us to wait 634.907754 seconds
# ['apple', 'negative', '125654540455378945']
# --> downloading tweet #125654540455378945 (361 of 4784)
# ['apple', 'negative', '125651769261965312']
# --> downloading tweet #125651769261965312 (362 of 4784)
# ['apple', 'negative', '125649285667749889']
# --> downloading tweet #125649285667749889 (363 of 4784)
# ['apple', 'negative', '125645811903250432']
# --> downloading tweet #125645811903250432 (364 of 4784)
# ['apple', 'negative', '125643054190305280']
# --> downloading tweet #125643054190305280 (365 of 4784)
# ['apple', 'negative', '125642742977138689']
# --> downloading tweet #125642742977138689 (366 of 4784)
# ...
# ['apple', 'neutral', '126049560878526464']
# --> downloading tweet #126049560878526464 (614 of 4784)
# ['apple', 'neutral', '126044055644807169']
# --> downloading tweet #126044055644807169 (615 of 4784)
# ['apple', 'neutral', '126042506717704192']
# --> downloading tweet #126042506717704192 (616 of 4784)
# ['apple', 'neutral', '126041773356232704']
# --> downloading tweet #126041773356232704 (617 of 4784)
# ['apple', 'neutral', '126041570876203009']
# --> downloading tweet #126041570876203009 (618 of 4784)
# ['apple', 'neutral', '126040050441011200']
# --> downloading tweet #126040050441011200 (619 of 4784)
# ['apple', 'neutral', '126039521853845504']
# --> downloading tweet #126039521853845504 (620 of 4784)
# ['apple', 'neutral', '126031463647944704']
# --> downloading tweet #126031463647944704 (621 of 4784)
# ['apple', 'neutral', '126030091892432896']
# --> downloading tweet #126030091892432896 (622 of 4784)
# ['apple', 'neutral', '126022527578406912']
# --> downloading tweet #126022527578406912 (623 of 4784)
# ['apple', 'neutral', '126019432194650113']
# --> downloading tweet #126019432194650113 (624 of 4784)
# ['apple', 'neutral', '126018538531061760']
# --> downloading tweet #126018538531061760 (625 of 4784)
# ['apple', 'neutral', '126017643747606528']
# --> downloading tweet #126017643747606528 (626 of 4784)
# ['apple', 'neutral', '126016494701256704']
# --> downloading tweet #126016494701256704 (627 of 4784)
# ['apple', 'neutral', '126016405085757440']
# --> downloading tweet #126016405085757440 (628 of 4784)
# ['apple', 'neutral', '126014643826208768']
# --> downloading tweet #126014643826208768 (629 of 4784)
# ['apple', 'neutral', '126014277814468608']
# --> downloading tweet #126014277814468608 (630 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=126014277814468608&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=5102990890359144928&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422171691&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=bpcxAuP4jXOAqsTBoZJ2oC6VPdo%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'neutral', '126014277814468608'])
# ['apple', 'neutral', '126014214467895297']
# --> downloading tweet #126014214467895297 (631 of 4784)
# ['apple', 'neutral', '126014102379302912']
# --> downloading tweet #126014102379302912 (632 of 4784)
# ['apple', 'neutral', '126013626426466304']
# --> downloading tweet #126013626426466304 (633 of 4784)
# ['apple', 'neutral', '126012833128390656']
# --> downloading tweet #126012833128390656 (634 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=126012833128390656&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=6607868872926661933&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422171697&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=rmRIhJUHXr2MXLah0ppxXvREcZM%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'neutral', '126012515019784192']
# --> downloading tweet #126012515019784192 (635 of 4784)
# ['apple', 'neutral', '126012034545496065']
# --> downloading tweet #126012034545496065 (636 of 4784)
# ['apple', 'neutral', '126012004312956928']
# --> downloading tweet #126012004312956928 (637 of 4784)
# ['apple', 'neutral', '126011120694726656']
# --> downloading tweet #126011120694726656 (638 of 4784)
# ['apple', 'neutral', '126010471202566144']
# --> downloading tweet #126010471202566144 (639 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=126010471202566144&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=4014585573630463967&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422171704&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=kPm2D7K%2FXr21rnBLMzfG8h7uZjI%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'neutral', '126010471202566144'])
# ['apple', 'neutral', '126009386022879232']
# --> downloading tweet #126009386022879232 (640 of 4784)
# Twitter sent status 403 for URL: 1.1/statuses/show.json using parameters: (id=126009386022879232&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=15043824807246468574&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422171706&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=B4hy8lldzLNtf2TbV0M5brr4Hvc%3D)
# details: {"errors":[{"code":179,"message":"Sorry, you are not authorized to see this status."}]}
# Not authorized to view this tweet.
# ['apple', 'neutral', '126008776322064384']
# --> downloading tweet #126008776322064384 (641 of 4784)
# ['apple', 'neutral', '126007705600135168']
# --> downloading tweet #126007705600135168 (642 of 4784)
# ['apple', 'neutral', '126006572420833282']
# --> downloading tweet #126006572420833282 (643 of 4784)
# ['apple', 'neutral', '126006349959135232']
# --> downloading tweet #126006349959135232 (644 of 4784)
# ['apple', 'neutral', '126004552557273088']
# --> downloading tweet #126004552557273088 (645 of 4784)
# ['apple', 'neutral', '126003746135224320']
# --> downloading tweet #126003746135224320 (646 of 4784)
# ['apple', 'neutral', '126003567315255296']
# --> downloading tweet #126003567315255296 (647 of 4784)
# ['apple', 'neutral', '126001989309054976']
# --> downloading tweet #126001989309054976 (648 of 4784)
# ['apple', 'neutral', '126001758853009409']
# --> downloading tweet #126001758853009409 (649 of 4784)
# ['apple', 'neutral', '126000843798491136']
# --> downloading tweet #126000843798491136 (650 of 4784)
# ['apple', 'neutral', '125999022908510209']
# --> downloading tweet #125999022908510209 (651 of 4784)
# ['apple', 'neutral', '125996330500890624']
# --> downloading tweet #125996330500890624 (652 of 4784)
# ['apple', 'neutral', '125994518989385729']
# --> downloading tweet #125994518989385729 (653 of 4784)
# ['apple', 'neutral', '125993702782025729']
# --> downloading tweet #125993702782025729 (654 of 4784)
# ['apple', 'neutral', '125993105722839040']
# --> downloading tweet #125993105722839040 (655 of 4784)
# ['apple', 'neutral', '125992838910586880']
# --> downloading tweet #125992838910586880 (656 of 4784)
# ['apple', 'neutral', '125991449455104000']
# --> downloading tweet #125991449455104000 (657 of 4784)
# ['apple', 'neutral', '125990236743405568']
# --> downloading tweet #125990236743405568 (658 of 4784)
# ['apple', 'neutral', '125990217801940992']
# --> downloading tweet #125990217801940992 (659 of 4784)
# ['apple', 'neutral', '125989605634879488']
# --> downloading tweet #125989605634879488 (660 of 4784)
# ['apple', 'neutral', '125989196132388864']
# --> downloading tweet #125989196132388864 (661 of 4784)
# ['apple', 'neutral', '125989009091592192']
# --> downloading tweet #125989009091592192 (662 of 4784)
# ['apple', 'neutral', '125988775548559360']
# --> downloading tweet #125988775548559360 (663 of 4784)
# ['apple', 'neutral', '125984350989860864']
# --> downloading tweet #125984350989860864 (664 of 4784)
# ['apple', 'neutral', '125983179877253120']
# --> downloading tweet #125983179877253120 (665 of 4784)
# ['apple', 'neutral', '125980918220464128']
# --> downloading tweet #125980918220464128 (666 of 4784)
# ['apple', 'neutral', '125980676653723648']
# --> downloading tweet #125980676653723648 (667 of 4784)
# ['apple', 'neutral', '125979228452818944']
# --> downloading tweet #125979228452818944 (668 of 4784)
# ['apple', 'neutral', '125978290367381504']
# --> downloading tweet #125978290367381504 (669 of 4784)
# ['apple', 'neutral', '125975779447291904']
# --> downloading tweet #125975779447291904 (670 of 4784)
# ['apple', 'neutral', '125974955983769603']
# --> downloading tweet #125974955983769603 (671 of 4784)
# ['apple', 'neutral', '125972882240188416']
# --> downloading tweet #125972882240188416 (672 of 4784)
# ['apple', 'neutral', '125969677997453312']
# --> downloading tweet #125969677997453312 (673 of 4784)
# ['apple', 'neutral', '125969128514260992']
# --> downloading tweet #125969128514260992 (674 of 4784)
# ['apple', 'neutral', '125967560171720704']
# --> downloading tweet #125967560171720704 (675 of 4784)
# ['apple', 'neutral', '125967126912712705']
# --> downloading tweet #125967126912712705 (676 of 4784)
# ['apple', 'neutral', '125965569659895808']
# --> downloading tweet #125965569659895808 (677 of 4784)
# ['apple', 'neutral', '125963773176582144']
# --> downloading tweet #125963773176582144 (678 of 4784)
# ['apple', 'neutral', '125962667541270528']
# --> downloading tweet #125962667541270528 (679 of 4784)
# ['apple', 'neutral', '125962608519036928']
# --> downloading tweet #125962608519036928 (680 of 4784)
# ['apple', 'neutral', '125961033348153345']
# --> downloading tweet #125961033348153345 (681 of 4784)
# ['apple', 'neutral', '125960438981734400']
# --> downloading tweet #125960438981734400 (682 of 4784)
# ['apple', 'neutral', '125958525708021760']
# --> downloading tweet #125958525708021760 (683 of 4784)
# ['apple', 'neutral', '125958117086347264']
# --> downloading tweet #125958117086347264 (684 of 4784)
# ['apple', 'neutral', '125957965109932032']
# --> downloading tweet #125957965109932032 (685 of 4784)
# ['apple', 'neutral', '125951303770845185']
# --> downloading tweet #125951303770845185 (686 of 4784)
# ['apple', 'neutral', '125950941349421057']
# --> downloading tweet #125950941349421057 (687 of 4784)
# ['apple', 'neutral', '125950505389273090']
# --> downloading tweet #125950505389273090 (688 of 4784)
# ['apple', 'neutral', '125948450620702720']
# --> downloading tweet #125948450620702720 (689 of 4784)
# ['apple', 'neutral', '125944856504827904']
# --> downloading tweet #125944856504827904 (690 of 4784)
# ['apple', 'neutral', '125944293671182336']
# --> downloading tweet #125944293671182336 (691 of 4784)
# ['apple', 'neutral', '125943115449253888']
# --> downloading tweet #125943115449253888 (692 of 4784)
# ['apple', 'neutral', '125943078837161984']
# --> downloading tweet #125943078837161984 (693 of 4784)
# ['apple', 'neutral', '125943020767019008']
# --> downloading tweet #125943020767019008 (694 of 4784)
# ['apple', 'neutral', '125940398915977217']
# --> downloading tweet #125940398915977217 (695 of 4784)
# ['apple', 'neutral', '125940300987371521']
# --> downloading tweet #125940300987371521 (696 of 4784)
# ['apple', 'neutral', '125939862078619648']
# --> downloading tweet #125939862078619648 (697 of 4784)
# ['apple', 'neutral', '125939833775460352']
# --> downloading tweet #125939833775460352 (698 of 4784)
# ['apple', 'neutral', '125938918540574720']
# --> downloading tweet #125938918540574720 (699 of 4784)
# ['apple', 'neutral', '125938325151432706']
# --> downloading tweet #125938325151432706 (700 of 4784)
# ['apple', 'neutral', '125936985796919296']
# --> downloading tweet #125936985796919296 (701 of 4784)
# ['apple', 'neutral', '125936323273048065']
# --> downloading tweet #125936323273048065 (702 of 4784)
# ['apple', 'neutral', '125935636300570624']
# --> downloading tweet #125935636300570624 (703 of 4784)
# ['apple', 'neutral', '125935627056324609']
# --> downloading tweet #125935627056324609 (704 of 4784)
# ['apple', 'neutral', '125935503752171520']
# --> downloading tweet #125935503752171520 (705 of 4784)
# ['apple', 'neutral', '125935314878476289']
# --> downloading tweet #125935314878476289 (706 of 4784)
# ['apple', 'neutral', '125933630613766144']
# --> downloading tweet #125933630613766144 (707 of 4784)
# ['apple', 'neutral', '125930342891790337']
# --> downloading tweet #125930342891790337 (708 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=125930342891790337&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=3630456550751073749&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422171807&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=wTL1ew4R6%2FTCy%2Bt9T4exzNKeCPc%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'neutral', '125930342891790337'])
# ['apple', 'neutral', '125930143066759169']
# --> downloading tweet #125930143066759169 (709 of 4784)
# ['apple', 'neutral', '125930002607906816']
# --> downloading tweet #125930002607906816 (710 of 4784)
# ['apple', 'neutral', '125927540249473024']
# --> downloading tweet #125927540249473024 (711 of 4784)
# ['apple', 'neutral', '125927536847880192']
# --> downloading tweet #125927536847880192 (712 of 4784)
# ['apple', 'neutral', '125927533614084097']
# --> downloading tweet #125927533614084097 (713 of 4784)
# ['apple', 'neutral', '125927530761953281']
# --> downloading tweet #125927530761953281 (714 of 4784)
# ['apple', 'neutral', '125927399010467840']
# --> downloading tweet #125927399010467840 (715 of 4784)
# ['apple', 'neutral', '125927174514540544']
# --> downloading tweet #125927174514540544 (716 of 4784)
# ['apple', 'neutral', '125927032185044992']
# --> downloading tweet #125927032185044992 (717 of 4784)
# ['apple', 'neutral', '125926624930693121']
# --> downloading tweet #125926624930693121 (718 of 4784)
# ['apple', 'neutral', '125922989844856833']
# --> downloading tweet #125922989844856833 (719 of 4784)
# ['apple', 'neutral', '125922500839342080']
# --> downloading tweet #125922500839342080 (720 of 4784)
# Twitter sent status 404 for URL: 1.1/statuses/show.json using parameters: (id=125922500839342080&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=17971050497914776261&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422171824&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=lFbEU%2FhSBSIOcMx%2FaV%2FEkWsjErQ%3D)
# details: {"errors":[{"message":"Sorry, that page does not exist","code":34}]}
# ('Tweet missing: ', ['apple', 'neutral', '125922500839342080'])
# ['apple', 'neutral', '125922174648324096']
# --> downloading tweet #125922174648324096 (721 of 4784)
# Twitter sent status 429 for URL: 1.1/statuses/show.json using parameters: (id=125922174648324096&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=2479945985998707104&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422171826&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=cgedAlP%2FEWFC2ItVYmy8MZjIS44%3D)
# details: {"errors":[{"message":"Rate limit exceeded","code":88}]}
# Rate limit exceeded.
# ---------------------------------------------------------------------------
# TwitterHTTPError                          Traceback (most recent call last)
# <ipython-input-12-deea02f71866> in <module>()
#     310
#     311 if __name__ == '__main__':
# --> 312     main()
#
# <ipython-input-12-deea02f71866> in main()
#     293     if fetch_list:
#     294         # start fetching data from twitter
# --> 295         download_tweets(fetch_list, user_params['rawDir'])
#     296
#     297         # second pass for any failed downloads
#
# <ipython-input-12-deea02f71866> in download_tweets(fetch_list, raw_dir)
#     161         try:
#     162             #import pdb;pdb.set_trace()
# --> 163             response = api.statuses.show(_id=item[2])
#     164
#     165             if response.rate_limit_remaining <= 0:
#
# /usr/lib/python2.7/site-packages/twitter/api.pyc in __call__(self, **kwargs)
#     264
#     265         req = urllib_request.Request(uriBase, body, headers)
# --> 266         return self._handle_response(req, uri, arg_data, _timeout)
#     267
#     268     def _handle_response(self, req, uri, arg_data, _timeout=None):
#
# /usr/lib/python2.7/site-packages/twitter/api.pyc in _handle_response(self, req, uri, arg_data, _timeout)
#     297                 return []
#     298             else:
# --> 299                 raise TwitterHTTPError(e, uri, self.format, arg_data)
#     300
#     301
#
# TwitterHTTPError: Twitter sent status 429 for URL: 1.1/statuses/show.json using parameters: (id=125922174648324096&oauth_consumer_key=GcRkL0gdhohaKsn0FqQLWEp8y&oauth_nonce=2479945985998707104&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1422171826&oauth_token=50568370-23CcdsyaeI2vK5QuGlRn1IlQHjD1Aubm2yfjTTAPz&oauth_version=1.0&oauth_signature=cgedAlP%2FEWFC2ItVYmy8MZjIS44%3D)
# details: {"errors":[{"message":"Rate limit exceeded","code":88}]}

# %%
# %load 01_start.py

# %%
# This code is supporting material for the book
# Building Machine Learning Systems with Python
# by Willi Richert and Luis Pedro Coelho
# published by PACKT Publishing
#
# It is made available under the MIT License

#
# This script trains multinomial Naive Bayes on the tweet corpus
# to find two different results:
# - How well can we distinguis positive from negative tweets?
# - How well can we detect whether a tweet contains sentiment at all?
#

import time
start_time = time.time()

import numpy as np

from sklearn.metrics import precision_recall_curve, roc_curve, auc
from sklearn.cross_validation import ShuffleSplit

from utils import plot_pr
from utils import load_sanders_data
from utils import tweak_labels

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline

from sklearn.naive_bayes import MultinomialNB


def create_ngram_model():
    tfidf_ngrams = TfidfVectorizer(ngram_range=(1, 3),
                                   analyzer="word", binary=False)
    clf = MultinomialNB()
    pipeline = Pipeline([('vect', tfidf_ngrams), ('clf', clf)])
    return pipeline


def train_model(clf_factory, X, Y, name="NB ngram", plot=False):
    cv = ShuffleSplit(
        n=len(X), n_iter=10, test_size=0.3, random_state=0)

    train_errors = []
    test_errors = []

    scores = []
    pr_scores = []
    precisions, recalls, thresholds = [], [], []

    for train, test in cv:
        X_train, y_train = X[train], Y[train]
        X_test, y_test = X[test], Y[test]

        clf = clf_factory()
        clf.fit(X_train, y_train)

        train_score = clf.score(X_train, y_train)
        test_score = clf.score(X_test, y_test)

        train_errors.append(1 - train_score)
        test_errors.append(1 - test_score)

        scores.append(test_score)
        proba = clf.predict_proba(X_test)

        fpr, tpr, roc_thresholds = roc_curve(y_test, proba[:, 1])
        precision, recall, pr_thresholds = precision_recall_curve(
            y_test, proba[:, 1])

        pr_scores.append(auc(recall, precision))
        precisions.append(precision)
        recalls.append(recall)
        thresholds.append(pr_thresholds)

    scores_to_sort = pr_scores
    median = np.argsort(scores_to_sort)[len(scores_to_sort) / 2]

    if plot:
        plot_pr(pr_scores[median], name, "01", precisions[median],
                recalls[median], label=name)

        summary = (np.mean(scores), np.std(scores),
                   np.mean(pr_scores), np.std(pr_scores))
        print("%.3f\t%.3f\t%.3f\t%.3f\t" % summary)

    return np.mean(train_errors), np.mean(test_errors)


def print_incorrect(clf, X, Y):
    Y_hat = clf.predict(X)
    wrong_idx = Y_hat != Y
    X_wrong = X[wrong_idx]
    Y_wrong = Y[wrong_idx]
    Y_hat_wrong = Y_hat[wrong_idx]
    for idx in range(len(X_wrong)):
        print("clf.predict('%s')=%i instead of %i" %
              (X_wrong[idx], Y_hat_wrong[idx], Y_wrong[idx]))


if __name__ == "__main__":
    X_orig, Y_orig = load_sanders_data()
    classes = np.unique(Y_orig)
    for c in classes:
        print("#%s: %i" % (c, sum(Y_orig == c)))

    print("== Pos vs. neg ==")
    pos_neg = np.logical_or(Y_orig == "positive", Y_orig == "negative")
    X = X_orig[pos_neg]
    Y = Y_orig[pos_neg]
    Y = tweak_labels(Y, ["positive"])

    train_model(create_ngram_model, X, Y, name="pos vs neg", plot=True)

    print("== Pos/neg vs. irrelevant/neutral ==")
    X = X_orig
    Y = tweak_labels(Y_orig, ["positive", "negative"])
    train_model(create_ngram_model, X, Y, name="sent vs rest", plot=True)

    print("== Pos vs. rest ==")
    X = X_orig
    Y = tweak_labels(Y_orig, ["positive"])
    train_model(create_ngram_model, X, Y, name="pos vs rest", plot=True)

    print("== Neg vs. rest ==")
    X = X_orig
    Y = tweak_labels(Y_orig, ["negative"])
    train_model(create_ngram_model, X, Y, name="neg vs rest", plot=True)

    print("time spent:", time.time() - start_time)
# Out:
# Tweet 'data/./rawdata/126394830791254016.json' not found. Skip.
# Tweet 'data/./rawdata/126366123368267776.json' not found. Skip.
# Tweet 'data/./rawdata/126354605130002432.json' not found. Skip.
# Tweet 'data/./rawdata/126350948548354048.json' not found. Skip.
# Tweet 'data/./rawdata/126350302113824769.json' not found. Skip.
# Tweet 'data/./rawdata/126344048637259776.json' not found. Skip.
# Tweet 'data/./rawdata/126323785145126912.json' not found. Skip.
# Tweet 'data/./rawdata/126319186141130752.json' not found. Skip.
# Tweet 'data/./rawdata/126312877916307458.json' not found. Skip.
# Tweet 'data/./rawdata/126267185025916928.json' not found. Skip.
# Tweet 'data/./rawdata/126213333123743744.json' not found. Skip.
# Tweet 'data/./rawdata/126148685737361408.json' not found. Skip.
# Tweet 'data/./rawdata/126130991365500928.json' not found. Skip.
# Tweet 'data/./rawdata/126093298619252737.json' not found. Skip.
# Tweet 'data/./rawdata/126079414986485761.json' not found. Skip.
# Tweet 'data/./rawdata/126076743613284354.json' not found. Skip.
# Tweet 'data/./rawdata/126063569660936193.json' not found. Skip.
# Tweet 'data/./rawdata/126063358037340161.json' not found. Skip.
# Tweet 'data/./rawdata/126059399319003136.json' not found. Skip.
# Tweet 'data/./rawdata/126049183865114624.json' not found. Skip.
# Tweet 'data/./rawdata/126040352237961217.json' not found. Skip.
# Tweet 'data/./rawdata/126039929523404801.json' not found. Skip.
# Tweet 'data/./rawdata/126015087386431488.json' not found. Skip.
# Tweet 'data/./rawdata/126008369562652672.json' not found. Skip.
# Tweet 'data/./rawdata/125995158679461888.json' not found. Skip.
# Tweet 'data/./rawdata/125979338846900224.json' not found. Skip.
# Tweet 'data/./rawdata/125978473712979969.json' not found. Skip.
# Tweet 'data/./rawdata/125954443643588608.json' not found. Skip.
# Tweet 'data/./rawdata/125947232359948288.json' not found. Skip.
# Tweet 'data/./rawdata/125943290288803841.json' not found. Skip.
# Tweet 'data/./rawdata/125932869389524992.json' not found. Skip.
# Tweet 'data/./rawdata/125930171562852353.json' not found. Skip.
# Tweet 'data/./rawdata/125910633731461120.json' not found. Skip.
# Tweet 'data/./rawdata/125909565031198720.json' not found. Skip.
# Tweet 'data/./rawdata/125907732388790272.json' not found. Skip.
# Tweet 'data/./rawdata/125898611572740097.json' not found. Skip.
# Tweet 'data/./rawdata/125816853867151360.json' not found. Skip.
# Tweet 'data/./rawdata/125727629012770816.json' not found. Skip.
# Tweet 'data/./rawdata/125688922410975232.json' not found. Skip.
# Tweet 'data/./rawdata/125685656415510528.json' not found. Skip.
# Tweet 'data/./rawdata/125673004511412224.json' not found. Skip.
# Tweet 'data/./rawdata/125665606853861376.json' not found. Skip.
# Tweet 'data/./rawdata/125633065757310976.json' not found. Skip.
# Tweet 'data/./rawdata/125616280215617537.json' not found. Skip.
# Tweet 'data/./rawdata/125595292304281601.json' not found. Skip.
# Tweet 'data/./rawdata/125536884813336576.json' not found. Skip.
# Tweet 'data/./rawdata/125533599737978882.json' not found. Skip.
# Tweet 'data/./rawdata/125458901192810496.json' not found. Skip.
# Tweet 'data/./rawdata/125445056218923008.json' not found. Skip.
# Tweet 'data/./rawdata/125422502284505088.json' not found. Skip.
# Tweet 'data/./rawdata/125402636764712960.json' not found. Skip.
# Tweet 'data/./rawdata/125330595302744064.json' not found. Skip.
# Tweet 'data/./rawdata/125281706327552001.json' not found. Skip.
# Tweet 'data/./rawdata/125279447669669888.json' not found. Skip.
# Tweet 'data/./rawdata/125264731035537409.json' not found. Skip.
# Tweet 'data/./rawdata/125251672896323584.json' not found. Skip.
# Tweet 'data/./rawdata/125243911538098176.json' not found. Skip.
# Tweet 'data/./rawdata/126400637930979329.json' not found. Skip.
# Tweet 'data/./rawdata/126391082308206593.json' not found. Skip.
# Tweet 'data/./rawdata/126328782700285952.json' not found. Skip.
# Tweet 'data/./rawdata/126325125749542913.json' not found. Skip.
# Tweet 'data/./rawdata/126312535203921920.json' not found. Skip.
# Tweet 'data/./rawdata/126311879218966529.json' not found. Skip.
# Tweet 'data/./rawdata/126308005779210241.json' not found. Skip.
# Tweet 'data/./rawdata/126304942049853441.json' not found. Skip.
# Tweet 'data/./rawdata/126297241190281216.json' not found. Skip.
# Tweet 'data/./rawdata/126295434862936064.json' not found. Skip.
# Tweet 'data/./rawdata/126282994821509120.json' not found. Skip.
# Tweet 'data/./rawdata/126270073420791810.json' not found. Skip.
# Tweet 'data/./rawdata/126264313563459585.json' not found. Skip.
# Tweet 'data/./rawdata/126239832895795200.json' not found. Skip.
# Tweet 'data/./rawdata/126182880123695104.json' not found. Skip.
# Tweet 'data/./rawdata/126156590662422528.json' not found. Skip.
# Tweet 'data/./rawdata/126153311521996800.json' not found. Skip.
# Tweet 'data/./rawdata/126148955217203200.json' not found. Skip.
# Tweet 'data/./rawdata/126148565302128640.json' not found. Skip.
# Tweet 'data/./rawdata/126140389873827841.json' not found. Skip.
# Tweet 'data/./rawdata/126129938247061504.json' not found. Skip.
# Tweet 'data/./rawdata/126126605344047105.json' not found. Skip.
# Tweet 'data/./rawdata/126121175926571009.json' not found. Skip.
# Tweet 'data/./rawdata/126082198720888833.json' not found. Skip.
# Tweet 'data/./rawdata/126073788323479552.json' not found. Skip.
# Tweet 'data/./rawdata/126070647125327872.json' not found. Skip.
# Tweet 'data/./rawdata/126060639268507649.json' not found. Skip.
# Tweet 'data/./rawdata/126042137740574720.json' not found. Skip.
# Tweet 'data/./rawdata/126042022900547584.json' not found. Skip.
# Tweet 'data/./rawdata/126033747991736320.json' not found. Skip.
# Tweet 'data/./rawdata/126012404332113920.json' not found. Skip.
# Tweet 'data/./rawdata/126012089415380992.json' not found. Skip.
# Tweet 'data/./rawdata/126006088725303296.json' not found. Skip.
# Tweet 'data/./rawdata/126004661248471040.json' not found. Skip.
# Tweet 'data/./rawdata/125988395787882497.json' not found. Skip.
# Tweet 'data/./rawdata/125974810021998595.json' not found. Skip.
# Tweet 'data/./rawdata/125969502587465729.json' not found. Skip.
# Tweet 'data/./rawdata/125954651152592896.json' not found. Skip.
# Tweet 'data/./rawdata/125934808592433153.json' not found. Skip.
# Tweet 'data/./rawdata/125836461936361472.json' not found. Skip.
# Tweet 'data/./rawdata/125824054958637056.json' not found. Skip.
# Tweet 'data/./rawdata/125814380871946240.json' not found. Skip.
# Tweet 'data/./rawdata/125812985301172224.json' not found. Skip.
# Tweet 'data/./rawdata/125811345064067072.json' not found. Skip.
# Tweet 'data/./rawdata/125799384976863232.json' not found. Skip.
# Tweet 'data/./rawdata/125794882257305600.json' not found. Skip.
# Tweet 'data/./rawdata/125728250579259392.json' not found. Skip.
# Tweet 'data/./rawdata/125722610179907584.json' not found. Skip.
# Tweet 'data/./rawdata/125711996074209280.json' not found. Skip.
# Tweet 'data/./rawdata/125694815743651840.json' not found. Skip.
# Tweet 'data/./rawdata/125692685033021441.json' not found. Skip.
# Tweet 'data/./rawdata/125692532750430209.json' not found. Skip.
# Tweet 'data/./rawdata/125681375058735104.json' not found. Skip.
# Tweet 'data/./rawdata/125675806977556480.json' not found. Skip.
# Tweet 'data/./rawdata/125673358418391041.json' not found. Skip.
# Tweet 'data/./rawdata/125659125886623744.json' not found. Skip.
# Tweet 'data/./rawdata/125656618326175745.json' not found. Skip.
# Tweet 'data/./rawdata/125619303356710912.json' not found. Skip.
# Tweet 'data/./rawdata/125607492356018176.json' not found. Skip.
# Tweet 'data/./rawdata/125588697872728065.json' not found. Skip.
# Tweet 'data/./rawdata/125578269197217792.json' not found. Skip.
# Tweet 'data/./rawdata/125561930416013312.json' not found. Skip.
# Tweet 'data/./rawdata/125547255947198465.json' not found. Skip.
# Tweet 'data/./rawdata/125476730067615744.json' not found. Skip.
# Tweet 'data/./rawdata/125475953509015552.json' not found. Skip.
# Tweet 'data/./rawdata/125441732941840385.json' not found. Skip.
# Tweet 'data/./rawdata/125435218017525760.json' not found. Skip.
# Tweet 'data/./rawdata/125420263687995392.json' not found. Skip.
# Tweet 'data/./rawdata/125400161886277632.json' not found. Skip.
# Tweet 'data/./rawdata/125395636219678720.json' not found. Skip.
# Tweet 'data/./rawdata/125380163302199296.json' not found. Skip.
# Tweet 'data/./rawdata/125371779039502336.json' not found. Skip.
# Tweet 'data/./rawdata/125369698840887297.json' not found. Skip.
# Tweet 'data/./rawdata/125368089159286784.json' not found. Skip.
# Tweet 'data/./rawdata/125355139409252352.json' not found. Skip.
# Tweet 'data/./rawdata/125347619072512000.json' not found. Skip.
# Tweet 'data/./rawdata/125346783390990337.json' not found. Skip.
# Tweet 'data/./rawdata/125334519254482944.json' not found. Skip.
# Tweet 'data/./rawdata/125330337847975937.json' not found. Skip.
# Tweet 'data/./rawdata/125309427422203904.json' not found. Skip.
# Tweet 'data/./rawdata/125304159581900800.json' not found. Skip.
# Tweet 'data/./rawdata/125295729139908608.json' not found. Skip.
# Tweet 'data/./rawdata/125294978623746048.json' not found. Skip.
# Tweet 'data/./rawdata/125271422431014914.json' not found. Skip.
# Tweet 'data/./rawdata/125268117680160768.json' not found. Skip.
# Tweet 'data/./rawdata/125245246136258561.json' not found. Skip.
# Tweet 'data/./rawdata/125232266849947648.json' not found. Skip.
# Tweet 'data/./rawdata/125212404299735040.json' not found. Skip.
# Tweet 'data/./rawdata/125204228967903232.json' not found. Skip.
# Tweet 'data/./rawdata/126394795802370049.json' not found. Skip.
# Tweet 'data/./rawdata/126386085164101634.json' not found. Skip.
# Tweet 'data/./rawdata/126382776072146944.json' not found. Skip.
# Tweet 'data/./rawdata/126380323733909504.json' not found. Skip.
# Tweet 'data/./rawdata/126362867778859008.json' not found. Skip.
# Tweet 'data/./rawdata/126343124174901248.json' not found. Skip.
# Tweet 'data/./rawdata/126339328434651136.json' not found. Skip.
# Tweet 'data/./rawdata/126329388320043008.json' not found. Skip.
# Tweet 'data/./rawdata/126317201962700800.json' not found. Skip.
# Tweet 'data/./rawdata/126314701721309184.json' not found. Skip.
# Tweet 'data/./rawdata/126312423132102657.json' not found. Skip.
# Tweet 'data/./rawdata/126307117274644480.json' not found. Skip.
# Tweet 'data/./rawdata/126298592364331008.json' not found. Skip.
# Tweet 'data/./rawdata/126293725155569664.json' not found. Skip.
# Tweet 'data/./rawdata/126292233963053056.json' not found. Skip.
# Tweet 'data/./rawdata/126287512296632320.json' not found. Skip.
# Tweet 'data/./rawdata/126283639959990274.json' not found. Skip.
# Tweet 'data/./rawdata/126229089651654656.json' not found. Skip.
# Tweet 'data/./rawdata/126225922159427584.json' not found. Skip.
# Tweet 'data/./rawdata/126219340214304768.json' not found. Skip.
# Tweet 'data/./rawdata/126192452297170945.json' not found. Skip.
# Tweet 'data/./rawdata/126186955296878592.json' not found. Skip.
# Tweet 'data/./rawdata/126186795808456704.json' not found. Skip.
# Tweet 'data/./rawdata/126147867478982656.json' not found. Skip.
# Tweet 'data/./rawdata/126125799744094208.json' not found. Skip.
# Tweet 'data/./rawdata/126110770864979968.json' not found. Skip.
# Tweet 'data/./rawdata/126102213956337664.json' not found. Skip.
# Tweet 'data/./rawdata/126082898783780864.json' not found. Skip.
# Tweet 'data/./rawdata/126081812236738560.json' not found. Skip.
# Tweet 'data/./rawdata/126065983138955265.json' not found. Skip.
# Tweet 'data/./rawdata/126054725727698944.json' not found. Skip.
# Tweet 'data/./rawdata/126044185815040000.json' not found. Skip.
# Tweet 'data/./rawdata/126043954641780736.json' not found. Skip.
# Tweet 'data/./rawdata/126039090578735104.json' not found. Skip.
# Tweet 'data/./rawdata/126029114850295809.json' not found. Skip.
# Tweet 'data/./rawdata/126021436149211136.json' not found. Skip.
# Tweet 'data/./rawdata/126017685246050304.json' not found. Skip.
# Tweet 'data/./rawdata/126014277814468608.json' not found. Skip.
# Tweet 'data/./rawdata/126012833128390656.json' not found. Skip.
# Tweet 'data/./rawdata/126010471202566144.json' not found. Skip.
# Tweet 'data/./rawdata/126009386022879232.json' not found. Skip.
# Tweet 'data/./rawdata/126006669535744000.json' not found. Skip.
# Tweet 'data/./rawdata/125998732046123009.json' not found. Skip.
# Tweet 'data/./rawdata/125996412252078080.json' not found. Skip.
# Tweet 'data/./rawdata/125994997609803776.json' not found. Skip.
# Tweet 'data/./rawdata/125992594395250688.json' not found. Skip.
# Tweet 'data/./rawdata/125988651426512899.json' not found. Skip.
# Tweet 'data/./rawdata/125981074114359297.json' not found. Skip.
# Tweet 'data/./rawdata/125980615664336896.json' not found. Skip.
# Tweet 'data/./rawdata/125974497546338304.json' not found. Skip.
# Tweet 'data/./rawdata/125971256335024128.json' not found. Skip.
# Tweet 'data/./rawdata/125958702455988225.json' not found. Skip.
# Tweet 'data/./rawdata/125957972466737152.json' not found. Skip.
# Tweet 'data/./rawdata/125950026181648385.json' not found. Skip.
# Tweet 'data/./rawdata/125949784677810176.json' not found. Skip.
# Tweet 'data/./rawdata/125947460592996352.json' not found. Skip.
# Tweet 'data/./rawdata/125932876721168384.json' not found. Skip.
# Tweet 'data/./rawdata/125930342891790337.json' not found. Skip.
# Tweet 'data/./rawdata/125922500839342080.json' not found. Skip.
# Tweet 'data/./rawdata/125922174648324096.json' not found. Skip.
# Tweet 'data/./rawdata/125921393350160384.json' not found. Skip.
# Tweet 'data/./rawdata/125920729194704896.json' not found. Skip.
# Tweet 'data/./rawdata/125920725595983874.json' not found. Skip.
# Tweet 'data/./rawdata/125920721200361472.json' not found. Skip.
# Tweet 'data/./rawdata/125920717966544896.json' not found. Skip.
# Tweet 'data/./rawdata/125920716297211904.json' not found. Skip.
# Tweet 'data/./rawdata/125919221845721090.json' not found. Skip.
# Tweet 'data/./rawdata/125918906215968771.json' not found. Skip.
# Tweet 'data/./rawdata/125918450920062977.json' not found. Skip.
# Tweet 'data/./rawdata/125918447979872258.json' not found. Skip.
# Tweet 'data/./rawdata/125918444762828800.json' not found. Skip.
# Tweet 'data/./rawdata/125918441013133312.json' not found. Skip.
# Tweet 'data/./rawdata/125917264267579393.json' not found. Skip.
# Tweet 'data/./rawdata/125917174618525696.json' not found. Skip.
# Tweet 'data/./rawdata/125917170571026432.json' not found. Skip.
# Tweet 'data/./rawdata/125917164535418880.json' not found. Skip.
# Tweet 'data/./rawdata/125917160982855680.json' not found. Skip.
# Tweet 'data/./rawdata/125915210337890304.json' not found. Skip.
# Tweet 'data/./rawdata/125908946702696448.json' not found. Skip.
# Tweet 'data/./rawdata/125907633466130432.json' not found. Skip.
# Tweet 'data/./rawdata/125892140940267522.json' not found. Skip.
# Tweet 'data/./rawdata/125891898517889024.json' not found. Skip.
# Tweet 'data/./rawdata/125887065861787648.json' not found. Skip.
# Tweet 'data/./rawdata/125882473312817152.json' not found. Skip.
# Tweet 'data/./rawdata/125878880916611072.json' not found. Skip.
# Tweet 'data/./rawdata/125866627337162752.json' not found. Skip.
# Tweet 'data/./rawdata/125866368758333440.json' not found. Skip.
# Tweet 'data/./rawdata/125859792802693120.json' not found. Skip.
# Tweet 'data/./rawdata/125859488728236032.json' not found. Skip.
# Tweet 'data/./rawdata/125854430171111424.json' not found. Skip.
# Tweet 'data/./rawdata/125840474132066304.json' not found. Skip.
# Tweet 'data/./rawdata/125830917578162176.json' not found. Skip.
# Tweet 'data/./rawdata/125829040740368384.json' not found. Skip.
# Tweet 'data/./rawdata/125828984293425152.json' not found. Skip.
# Tweet 'data/./rawdata/125826820057731074.json' not found. Skip.
# Tweet 'data/./rawdata/125824709421039616.json' not found. Skip.
# Tweet 'data/./rawdata/125823389804929024.json' not found. Skip.
# Tweet 'data/./rawdata/125821979797364736.json' not found. Skip.
# Tweet 'data/./rawdata/125821218258550784.json' not found. Skip.
# Tweet 'data/./rawdata/125817967240949760.json' not found. Skip.
# Tweet 'data/./rawdata/125815990620659713.json' not found. Skip.
# Tweet 'data/./rawdata/125811943054393344.json' not found. Skip.
# Tweet 'data/./rawdata/125807897568481280.json' not found. Skip.
# Tweet 'data/./rawdata/125804983185719297.json' not found. Skip.
# Tweet 'data/./rawdata/125803571601080320.json' not found. Skip.
# Tweet 'data/./rawdata/125803457155301376.json' not found. Skip.
# Tweet 'data/./rawdata/125801811817922561.json' not found. Skip.
# Tweet 'data/./rawdata/125793487479259136.json' not found. Skip.
# Tweet 'data/./rawdata/125792596114161665.json' not found. Skip.
# Tweet 'data/./rawdata/125792107930714113.json' not found. Skip.
# Tweet 'data/./rawdata/125727869363163137.json' not found. Skip.
# Tweet 'data/./rawdata/125727349034598401.json' not found. Skip.
# Tweet 'data/./rawdata/125727044263874560.json' not found. Skip.
# Tweet 'data/./rawdata/125726769297891330.json' not found. Skip.
# Tweet 'data/./rawdata/125725274317914112.json' not found. Skip.
# Tweet 'data/./rawdata/125725019178409984.json' not found. Skip.
# Tweet 'data/./rawdata/125724524732882944.json' not found. Skip.
# Tweet 'data/./rawdata/125721197437648896.json' not found. Skip.
# Tweet 'data/./rawdata/125714971261812736.json' not found. Skip.
# Tweet 'data/./rawdata/125708425752612864.json' not found. Skip.
# Tweet 'data/./rawdata/125708240225959936.json' not found. Skip.
# Tweet 'data/./rawdata/125706125764083712.json' not found. Skip.
# Tweet 'data/./rawdata/125703536632807424.json' not found. Skip.
# Tweet 'data/./rawdata/125698733768843264.json' not found. Skip.
# Tweet 'data/./rawdata/125695449423286272.json' not found. Skip.
# Tweet 'data/./rawdata/125695107734319104.json' not found. Skip.
# Tweet 'data/./rawdata/125694587313467393.json' not found. Skip.
# Tweet 'data/./rawdata/125692890474233856.json' not found. Skip.
# Tweet 'data/./rawdata/125692845054115842.json' not found. Skip.
# Tweet 'data/./rawdata/125691975474229248.json' not found. Skip.
# Tweet 'data/./rawdata/125690764331196416.json' not found. Skip.
# Tweet 'data/./rawdata/125689905954299904.json' not found. Skip.
# Tweet 'data/./rawdata/125687710705926144.json' not found. Skip.
# Tweet 'data/./rawdata/125686643960193024.json' not found. Skip.
# Tweet 'data/./rawdata/125685016389894144.json' not found. Skip.
# Tweet 'data/./rawdata/125679996420374530.json' not found. Skip.
# Tweet 'data/./rawdata/125677838295764992.json' not found. Skip.
# Tweet 'data/./rawdata/125674121722998785.json' not found. Skip.
# Tweet 'data/./rawdata/125669834922008576.json' not found. Skip.
# Tweet 'data/./rawdata/125667332931596290.json' not found. Skip.
# Tweet 'data/./rawdata/125667159547461633.json' not found. Skip.
# Tweet 'data/./rawdata/125666909080387584.json' not found. Skip.
# Tweet 'data/./rawdata/125665930339565568.json' not found. Skip.
# Tweet 'data/./rawdata/125664999036301312.json' not found. Skip.
# Tweet 'data/./rawdata/125664891691474944.json' not found. Skip.
# Tweet 'data/./rawdata/125663967296229376.json' not found. Skip.
# Tweet 'data/./rawdata/125663914552868864.json' not found. Skip.
# Tweet 'data/./rawdata/125661036891226113.json' not found. Skip.
# Tweet 'data/./rawdata/125660067482697729.json' not found. Skip.
# Tweet 'data/./rawdata/125657950185463808.json' not found. Skip.
# Tweet 'data/./rawdata/125647236418912256.json' not found. Skip.
# Tweet 'data/./rawdata/125645376790331392.json' not found. Skip.
# Tweet 'data/./rawdata/125643523792969728.json' not found. Skip.
# Tweet 'data/./rawdata/125642256114909184.json' not found. Skip.
# Tweet 'data/./rawdata/125642161659199488.json' not found. Skip.
# Tweet 'data/./rawdata/125642041140060160.json' not found. Skip.
# Tweet 'data/./rawdata/125641351848136704.json' not found. Skip.
# Tweet 'data/./rawdata/125640758966484992.json' not found. Skip.
# Tweet 'data/./rawdata/125640679325052929.json' not found. Skip.
# Tweet 'data/./rawdata/125640515021578240.json' not found. Skip.
# Tweet 'data/./rawdata/125638955952640000.json' not found. Skip.
# Tweet 'data/./rawdata/125633549847117824.json' not found. Skip.
# Tweet 'data/./rawdata/125633468708302848.json' not found. Skip.
# Tweet 'data/./rawdata/125633233982459904.json' not found. Skip.
# Tweet 'data/./rawdata/125632687879884800.json' not found. Skip.
# Tweet 'data/./rawdata/125632582795804672.json' not found. Skip.
# Tweet 'data/./rawdata/125631556051140608.json' not found. Skip.
# Tweet 'data/./rawdata/125630955154190336.json' not found. Skip.
# Tweet 'data/./rawdata/125630836245676033.json' not found. Skip.
# Tweet 'data/./rawdata/125630016485732352.json' not found. Skip.
# Tweet 'data/./rawdata/125629788563050496.json' not found. Skip.
# Tweet 'data/./rawdata/125627732032888833.json' not found. Skip.
# Tweet 'data/./rawdata/125626286939979776.json' not found. Skip.
# Tweet 'data/./rawdata/125625630254567424.json' not found. Skip.
# Tweet 'data/./rawdata/125625566203346944.json' not found. Skip.
# Tweet 'data/./rawdata/125620113582993408.json' not found. Skip.
# Tweet 'data/./rawdata/125617451705712640.json' not found. Skip.
# Tweet 'data/./rawdata/125617133123153921.json' not found. Skip.
# Tweet 'data/./rawdata/125616747863736320.json' not found. Skip.
# Tweet 'data/./rawdata/125614951787266048.json' not found. Skip.
# Tweet 'data/./rawdata/125614910804738049.json' not found. Skip.
# Tweet 'data/./rawdata/125607526967410689.json' not found. Skip.
# Tweet 'data/./rawdata/125598495137726464.json' not found. Skip.
# Tweet 'data/./rawdata/125596991290998784.json' not found. Skip.
# Tweet 'data/./rawdata/125595669145722880.json' not found. Skip.
# Tweet 'data/./rawdata/125595441562783744.json' not found. Skip.
# Tweet 'data/./rawdata/125591434056318977.json' not found. Skip.
# Tweet 'data/./rawdata/125589884445536257.json' not found. Skip.
# Tweet 'data/./rawdata/125589258898644992.json' not found. Skip.
# Tweet 'data/./rawdata/125588749454278656.json' not found. Skip.
# Tweet 'data/./rawdata/125588587180863489.json' not found. Skip.
# Tweet 'data/./rawdata/125587186723725312.json' not found. Skip.
# Tweet 'data/./rawdata/125586682790674434.json' not found. Skip.
# Tweet 'data/./rawdata/125585063327956992.json' not found. Skip.
# Tweet 'data/./rawdata/125583717354831872.json' not found. Skip.
# Tweet 'data/./rawdata/125581507355086848.json' not found. Skip.
# Tweet 'data/./rawdata/125581280430669824.json' not found. Skip.
# Tweet 'data/./rawdata/125564573167263746.json' not found. Skip.
# Tweet 'data/./rawdata/125559846870323200.json' not found. Skip.
# Tweet 'data/./rawdata/125559232157327360.json' not found. Skip.
# Tweet 'data/./rawdata/125551370676862976.json' not found. Skip.
# Tweet 'data/./rawdata/125546017205665792.json' not found. Skip.
# Tweet 'data/./rawdata/125545914864640000.json' not found. Skip.
# Tweet 'data/./rawdata/125544363945230336.json' not found. Skip.
# Tweet 'data/./rawdata/125541112491425792.json' not found. Skip.
# Tweet 'data/./rawdata/125538769632886784.json' not found. Skip.
# Tweet 'data/./rawdata/125537487455137793.json' not found. Skip.
# Tweet 'data/./rawdata/125532364406398977.json' not found. Skip.
# Tweet 'data/./rawdata/125532202057482240.json' not found. Skip.
# Tweet 'data/./rawdata/125528344480587776.json' not found. Skip.
# Tweet 'data/./rawdata/125527718203887616.json' not found. Skip.
# Tweet 'data/./rawdata/125512197135806464.json' not found. Skip.
# Tweet 'data/./rawdata/125498684401135616.json' not found. Skip.
# Tweet 'data/./rawdata/125496516000485376.json' not found. Skip.
# Tweet 'data/./rawdata/125493419522002944.json' not found. Skip.
# Tweet 'data/./rawdata/125493125098635265.json' not found. Skip.
# Tweet 'data/./rawdata/125489264157917184.json' not found. Skip.
# Tweet 'data/./rawdata/125486845768368128.json' not found. Skip.
# Tweet 'data/./rawdata/125460019859820544.json' not found. Skip.
# Tweet 'data/./rawdata/125459423870197760.json' not found. Skip.
# Tweet 'data/./rawdata/125459375245635584.json' not found. Skip.
# Tweet 'data/./rawdata/125457535951060993.json' not found. Skip.
# Tweet 'data/./rawdata/125448837404954624.json' not found. Skip.
# Tweet 'data/./rawdata/125433354488254464.json' not found. Skip.
# Tweet 'data/./rawdata/125432626482917376.json' not found. Skip.
# Tweet 'data/./rawdata/125432518324400128.json' not found. Skip.
# Tweet 'data/./rawdata/125425087800291328.json' not found. Skip.
# Tweet 'data/./rawdata/125424738662223872.json' not found. Skip.
# Tweet 'data/./rawdata/125419216227667968.json' not found. Skip.
# Tweet 'data/./rawdata/125417324621737985.json' not found. Skip.
# Tweet 'data/./rawdata/125416866243018753.json' not found. Skip.
# Tweet 'data/./rawdata/125416811490578435.json' not found. Skip.
# Tweet 'data/./rawdata/125410153196560384.json' not found. Skip.
# Tweet 'data/./rawdata/125409201907437569.json' not found. Skip.
# Tweet 'data/./rawdata/125406528487424003.json' not found. Skip.
# Tweet 'data/./rawdata/125406003863883776.json' not found. Skip.
# Tweet 'data/./rawdata/125405939015757824.json' not found. Skip.
# Tweet 'data/./rawdata/125402652610797569.json' not found. Skip.
# Tweet 'data/./rawdata/125398913313284096.json' not found. Skip.
# Tweet 'data/./rawdata/125398813543374848.json' not found. Skip.
# Tweet 'data/./rawdata/125394805449699329.json' not found. Skip.
# Tweet 'data/./rawdata/125379023307153408.json' not found. Skip.
# Tweet 'data/./rawdata/125374041556127744.json' not found. Skip.
# Tweet 'data/./rawdata/125373658389692416.json' not found. Skip.
# Tweet 'data/./rawdata/125373427661029376.json' not found. Skip.
# Tweet 'data/./rawdata/125372628746768384.json' not found. Skip.
# Tweet 'data/./rawdata/125369026351349760.json' not found. Skip.
# Tweet 'data/./rawdata/125368381728763904.json' not found. Skip.
# Tweet 'data/./rawdata/125367492976717824.json' not found. Skip.
# Tweet 'data/./rawdata/125366519680086016.json' not found. Skip.
# Tweet 'data/./rawdata/125365963972542464.json' not found. Skip.
# Tweet 'data/./rawdata/125365264656236544.json' not found. Skip.
# Tweet 'data/./rawdata/125364154629492737.json' not found. Skip.
# Tweet 'data/./rawdata/125364122853453824.json' not found. Skip.
# Tweet 'data/./rawdata/125361209137565696.json' not found. Skip.
# Tweet 'data/./rawdata/125360952878182400.json' not found. Skip.
# Tweet 'data/./rawdata/125360877359742976.json' not found. Skip.
# Tweet 'data/./rawdata/125359697770450944.json' not found. Skip.
# Tweet 'data/./rawdata/125359622193295360.json' not found. Skip.
# Tweet 'data/./rawdata/125357901580746752.json' not found. Skip.
# Tweet 'data/./rawdata/125354296752619520.json' not found. Skip.
# Tweet 'data/./rawdata/125351067620880385.json' not found. Skip.
# Tweet 'data/./rawdata/125350537821569024.json' not found. Skip.
# Tweet 'data/./rawdata/125347828754169856.json' not found. Skip.
# Tweet 'data/./rawdata/125347618862792705.json' not found. Skip.
# Tweet 'data/./rawdata/125345723020607488.json' not found. Skip.
# Tweet 'data/./rawdata/125344722196766720.json' not found. Skip.
# Tweet 'data/./rawdata/125344351218974720.json' not found. Skip.
# Tweet 'data/./rawdata/125338231280644096.json' not found. Skip.
# Tweet 'data/./rawdata/125336929825849344.json' not found. Skip.
# Tweet 'data/./rawdata/125336798690942977.json' not found. Skip.
# Tweet 'data/./rawdata/125335012961828866.json' not found. Skip.
# Tweet 'data/./rawdata/125332871174037504.json' not found. Skip.
# Tweet 'data/./rawdata/125332609428496384.json' not found. Skip.
# Tweet 'data/./rawdata/125327281181835264.json' not found. Skip.
# Tweet 'data/./rawdata/125326760769372160.json' not found. Skip.
# Tweet 'data/./rawdata/125325397712846848.json' not found. Skip.
# Tweet 'data/./rawdata/125324916009615360.json' not found. Skip.
# Tweet 'data/./rawdata/125321084525490176.json' not found. Skip.
# Tweet 'data/./rawdata/125318029390249984.json' not found. Skip.
# Tweet 'data/./rawdata/125317541504626688.json' not found. Skip.
# Tweet 'data/./rawdata/125317300860620801.json' not found. Skip.
# Tweet 'data/./rawdata/125315460030922752.json' not found. Skip.
# Tweet 'data/./rawdata/125315263183851521.json' not found. Skip.
# Tweet 'data/./rawdata/125315080081518592.json' not found. Skip.
# Tweet 'data/./rawdata/125312789345599489.json' not found. Skip.
# Tweet 'data/./rawdata/125312357797863425.json' not found. Skip.
# Tweet 'data/./rawdata/125309663913840640.json' not found. Skip.
# Tweet 'data/./rawdata/125305567148388352.json' not found. Skip.
# Tweet 'data/./rawdata/125300705836793856.json' not found. Skip.
# Tweet 'data/./rawdata/125300603059576833.json' not found. Skip.
# Tweet 'data/./rawdata/125287442407362560.json' not found. Skip.
# Tweet 'data/./rawdata/125283873331494913.json' not found. Skip.
# Tweet 'data/./rawdata/125281502866059264.json' not found. Skip.
# Tweet 'data/./rawdata/125278676949544960.json' not found. Skip.
# Tweet 'data/./rawdata/125276525472911360.json' not found. Skip.
# Tweet 'data/./rawdata/125275795252977664.json' not found. Skip.
# Tweet 'data/./rawdata/125275280678993920.json' not found. Skip.
# Tweet 'data/./rawdata/125273317673414656.json' not found. Skip.
# Tweet 'data/./rawdata/125270965268643840.json' not found. Skip.
# Tweet 'data/./rawdata/125267017942052866.json' not found. Skip.
# Tweet 'data/./rawdata/125266503657472000.json' not found. Skip.
# Tweet 'data/./rawdata/125261029834899456.json' not found. Skip.
# Tweet 'data/./rawdata/125260105154437121.json' not found. Skip.
# Tweet 'data/./rawdata/125257803790159873.json' not found. Skip.
# Tweet 'data/./rawdata/125252442836320256.json' not found. Skip.
# Tweet 'data/./rawdata/125250721280040961.json' not found. Skip.
# Tweet 'data/./rawdata/125250617911418881.json' not found. Skip.
# Tweet 'data/./rawdata/125250078108684288.json' not found. Skip.
# Tweet 'data/./rawdata/125246898830458880.json' not found. Skip.
# Tweet 'data/./rawdata/125245892814045184.json' not found. Skip.
# Tweet 'data/./rawdata/125244798671142912.json' not found. Skip.
# Tweet 'data/./rawdata/125231250247135233.json' not found. Skip.
# Tweet 'data/./rawdata/125227689895407616.json' not found. Skip.
# Tweet 'data/./rawdata/125222749034659840.json' not found. Skip.
# Tweet 'data/./rawdata/125218106778992640.json' not found. Skip.
# Tweet 'data/./rawdata/125211793655218178.json' not found. Skip.
# Tweet 'data/./rawdata/125206271560384512.json' not found. Skip.
# Tweet 'data/./rawdata/125196751387889665.json' not found. Skip.
# Tweet 'data/./rawdata/125193298624258049.json' not found. Skip.
# Tweet 'data/./rawdata/125184976579862530.json' not found. Skip.
# Tweet 'data/./rawdata/125085987431923713.json' not found. Skip.
# Tweet 'data/./rawdata/126405660308021248.json' not found. Skip.
# Tweet 'data/./rawdata/126403953058529280.json' not found. Skip.
# Tweet 'data/./rawdata/126402391259103232.json' not found. Skip.
# Tweet 'data/./rawdata/126399172495679488.json' not found. Skip.
# Tweet 'data/./rawdata/126394266145665025.json' not found. Skip.
# Tweet 'data/./rawdata/126391727408947200.json' not found. Skip.
# Tweet 'data/./rawdata/126387209824776192.json' not found. Skip.
# Tweet 'data/./rawdata/126385587740610563.json' not found. Skip.
# Tweet 'data/./rawdata/126381904621600768.json' not found. Skip.
# Tweet 'data/./rawdata/126379095004160001.json' not found. Skip.
# Tweet 'data/./rawdata/126373281099026432.json' not found. Skip.
# Tweet 'data/./rawdata/126367728754884609.json' not found. Skip.
# Tweet 'data/./rawdata/126362562865528832.json' not found. Skip.
# Tweet 'data/./rawdata/126360606042374144.json' not found. Skip.
# Tweet 'data/./rawdata/126355839274594304.json' not found. Skip.
# Tweet 'data/./rawdata/126355573586399232.json' not found. Skip.
# Tweet 'data/./rawdata/126352049070809089.json' not found. Skip.
# Tweet 'data/./rawdata/126346705292640257.json' not found. Skip.
# Tweet 'data/./rawdata/126346563147673600.json' not found. Skip.
# Tweet 'data/./rawdata/126346004688674816.json' not found. Skip.
# Tweet 'data/./rawdata/126342441057001472.json' not found. Skip.
# Tweet 'data/./rawdata/126340074777489408.json' not found. Skip.
# Tweet 'data/./rawdata/126332817134190592.json' not found. Skip.
# Tweet 'data/./rawdata/126331879883415552.json' not found. Skip.
# Tweet 'data/./rawdata/126329876935479296.json' not found. Skip.
# Tweet 'data/./rawdata/126319126913363968.json' not found. Skip.
# Tweet 'data/./rawdata/126313259572793345.json' not found. Skip.
# Tweet 'data/./rawdata/126312509983559681.json' not found. Skip.
# Tweet 'data/./rawdata/126310736577298432.json' not found. Skip.
# Tweet 'data/./rawdata/126307114959372289.json' not found. Skip.
# Tweet 'data/./rawdata/126304243144597505.json' not found. Skip.
# Tweet 'data/./rawdata/126303928039116800.json' not found. Skip.
# Tweet 'data/./rawdata/126303310054559744.json' not found. Skip.
# Tweet 'data/./rawdata/126298834203713536.json' not found. Skip.
# Tweet 'data/./rawdata/126298134212120577.json' not found. Skip.
# Tweet 'data/./rawdata/126297754799587328.json' not found. Skip.
# Tweet 'data/./rawdata/126290039138291712.json' not found. Skip.
# Tweet 'data/./rawdata/126271901340401665.json' not found. Skip.
# Tweet 'data/./rawdata/126270990459219968.json' not found. Skip.
# Tweet 'data/./rawdata/126264647652343808.json' not found. Skip.
# Tweet 'data/./rawdata/126264035007143936.json' not found. Skip.
# Tweet 'data/./rawdata/126263600548556800.json' not found. Skip.
# Tweet 'data/./rawdata/126260304819662849.json' not found. Skip.
# Tweet 'data/./rawdata/126252530819809280.json' not found. Skip.
# Tweet 'data/./rawdata/126236984644612096.json' not found. Skip.
# Tweet 'data/./rawdata/126232767821381632.json' not found. Skip.
# Tweet 'data/./rawdata/126228762596618240.json' not found. Skip.
# Tweet 'data/./rawdata/126215978341236736.json' not found. Skip.
# Tweet 'data/./rawdata/126195701704163328.json' not found. Skip.
# Tweet 'data/./rawdata/126186608113356800.json' not found. Skip.
# Tweet 'data/./rawdata/126175729024122880.json' not found. Skip.
# Tweet 'data/./rawdata/126173465253384193.json' not found. Skip.
# Tweet 'data/./rawdata/126164921485492224.json' not found. Skip.
# Tweet 'data/./rawdata/126149195957673984.json' not found. Skip.
# Tweet 'data/./rawdata/126138637652992001.json' not found. Skip.
# Tweet 'data/./rawdata/126131070050639874.json' not found. Skip.
# Tweet 'data/./rawdata/126111632773480448.json' not found. Skip.
# Tweet 'data/./rawdata/126097345124368385.json' not found. Skip.
# Tweet 'data/./rawdata/126093841232166912.json' not found. Skip.
# Tweet 'data/./rawdata/126061579233017856.json' not found. Skip.
# Tweet 'data/./rawdata/126054622564589569.json' not found. Skip.
# Tweet 'data/./rawdata/126054568273518592.json' not found. Skip.
# Tweet 'data/./rawdata/126052637014630400.json' not found. Skip.
# Tweet 'data/./rawdata/126042611709521921.json' not found. Skip.
# Tweet 'data/./rawdata/126024290201124864.json' not found. Skip.
# Tweet 'data/./rawdata/126022958710915072.json' not found. Skip.
# Tweet 'data/./rawdata/126022708524888064.json' not found. Skip.
# Tweet 'data/./rawdata/126007147199868928.json' not found. Skip.
# Tweet 'data/./rawdata/126005063595466753.json' not found. Skip.
# Tweet 'data/./rawdata/126001383869644800.json' not found. Skip.
# Tweet 'data/./rawdata/126000885485678592.json' not found. Skip.
# Tweet 'data/./rawdata/125998496535937024.json' not found. Skip.
# Tweet 'data/./rawdata/125996653990772737.json' not found. Skip.
# Tweet 'data/./rawdata/125993886249267200.json' not found. Skip.
# Tweet 'data/./rawdata/125993438205321218.json' not found. Skip.
# Tweet 'data/./rawdata/125993305325576193.json' not found. Skip.
# Tweet 'data/./rawdata/125992545552576512.json' not found. Skip.
# Tweet 'data/./rawdata/125991634855923712.json' not found. Skip.
# Tweet 'data/./rawdata/125990804488601600.json' not found. Skip.
# Tweet 'data/./rawdata/125990754769309696.json' not found. Skip.
# Tweet 'data/./rawdata/125982640263274496.json' not found. Skip.
# Tweet 'data/./rawdata/125973789526863872.json' not found. Skip.
# Tweet 'data/./rawdata/125970459404673026.json' not found. Skip.
# Tweet 'data/./rawdata/125968277083136000.json' not found. Skip.
# Tweet 'data/./rawdata/125967413299773440.json' not found. Skip.
# Tweet 'data/./rawdata/125967315488608257.json' not found. Skip.
# Tweet 'data/./rawdata/125965369532878849.json' not found. Skip.
# Tweet 'data/./rawdata/125965364667486209.json' not found. Skip.
# Tweet 'data/./rawdata/125959699089719297.json' not found. Skip.
# Tweet 'data/./rawdata/125959482588143616.json' not found. Skip.
# Tweet 'data/./rawdata/125957826500771840.json' not found. Skip.
# Tweet 'data/./rawdata/125957742698561537.json' not found. Skip.
# Tweet 'data/./rawdata/125948329694724097.json' not found. Skip.
# Tweet 'data/./rawdata/125930962545672192.json' not found. Skip.
# Tweet 'data/./rawdata/125928640394432513.json' not found. Skip.
# Tweet 'data/./rawdata/125910538550124545.json' not found. Skip.
# Tweet 'data/./rawdata/125909170074562561.json' not found. Skip.
# Tweet 'data/./rawdata/125877369796968448.json' not found. Skip.
# Tweet 'data/./rawdata/125873952953352192.json' not found. Skip.
# Tweet 'data/./rawdata/125862601677737985.json' not found. Skip.
# Tweet 'data/./rawdata/125857117407166464.json' not found. Skip.
# Tweet 'data/./rawdata/125827656238379008.json' not found. Skip.
# Tweet 'data/./rawdata/125826633713201152.json' not found. Skip.
# Tweet 'data/./rawdata/125825293473685505.json' not found. Skip.
# Tweet 'data/./rawdata/125815316596002816.json' not found. Skip.
# Tweet 'data/./rawdata/125797001337122817.json' not found. Skip.
# Tweet 'data/./rawdata/125724424774221826.json' not found. Skip.
# Tweet 'data/./rawdata/125707107495452673.json' not found. Skip.
# Tweet 'data/./rawdata/125705666592641024.json' not found. Skip.
# Tweet 'data/./rawdata/125705646942330880.json' not found. Skip.
# Tweet 'data/./rawdata/125699684693065728.json' not found. Skip.
# Tweet 'data/./rawdata/125695680135172096.json' not found. Skip.
# Tweet 'data/./rawdata/125695094836826112.json' not found. Skip.
# Tweet 'data/./rawdata/125653144993660928.json' not found. Skip.
# Tweet 'data/./rawdata/125650076759638016.json' not found. Skip.
# Tweet 'data/./rawdata/125647972087242754.json' not found. Skip.
# Tweet 'data/./rawdata/125641150186000384.json' not found. Skip.
# Tweet 'data/./rawdata/125622089502830592.json' not found. Skip.
# Tweet 'data/./rawdata/125621628917915648.json' not found. Skip.
# Tweet 'data/./rawdata/125602732278169601.json' not found. Skip.
# Tweet 'data/./rawdata/125595437938905088.json' not found. Skip.
# Tweet 'data/./rawdata/125590191502131200.json' not found. Skip.
# Tweet 'data/./rawdata/125580342244548608.json' not found. Skip.
# Tweet 'data/./rawdata/125568051277086721.json' not found. Skip.
# Tweet 'data/./rawdata/125542968844226560.json' not found. Skip.
# Tweet 'data/./rawdata/125542941287649280.json' not found. Skip.
# Tweet 'data/./rawdata/125534067495141376.json' not found. Skip.
# Tweet 'data/./rawdata/125526544377577472.json' not found. Skip.
# Tweet 'data/./rawdata/125521498055254016.json' not found. Skip.
# Tweet 'data/./rawdata/125521344342392832.json' not found. Skip.
# Tweet 'data/./rawdata/125516954407677952.json' not found. Skip.
# Tweet 'data/./rawdata/125495075504537600.json' not found. Skip.
# Tweet 'data/./rawdata/125490577130258432.json' not found. Skip.
# Tweet 'data/./rawdata/125485687339352064.json' not found. Skip.
# Tweet 'data/./rawdata/125447473786392576.json' not found. Skip.
# Tweet 'data/./rawdata/125445752083329025.json' not found. Skip.
# Tweet 'data/./rawdata/125445407592546304.json' not found. Skip.
# Tweet 'data/./rawdata/125421514928558080.json' not found. Skip.
# Tweet 'data/./rawdata/125411589905068033.json' not found. Skip.
# Tweet 'data/./rawdata/125409044222586880.json' not found. Skip.
# Tweet 'data/./rawdata/125406418777018368.json' not found. Skip.
# Tweet 'data/./rawdata/125405429583970305.json' not found. Skip.
# Tweet 'data/./rawdata/125375333162684416.json' not found. Skip.
# Tweet 'data/./rawdata/125361267555835905.json' not found. Skip.
# Tweet 'data/./rawdata/125353260520443904.json' not found. Skip.
# Tweet 'data/./rawdata/125352405482217473.json' not found. Skip.
# Tweet 'data/./rawdata/125346522618535937.json' not found. Skip.
# Tweet 'data/./rawdata/125339193802100736.json' not found. Skip.
# Tweet 'data/./rawdata/125336882862231552.json' not found. Skip.
# Tweet 'data/./rawdata/125333140414808065.json' not found. Skip.
# Tweet 'data/./rawdata/125325092841467904.json' not found. Skip.
# Tweet 'data/./rawdata/125321769203666944.json' not found. Skip.
# Tweet 'data/./rawdata/125319263027343360.json' not found. Skip.
# Tweet 'data/./rawdata/125305753903964161.json' not found. Skip.
# Tweet 'data/./rawdata/125301831286013952.json' not found. Skip.
# Tweet 'data/./rawdata/125287180561166336.json' not found. Skip.
# Tweet 'data/./rawdata/125275735815491584.json' not found. Skip.
# Tweet 'data/./rawdata/125232405517844481.json' not found. Skip.
# Tweet 'data/./rawdata/125228207002759168.json' not found. Skip.
# Tweet 'data/./rawdata/125219664488960000.json' not found. Skip.
# Tweet 'data/./rawdata/125209676416679936.json' not found. Skip.
# Tweet 'data/./rawdata/125206785584922624.json' not found. Skip.
# Tweet 'data/./rawdata/125184213342367744.json' not found. Skip.
# Tweet 'data/./rawdata/125082707389718529.json' not found. Skip.
# Tweet 'data/./rawdata/126534770095169536.json' not found. Skip.
# Tweet 'data/./rawdata/126534201880219648.json' not found. Skip.
# Tweet 'data/./rawdata/126534020367519744.json' not found. Skip.
# Tweet 'data/./rawdata/126533948925952000.json' not found. Skip.
# Tweet 'data/./rawdata/126533885109600256.json' not found. Skip.
# Tweet 'data/./rawdata/126533562781544448.json' not found. Skip.
# Tweet 'data/./rawdata/126533349727666176.json' not found. Skip.
# Tweet 'data/./rawdata/126533268119109632.json' not found. Skip.
# Tweet 'data/./rawdata/126533166352699392.json' not found. Skip.
# Tweet 'data/./rawdata/126532897715929088.json' not found. Skip.
# Tweet 'data/./rawdata/126531552367751169.json' not found. Skip.
# Tweet 'data/./rawdata/126531180907601920.json' not found. Skip.
# Tweet 'data/./rawdata/126530945976238080.json' not found. Skip.
# Tweet 'data/./rawdata/126530924576907264.json' not found. Skip.
# Tweet 'data/./rawdata/126530807891374082.json' not found. Skip.
# Tweet 'data/./rawdata/126530189579649024.json' not found. Skip.
# Tweet 'data/./rawdata/126530027939569665.json' not found. Skip.
# Tweet 'data/./rawdata/126529770778411008.json' not found. Skip.
# Tweet 'data/./rawdata/126528982807089152.json' not found. Skip.
# Tweet 'data/./rawdata/126528978239496194.json' not found. Skip.
# Tweet 'data/./rawdata/126528804192653312.json' not found. Skip.
# Tweet 'data/./rawdata/126528264117293056.json' not found. Skip.
# Tweet 'data/./rawdata/126526219587039233.json' not found. Skip.
# Tweet 'data/./rawdata/126525469897146368.json' not found. Skip.
# Tweet 'data/./rawdata/126525368860540928.json' not found. Skip.
# Tweet 'data/./rawdata/126525172969766912.json' not found. Skip.
# Tweet 'data/./rawdata/126524301259194368.json' not found. Skip.
# Tweet 'data/./rawdata/126523731710443521.json' not found. Skip.
# Tweet 'data/./rawdata/126523530903953408.json' not found. Skip.
# Tweet 'data/./rawdata/126523525598162944.json' not found. Skip.
# Tweet 'data/./rawdata/126522990585315328.json' not found. Skip.
# Tweet 'data/./rawdata/126522810821644288.json' not found. Skip.
# Tweet 'data/./rawdata/126522714713370624.json' not found. Skip.
# Tweet 'data/./rawdata/126522621251682304.json' not found. Skip.
# Tweet 'data/./rawdata/126522262768726016.json' not found. Skip.
# Tweet 'data/./rawdata/126521613259771904.json' not found. Skip.
# Tweet 'data/./rawdata/126521382220738560.json' not found. Skip.
# Tweet 'data/./rawdata/126521286053724160.json' not found. Skip.
# Tweet 'data/./rawdata/126520518609350656.json' not found. Skip.
# Tweet 'data/./rawdata/126520029410885632.json' not found. Skip.
# Tweet 'data/./rawdata/126519483752914944.json' not found. Skip.
# Tweet 'data/./rawdata/126519329025040384.json' not found. Skip.
# Tweet 'data/./rawdata/126519123772588032.json' not found. Skip.
# Tweet 'data/./rawdata/126519017405030400.json' not found. Skip.
# Tweet 'data/./rawdata/126518882939838464.json' not found. Skip.
# Tweet 'data/./rawdata/126516914678808578.json' not found. Skip.
# Tweet 'data/./rawdata/126516779886456832.json' not found. Skip.
# Tweet 'data/./rawdata/126516304336257025.json' not found. Skip.
# Tweet 'data/./rawdata/126515760855134208.json' not found. Skip.
# Tweet 'data/./rawdata/126514474378203136.json' not found. Skip.
# Tweet 'data/./rawdata/126513620686352384.json' not found. Skip.
# Tweet 'data/./rawdata/126513526385819648.json' not found. Skip.
# Tweet 'data/./rawdata/126513425043030016.json' not found. Skip.
# Tweet 'data/./rawdata/126512728297844736.json' not found. Skip.
# Tweet 'data/./rawdata/126512631937904640.json' not found. Skip.
# Tweet 'data/./rawdata/126512208451600384.json' not found. Skip.
# Tweet 'data/./rawdata/126511837796765696.json' not found. Skip.
# Tweet 'data/./rawdata/126511545160171520.json' not found. Skip.
# Tweet 'data/./rawdata/126511426926944256.json' not found. Skip.
# Tweet 'data/./rawdata/126511000907288576.json' not found. Skip.
# Tweet 'data/./rawdata/126510977335300096.json' not found. Skip.
# Tweet 'data/./rawdata/126510551789604864.json' not found. Skip.
# Tweet 'data/./rawdata/126509929619132417.json' not found. Skip.
# Tweet 'data/./rawdata/126509528287166464.json' not found. Skip.
# Tweet 'data/./rawdata/126508433582211072.json' not found. Skip.
# Tweet 'data/./rawdata/126508393203642368.json' not found. Skip.
# Tweet 'data/./rawdata/126507456019968000.json' not found. Skip.
# Tweet 'data/./rawdata/126507105023819776.json' not found. Skip.
# Tweet 'data/./rawdata/126506850781888512.json' not found. Skip.
# Tweet 'data/./rawdata/126506410195431424.json' not found. Skip.
# Tweet 'data/./rawdata/126506064387637249.json' not found. Skip.
# Tweet 'data/./rawdata/126505384428052481.json' not found. Skip.
# Tweet 'data/./rawdata/126505187752943616.json' not found. Skip.
# Tweet 'data/./rawdata/126505144878772224.json' not found. Skip.
# Tweet 'data/./rawdata/126504782465732608.json' not found. Skip.
# Tweet 'data/./rawdata/126504452680187905.json' not found. Skip.
# Tweet 'data/./rawdata/126504346639802368.json' not found. Skip.
# Tweet 'data/./rawdata/126504216004005888.json' not found. Skip.
# Tweet 'data/./rawdata/126504013939216384.json' not found. Skip.
# Tweet 'data/./rawdata/126503946092158976.json' not found. Skip.
# Tweet 'data/./rawdata/126503805369069568.json' not found. Skip.
# Tweet 'data/./rawdata/126503790412181504.json' not found. Skip.
# Tweet 'data/./rawdata/126503029548654593.json' not found. Skip.
# Tweet 'data/./rawdata/126502415322193920.json' not found. Skip.
# Tweet 'data/./rawdata/126502014560649216.json' not found. Skip.
# Tweet 'data/./rawdata/126501732443361280.json' not found. Skip.
# Tweet 'data/./rawdata/126501468902658048.json' not found. Skip.
# Tweet 'data/./rawdata/126500614552289282.json' not found. Skip.
# Tweet 'data/./rawdata/126499965869625345.json' not found. Skip.
# Tweet 'data/./rawdata/126499581520384001.json' not found. Skip.
# Tweet 'data/./rawdata/126499428965158912.json' not found. Skip.
# Tweet 'data/./rawdata/126499145014980608.json' not found. Skip.
# Tweet 'data/./rawdata/126499143282737152.json' not found. Skip.
# Tweet 'data/./rawdata/126498734409396224.json' not found. Skip.
# Tweet 'data/./rawdata/126498608815149056.json' not found. Skip.
# Tweet 'data/./rawdata/126498587499696128.json' not found. Skip.
# Tweet 'data/./rawdata/126497976314109952.json' not found. Skip.
# Tweet 'data/./rawdata/126497860752646146.json' not found. Skip.
# Tweet 'data/./rawdata/126497655785402368.json' not found. Skip.
# Tweet 'data/./rawdata/126496772586610688.json' not found. Skip.
# Tweet 'data/./rawdata/126496739531304960.json' not found. Skip.
# Tweet 'data/./rawdata/126496342901133313.json' not found. Skip.
# Tweet 'data/./rawdata/126496262668292096.json' not found. Skip.
# Tweet 'data/./rawdata/126496155856142336.json' not found. Skip.
# Tweet 'data/./rawdata/126496005809127424.json' not found. Skip.
# Tweet 'data/./rawdata/126495843116265475.json' not found. Skip.
# Tweet 'data/./rawdata/126495812724338688.json' not found. Skip.
# Tweet 'data/./rawdata/126495283176685569.json' not found. Skip.
# Tweet 'data/./rawdata/126495221373607936.json' not found. Skip.
# Tweet 'data/./rawdata/126494976396898305.json' not found. Skip.
# Tweet 'data/./rawdata/126494883367235585.json' not found. Skip.
# Tweet 'data/./rawdata/126494838689513473.json' not found. Skip.
# Tweet 'data/./rawdata/126494834449063936.json' not found. Skip.
# Tweet 'data/./rawdata/126494645281755136.json' not found. Skip.
# Tweet 'data/./rawdata/126494573966016512.json' not found. Skip.
# Tweet 'data/./rawdata/126494442290020352.json' not found. Skip.
# Tweet 'data/./rawdata/126494344566943744.json' not found. Skip.
# Tweet 'data/./rawdata/126494339248562176.json' not found. Skip.
# ...
# Tweet 'data/./rawdata/126866905096130560.json' not found. Skip.
# Tweet 'data/./rawdata/126866882979573760.json' not found. Skip.
# Tweet 'data/./rawdata/126866835449708544.json' not found. Skip.
# Tweet 'data/./rawdata/126866833537110016.json' not found. Skip.
# Tweet 'data/./rawdata/126866827715420160.json' not found. Skip.
# Tweet 'data/./rawdata/126866789962498048.json' not found. Skip.
# Tweet 'data/./rawdata/126866773705375744.json' not found. Skip.
# Tweet 'data/./rawdata/126866759792852992.json' not found. Skip.
# Tweet 'data/./rawdata/126866701877903361.json' not found. Skip.
# Tweet 'data/./rawdata/126866689236283392.json' not found. Skip.
# Tweet 'data/./rawdata/126866515122331648.json' not found. Skip.
# Tweet 'data/./rawdata/126866508818296832.json' not found. Skip.
# Tweet 'data/./rawdata/126866474806673408.json' not found. Skip.
# Tweet 'data/./rawdata/126866454845984768.json' not found. Skip.
# Tweet 'data/./rawdata/126866426521849857.json' not found. Skip.
# Tweet 'data/./rawdata/126866385757417472.json' not found. Skip.
# Tweet 'data/./rawdata/126866312130609152.json' not found. Skip.
# Tweet 'data/./rawdata/126866267998134272.json' not found. Skip.
# Tweet 'data/./rawdata/126866222355722240.json' not found. Skip.
# Tweet 'data/./rawdata/126866176889454592.json' not found. Skip.
# Tweet 'data/./rawdata/126866076016447489.json' not found. Skip.
# Tweet 'data/./rawdata/126866058337460224.json' not found. Skip.
# Tweet 'data/./rawdata/126866027316383744.json' not found. Skip.
# Tweet 'data/./rawdata/126866021402427392.json' not found. Skip.
# Tweet 'data/./rawdata/126865987365634048.json' not found. Skip.
# Tweet 'data/./rawdata/126865977970401280.json' not found. Skip.
# Tweet 'data/./rawdata/126865966624813057.json' not found. Skip.
# Tweet 'data/./rawdata/126865936115445761.json' not found. Skip.
# Tweet 'data/./rawdata/126865932806139904.json' not found. Skip.
# Tweet 'data/./rawdata/126865890665967618.json' not found. Skip.
# Tweet 'data/./rawdata/126865868599726080.json' not found. Skip.
# Tweet 'data/./rawdata/126865864086667264.json' not found. Skip.
# Tweet 'data/./rawdata/126865777423941633.json' not found. Skip.
# Tweet 'data/./rawdata/126865704380153856.json' not found. Skip.
# Tweet 'data/./rawdata/126865703969099776.json' not found. Skip.
# Tweet 'data/./rawdata/126865661602447362.json' not found. Skip.
# Tweet 'data/./rawdata/126865633869709312.json' not found. Skip.
# Tweet 'data/./rawdata/126865576093171712.json' not found. Skip.
# Tweet 'data/./rawdata/126865573228445696.json' not found. Skip.
# Tweet 'data/./rawdata/126865566236553216.json' not found. Skip.
# Tweet 'data/./rawdata/126865487584968704.json' not found. Skip.
# Tweet 'data/./rawdata/126865416671862785.json' not found. Skip.
# Tweet 'data/./rawdata/126865410598502400.json' not found. Skip.
# Tweet 'data/./rawdata/126865389861871617.json' not found. Skip.
# Tweet 'data/./rawdata/126865304277090304.json' not found. Skip.
# Tweet 'data/./rawdata/126865296463118337.json' not found. Skip.
# Tweet 'data/./rawdata/126865215492071424.json' not found. Skip.
# Tweet 'data/./rawdata/126865127977918464.json' not found. Skip.
# Tweet 'data/./rawdata/126865092565417984.json' not found. Skip.
# Tweet 'data/./rawdata/126865045949919233.json' not found. Skip.
# Tweet 'data/./rawdata/126865038676987904.json' not found. Skip.
# Tweet 'data/./rawdata/126865014215802880.json' not found. Skip.
# Tweet 'data/./rawdata/126864993760182272.json' not found. Skip.
# Tweet 'data/./rawdata/126864955285831680.json' not found. Skip.
# Tweet 'data/./rawdata/126864954140803072.json' not found. Skip.
# Tweet 'data/./rawdata/126864917566455809.json' not found. Skip.
# Tweet 'data/./rawdata/126864908582260736.json' not found. Skip.
# Tweet 'data/./rawdata/126864848649846784.json' not found. Skip.
# Tweet 'data/./rawdata/126864847399944192.json' not found. Skip.
# Tweet 'data/./rawdata/126864712766980096.json' not found. Skip.
# Tweet 'data/./rawdata/126864692470751232.json' not found. Skip.
# Tweet 'data/./rawdata/126864673416032256.json' not found. Skip.
# Tweet 'data/./rawdata/126864623252144128.json' not found. Skip.
# Tweet 'data/./rawdata/126864485943214080.json' not found. Skip.
# Tweet 'data/./rawdata/126864460957749248.json' not found. Skip.
# Tweet 'data/./rawdata/126864441999507456.json' not found. Skip.
# Tweet 'data/./rawdata/126864344125419520.json' not found. Skip.
# Tweet 'data/./rawdata/126864341071962112.json' not found. Skip.
# Tweet 'data/./rawdata/126864316120047617.json' not found. Skip.
# Tweet 'data/./rawdata/126864259027181568.json' not found. Skip.
# Tweet 'data/./rawdata/126864201804300289.json' not found. Skip.
# Tweet 'data/./rawdata/126864188969725953.json' not found. Skip.
# Tweet 'data/./rawdata/126864074045784064.json' not found. Skip.
# Tweet 'data/./rawdata/126864072447766528.json' not found. Skip.
# Tweet 'data/./rawdata/126864016613183489.json' not found. Skip.
# Tweet 'data/./rawdata/126863938339094531.json' not found. Skip.
# Tweet 'data/./rawdata/126863859075121152.json' not found. Skip.
# Tweet 'data/./rawdata/126863845326209024.json' not found. Skip.
# Tweet 'data/./rawdata/126863808177254400.json' not found. Skip.
# Tweet 'data/./rawdata/126863734265217025.json' not found. Skip.
# Tweet 'data/./rawdata/126863732931432448.json' not found. Skip.
# Tweet 'data/./rawdata/126863723179675648.json' not found. Skip.
# Tweet 'data/./rawdata/126863722412118017.json' not found. Skip.
# Tweet 'data/./rawdata/126863708889690112.json' not found. Skip.
# Tweet 'data/./rawdata/126863696726200320.json' not found. Skip.
# Tweet 'data/./rawdata/126863647845789696.json' not found. Skip.
# Tweet 'data/./rawdata/126863644968501250.json' not found. Skip.
# Tweet 'data/./rawdata/126863594850746369.json' not found. Skip.
# Tweet 'data/./rawdata/126863579914829824.json' not found. Skip.
# Tweet 'data/./rawdata/126863563133431809.json' not found. Skip.
# Tweet 'data/./rawdata/126863551355822080.json' not found. Skip.
# Tweet 'data/./rawdata/126863538626109440.json' not found. Skip.
# Tweet 'data/./rawdata/126863416211156992.json' not found. Skip.
# Tweet 'data/./rawdata/126863368492564481.json' not found. Skip.
# Tweet 'data/./rawdata/126863360779227136.json' not found. Skip.
# Tweet 'data/./rawdata/126863360686956544.json' not found. Skip.
# Tweet 'data/./rawdata/126863321327611904.json' not found. Skip.
# Tweet 'data/./rawdata/126863319226265600.json' not found. Skip.
# Tweet 'data/./rawdata/126863283658567680.json' not found. Skip.
# Tweet 'data/./rawdata/126863189844566016.json' not found. Skip.
# Tweet 'data/./rawdata/126863136111333376.json' not found. Skip.
# Tweet 'data/./rawdata/126863118398787584.json' not found. Skip.
# Tweet 'data/./rawdata/126863108802232320.json' not found. Skip.
# Tweet 'data/./rawdata/126863108688986112.json' not found. Skip.
# Tweet 'data/./rawdata/126863078112509952.json' not found. Skip.
# Tweet 'data/./rawdata/126863012433899520.json' not found. Skip.
# Tweet 'data/./rawdata/126862981333139457.json' not found. Skip.
# Tweet 'data/./rawdata/126862918921891840.json' not found. Skip.
# Tweet 'data/./rawdata/126862904514445312.json' not found. Skip.
# Tweet 'data/./rawdata/126862853822099456.json' not found. Skip.
# Tweet 'data/./rawdata/126862852681240576.json' not found. Skip.
# Tweet 'data/./rawdata/126862832489861121.json' not found. Skip.
# Tweet 'data/./rawdata/126862813355442176.json' not found. Skip.
# Tweet 'data/./rawdata/126862789649248256.json' not found. Skip.
# Tweet 'data/./rawdata/126862725933576192.json' not found. Skip.
# Tweet 'data/./rawdata/126862722028666880.json' not found. Skip.
# Tweet 'data/./rawdata/126862722007699456.json' not found. Skip.
# Tweet 'data/./rawdata/126862721793789953.json' not found. Skip.
# Tweet 'data/./rawdata/126862721609248769.json' not found. Skip.
# Tweet 'data/./rawdata/126862719927332864.json' not found. Skip.
# Tweet 'data/./rawdata/126862668039598080.json' not found. Skip.
# Tweet 'data/./rawdata/126862654324211713.json' not found. Skip.
# Tweet 'data/./rawdata/126862632648065025.json' not found. Skip.
# Tweet 'data/./rawdata/126862595117424641.json' not found. Skip.
# Tweet 'data/./rawdata/126862536162295808.json' not found. Skip.
# Tweet 'data/./rawdata/126862464003477504.json' not found. Skip.
# Tweet 'data/./rawdata/126862447041712128.json' not found. Skip.
# Tweet 'data/./rawdata/126862429912186880.json' not found. Skip.
# Tweet 'data/./rawdata/126862343148802048.json' not found. Skip.
# Tweet 'data/./rawdata/126862329269858305.json' not found. Skip.
# Tweet 'data/./rawdata/126862315990679552.json' not found. Skip.
# Tweet 'data/./rawdata/126862308302532608.json' not found. Skip.
# Tweet 'data/./rawdata/126862269148692481.json' not found. Skip.
# Tweet 'data/./rawdata/126862268725080065.json' not found. Skip.
# Tweet 'data/./rawdata/126862217013497856.json' not found. Skip.
# Tweet 'data/./rawdata/126862201440043008.json' not found. Skip.
# Tweet 'data/./rawdata/126862151393619968.json' not found. Skip.
# Tweet 'data/./rawdata/126862151343284224.json' not found. Skip.
# Tweet 'data/./rawdata/126862150265352193.json' not found. Skip.
# Tweet 'data/./rawdata/126862116874489856.json' not found. Skip.
# Tweet 'data/./rawdata/126861992001679360.json' not found. Skip.
# Tweet 'data/./rawdata/126861988004499457.json' not found. Skip.
# Tweet 'data/./rawdata/126861979762696192.json' not found. Skip.
# Tweet 'data/./rawdata/126861960137539585.json' not found. Skip.
# Tweet 'data/./rawdata/126861955762888706.json' not found. Skip.
# Tweet 'data/./rawdata/126861933071704065.json' not found. Skip.
# Tweet 'data/./rawdata/126861782378745856.json' not found. Skip.
# Tweet 'data/./rawdata/126861771314184192.json' not found. Skip.
# Tweet 'data/./rawdata/126861717790658561.json' not found. Skip.
# Tweet 'data/./rawdata/126861611741872128.json' not found. Skip.
# Tweet 'data/./rawdata/126861593249185793.json' not found. Skip.
# Tweet 'data/./rawdata/126861589122002944.json' not found. Skip.
# Tweet 'data/./rawdata/126861539511775232.json' not found. Skip.
# Tweet 'data/./rawdata/126861496109121536.json' not found. Skip.
# Tweet 'data/./rawdata/126861493059854336.json' not found. Skip.
# Tweet 'data/./rawdata/126861480128819201.json' not found. Skip.
# Tweet 'data/./rawdata/126861380992241664.json' not found. Skip.
# Tweet 'data/./rawdata/126861357831303168.json' not found. Skip.
# Tweet 'data/./rawdata/126861252134830080.json' not found. Skip.
# Tweet 'data/./rawdata/126861245109387264.json' not found. Skip.
# Tweet 'data/./rawdata/126861233138827264.json' not found. Skip.
# Tweet 'data/./rawdata/126861218592980992.json' not found. Skip.
# Tweet 'data/./rawdata/126861187605471232.json' not found. Skip.
# Tweet 'data/./rawdata/126861118684676096.json' not found. Skip.
# Tweet 'data/./rawdata/126861100120686592.json' not found. Skip.
# Tweet 'data/./rawdata/126860970583797760.json' not found. Skip.
# Tweet 'data/./rawdata/126860953450065920.json' not found. Skip.
# Tweet 'data/./rawdata/126860911557345280.json' not found. Skip.
# Tweet 'data/./rawdata/126860890749419521.json' not found. Skip.
# Tweet 'data/./rawdata/126860877344407552.json' not found. Skip.
# Tweet 'data/./rawdata/126860835892109312.json' not found. Skip.
# Tweet 'data/./rawdata/126860830942834689.json' not found. Skip.
# Tweet 'data/./rawdata/126860808251637762.json' not found. Skip.
# Tweet 'data/./rawdata/126860789536657408.json' not found. Skip.
# Tweet 'data/./rawdata/126860754912681985.json' not found. Skip.
# Tweet 'data/./rawdata/126860740689797120.json' not found. Skip.
# Tweet 'data/./rawdata/126860719860883458.json' not found. Skip.
# Tweet 'data/./rawdata/126860653167263744.json' not found. Skip.
# Tweet 'data/./rawdata/126860610020446209.json' not found. Skip.
# Tweet 'data/./rawdata/126860576600227841.json' not found. Skip.
# Tweet 'data/./rawdata/126860372987740160.json' not found. Skip.
# Tweet 'data/./rawdata/126860329463447552.json' not found. Skip.
# Tweet 'data/./rawdata/126860270181171201.json' not found. Skip.
# Tweet 'data/./rawdata/126860146289803265.json' not found. Skip.
# Tweet 'data/./rawdata/126860127167987712.json' not found. Skip.
# Tweet 'data/./rawdata/126860114610241536.json' not found. Skip.
# Tweet 'data/./rawdata/126860109090521088.json' not found. Skip.
# Tweet 'data/./rawdata/126859990513369088.json' not found. Skip.
# Tweet 'data/./rawdata/126859860640940032.json' not found. Skip.
# Tweet 'data/./rawdata/126859857604247552.json' not found. Skip.
# Tweet 'data/./rawdata/126859846506127360.json' not found. Skip.
# Tweet 'data/./rawdata/126859794383515649.json' not found. Skip.
# Tweet 'data/./rawdata/126859777308495872.json' not found. Skip.
# Tweet 'data/./rawdata/126859668151738368.json' not found. Skip.
# Tweet 'data/./rawdata/126859627051757568.json' not found. Skip.
# Tweet 'data/./rawdata/126859610006110208.json' not found. Skip.
# Tweet 'data/./rawdata/126859509414100992.json' not found. Skip.
# Tweet 'data/./rawdata/126859503495938048.json' not found. Skip.
# Tweet 'data/./rawdata/126859490061598720.json' not found. Skip.
# Tweet 'data/./rawdata/126859443127332864.json' not found. Skip.
# Tweet 'data/./rawdata/126859428455657472.json' not found. Skip.
# Tweet 'data/./rawdata/126859363079041024.json' not found. Skip.
# Tweet 'data/./rawdata/126859354614939648.json' not found. Skip.
# Tweet 'data/./rawdata/126859286558158849.json' not found. Skip.
# Tweet 'data/./rawdata/126859257856540672.json' not found. Skip.
# Tweet 'data/./rawdata/126859211593351168.json' not found. Skip.
# Tweet 'data/./rawdata/126859155175772161.json' not found. Skip.
# Tweet 'data/./rawdata/126859077304320001.json' not found. Skip.
# Tweet 'data/./rawdata/126858835058098176.json' not found. Skip.
# Tweet 'data/./rawdata/126858789868670976.json' not found. Skip.
# Tweet 'data/./rawdata/126858639855206400.json' not found. Skip.
# Tweet 'data/./rawdata/126858516655898625.json' not found. Skip.
# Tweet 'data/./rawdata/126858260216160256.json' not found. Skip.
# Tweet 'data/./rawdata/126858248325308416.json' not found. Skip.
# Tweet 'data/./rawdata/126858186962644992.json' not found. Skip.
# Tweet 'data/./rawdata/126858148878368769.json' not found. Skip.
# Tweet 'data/./rawdata/126858034466131969.json' not found. Skip.
# Tweet 'data/./rawdata/126858032951996416.json' not found. Skip.
# Tweet 'data/./rawdata/126858004690767872.json' not found. Skip.
# Tweet 'data/./rawdata/126857921068941314.json' not found. Skip.
# Tweet 'data/./rawdata/126857918929838080.json' not found. Skip.
# Tweet 'data/./rawdata/126857746200014849.json' not found. Skip.
# Tweet 'data/./rawdata/126857736238530560.json' not found. Skip.
# Tweet 'data/./rawdata/126857518591901698.json' not found. Skip.
# Tweet 'data/./rawdata/126857511230902272.json' not found. Skip.
# Tweet 'data/./rawdata/126857421321797634.json' not found. Skip.
# Tweet 'data/./rawdata/126857383715676160.json' not found. Skip.
# Tweet 'data/./rawdata/126857361515216897.json' not found. Skip.
# Tweet 'data/./rawdata/126857211921174528.json' not found. Skip.
# Tweet 'data/./rawdata/126857080513638400.json' not found. Skip.
# Tweet 'data/./rawdata/126857071667847168.json' not found. Skip.
# Tweet 'data/./rawdata/126857049920385024.json' not found. Skip.
# Tweet 'data/./rawdata/126856764242137088.json' not found. Skip.
# Tweet 'data/./rawdata/126856732331884545.json' not found. Skip.
# Tweet 'data/./rawdata/126856603021484032.json' not found. Skip.
# Tweet 'data/./rawdata/126856425371746304.json' not found. Skip.
# Tweet 'data/./rawdata/126856274531991552.json' not found. Skip.
# Tweet 'data/./rawdata/126856135918620673.json' not found. Skip.
# Tweet 'data/./rawdata/126856097863708672.json' not found. Skip.
# Tweet 'data/./rawdata/126856097431699456.json' not found. Skip.
# Tweet 'data/./rawdata/126855687060987904.json' not found. Skip.
# Tweet 'data/./rawdata/126855171702661120.json' not found. Skip.
# Tweet 'data/./rawdata/126854999442587648.json' not found. Skip.
# Tweet 'data/./rawdata/126854818101858304.json' not found. Skip.
# Tweet 'data/./rawdata/126854423317188608.json' not found. Skip.
# #negative: 282
# #neutral: 253
# #positive: 131
# == Pos vs. neg ==
# 0.715	0.035	0.791	0.056
# == Pos/neg vs. irrelevant/neutral ==
# 0.722	0.025	0.853	0.016
# == Pos vs. rest ==
# 0.807	0.025	0.476	0.067
# == Neg vs. rest ==
# 0.730	0.033	0.808	0.021
# ('time spent:', 5.783638000488281)

# %%
imgshow('./charts/pr_neg_vs_rest_01.png')
imgshow('./charts/pr_pos_vs_neg_01.png')
imgshow('./charts/pr_pos_vs_rest_01.png')
imgshow('./charts/pr_sent_vs_rest_01.png')

# %%
# %load 02_tuning.py

# %%
# This code is supporting material for the book
# Building Machine Learning Systems with Python
# by Willi Richert and Luis Pedro Coelho
# published by PACKT Publishing
#
# It is made available under the MIT License

#
# This script trains tries to tweak hyperparameters to improve P/R AUC
#

import time
start_time = time.time()

import numpy as np

from sklearn.metrics import precision_recall_curve, roc_curve, auc
from sklearn.cross_validation import ShuffleSplit

from utils import plot_pr
from utils import load_sanders_data
from utils import tweak_labels

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import f1_score

from sklearn.naive_bayes import MultinomialNB

phase = "02"


def create_ngram_model(params=None):
    tfidf_ngrams = TfidfVectorizer(ngram_range=(1, 3),
                                   analyzer="word", binary=False)
    clf = MultinomialNB()
    pipeline = Pipeline([('vect', tfidf_ngrams), ('clf', clf)])

    if params:
        pipeline.set_params(**params)

    return pipeline


def grid_search_model(clf_factory, X, Y):
    cv = ShuffleSplit(
        n=len(X), n_iter=10, test_size=0.3, random_state=0)

    param_grid = dict(vect__ngram_range=[(1, 1), (1, 2), (1, 3)],
                      vect__min_df=[1, 2],
                      vect__stop_words=[None, "english"],
                      vect__smooth_idf=[False, True],
                      vect__use_idf=[False, True],
                      vect__sublinear_tf=[False, True],
                      vect__binary=[False, True],
                      clf__alpha=[0, 0.01, 0.05, 0.1, 0.5, 1],
                      )

    grid_search = GridSearchCV(clf_factory(),
                               param_grid=param_grid,
                               cv=cv,
                               score_func=f1_score,
                               verbose=10)
    grid_search.fit(X, Y)
    clf = grid_search.best_estimator_
    print(clf)

    return clf


def train_model(clf, X, Y, name="NB ngram", plot=False):
    # create it again for plotting
    cv = ShuffleSplit(
        n=len(X), n_iter=10, test_size=0.3, indices=True, random_state=0)

    train_errors = []
    test_errors = []

    scores = []
    pr_scores = []
    precisions, recalls, thresholds = [], [], []

    for train, test in cv:
        X_train, y_train = X[train], Y[train]
        X_test, y_test = X[test], Y[test]

        clf.fit(X_train, y_train)

        train_score = clf.score(X_train, y_train)
        test_score = clf.score(X_test, y_test)

        train_errors.append(1 - train_score)
        test_errors.append(1 - test_score)

        scores.append(test_score)
        proba = clf.predict_proba(X_test)

        fpr, tpr, roc_thresholds = roc_curve(y_test, proba[:, 1])
        precision, recall, pr_thresholds = precision_recall_curve(
            y_test, proba[:, 1])

        pr_scores.append(auc(recall, precision))
        precisions.append(precision)
        recalls.append(recall)
        thresholds.append(pr_thresholds)

    if plot:
        scores_to_sort = pr_scores
        median = np.argsort(scores_to_sort)[len(scores_to_sort) / 2]

        plot_pr(pr_scores[median], name, phase, precisions[median],
                recalls[median], label=name)

    summary = (np.mean(scores), np.std(scores),
               np.mean(pr_scores), np.std(pr_scores))
    print("%.3f\t%.3f\t%.3f\t%.3f\t" % summary)

    return np.mean(train_errors), np.mean(test_errors)


def print_incorrect(clf, X, Y):
    Y_hat = clf.predict(X)
    wrong_idx = Y_hat != Y
    X_wrong = X[wrong_idx]
    Y_wrong = Y[wrong_idx]
    Y_hat_wrong = Y_hat[wrong_idx]
    for idx in range(len(X_wrong)):
        print("clf.predict('%s')=%i instead of %i" %
              (X_wrong[idx], Y_hat_wrong[idx], Y_wrong[idx]))


def get_best_model():
    best_params = dict(vect__ngram_range=(1, 2),
                       vect__min_df=1,
                       vect__stop_words=None,
                       vect__smooth_idf=False,
                       vect__use_idf=False,
                       vect__sublinear_tf=True,
                       vect__binary=False,
                       clf__alpha=0.01,
                       )

    best_clf = create_ngram_model(best_params)

    return best_clf

if __name__ == "__main__":
    X_orig, Y_orig = load_sanders_data()
    classes = np.unique(Y_orig)
    for c in classes:
        print("#%s: %i" % (c, sum(Y_orig == c)))

    print("== Pos vs. neg ==")
    pos_neg = np.logical_or(Y_orig == "positive", Y_orig == "negative")
    X = X_orig[pos_neg]
    Y = Y_orig[pos_neg]
    Y = tweak_labels(Y, ["positive"])
    train_model(get_best_model(), X, Y, name="pos vs neg", plot=True)

    print("== Pos/neg vs. irrelevant/neutral ==")
    X = X_orig
    Y = tweak_labels(Y_orig, ["positive", "negative"])

    # best_clf = grid_search_model(create_ngram_model, X, Y, name="sent vs
    # rest", plot=True)
    train_model(get_best_model(), X, Y, name="pos vs neg", plot=True)

    print("== Pos vs. rest ==")
    X = X_orig
    Y = tweak_labels(Y_orig, ["positive"])
    train_model(get_best_model(), X, Y, name="pos vs rest",
                plot=True)

    print("== Neg vs. rest ==")
    X = X_orig
    Y = tweak_labels(Y_orig, ["negative"])
    train_model(get_best_model(), X, Y, name="neg vs rest",
                plot=True)

    print("time spent:", time.time() - start_time)
# Out:
# Tweet 'data/./rawdata/126394830791254016.json' not found. Skip.
# Tweet 'data/./rawdata/126366123368267776.json' not found. Skip.
# Tweet 'data/./rawdata/126354605130002432.json' not found. Skip.
# Tweet 'data/./rawdata/126350948548354048.json' not found. Skip.
# Tweet 'data/./rawdata/126350302113824769.json' not found. Skip.
# Tweet 'data/./rawdata/126344048637259776.json' not found. Skip.
# Tweet 'data/./rawdata/126323785145126912.json' not found. Skip.
# Tweet 'data/./rawdata/126319186141130752.json' not found. Skip.
# Tweet 'data/./rawdata/126312877916307458.json' not found. Skip.
# Tweet 'data/./rawdata/126267185025916928.json' not found. Skip.
# Tweet 'data/./rawdata/126213333123743744.json' not found. Skip.
# Tweet 'data/./rawdata/126148685737361408.json' not found. Skip.
# Tweet 'data/./rawdata/126130991365500928.json' not found. Skip.
# Tweet 'data/./rawdata/126093298619252737.json' not found. Skip.
# Tweet 'data/./rawdata/126079414986485761.json' not found. Skip.
# Tweet 'data/./rawdata/126076743613284354.json' not found. Skip.
# Tweet 'data/./rawdata/126063569660936193.json' not found. Skip.
# Tweet 'data/./rawdata/126063358037340161.json' not found. Skip.
# Tweet 'data/./rawdata/126059399319003136.json' not found. Skip.
# Tweet 'data/./rawdata/126049183865114624.json' not found. Skip.
# Tweet 'data/./rawdata/126040352237961217.json' not found. Skip.
# Tweet 'data/./rawdata/126039929523404801.json' not found. Skip.
# Tweet 'data/./rawdata/126015087386431488.json' not found. Skip.
# Tweet 'data/./rawdata/126008369562652672.json' not found. Skip.
# Tweet 'data/./rawdata/125995158679461888.json' not found. Skip.
# Tweet 'data/./rawdata/125979338846900224.json' not found. Skip.
# Tweet 'data/./rawdata/125978473712979969.json' not found. Skip.
# Tweet 'data/./rawdata/125954443643588608.json' not found. Skip.
# Tweet 'data/./rawdata/125947232359948288.json' not found. Skip.
# Tweet 'data/./rawdata/125943290288803841.json' not found. Skip.
# Tweet 'data/./rawdata/125932869389524992.json' not found. Skip.
# Tweet 'data/./rawdata/125930171562852353.json' not found. Skip.
# Tweet 'data/./rawdata/125910633731461120.json' not found. Skip.
# Tweet 'data/./rawdata/125909565031198720.json' not found. Skip.
# Tweet 'data/./rawdata/125907732388790272.json' not found. Skip.
# Tweet 'data/./rawdata/125898611572740097.json' not found. Skip.
# Tweet 'data/./rawdata/125816853867151360.json' not found. Skip.
# Tweet 'data/./rawdata/125727629012770816.json' not found. Skip.
# Tweet 'data/./rawdata/125688922410975232.json' not found. Skip.
# Tweet 'data/./rawdata/125685656415510528.json' not found. Skip.
# Tweet 'data/./rawdata/125673004511412224.json' not found. Skip.
# Tweet 'data/./rawdata/125665606853861376.json' not found. Skip.
# Tweet 'data/./rawdata/125633065757310976.json' not found. Skip.
# Tweet 'data/./rawdata/125616280215617537.json' not found. Skip.
# Tweet 'data/./rawdata/125595292304281601.json' not found. Skip.
# Tweet 'data/./rawdata/125536884813336576.json' not found. Skip.
# Tweet 'data/./rawdata/125533599737978882.json' not found. Skip.
# Tweet 'data/./rawdata/125458901192810496.json' not found. Skip.
# Tweet 'data/./rawdata/125445056218923008.json' not found. Skip.
# Tweet 'data/./rawdata/125422502284505088.json' not found. Skip.
# Tweet 'data/./rawdata/125402636764712960.json' not found. Skip.
# Tweet 'data/./rawdata/125330595302744064.json' not found. Skip.
# Tweet 'data/./rawdata/125281706327552001.json' not found. Skip.
# Tweet 'data/./rawdata/125279447669669888.json' not found. Skip.
# Tweet 'data/./rawdata/125264731035537409.json' not found. Skip.
# Tweet 'data/./rawdata/125251672896323584.json' not found. Skip.
# Tweet 'data/./rawdata/125243911538098176.json' not found. Skip.
# Tweet 'data/./rawdata/126400637930979329.json' not found. Skip.
# Tweet 'data/./rawdata/126391082308206593.json' not found. Skip.
# Tweet 'data/./rawdata/126328782700285952.json' not found. Skip.
# Tweet 'data/./rawdata/126325125749542913.json' not found. Skip.
# Tweet 'data/./rawdata/126312535203921920.json' not found. Skip.
# Tweet 'data/./rawdata/126311879218966529.json' not found. Skip.
# Tweet 'data/./rawdata/126308005779210241.json' not found. Skip.
# Tweet 'data/./rawdata/126304942049853441.json' not found. Skip.
# Tweet 'data/./rawdata/126297241190281216.json' not found. Skip.
# Tweet 'data/./rawdata/126295434862936064.json' not found. Skip.
# Tweet 'data/./rawdata/126282994821509120.json' not found. Skip.
# Tweet 'data/./rawdata/126270073420791810.json' not found. Skip.
# Tweet 'data/./rawdata/126264313563459585.json' not found. Skip.
# Tweet 'data/./rawdata/126239832895795200.json' not found. Skip.
# Tweet 'data/./rawdata/126182880123695104.json' not found. Skip.
# Tweet 'data/./rawdata/126156590662422528.json' not found. Skip.
# Tweet 'data/./rawdata/126153311521996800.json' not found. Skip.
# Tweet 'data/./rawdata/126148955217203200.json' not found. Skip.
# Tweet 'data/./rawdata/126148565302128640.json' not found. Skip.
# Tweet 'data/./rawdata/126140389873827841.json' not found. Skip.
# Tweet 'data/./rawdata/126129938247061504.json' not found. Skip.
# Tweet 'data/./rawdata/126126605344047105.json' not found. Skip.
# Tweet 'data/./rawdata/126121175926571009.json' not found. Skip.
# Tweet 'data/./rawdata/126082198720888833.json' not found. Skip.
# Tweet 'data/./rawdata/126073788323479552.json' not found. Skip.
# Tweet 'data/./rawdata/126070647125327872.json' not found. Skip.
# Tweet 'data/./rawdata/126060639268507649.json' not found. Skip.
# Tweet 'data/./rawdata/126042137740574720.json' not found. Skip.
# Tweet 'data/./rawdata/126042022900547584.json' not found. Skip.
# Tweet 'data/./rawdata/126033747991736320.json' not found. Skip.
# Tweet 'data/./rawdata/126012404332113920.json' not found. Skip.
# Tweet 'data/./rawdata/126012089415380992.json' not found. Skip.
# Tweet 'data/./rawdata/126006088725303296.json' not found. Skip.
# Tweet 'data/./rawdata/126004661248471040.json' not found. Skip.
# Tweet 'data/./rawdata/125988395787882497.json' not found. Skip.
# Tweet 'data/./rawdata/125974810021998595.json' not found. Skip.
# Tweet 'data/./rawdata/125969502587465729.json' not found. Skip.
# Tweet 'data/./rawdata/125954651152592896.json' not found. Skip.
# Tweet 'data/./rawdata/125934808592433153.json' not found. Skip.
# Tweet 'data/./rawdata/125836461936361472.json' not found. Skip.
# Tweet 'data/./rawdata/125824054958637056.json' not found. Skip.
# Tweet 'data/./rawdata/125814380871946240.json' not found. Skip.
# Tweet 'data/./rawdata/125812985301172224.json' not found. Skip.
# Tweet 'data/./rawdata/125811345064067072.json' not found. Skip.
# Tweet 'data/./rawdata/125799384976863232.json' not found. Skip.
# Tweet 'data/./rawdata/125794882257305600.json' not found. Skip.
# Tweet 'data/./rawdata/125728250579259392.json' not found. Skip.
# Tweet 'data/./rawdata/125722610179907584.json' not found. Skip.
# Tweet 'data/./rawdata/125711996074209280.json' not found. Skip.
# Tweet 'data/./rawdata/125694815743651840.json' not found. Skip.
# Tweet 'data/./rawdata/125692685033021441.json' not found. Skip.
# Tweet 'data/./rawdata/125692532750430209.json' not found. Skip.
# Tweet 'data/./rawdata/125681375058735104.json' not found. Skip.
# Tweet 'data/./rawdata/125675806977556480.json' not found. Skip.
# Tweet 'data/./rawdata/125673358418391041.json' not found. Skip.
# Tweet 'data/./rawdata/125659125886623744.json' not found. Skip.
# Tweet 'data/./rawdata/125656618326175745.json' not found. Skip.
# Tweet 'data/./rawdata/125619303356710912.json' not found. Skip.
# Tweet 'data/./rawdata/125607492356018176.json' not found. Skip.
# Tweet 'data/./rawdata/125588697872728065.json' not found. Skip.
# Tweet 'data/./rawdata/125578269197217792.json' not found. Skip.
# Tweet 'data/./rawdata/125561930416013312.json' not found. Skip.
# Tweet 'data/./rawdata/125547255947198465.json' not found. Skip.
# Tweet 'data/./rawdata/125476730067615744.json' not found. Skip.
# Tweet 'data/./rawdata/125475953509015552.json' not found. Skip.
# Tweet 'data/./rawdata/125441732941840385.json' not found. Skip.
# Tweet 'data/./rawdata/125435218017525760.json' not found. Skip.
# Tweet 'data/./rawdata/125420263687995392.json' not found. Skip.
# Tweet 'data/./rawdata/125400161886277632.json' not found. Skip.
# Tweet 'data/./rawdata/125395636219678720.json' not found. Skip.
# Tweet 'data/./rawdata/125380163302199296.json' not found. Skip.
# Tweet 'data/./rawdata/125371779039502336.json' not found. Skip.
# Tweet 'data/./rawdata/125369698840887297.json' not found. Skip.
# Tweet 'data/./rawdata/125368089159286784.json' not found. Skip.
# Tweet 'data/./rawdata/125355139409252352.json' not found. Skip.
# Tweet 'data/./rawdata/125347619072512000.json' not found. Skip.
# Tweet 'data/./rawdata/125346783390990337.json' not found. Skip.
# Tweet 'data/./rawdata/125334519254482944.json' not found. Skip.
# Tweet 'data/./rawdata/125330337847975937.json' not found. Skip.
# Tweet 'data/./rawdata/125309427422203904.json' not found. Skip.
# Tweet 'data/./rawdata/125304159581900800.json' not found. Skip.
# Tweet 'data/./rawdata/125295729139908608.json' not found. Skip.
# Tweet 'data/./rawdata/125294978623746048.json' not found. Skip.
# Tweet 'data/./rawdata/125271422431014914.json' not found. Skip.
# Tweet 'data/./rawdata/125268117680160768.json' not found. Skip.
# Tweet 'data/./rawdata/125245246136258561.json' not found. Skip.
# Tweet 'data/./rawdata/125232266849947648.json' not found. Skip.
# Tweet 'data/./rawdata/125212404299735040.json' not found. Skip.
# Tweet 'data/./rawdata/125204228967903232.json' not found. Skip.
# Tweet 'data/./rawdata/126394795802370049.json' not found. Skip.
# Tweet 'data/./rawdata/126386085164101634.json' not found. Skip.
# Tweet 'data/./rawdata/126382776072146944.json' not found. Skip.
# Tweet 'data/./rawdata/126380323733909504.json' not found. Skip.
# Tweet 'data/./rawdata/126362867778859008.json' not found. Skip.
# Tweet 'data/./rawdata/126343124174901248.json' not found. Skip.
# Tweet 'data/./rawdata/126339328434651136.json' not found. Skip.
# Tweet 'data/./rawdata/126329388320043008.json' not found. Skip.
# Tweet 'data/./rawdata/126317201962700800.json' not found. Skip.
# Tweet 'data/./rawdata/126314701721309184.json' not found. Skip.
# Tweet 'data/./rawdata/126312423132102657.json' not found. Skip.
# Tweet 'data/./rawdata/126307117274644480.json' not found. Skip.
# Tweet 'data/./rawdata/126298592364331008.json' not found. Skip.
# Tweet 'data/./rawdata/126293725155569664.json' not found. Skip.
# Tweet 'data/./rawdata/126292233963053056.json' not found. Skip.
# Tweet 'data/./rawdata/126287512296632320.json' not found. Skip.
# Tweet 'data/./rawdata/126283639959990274.json' not found. Skip.
# Tweet 'data/./rawdata/126229089651654656.json' not found. Skip.
# Tweet 'data/./rawdata/126225922159427584.json' not found. Skip.
# Tweet 'data/./rawdata/126219340214304768.json' not found. Skip.
# Tweet 'data/./rawdata/126192452297170945.json' not found. Skip.
# Tweet 'data/./rawdata/126186955296878592.json' not found. Skip.
# Tweet 'data/./rawdata/126186795808456704.json' not found. Skip.
# Tweet 'data/./rawdata/126147867478982656.json' not found. Skip.
# Tweet 'data/./rawdata/126125799744094208.json' not found. Skip.
# Tweet 'data/./rawdata/126110770864979968.json' not found. Skip.
# Tweet 'data/./rawdata/126102213956337664.json' not found. Skip.
# Tweet 'data/./rawdata/126082898783780864.json' not found. Skip.
# Tweet 'data/./rawdata/126081812236738560.json' not found. Skip.
# Tweet 'data/./rawdata/126065983138955265.json' not found. Skip.
# Tweet 'data/./rawdata/126054725727698944.json' not found. Skip.
# Tweet 'data/./rawdata/126044185815040000.json' not found. Skip.
# Tweet 'data/./rawdata/126043954641780736.json' not found. Skip.
# Tweet 'data/./rawdata/126039090578735104.json' not found. Skip.
# Tweet 'data/./rawdata/126029114850295809.json' not found. Skip.
# Tweet 'data/./rawdata/126021436149211136.json' not found. Skip.
# Tweet 'data/./rawdata/126017685246050304.json' not found. Skip.
# Tweet 'data/./rawdata/126014277814468608.json' not found. Skip.
# Tweet 'data/./rawdata/126012833128390656.json' not found. Skip.
# Tweet 'data/./rawdata/126010471202566144.json' not found. Skip.
# Tweet 'data/./rawdata/126009386022879232.json' not found. Skip.
# Tweet 'data/./rawdata/126006669535744000.json' not found. Skip.
# Tweet 'data/./rawdata/125998732046123009.json' not found. Skip.
# Tweet 'data/./rawdata/125996412252078080.json' not found. Skip.
# Tweet 'data/./rawdata/125994997609803776.json' not found. Skip.
# Tweet 'data/./rawdata/125992594395250688.json' not found. Skip.
# Tweet 'data/./rawdata/125988651426512899.json' not found. Skip.
# Tweet 'data/./rawdata/125981074114359297.json' not found. Skip.
# Tweet 'data/./rawdata/125980615664336896.json' not found. Skip.
# Tweet 'data/./rawdata/125974497546338304.json' not found. Skip.
# Tweet 'data/./rawdata/125971256335024128.json' not found. Skip.
# Tweet 'data/./rawdata/125958702455988225.json' not found. Skip.
# Tweet 'data/./rawdata/125957972466737152.json' not found. Skip.
# Tweet 'data/./rawdata/125950026181648385.json' not found. Skip.
# Tweet 'data/./rawdata/125949784677810176.json' not found. Skip.
# Tweet 'data/./rawdata/125947460592996352.json' not found. Skip.
# Tweet 'data/./rawdata/125932876721168384.json' not found. Skip.
# Tweet 'data/./rawdata/125930342891790337.json' not found. Skip.
# Tweet 'data/./rawdata/125922500839342080.json' not found. Skip.
# Tweet 'data/./rawdata/125922174648324096.json' not found. Skip.
# Tweet 'data/./rawdata/125921393350160384.json' not found. Skip.
# Tweet 'data/./rawdata/125920729194704896.json' not found. Skip.
# Tweet 'data/./rawdata/125920725595983874.json' not found. Skip.
# Tweet 'data/./rawdata/125920721200361472.json' not found. Skip.
# Tweet 'data/./rawdata/125920717966544896.json' not found. Skip.
# Tweet 'data/./rawdata/125920716297211904.json' not found. Skip.
# Tweet 'data/./rawdata/125919221845721090.json' not found. Skip.
# Tweet 'data/./rawdata/125918906215968771.json' not found. Skip.
# Tweet 'data/./rawdata/125918450920062977.json' not found. Skip.
# Tweet 'data/./rawdata/125918447979872258.json' not found. Skip.
# Tweet 'data/./rawdata/125918444762828800.json' not found. Skip.
# Tweet 'data/./rawdata/125918441013133312.json' not found. Skip.
# Tweet 'data/./rawdata/125917264267579393.json' not found. Skip.
# Tweet 'data/./rawdata/125917174618525696.json' not found. Skip.
# Tweet 'data/./rawdata/125917170571026432.json' not found. Skip.
# Tweet 'data/./rawdata/125917164535418880.json' not found. Skip.
# Tweet 'data/./rawdata/125917160982855680.json' not found. Skip.
# Tweet 'data/./rawdata/125915210337890304.json' not found. Skip.
# Tweet 'data/./rawdata/125908946702696448.json' not found. Skip.
# Tweet 'data/./rawdata/125907633466130432.json' not found. Skip.
# Tweet 'data/./rawdata/125892140940267522.json' not found. Skip.
# Tweet 'data/./rawdata/125891898517889024.json' not found. Skip.
# Tweet 'data/./rawdata/125887065861787648.json' not found. Skip.
# Tweet 'data/./rawdata/125882473312817152.json' not found. Skip.
# Tweet 'data/./rawdata/125878880916611072.json' not found. Skip.
# Tweet 'data/./rawdata/125866627337162752.json' not found. Skip.
# Tweet 'data/./rawdata/125866368758333440.json' not found. Skip.
# Tweet 'data/./rawdata/125859792802693120.json' not found. Skip.
# Tweet 'data/./rawdata/125859488728236032.json' not found. Skip.
# Tweet 'data/./rawdata/125854430171111424.json' not found. Skip.
# Tweet 'data/./rawdata/125840474132066304.json' not found. Skip.
# Tweet 'data/./rawdata/125830917578162176.json' not found. Skip.
# Tweet 'data/./rawdata/125829040740368384.json' not found. Skip.
# Tweet 'data/./rawdata/125828984293425152.json' not found. Skip.
# Tweet 'data/./rawdata/125826820057731074.json' not found. Skip.
# Tweet 'data/./rawdata/125824709421039616.json' not found. Skip.
# Tweet 'data/./rawdata/125823389804929024.json' not found. Skip.
# Tweet 'data/./rawdata/125821979797364736.json' not found. Skip.
# Tweet 'data/./rawdata/125821218258550784.json' not found. Skip.
# Tweet 'data/./rawdata/125817967240949760.json' not found. Skip.
# Tweet 'data/./rawdata/125815990620659713.json' not found. Skip.
# Tweet 'data/./rawdata/125811943054393344.json' not found. Skip.
# Tweet 'data/./rawdata/125807897568481280.json' not found. Skip.
# Tweet 'data/./rawdata/125804983185719297.json' not found. Skip.
# Tweet 'data/./rawdata/125803571601080320.json' not found. Skip.
# Tweet 'data/./rawdata/125803457155301376.json' not found. Skip.
# Tweet 'data/./rawdata/125801811817922561.json' not found. Skip.
# Tweet 'data/./rawdata/125793487479259136.json' not found. Skip.
# Tweet 'data/./rawdata/125792596114161665.json' not found. Skip.
# Tweet 'data/./rawdata/125792107930714113.json' not found. Skip.
# Tweet 'data/./rawdata/125727869363163137.json' not found. Skip.
# Tweet 'data/./rawdata/125727349034598401.json' not found. Skip.
# Tweet 'data/./rawdata/125727044263874560.json' not found. Skip.
# Tweet 'data/./rawdata/125726769297891330.json' not found. Skip.
# Tweet 'data/./rawdata/125725274317914112.json' not found. Skip.
# Tweet 'data/./rawdata/125725019178409984.json' not found. Skip.
# Tweet 'data/./rawdata/125724524732882944.json' not found. Skip.
# Tweet 'data/./rawdata/125721197437648896.json' not found. Skip.
# Tweet 'data/./rawdata/125714971261812736.json' not found. Skip.
# Tweet 'data/./rawdata/125708425752612864.json' not found. Skip.
# Tweet 'data/./rawdata/125708240225959936.json' not found. Skip.
# Tweet 'data/./rawdata/125706125764083712.json' not found. Skip.
# Tweet 'data/./rawdata/125703536632807424.json' not found. Skip.
# Tweet 'data/./rawdata/125698733768843264.json' not found. Skip.
# Tweet 'data/./rawdata/125695449423286272.json' not found. Skip.
# Tweet 'data/./rawdata/125695107734319104.json' not found. Skip.
# Tweet 'data/./rawdata/125694587313467393.json' not found. Skip.
# Tweet 'data/./rawdata/125692890474233856.json' not found. Skip.
# Tweet 'data/./rawdata/125692845054115842.json' not found. Skip.
# Tweet 'data/./rawdata/125691975474229248.json' not found. Skip.
# Tweet 'data/./rawdata/125690764331196416.json' not found. Skip.
# Tweet 'data/./rawdata/125689905954299904.json' not found. Skip.
# Tweet 'data/./rawdata/125687710705926144.json' not found. Skip.
# Tweet 'data/./rawdata/125686643960193024.json' not found. Skip.
# Tweet 'data/./rawdata/125685016389894144.json' not found. Skip.
# Tweet 'data/./rawdata/125679996420374530.json' not found. Skip.
# Tweet 'data/./rawdata/125677838295764992.json' not found. Skip.
# Tweet 'data/./rawdata/125674121722998785.json' not found. Skip.
# Tweet 'data/./rawdata/125669834922008576.json' not found. Skip.
# Tweet 'data/./rawdata/125667332931596290.json' not found. Skip.
# Tweet 'data/./rawdata/125667159547461633.json' not found. Skip.
# Tweet 'data/./rawdata/125666909080387584.json' not found. Skip.
# Tweet 'data/./rawdata/125665930339565568.json' not found. Skip.
# Tweet 'data/./rawdata/125664999036301312.json' not found. Skip.
# Tweet 'data/./rawdata/125664891691474944.json' not found. Skip.
# Tweet 'data/./rawdata/125663967296229376.json' not found. Skip.
# Tweet 'data/./rawdata/125663914552868864.json' not found. Skip.
# Tweet 'data/./rawdata/125661036891226113.json' not found. Skip.
# Tweet 'data/./rawdata/125660067482697729.json' not found. Skip.
# Tweet 'data/./rawdata/125657950185463808.json' not found. Skip.
# Tweet 'data/./rawdata/125647236418912256.json' not found. Skip.
# Tweet 'data/./rawdata/125645376790331392.json' not found. Skip.
# Tweet 'data/./rawdata/125643523792969728.json' not found. Skip.
# Tweet 'data/./rawdata/125642256114909184.json' not found. Skip.
# Tweet 'data/./rawdata/125642161659199488.json' not found. Skip.
# Tweet 'data/./rawdata/125642041140060160.json' not found. Skip.
# Tweet 'data/./rawdata/125641351848136704.json' not found. Skip.
# Tweet 'data/./rawdata/125640758966484992.json' not found. Skip.
# Tweet 'data/./rawdata/125640679325052929.json' not found. Skip.
# Tweet 'data/./rawdata/125640515021578240.json' not found. Skip.
# Tweet 'data/./rawdata/125638955952640000.json' not found. Skip.
# Tweet 'data/./rawdata/125633549847117824.json' not found. Skip.
# Tweet 'data/./rawdata/125633468708302848.json' not found. Skip.
# Tweet 'data/./rawdata/125633233982459904.json' not found. Skip.
# Tweet 'data/./rawdata/125632687879884800.json' not found. Skip.
# Tweet 'data/./rawdata/125632582795804672.json' not found. Skip.
# Tweet 'data/./rawdata/125631556051140608.json' not found. Skip.
# Tweet 'data/./rawdata/125630955154190336.json' not found. Skip.
# Tweet 'data/./rawdata/125630836245676033.json' not found. Skip.
# Tweet 'data/./rawdata/125630016485732352.json' not found. Skip.
# Tweet 'data/./rawdata/125629788563050496.json' not found. Skip.
# Tweet 'data/./rawdata/125627732032888833.json' not found. Skip.
# Tweet 'data/./rawdata/125626286939979776.json' not found. Skip.
# Tweet 'data/./rawdata/125625630254567424.json' not found. Skip.
# Tweet 'data/./rawdata/125625566203346944.json' not found. Skip.
# Tweet 'data/./rawdata/125620113582993408.json' not found. Skip.
# Tweet 'data/./rawdata/125617451705712640.json' not found. Skip.
# Tweet 'data/./rawdata/125617133123153921.json' not found. Skip.
# Tweet 'data/./rawdata/125616747863736320.json' not found. Skip.
# Tweet 'data/./rawdata/125614951787266048.json' not found. Skip.
# Tweet 'data/./rawdata/125614910804738049.json' not found. Skip.
# Tweet 'data/./rawdata/125607526967410689.json' not found. Skip.
# Tweet 'data/./rawdata/125598495137726464.json' not found. Skip.
# Tweet 'data/./rawdata/125596991290998784.json' not found. Skip.
# Tweet 'data/./rawdata/125595669145722880.json' not found. Skip.
# Tweet 'data/./rawdata/125595441562783744.json' not found. Skip.
# Tweet 'data/./rawdata/125591434056318977.json' not found. Skip.
# Tweet 'data/./rawdata/125589884445536257.json' not found. Skip.
# Tweet 'data/./rawdata/125589258898644992.json' not found. Skip.
# Tweet 'data/./rawdata/125588749454278656.json' not found. Skip.
# Tweet 'data/./rawdata/125588587180863489.json' not found. Skip.
# Tweet 'data/./rawdata/125587186723725312.json' not found. Skip.
# Tweet 'data/./rawdata/125586682790674434.json' not found. Skip.
# Tweet 'data/./rawdata/125585063327956992.json' not found. Skip.
# Tweet 'data/./rawdata/125583717354831872.json' not found. Skip.
# Tweet 'data/./rawdata/125581507355086848.json' not found. Skip.
# Tweet 'data/./rawdata/125581280430669824.json' not found. Skip.
# Tweet 'data/./rawdata/125564573167263746.json' not found. Skip.
# Tweet 'data/./rawdata/125559846870323200.json' not found. Skip.
# Tweet 'data/./rawdata/125559232157327360.json' not found. Skip.
# Tweet 'data/./rawdata/125551370676862976.json' not found. Skip.
# Tweet 'data/./rawdata/125546017205665792.json' not found. Skip.
# Tweet 'data/./rawdata/125545914864640000.json' not found. Skip.
# Tweet 'data/./rawdata/125544363945230336.json' not found. Skip.
# Tweet 'data/./rawdata/125541112491425792.json' not found. Skip.
# Tweet 'data/./rawdata/125538769632886784.json' not found. Skip.
# Tweet 'data/./rawdata/125537487455137793.json' not found. Skip.
# Tweet 'data/./rawdata/125532364406398977.json' not found. Skip.
# Tweet 'data/./rawdata/125532202057482240.json' not found. Skip.
# Tweet 'data/./rawdata/125528344480587776.json' not found. Skip.
# Tweet 'data/./rawdata/125527718203887616.json' not found. Skip.
# Tweet 'data/./rawdata/125512197135806464.json' not found. Skip.
# Tweet 'data/./rawdata/125498684401135616.json' not found. Skip.
# Tweet 'data/./rawdata/125496516000485376.json' not found. Skip.
# Tweet 'data/./rawdata/125493419522002944.json' not found. Skip.
# Tweet 'data/./rawdata/125493125098635265.json' not found. Skip.
# Tweet 'data/./rawdata/125489264157917184.json' not found. Skip.
# Tweet 'data/./rawdata/125486845768368128.json' not found. Skip.
# Tweet 'data/./rawdata/125460019859820544.json' not found. Skip.
# Tweet 'data/./rawdata/125459423870197760.json' not found. Skip.
# Tweet 'data/./rawdata/125459375245635584.json' not found. Skip.
# Tweet 'data/./rawdata/125457535951060993.json' not found. Skip.
# Tweet 'data/./rawdata/125448837404954624.json' not found. Skip.
# Tweet 'data/./rawdata/125433354488254464.json' not found. Skip.
# Tweet 'data/./rawdata/125432626482917376.json' not found. Skip.
# Tweet 'data/./rawdata/125432518324400128.json' not found. Skip.
# Tweet 'data/./rawdata/125425087800291328.json' not found. Skip.
# Tweet 'data/./rawdata/125424738662223872.json' not found. Skip.
# Tweet 'data/./rawdata/125419216227667968.json' not found. Skip.
# Tweet 'data/./rawdata/125417324621737985.json' not found. Skip.
# Tweet 'data/./rawdata/125416866243018753.json' not found. Skip.
# Tweet 'data/./rawdata/125416811490578435.json' not found. Skip.
# Tweet 'data/./rawdata/125410153196560384.json' not found. Skip.
# Tweet 'data/./rawdata/125409201907437569.json' not found. Skip.
# Tweet 'data/./rawdata/125406528487424003.json' not found. Skip.
# Tweet 'data/./rawdata/125406003863883776.json' not found. Skip.
# Tweet 'data/./rawdata/125405939015757824.json' not found. Skip.
# Tweet 'data/./rawdata/125402652610797569.json' not found. Skip.
# Tweet 'data/./rawdata/125398913313284096.json' not found. Skip.
# Tweet 'data/./rawdata/125398813543374848.json' not found. Skip.
# Tweet 'data/./rawdata/125394805449699329.json' not found. Skip.
# Tweet 'data/./rawdata/125379023307153408.json' not found. Skip.
# Tweet 'data/./rawdata/125374041556127744.json' not found. Skip.
# Tweet 'data/./rawdata/125373658389692416.json' not found. Skip.
# Tweet 'data/./rawdata/125373427661029376.json' not found. Skip.
# Tweet 'data/./rawdata/125372628746768384.json' not found. Skip.
# Tweet 'data/./rawdata/125369026351349760.json' not found. Skip.
# Tweet 'data/./rawdata/125368381728763904.json' not found. Skip.
# Tweet 'data/./rawdata/125367492976717824.json' not found. Skip.
# Tweet 'data/./rawdata/125366519680086016.json' not found. Skip.
# Tweet 'data/./rawdata/125365963972542464.json' not found. Skip.
# Tweet 'data/./rawdata/125365264656236544.json' not found. Skip.
# Tweet 'data/./rawdata/125364154629492737.json' not found. Skip.
# Tweet 'data/./rawdata/125364122853453824.json' not found. Skip.
# Tweet 'data/./rawdata/125361209137565696.json' not found. Skip.
# Tweet 'data/./rawdata/125360952878182400.json' not found. Skip.
# Tweet 'data/./rawdata/125360877359742976.json' not found. Skip.
# Tweet 'data/./rawdata/125359697770450944.json' not found. Skip.
# Tweet 'data/./rawdata/125359622193295360.json' not found. Skip.
# Tweet 'data/./rawdata/125357901580746752.json' not found. Skip.
# Tweet 'data/./rawdata/125354296752619520.json' not found. Skip.
# Tweet 'data/./rawdata/125351067620880385.json' not found. Skip.
# Tweet 'data/./rawdata/125350537821569024.json' not found. Skip.
# Tweet 'data/./rawdata/125347828754169856.json' not found. Skip.
# Tweet 'data/./rawdata/125347618862792705.json' not found. Skip.
# Tweet 'data/./rawdata/125345723020607488.json' not found. Skip.
# Tweet 'data/./rawdata/125344722196766720.json' not found. Skip.
# Tweet 'data/./rawdata/125344351218974720.json' not found. Skip.
# Tweet 'data/./rawdata/125338231280644096.json' not found. Skip.
# Tweet 'data/./rawdata/125336929825849344.json' not found. Skip.
# Tweet 'data/./rawdata/125336798690942977.json' not found. Skip.
# Tweet 'data/./rawdata/125335012961828866.json' not found. Skip.
# Tweet 'data/./rawdata/125332871174037504.json' not found. Skip.
# Tweet 'data/./rawdata/125332609428496384.json' not found. Skip.
# Tweet 'data/./rawdata/125327281181835264.json' not found. Skip.
# Tweet 'data/./rawdata/125326760769372160.json' not found. Skip.
# Tweet 'data/./rawdata/125325397712846848.json' not found. Skip.
# Tweet 'data/./rawdata/125324916009615360.json' not found. Skip.
# Tweet 'data/./rawdata/125321084525490176.json' not found. Skip.
# Tweet 'data/./rawdata/125318029390249984.json' not found. Skip.
# Tweet 'data/./rawdata/125317541504626688.json' not found. Skip.
# Tweet 'data/./rawdata/125317300860620801.json' not found. Skip.
# Tweet 'data/./rawdata/125315460030922752.json' not found. Skip.
# Tweet 'data/./rawdata/125315263183851521.json' not found. Skip.
# Tweet 'data/./rawdata/125315080081518592.json' not found. Skip.
# Tweet 'data/./rawdata/125312789345599489.json' not found. Skip.
# Tweet 'data/./rawdata/125312357797863425.json' not found. Skip.
# Tweet 'data/./rawdata/125309663913840640.json' not found. Skip.
# Tweet 'data/./rawdata/125305567148388352.json' not found. Skip.
# Tweet 'data/./rawdata/125300705836793856.json' not found. Skip.
# Tweet 'data/./rawdata/125300603059576833.json' not found. Skip.
# Tweet 'data/./rawdata/125287442407362560.json' not found. Skip.
# Tweet 'data/./rawdata/125283873331494913.json' not found. Skip.
# Tweet 'data/./rawdata/125281502866059264.json' not found. Skip.
# Tweet 'data/./rawdata/125278676949544960.json' not found. Skip.
# Tweet 'data/./rawdata/125276525472911360.json' not found. Skip.
# Tweet 'data/./rawdata/125275795252977664.json' not found. Skip.
# Tweet 'data/./rawdata/125275280678993920.json' not found. Skip.
# Tweet 'data/./rawdata/125273317673414656.json' not found. Skip.
# Tweet 'data/./rawdata/125270965268643840.json' not found. Skip.
# Tweet 'data/./rawdata/125267017942052866.json' not found. Skip.
# Tweet 'data/./rawdata/125266503657472000.json' not found. Skip.
# Tweet 'data/./rawdata/125261029834899456.json' not found. Skip.
# Tweet 'data/./rawdata/125260105154437121.json' not found. Skip.
# Tweet 'data/./rawdata/125257803790159873.json' not found. Skip.
# Tweet 'data/./rawdata/125252442836320256.json' not found. Skip.
# Tweet 'data/./rawdata/125250721280040961.json' not found. Skip.
# Tweet 'data/./rawdata/125250617911418881.json' not found. Skip.
# Tweet 'data/./rawdata/125250078108684288.json' not found. Skip.
# Tweet 'data/./rawdata/125246898830458880.json' not found. Skip.
# Tweet 'data/./rawdata/125245892814045184.json' not found. Skip.
# Tweet 'data/./rawdata/125244798671142912.json' not found. Skip.
# Tweet 'data/./rawdata/125231250247135233.json' not found. Skip.
# Tweet 'data/./rawdata/125227689895407616.json' not found. Skip.
# Tweet 'data/./rawdata/125222749034659840.json' not found. Skip.
# Tweet 'data/./rawdata/125218106778992640.json' not found. Skip.
# Tweet 'data/./rawdata/125211793655218178.json' not found. Skip.
# Tweet 'data/./rawdata/125206271560384512.json' not found. Skip.
# Tweet 'data/./rawdata/125196751387889665.json' not found. Skip.
# Tweet 'data/./rawdata/125193298624258049.json' not found. Skip.
# Tweet 'data/./rawdata/125184976579862530.json' not found. Skip.
# Tweet 'data/./rawdata/125085987431923713.json' not found. Skip.
# Tweet 'data/./rawdata/126405660308021248.json' not found. Skip.
# Tweet 'data/./rawdata/126403953058529280.json' not found. Skip.
# Tweet 'data/./rawdata/126402391259103232.json' not found. Skip.
# Tweet 'data/./rawdata/126399172495679488.json' not found. Skip.
# Tweet 'data/./rawdata/126394266145665025.json' not found. Skip.
# Tweet 'data/./rawdata/126391727408947200.json' not found. Skip.
# Tweet 'data/./rawdata/126387209824776192.json' not found. Skip.
# Tweet 'data/./rawdata/126385587740610563.json' not found. Skip.
# Tweet 'data/./rawdata/126381904621600768.json' not found. Skip.
# Tweet 'data/./rawdata/126379095004160001.json' not found. Skip.
# Tweet 'data/./rawdata/126373281099026432.json' not found. Skip.
# Tweet 'data/./rawdata/126367728754884609.json' not found. Skip.
# Tweet 'data/./rawdata/126362562865528832.json' not found. Skip.
# Tweet 'data/./rawdata/126360606042374144.json' not found. Skip.
# Tweet 'data/./rawdata/126355839274594304.json' not found. Skip.
# Tweet 'data/./rawdata/126355573586399232.json' not found. Skip.
# Tweet 'data/./rawdata/126352049070809089.json' not found. Skip.
# Tweet 'data/./rawdata/126346705292640257.json' not found. Skip.
# Tweet 'data/./rawdata/126346563147673600.json' not found. Skip.
# Tweet 'data/./rawdata/126346004688674816.json' not found. Skip.
# Tweet 'data/./rawdata/126342441057001472.json' not found. Skip.
# Tweet 'data/./rawdata/126340074777489408.json' not found. Skip.
# Tweet 'data/./rawdata/126332817134190592.json' not found. Skip.
# Tweet 'data/./rawdata/126331879883415552.json' not found. Skip.
# Tweet 'data/./rawdata/126329876935479296.json' not found. Skip.
# Tweet 'data/./rawdata/126319126913363968.json' not found. Skip.
# Tweet 'data/./rawdata/126313259572793345.json' not found. Skip.
# Tweet 'data/./rawdata/126312509983559681.json' not found. Skip.
# Tweet 'data/./rawdata/126310736577298432.json' not found. Skip.
# Tweet 'data/./rawdata/126307114959372289.json' not found. Skip.
# Tweet 'data/./rawdata/126304243144597505.json' not found. Skip.
# Tweet 'data/./rawdata/126303928039116800.json' not found. Skip.
# Tweet 'data/./rawdata/126303310054559744.json' not found. Skip.
# Tweet 'data/./rawdata/126298834203713536.json' not found. Skip.
# Tweet 'data/./rawdata/126298134212120577.json' not found. Skip.
# Tweet 'data/./rawdata/126297754799587328.json' not found. Skip.
# Tweet 'data/./rawdata/126290039138291712.json' not found. Skip.
# Tweet 'data/./rawdata/126271901340401665.json' not found. Skip.
# Tweet 'data/./rawdata/126270990459219968.json' not found. Skip.
# Tweet 'data/./rawdata/126264647652343808.json' not found. Skip.
# Tweet 'data/./rawdata/126264035007143936.json' not found. Skip.
# Tweet 'data/./rawdata/126263600548556800.json' not found. Skip.
# Tweet 'data/./rawdata/126260304819662849.json' not found. Skip.
# Tweet 'data/./rawdata/126252530819809280.json' not found. Skip.
# Tweet 'data/./rawdata/126236984644612096.json' not found. Skip.
# Tweet 'data/./rawdata/126232767821381632.json' not found. Skip.
# Tweet 'data/./rawdata/126228762596618240.json' not found. Skip.
# Tweet 'data/./rawdata/126215978341236736.json' not found. Skip.
# Tweet 'data/./rawdata/126195701704163328.json' not found. Skip.
# Tweet 'data/./rawdata/126186608113356800.json' not found. Skip.
# Tweet 'data/./rawdata/126175729024122880.json' not found. Skip.
# Tweet 'data/./rawdata/126173465253384193.json' not found. Skip.
# Tweet 'data/./rawdata/126164921485492224.json' not found. Skip.
# Tweet 'data/./rawdata/126149195957673984.json' not found. Skip.
# Tweet 'data/./rawdata/126138637652992001.json' not found. Skip.
# Tweet 'data/./rawdata/126131070050639874.json' not found. Skip.
# Tweet 'data/./rawdata/126111632773480448.json' not found. Skip.
# Tweet 'data/./rawdata/126097345124368385.json' not found. Skip.
# Tweet 'data/./rawdata/126093841232166912.json' not found. Skip.
# Tweet 'data/./rawdata/126061579233017856.json' not found. Skip.
# Tweet 'data/./rawdata/126054622564589569.json' not found. Skip.
# Tweet 'data/./rawdata/126054568273518592.json' not found. Skip.
# Tweet 'data/./rawdata/126052637014630400.json' not found. Skip.
# Tweet 'data/./rawdata/126042611709521921.json' not found. Skip.
# Tweet 'data/./rawdata/126024290201124864.json' not found. Skip.
# Tweet 'data/./rawdata/126022958710915072.json' not found. Skip.
# Tweet 'data/./rawdata/126022708524888064.json' not found. Skip.
# Tweet 'data/./rawdata/126007147199868928.json' not found. Skip.
# Tweet 'data/./rawdata/126005063595466753.json' not found. Skip.
# Tweet 'data/./rawdata/126001383869644800.json' not found. Skip.
# Tweet 'data/./rawdata/126000885485678592.json' not found. Skip.
# Tweet 'data/./rawdata/125998496535937024.json' not found. Skip.
# Tweet 'data/./rawdata/125996653990772737.json' not found. Skip.
# Tweet 'data/./rawdata/125993886249267200.json' not found. Skip.
# Tweet 'data/./rawdata/125993438205321218.json' not found. Skip.
# Tweet 'data/./rawdata/125993305325576193.json' not found. Skip.
# Tweet 'data/./rawdata/125992545552576512.json' not found. Skip.
# Tweet 'data/./rawdata/125991634855923712.json' not found. Skip.
# Tweet 'data/./rawdata/125990804488601600.json' not found. Skip.
# Tweet 'data/./rawdata/125990754769309696.json' not found. Skip.
# Tweet 'data/./rawdata/125982640263274496.json' not found. Skip.
# Tweet 'data/./rawdata/125973789526863872.json' not found. Skip.
# Tweet 'data/./rawdata/125970459404673026.json' not found. Skip.
# Tweet 'data/./rawdata/125968277083136000.json' not found. Skip.
# Tweet 'data/./rawdata/125967413299773440.json' not found. Skip.
# Tweet 'data/./rawdata/125967315488608257.json' not found. Skip.
# Tweet 'data/./rawdata/125965369532878849.json' not found. Skip.
# Tweet 'data/./rawdata/125965364667486209.json' not found. Skip.
# Tweet 'data/./rawdata/125959699089719297.json' not found. Skip.
# Tweet 'data/./rawdata/125959482588143616.json' not found. Skip.
# Tweet 'data/./rawdata/125957826500771840.json' not found. Skip.
# Tweet 'data/./rawdata/125957742698561537.json' not found. Skip.
# Tweet 'data/./rawdata/125948329694724097.json' not found. Skip.
# Tweet 'data/./rawdata/125930962545672192.json' not found. Skip.
# Tweet 'data/./rawdata/125928640394432513.json' not found. Skip.
# Tweet 'data/./rawdata/125910538550124545.json' not found. Skip.
# Tweet 'data/./rawdata/125909170074562561.json' not found. Skip.
# Tweet 'data/./rawdata/125877369796968448.json' not found. Skip.
# Tweet 'data/./rawdata/125873952953352192.json' not found. Skip.
# Tweet 'data/./rawdata/125862601677737985.json' not found. Skip.
# Tweet 'data/./rawdata/125857117407166464.json' not found. Skip.
# Tweet 'data/./rawdata/125827656238379008.json' not found. Skip.
# Tweet 'data/./rawdata/125826633713201152.json' not found. Skip.
# Tweet 'data/./rawdata/125825293473685505.json' not found. Skip.
# Tweet 'data/./rawdata/125815316596002816.json' not found. Skip.
# Tweet 'data/./rawdata/125797001337122817.json' not found. Skip.
# Tweet 'data/./rawdata/125724424774221826.json' not found. Skip.
# Tweet 'data/./rawdata/125707107495452673.json' not found. Skip.
# Tweet 'data/./rawdata/125705666592641024.json' not found. Skip.
# Tweet 'data/./rawdata/125705646942330880.json' not found. Skip.
# Tweet 'data/./rawdata/125699684693065728.json' not found. Skip.
# Tweet 'data/./rawdata/125695680135172096.json' not found. Skip.
# Tweet 'data/./rawdata/125695094836826112.json' not found. Skip.
# Tweet 'data/./rawdata/125653144993660928.json' not found. Skip.
# Tweet 'data/./rawdata/125650076759638016.json' not found. Skip.
# Tweet 'data/./rawdata/125647972087242754.json' not found. Skip.
# Tweet 'data/./rawdata/125641150186000384.json' not found. Skip.
# Tweet 'data/./rawdata/125622089502830592.json' not found. Skip.
# Tweet 'data/./rawdata/125621628917915648.json' not found. Skip.
# Tweet 'data/./rawdata/125602732278169601.json' not found. Skip.
# Tweet 'data/./rawdata/125595437938905088.json' not found. Skip.
# Tweet 'data/./rawdata/125590191502131200.json' not found. Skip.
# Tweet 'data/./rawdata/125580342244548608.json' not found. Skip.
# Tweet 'data/./rawdata/125568051277086721.json' not found. Skip.
# Tweet 'data/./rawdata/125542968844226560.json' not found. Skip.
# Tweet 'data/./rawdata/125542941287649280.json' not found. Skip.
# Tweet 'data/./rawdata/125534067495141376.json' not found. Skip.
# Tweet 'data/./rawdata/125526544377577472.json' not found. Skip.
# Tweet 'data/./rawdata/125521498055254016.json' not found. Skip.
# Tweet 'data/./rawdata/125521344342392832.json' not found. Skip.
# Tweet 'data/./rawdata/125516954407677952.json' not found. Skip.
# Tweet 'data/./rawdata/125495075504537600.json' not found. Skip.
# Tweet 'data/./rawdata/125490577130258432.json' not found. Skip.
# Tweet 'data/./rawdata/125485687339352064.json' not found. Skip.
# Tweet 'data/./rawdata/125447473786392576.json' not found. Skip.
# Tweet 'data/./rawdata/125445752083329025.json' not found. Skip.
# Tweet 'data/./rawdata/125445407592546304.json' not found. Skip.
# Tweet 'data/./rawdata/125421514928558080.json' not found. Skip.
# Tweet 'data/./rawdata/125411589905068033.json' not found. Skip.
# Tweet 'data/./rawdata/125409044222586880.json' not found. Skip.
# Tweet 'data/./rawdata/125406418777018368.json' not found. Skip.
# Tweet 'data/./rawdata/125405429583970305.json' not found. Skip.
# Tweet 'data/./rawdata/125375333162684416.json' not found. Skip.
# Tweet 'data/./rawdata/125361267555835905.json' not found. Skip.
# Tweet 'data/./rawdata/125353260520443904.json' not found. Skip.
# Tweet 'data/./rawdata/125352405482217473.json' not found. Skip.
# Tweet 'data/./rawdata/125346522618535937.json' not found. Skip.
# Tweet 'data/./rawdata/125339193802100736.json' not found. Skip.
# Tweet 'data/./rawdata/125336882862231552.json' not found. Skip.
# Tweet 'data/./rawdata/125333140414808065.json' not found. Skip.
# Tweet 'data/./rawdata/125325092841467904.json' not found. Skip.
# Tweet 'data/./rawdata/125321769203666944.json' not found. Skip.
# Tweet 'data/./rawdata/125319263027343360.json' not found. Skip.
# Tweet 'data/./rawdata/125305753903964161.json' not found. Skip.
# Tweet 'data/./rawdata/125301831286013952.json' not found. Skip.
# Tweet 'data/./rawdata/125287180561166336.json' not found. Skip.
# Tweet 'data/./rawdata/125275735815491584.json' not found. Skip.
# Tweet 'data/./rawdata/125232405517844481.json' not found. Skip.
# Tweet 'data/./rawdata/125228207002759168.json' not found. Skip.
# Tweet 'data/./rawdata/125219664488960000.json' not found. Skip.
# Tweet 'data/./rawdata/125209676416679936.json' not found. Skip.
# Tweet 'data/./rawdata/125206785584922624.json' not found. Skip.
# Tweet 'data/./rawdata/125184213342367744.json' not found. Skip.
# Tweet 'data/./rawdata/125082707389718529.json' not found. Skip.
# Tweet 'data/./rawdata/126534770095169536.json' not found. Skip.
# Tweet 'data/./rawdata/126534201880219648.json' not found. Skip.
# Tweet 'data/./rawdata/126534020367519744.json' not found. Skip.
# Tweet 'data/./rawdata/126533948925952000.json' not found. Skip.
# Tweet 'data/./rawdata/126533885109600256.json' not found. Skip.
# Tweet 'data/./rawdata/126533562781544448.json' not found. Skip.
# Tweet 'data/./rawdata/126533349727666176.json' not found. Skip.
# Tweet 'data/./rawdata/126533268119109632.json' not found. Skip.
# Tweet 'data/./rawdata/126533166352699392.json' not found. Skip.
# Tweet 'data/./rawdata/126532897715929088.json' not found. Skip.
# Tweet 'data/./rawdata/126531552367751169.json' not found. Skip.
# Tweet 'data/./rawdata/126531180907601920.json' not found. Skip.
# Tweet 'data/./rawdata/126530945976238080.json' not found. Skip.
# Tweet 'data/./rawdata/126530924576907264.json' not found. Skip.
# Tweet 'data/./rawdata/126530807891374082.json' not found. Skip.
# Tweet 'data/./rawdata/126530189579649024.json' not found. Skip.
# Tweet 'data/./rawdata/126530027939569665.json' not found. Skip.
# Tweet 'data/./rawdata/126529770778411008.json' not found. Skip.
# Tweet 'data/./rawdata/126528982807089152.json' not found. Skip.
# Tweet 'data/./rawdata/126528978239496194.json' not found. Skip.
# Tweet 'data/./rawdata/126528804192653312.json' not found. Skip.
# Tweet 'data/./rawdata/126528264117293056.json' not found. Skip.
# Tweet 'data/./rawdata/126526219587039233.json' not found. Skip.
# Tweet 'data/./rawdata/126525469897146368.json' not found. Skip.
# Tweet 'data/./rawdata/126525368860540928.json' not found. Skip.
# Tweet 'data/./rawdata/126525172969766912.json' not found. Skip.
# Tweet 'data/./rawdata/126524301259194368.json' not found. Skip.
# Tweet 'data/./rawdata/126523731710443521.json' not found. Skip.
# Tweet 'data/./rawdata/126523530903953408.json' not found. Skip.
# Tweet 'data/./rawdata/126523525598162944.json' not found. Skip.
# Tweet 'data/./rawdata/126522990585315328.json' not found. Skip.
# Tweet 'data/./rawdata/126522810821644288.json' not found. Skip.
# Tweet 'data/./rawdata/126522714713370624.json' not found. Skip.
# Tweet 'data/./rawdata/126522621251682304.json' not found. Skip.
# Tweet 'data/./rawdata/126522262768726016.json' not found. Skip.
# Tweet 'data/./rawdata/126521613259771904.json' not found. Skip.
# Tweet 'data/./rawdata/126521382220738560.json' not found. Skip.
# Tweet 'data/./rawdata/126521286053724160.json' not found. Skip.
# Tweet 'data/./rawdata/126520518609350656.json' not found. Skip.
# Tweet 'data/./rawdata/126520029410885632.json' not found. Skip.
# Tweet 'data/./rawdata/126519483752914944.json' not found. Skip.
# Tweet 'data/./rawdata/126519329025040384.json' not found. Skip.
# Tweet 'data/./rawdata/126519123772588032.json' not found. Skip.
# Tweet 'data/./rawdata/126519017405030400.json' not found. Skip.
# Tweet 'data/./rawdata/126518882939838464.json' not found. Skip.
# Tweet 'data/./rawdata/126516914678808578.json' not found. Skip.
# Tweet 'data/./rawdata/126516779886456832.json' not found. Skip.
# Tweet 'data/./rawdata/126516304336257025.json' not found. Skip.
# Tweet 'data/./rawdata/126515760855134208.json' not found. Skip.
# Tweet 'data/./rawdata/126514474378203136.json' not found. Skip.
# Tweet 'data/./rawdata/126513620686352384.json' not found. Skip.
# Tweet 'data/./rawdata/126513526385819648.json' not found. Skip.
# Tweet 'data/./rawdata/126513425043030016.json' not found. Skip.
# Tweet 'data/./rawdata/126512728297844736.json' not found. Skip.
# Tweet 'data/./rawdata/126512631937904640.json' not found. Skip.
# Tweet 'data/./rawdata/126512208451600384.json' not found. Skip.
# Tweet 'data/./rawdata/126511837796765696.json' not found. Skip.
# Tweet 'data/./rawdata/126511545160171520.json' not found. Skip.
# Tweet 'data/./rawdata/126511426926944256.json' not found. Skip.
# Tweet 'data/./rawdata/126511000907288576.json' not found. Skip.
# Tweet 'data/./rawdata/126510977335300096.json' not found. Skip.
# Tweet 'data/./rawdata/126510551789604864.json' not found. Skip.
# Tweet 'data/./rawdata/126509929619132417.json' not found. Skip.
# Tweet 'data/./rawdata/126509528287166464.json' not found. Skip.
# Tweet 'data/./rawdata/126508433582211072.json' not found. Skip.
# Tweet 'data/./rawdata/126508393203642368.json' not found. Skip.
# Tweet 'data/./rawdata/126507456019968000.json' not found. Skip.
# Tweet 'data/./rawdata/126507105023819776.json' not found. Skip.
# Tweet 'data/./rawdata/126506850781888512.json' not found. Skip.
# Tweet 'data/./rawdata/126506410195431424.json' not found. Skip.
# Tweet 'data/./rawdata/126506064387637249.json' not found. Skip.
# Tweet 'data/./rawdata/126505384428052481.json' not found. Skip.
# Tweet 'data/./rawdata/126505187752943616.json' not found. Skip.
# Tweet 'data/./rawdata/126505144878772224.json' not found. Skip.
# Tweet 'data/./rawdata/126504782465732608.json' not found. Skip.
# Tweet 'data/./rawdata/126504452680187905.json' not found. Skip.
# Tweet 'data/./rawdata/126504346639802368.json' not found. Skip.
# Tweet 'data/./rawdata/126504216004005888.json' not found. Skip.
# Tweet 'data/./rawdata/126504013939216384.json' not found. Skip.
# Tweet 'data/./rawdata/126503946092158976.json' not found. Skip.
# Tweet 'data/./rawdata/126503805369069568.json' not found. Skip.
# Tweet 'data/./rawdata/126503790412181504.json' not found. Skip.
# Tweet 'data/./rawdata/126503029548654593.json' not found. Skip.
# Tweet 'data/./rawdata/126502415322193920.json' not found. Skip.
# Tweet 'data/./rawdata/126502014560649216.json' not found. Skip.
# Tweet 'data/./rawdata/126501732443361280.json' not found. Skip.
# Tweet 'data/./rawdata/126501468902658048.json' not found. Skip.
# Tweet 'data/./rawdata/126500614552289282.json' not found. Skip.
# Tweet 'data/./rawdata/126499965869625345.json' not found. Skip.
# Tweet 'data/./rawdata/126499581520384001.json' not found. Skip.
# Tweet 'data/./rawdata/126499428965158912.json' not found. Skip.
# Tweet 'data/./rawdata/126499145014980608.json' not found. Skip.
# Tweet 'data/./rawdata/126499143282737152.json' not found. Skip.
# Tweet 'data/./rawdata/126498734409396224.json' not found. Skip.
# Tweet 'data/./rawdata/126498608815149056.json' not found. Skip.
# Tweet 'data/./rawdata/126498587499696128.json' not found. Skip.
# Tweet 'data/./rawdata/126497976314109952.json' not found. Skip.
# Tweet 'data/./rawdata/126497860752646146.json' not found. Skip.
# Tweet 'data/./rawdata/126497655785402368.json' not found. Skip.
# Tweet 'data/./rawdata/126496772586610688.json' not found. Skip.
# Tweet 'data/./rawdata/126496739531304960.json' not found. Skip.
# Tweet 'data/./rawdata/126496342901133313.json' not found. Skip.
# Tweet 'data/./rawdata/126496262668292096.json' not found. Skip.
# Tweet 'data/./rawdata/126496155856142336.json' not found. Skip.
# Tweet 'data/./rawdata/126496005809127424.json' not found. Skip.
# Tweet 'data/./rawdata/126495843116265475.json' not found. Skip.
# Tweet 'data/./rawdata/126495812724338688.json' not found. Skip.
# Tweet 'data/./rawdata/126495283176685569.json' not found. Skip.
# Tweet 'data/./rawdata/126495221373607936.json' not found. Skip.
# Tweet 'data/./rawdata/126494976396898305.json' not found. Skip.
# Tweet 'data/./rawdata/126494883367235585.json' not found. Skip.
# Tweet 'data/./rawdata/126494838689513473.json' not found. Skip.
# Tweet 'data/./rawdata/126494834449063936.json' not found. Skip.
# Tweet 'data/./rawdata/126494645281755136.json' not found. Skip.
# Tweet 'data/./rawdata/126494573966016512.json' not found. Skip.
# Tweet 'data/./rawdata/126494442290020352.json' not found. Skip.
# Tweet 'data/./rawdata/126494344566943744.json' not found. Skip.
# Tweet 'data/./rawdata/126494339248562176.json' not found. Skip.
# ...
# Tweet 'data/./rawdata/126866426521849857.json' not found. Skip.
# Tweet 'data/./rawdata/126866385757417472.json' not found. Skip.
# Tweet 'data/./rawdata/126866312130609152.json' not found. Skip.
# Tweet 'data/./rawdata/126866267998134272.json' not found. Skip.
# Tweet 'data/./rawdata/126866222355722240.json' not found. Skip.
# Tweet 'data/./rawdata/126866176889454592.json' not found. Skip.
# Tweet 'data/./rawdata/126866076016447489.json' not found. Skip.
# Tweet 'data/./rawdata/126866058337460224.json' not found. Skip.
# Tweet 'data/./rawdata/126866027316383744.json' not found. Skip.
# Tweet 'data/./rawdata/126866021402427392.json' not found. Skip.
# Tweet 'data/./rawdata/126865987365634048.json' not found. Skip.
# Tweet 'data/./rawdata/126865977970401280.json' not found. Skip.
# Tweet 'data/./rawdata/126865966624813057.json' not found. Skip.
# Tweet 'data/./rawdata/126865936115445761.json' not found. Skip.
# Tweet 'data/./rawdata/126865932806139904.json' not found. Skip.
# Tweet 'data/./rawdata/126865890665967618.json' not found. Skip.
# Tweet 'data/./rawdata/126865868599726080.json' not found. Skip.
# Tweet 'data/./rawdata/126865864086667264.json' not found. Skip.
# Tweet 'data/./rawdata/126865777423941633.json' not found. Skip.
# Tweet 'data/./rawdata/126865704380153856.json' not found. Skip.
# Tweet 'data/./rawdata/126865703969099776.json' not found. Skip.
# Tweet 'data/./rawdata/126865661602447362.json' not found. Skip.
# Tweet 'data/./rawdata/126865633869709312.json' not found. Skip.
# Tweet 'data/./rawdata/126865576093171712.json' not found. Skip.
# Tweet 'data/./rawdata/126865573228445696.json' not found. Skip.
# Tweet 'data/./rawdata/126865566236553216.json' not found. Skip.
# Tweet 'data/./rawdata/126865487584968704.json' not found. Skip.
# Tweet 'data/./rawdata/126865416671862785.json' not found. Skip.
# Tweet 'data/./rawdata/126865410598502400.json' not found. Skip.
# Tweet 'data/./rawdata/126865389861871617.json' not found. Skip.
# Tweet 'data/./rawdata/126865304277090304.json' not found. Skip.
# Tweet 'data/./rawdata/126865296463118337.json' not found. Skip.
# Tweet 'data/./rawdata/126865215492071424.json' not found. Skip.
# Tweet 'data/./rawdata/126865127977918464.json' not found. Skip.
# Tweet 'data/./rawdata/126865092565417984.json' not found. Skip.
# Tweet 'data/./rawdata/126865045949919233.json' not found. Skip.
# Tweet 'data/./rawdata/126865038676987904.json' not found. Skip.
# Tweet 'data/./rawdata/126865014215802880.json' not found. Skip.
# Tweet 'data/./rawdata/126864993760182272.json' not found. Skip.
# Tweet 'data/./rawdata/126864955285831680.json' not found. Skip.
# Tweet 'data/./rawdata/126864954140803072.json' not found. Skip.
# Tweet 'data/./rawdata/126864917566455809.json' not found. Skip.
# Tweet 'data/./rawdata/126864908582260736.json' not found. Skip.
# Tweet 'data/./rawdata/126864848649846784.json' not found. Skip.
# Tweet 'data/./rawdata/126864847399944192.json' not found. Skip.
# Tweet 'data/./rawdata/126864712766980096.json' not found. Skip.
# Tweet 'data/./rawdata/126864692470751232.json' not found. Skip.
# Tweet 'data/./rawdata/126864673416032256.json' not found. Skip.
# Tweet 'data/./rawdata/126864623252144128.json' not found. Skip.
# Tweet 'data/./rawdata/126864485943214080.json' not found. Skip.
# Tweet 'data/./rawdata/126864460957749248.json' not found. Skip.
# Tweet 'data/./rawdata/126864441999507456.json' not found. Skip.
# Tweet 'data/./rawdata/126864344125419520.json' not found. Skip.
# Tweet 'data/./rawdata/126864341071962112.json' not found. Skip.
# Tweet 'data/./rawdata/126864316120047617.json' not found. Skip.
# Tweet 'data/./rawdata/126864259027181568.json' not found. Skip.
# Tweet 'data/./rawdata/126864201804300289.json' not found. Skip.
# Tweet 'data/./rawdata/126864188969725953.json' not found. Skip.
# Tweet 'data/./rawdata/126864074045784064.json' not found. Skip.
# Tweet 'data/./rawdata/126864072447766528.json' not found. Skip.
# Tweet 'data/./rawdata/126864016613183489.json' not found. Skip.
# Tweet 'data/./rawdata/126863938339094531.json' not found. Skip.
# Tweet 'data/./rawdata/126863859075121152.json' not found. Skip.
# Tweet 'data/./rawdata/126863845326209024.json' not found. Skip.
# Tweet 'data/./rawdata/126863808177254400.json' not found. Skip.
# Tweet 'data/./rawdata/126863734265217025.json' not found. Skip.
# Tweet 'data/./rawdata/126863732931432448.json' not found. Skip.
# Tweet 'data/./rawdata/126863723179675648.json' not found. Skip.
# Tweet 'data/./rawdata/126863722412118017.json' not found. Skip.
# Tweet 'data/./rawdata/126863708889690112.json' not found. Skip.
# Tweet 'data/./rawdata/126863696726200320.json' not found. Skip.
# Tweet 'data/./rawdata/126863647845789696.json' not found. Skip.
# Tweet 'data/./rawdata/126863644968501250.json' not found. Skip.
# Tweet 'data/./rawdata/126863594850746369.json' not found. Skip.
# Tweet 'data/./rawdata/126863579914829824.json' not found. Skip.
# Tweet 'data/./rawdata/126863563133431809.json' not found. Skip.
# Tweet 'data/./rawdata/126863551355822080.json' not found. Skip.
# Tweet 'data/./rawdata/126863538626109440.json' not found. Skip.
# Tweet 'data/./rawdata/126863416211156992.json' not found. Skip.
# Tweet 'data/./rawdata/126863368492564481.json' not found. Skip.
# Tweet 'data/./rawdata/126863360779227136.json' not found. Skip.
# Tweet 'data/./rawdata/126863360686956544.json' not found. Skip.
# Tweet 'data/./rawdata/126863321327611904.json' not found. Skip.
# Tweet 'data/./rawdata/126863319226265600.json' not found. Skip.
# Tweet 'data/./rawdata/126863283658567680.json' not found. Skip.
# Tweet 'data/./rawdata/126863189844566016.json' not found. Skip.
# Tweet 'data/./rawdata/126863136111333376.json' not found. Skip.
# Tweet 'data/./rawdata/126863118398787584.json' not found. Skip.
# Tweet 'data/./rawdata/126863108802232320.json' not found. Skip.
# Tweet 'data/./rawdata/126863108688986112.json' not found. Skip.
# Tweet 'data/./rawdata/126863078112509952.json' not found. Skip.
# Tweet 'data/./rawdata/126863012433899520.json' not found. Skip.
# Tweet 'data/./rawdata/126862981333139457.json' not found. Skip.
# Tweet 'data/./rawdata/126862918921891840.json' not found. Skip.
# Tweet 'data/./rawdata/126862904514445312.json' not found. Skip.
# Tweet 'data/./rawdata/126862853822099456.json' not found. Skip.
# Tweet 'data/./rawdata/126862852681240576.json' not found. Skip.
# Tweet 'data/./rawdata/126862832489861121.json' not found. Skip.
# Tweet 'data/./rawdata/126862813355442176.json' not found. Skip.
# Tweet 'data/./rawdata/126862789649248256.json' not found. Skip.
# Tweet 'data/./rawdata/126862725933576192.json' not found. Skip.
# Tweet 'data/./rawdata/126862722028666880.json' not found. Skip.
# Tweet 'data/./rawdata/126862722007699456.json' not found. Skip.
# Tweet 'data/./rawdata/126862721793789953.json' not found. Skip.
# Tweet 'data/./rawdata/126862721609248769.json' not found. Skip.
# Tweet 'data/./rawdata/126862719927332864.json' not found. Skip.
# Tweet 'data/./rawdata/126862668039598080.json' not found. Skip.
# Tweet 'data/./rawdata/126862654324211713.json' not found. Skip.
# Tweet 'data/./rawdata/126862632648065025.json' not found. Skip.
# Tweet 'data/./rawdata/126862595117424641.json' not found. Skip.
# Tweet 'data/./rawdata/126862536162295808.json' not found. Skip.
# Tweet 'data/./rawdata/126862464003477504.json' not found. Skip.
# Tweet 'data/./rawdata/126862447041712128.json' not found. Skip.
# Tweet 'data/./rawdata/126862429912186880.json' not found. Skip.
# Tweet 'data/./rawdata/126862343148802048.json' not found. Skip.
# Tweet 'data/./rawdata/126862329269858305.json' not found. Skip.
# Tweet 'data/./rawdata/126862315990679552.json' not found. Skip.
# Tweet 'data/./rawdata/126862308302532608.json' not found. Skip.
# Tweet 'data/./rawdata/126862269148692481.json' not found. Skip.
# Tweet 'data/./rawdata/126862268725080065.json' not found. Skip.
# Tweet 'data/./rawdata/126862217013497856.json' not found. Skip.
# Tweet 'data/./rawdata/126862201440043008.json' not found. Skip.
# Tweet 'data/./rawdata/126862151393619968.json' not found. Skip.
# Tweet 'data/./rawdata/126862151343284224.json' not found. Skip.
# Tweet 'data/./rawdata/126862150265352193.json' not found. Skip.
# Tweet 'data/./rawdata/126862116874489856.json' not found. Skip.
# Tweet 'data/./rawdata/126861992001679360.json' not found. Skip.
# Tweet 'data/./rawdata/126861988004499457.json' not found. Skip.
# Tweet 'data/./rawdata/126861979762696192.json' not found. Skip.
# Tweet 'data/./rawdata/126861960137539585.json' not found. Skip.
# Tweet 'data/./rawdata/126861955762888706.json' not found. Skip.
# Tweet 'data/./rawdata/126861933071704065.json' not found. Skip.
# Tweet 'data/./rawdata/126861782378745856.json' not found. Skip.
# Tweet 'data/./rawdata/126861771314184192.json' not found. Skip.
# Tweet 'data/./rawdata/126861717790658561.json' not found. Skip.
# Tweet 'data/./rawdata/126861611741872128.json' not found. Skip.
# Tweet 'data/./rawdata/126861593249185793.json' not found. Skip.
# Tweet 'data/./rawdata/126861589122002944.json' not found. Skip.
# Tweet 'data/./rawdata/126861539511775232.json' not found. Skip.
# Tweet 'data/./rawdata/126861496109121536.json' not found. Skip.
# Tweet 'data/./rawdata/126861493059854336.json' not found. Skip.
# Tweet 'data/./rawdata/126861480128819201.json' not found. Skip.
# Tweet 'data/./rawdata/126861380992241664.json' not found. Skip.
# Tweet 'data/./rawdata/126861357831303168.json' not found. Skip.
# Tweet 'data/./rawdata/126861252134830080.json' not found. Skip.
# Tweet 'data/./rawdata/126861245109387264.json' not found. Skip.
# Tweet 'data/./rawdata/126861233138827264.json' not found. Skip.
# Tweet 'data/./rawdata/126861218592980992.json' not found. Skip.
# Tweet 'data/./rawdata/126861187605471232.json' not found. Skip.
# Tweet 'data/./rawdata/126861118684676096.json' not found. Skip.
# Tweet 'data/./rawdata/126861100120686592.json' not found. Skip.
# Tweet 'data/./rawdata/126860970583797760.json' not found. Skip.
# Tweet 'data/./rawdata/126860953450065920.json' not found. Skip.
# Tweet 'data/./rawdata/126860911557345280.json' not found. Skip.
# Tweet 'data/./rawdata/126860890749419521.json' not found. Skip.
# Tweet 'data/./rawdata/126860877344407552.json' not found. Skip.
# Tweet 'data/./rawdata/126860835892109312.json' not found. Skip.
# Tweet 'data/./rawdata/126860830942834689.json' not found. Skip.
# Tweet 'data/./rawdata/126860808251637762.json' not found. Skip.
# Tweet 'data/./rawdata/126860789536657408.json' not found. Skip.
# Tweet 'data/./rawdata/126860754912681985.json' not found. Skip.
# Tweet 'data/./rawdata/126860740689797120.json' not found. Skip.
# Tweet 'data/./rawdata/126860719860883458.json' not found. Skip.
# Tweet 'data/./rawdata/126860653167263744.json' not found. Skip.
# Tweet 'data/./rawdata/126860610020446209.json' not found. Skip.
# Tweet 'data/./rawdata/126860576600227841.json' not found. Skip.
# Tweet 'data/./rawdata/126860372987740160.json' not found. Skip.
# Tweet 'data/./rawdata/126860329463447552.json' not found. Skip.
# Tweet 'data/./rawdata/126860270181171201.json' not found. Skip.
# Tweet 'data/./rawdata/126860146289803265.json' not found. Skip.
# Tweet 'data/./rawdata/126860127167987712.json' not found. Skip.
# Tweet 'data/./rawdata/126860114610241536.json' not found. Skip.
# Tweet 'data/./rawdata/126860109090521088.json' not found. Skip.
# Tweet 'data/./rawdata/126859990513369088.json' not found. Skip.
# Tweet 'data/./rawdata/126859860640940032.json' not found. Skip.
# Tweet 'data/./rawdata/126859857604247552.json' not found. Skip.
# Tweet 'data/./rawdata/126859846506127360.json' not found. Skip.
# Tweet 'data/./rawdata/126859794383515649.json' not found. Skip.
# Tweet 'data/./rawdata/126859777308495872.json' not found. Skip.
# Tweet 'data/./rawdata/126859668151738368.json' not found. Skip.
# Tweet 'data/./rawdata/126859627051757568.json' not found. Skip.
# Tweet 'data/./rawdata/126859610006110208.json' not found. Skip.
# Tweet 'data/./rawdata/126859509414100992.json' not found. Skip.
# Tweet 'data/./rawdata/126859503495938048.json' not found. Skip.
# Tweet 'data/./rawdata/126859490061598720.json' not found. Skip.
# Tweet 'data/./rawdata/126859443127332864.json' not found. Skip.
# Tweet 'data/./rawdata/126859428455657472.json' not found. Skip.
# Tweet 'data/./rawdata/126859363079041024.json' not found. Skip.
# Tweet 'data/./rawdata/126859354614939648.json' not found. Skip.
# Tweet 'data/./rawdata/126859286558158849.json' not found. Skip.
# Tweet 'data/./rawdata/126859257856540672.json' not found. Skip.
# Tweet 'data/./rawdata/126859211593351168.json' not found. Skip.
# Tweet 'data/./rawdata/126859155175772161.json' not found. Skip.
# Tweet 'data/./rawdata/126859077304320001.json' not found. Skip.
# Tweet 'data/./rawdata/126858835058098176.json' not found. Skip.
# Tweet 'data/./rawdata/126858789868670976.json' not found. Skip.
# Tweet 'data/./rawdata/126858639855206400.json' not found. Skip.
# Tweet 'data/./rawdata/126858516655898625.json' not found. Skip.
# Tweet 'data/./rawdata/126858260216160256.json' not found. Skip.
# Tweet 'data/./rawdata/126858248325308416.json' not found. Skip.
# Tweet 'data/./rawdata/126858186962644992.json' not found. Skip.
# Tweet 'data/./rawdata/126858148878368769.json' not found. Skip.
# Tweet 'data/./rawdata/126858034466131969.json' not found. Skip.
# Tweet 'data/./rawdata/126858032951996416.json' not found. Skip.
# Tweet 'data/./rawdata/126858004690767872.json' not found. Skip.
# Tweet 'data/./rawdata/126857921068941314.json' not found. Skip.
# Tweet 'data/./rawdata/126857918929838080.json' not found. Skip.
# Tweet 'data/./rawdata/126857746200014849.json' not found. Skip.
# Tweet 'data/./rawdata/126857736238530560.json' not found. Skip.
# Tweet 'data/./rawdata/126857518591901698.json' not found. Skip.
# Tweet 'data/./rawdata/126857511230902272.json' not found. Skip.
# Tweet 'data/./rawdata/126857421321797634.json' not found. Skip.
# Tweet 'data/./rawdata/126857383715676160.json' not found. Skip.
# Tweet 'data/./rawdata/126857361515216897.json' not found. Skip.
# Tweet 'data/./rawdata/126857211921174528.json' not found. Skip.
# Tweet 'data/./rawdata/126857080513638400.json' not found. Skip.
# Tweet 'data/./rawdata/126857071667847168.json' not found. Skip.
# Tweet 'data/./rawdata/126857049920385024.json' not found. Skip.
# Tweet 'data/./rawdata/126856764242137088.json' not found. Skip.
# Tweet 'data/./rawdata/126856732331884545.json' not found. Skip.
# Tweet 'data/./rawdata/126856603021484032.json' not found. Skip.
# Tweet 'data/./rawdata/126856425371746304.json' not found. Skip.
# Tweet 'data/./rawdata/126856274531991552.json' not found. Skip.
# Tweet 'data/./rawdata/126856135918620673.json' not found. Skip.
# Tweet 'data/./rawdata/126856097863708672.json' not found. Skip.
# Tweet 'data/./rawdata/126856097431699456.json' not found. Skip.
# Tweet 'data/./rawdata/126855687060987904.json' not found. Skip.
# Tweet 'data/./rawdata/126855171702661120.json' not found. Skip.
# Tweet 'data/./rawdata/126854999442587648.json' not found. Skip.
# Tweet 'data/./rawdata/126854818101858304.json' not found. Skip.
# Tweet 'data/./rawdata/126854423317188608.json' not found. Skip.
# #negative: 282
# #neutral: 253
# #positive: 131
# == Pos vs. neg ==
# 0.806	0.032	0.812	0.033
# /usr/lib64/python2.7/site-packages/sklearn/cross_validation.py:758: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   "removed (assumed True) in 0.17", DeprecationWarning)
# /usr/lib64/python2.7/site-packages/sklearn/cross_validation.py:758: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   "removed (assumed True) in 0.17", DeprecationWarning)
# == Pos/neg vs. irrelevant/neutral ==
# 0.743	0.016	0.874	0.013
# == Pos vs. rest ==
# 0.832	0.024	0.564	0.055
# /usr/lib64/python2.7/site-packages/sklearn/cross_validation.py:758: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   "removed (assumed True) in 0.17", DeprecationWarning)
# /usr/lib64/python2.7/site-packages/sklearn/cross_validation.py:758: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   "removed (assumed True) in 0.17", DeprecationWarning)
# == Neg vs. rest ==
# 0.774	0.022	0.814	0.028
# ('time spent:', 3.350123167037964)

# %%
imgshow('./charts/pr_neg_vs_rest_02.png')
imgshow('./charts/pr_pos_vs_neg_02.png')
imgshow('./charts/pr_pos_vs_rest_02.png')

# %%
# %load 03_clean.py

# %%
# This code is supporting material for the book
# Building Machine Learning Systems with Python
# by Willi Richert and Luis Pedro Coelho
# published by PACKT Publishing
#
# It is made available under the MIT License

#
# This script tries to improve the classifier by cleaning the tweets a bit
#

import time
start_time = time.time()
import re

import numpy as np

from sklearn.metrics import precision_recall_curve, roc_curve, auc
from sklearn.cross_validation import ShuffleSplit
from sklearn.pipeline import Pipeline

from utils import plot_pr
from utils import load_sanders_data
from utils import tweak_labels
from utils import log_false_positives

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.naive_bayes import MultinomialNB

from utils import load_sent_word_net

sent_word_net = load_sent_word_net()

phase = "03"

emo_repl = {
    # positive emoticons
    "&lt;3": " good ",
    ":d": " good ",  # :D in lower case
    ":dd": " good ",  # :DD in lower case
    "8)": " good ",
    ":-)": " good ",
    ":)": " good ",
    ";)": " good ",
    "(-:": " good ",
    "(:": " good ",

    # negative emoticons:
    ":/": " bad ",
    ":&gt;": " sad ",
    ":')": " sad ",
    ":-(": " bad ",
    ":(": " bad ",
    ":S": " bad ",
    ":-S": " bad ",
}

emo_repl_order = [k for (k_len, k) in reversed(
    sorted([(len(k), k) for k in list(emo_repl.keys())]))]

re_repl = {
    r"\br\b": "are",
    r"\bu\b": "you",
    r"\bhaha\b": "ha",
    r"\bhahaha\b": "ha",
    r"\bdon't\b": "do not",
    r"\bdoesn't\b": "does not",
    r"\bdidn't\b": "did not",
    r"\bhasn't\b": "has not",
    r"\bhaven't\b": "have not",
    r"\bhadn't\b": "had not",
    r"\bwon't\b": "will not",
    r"\bwouldn't\b": "would not",
    r"\bcan't\b": "can not",
    r"\bcannot\b": "can not",
}


def create_ngram_model(params=None):
    def preprocessor(tweet):
        global emoticons_replaced
        tweet = tweet.lower()

        for k in emo_repl_order:
            tweet = tweet.replace(k, emo_repl[k])
        for r, repl in re_repl.items():
            tweet = re.sub(r, repl, tweet)

        return tweet

    tfidf_ngrams = TfidfVectorizer(preprocessor=preprocessor,
                                   analyzer="word")
    clf = MultinomialNB()
    pipeline = Pipeline([('tfidf', tfidf_ngrams), ('clf', clf)])

    if params:
        pipeline.set_params(**params)

    return pipeline


def train_model(clf, X, Y, name="NB ngram", plot=False):
    # create it again for plotting
    cv = ShuffleSplit(
        n=len(X), n_iter=10, test_size=0.3, random_state=0)

    train_errors = []
    test_errors = []

    scores = []
    pr_scores = []
    precisions, recalls, thresholds = [], [], []

    clfs = []  # just to later get the median

    for train, test in cv:
        X_train, y_train = X[train], Y[train]
        X_test, y_test = X[test], Y[test]

        clf.fit(X_train, y_train)
        clfs.append(clf)

        train_score = clf.score(X_train, y_train)
        test_score = clf.score(X_test, y_test)

        train_errors.append(1 - train_score)
        test_errors.append(1 - test_score)

        scores.append(test_score)
        proba = clf.predict_proba(X_test)

        fpr, tpr, roc_thresholds = roc_curve(y_test, proba[:, 1])
        precision, recall, pr_thresholds = precision_recall_curve(
            y_test, proba[:, 1])

        pr_scores.append(auc(recall, precision))
        precisions.append(precision)
        recalls.append(recall)
        thresholds.append(pr_thresholds)

    if plot:
        scores_to_sort = pr_scores
        median = np.argsort(scores_to_sort)[len(scores_to_sort) / 2]

        plot_pr(pr_scores[median], name, phase, precisions[median],
                recalls[median], label=name)

        log_false_positives(clfs[median], X_test, y_test, name)

    summary = (np.mean(scores), np.std(scores),
               np.mean(pr_scores), np.std(pr_scores))
    print("%.3f\t%.3f\t%.3f\t%.3f\t" % summary)

    return np.mean(train_errors), np.mean(test_errors)


def print_incorrect(clf, X, Y):
    Y_hat = clf.predict(X)
    wrong_idx = Y_hat != Y
    X_wrong = X[wrong_idx]
    Y_wrong = Y[wrong_idx]
    Y_hat_wrong = Y_hat[wrong_idx]
    for idx in range(len(X_wrong)):
        print("clf.predict('%s')=%i instead of %i" %
              (X_wrong[idx], Y_hat_wrong[idx], Y_wrong[idx]))


def get_best_model():
    best_params = dict(tfidf__ngram_range=(1, 2),
                       tfidf__min_df=1,
                       tfidf__stop_words=None,
                       tfidf__smooth_idf=False,
                       tfidf__use_idf=False,
                       tfidf__sublinear_tf=True,
                       tfidf__binary=False,
                       clf__alpha=0.01,
                       )

    best_clf = create_ngram_model(best_params)

    return best_clf

if __name__ == "__main__":
    X_orig, Y_orig = load_sanders_data()
    classes = np.unique(Y_orig)
    for c in classes:
        print("#%s: %i" % (c, sum(Y_orig == c)))

    print("== Pos vs. neg ==")
    pos_neg = np.logical_or(Y_orig == "positive", Y_orig == "negative")
    X = X_orig[pos_neg]
    Y = Y_orig[pos_neg]
    Y = tweak_labels(Y, ["positive"])
    train_model(get_best_model(), X, Y, name="pos vs neg", plot=True)

    print("== Pos/neg vs. irrelevant/neutral ==")
    X = X_orig
    Y = tweak_labels(Y_orig, ["positive", "negative"])

    # best_clf = grid_search_model(create_union_model, X, Y, name="sent vs
    # rest", plot=True)
    train_model(get_best_model(), X, Y, name="pos+neg vs rest", plot=True)

    print("== Pos vs. rest ==")
    X = X_orig
    Y = tweak_labels(Y_orig, ["positive"])
    train_model(get_best_model(), X, Y, name="pos vs rest",
                plot=True)

    print("== Neg vs. rest ==")
    X = X_orig
    Y = tweak_labels(Y_orig, ["negative"])
    train_model(get_best_model(), X, Y, name="neg vs rest",
                plot=True)

    print("time spent:", time.time() - start_time)
# Out:
# Tweet 'data/./rawdata/126394830791254016.json' not found. Skip.
# Tweet 'data/./rawdata/126366123368267776.json' not found. Skip.
# Tweet 'data/./rawdata/126354605130002432.json' not found. Skip.
# Tweet 'data/./rawdata/126350948548354048.json' not found. Skip.
# Tweet 'data/./rawdata/126350302113824769.json' not found. Skip.
# Tweet 'data/./rawdata/126344048637259776.json' not found. Skip.
# Tweet 'data/./rawdata/126323785145126912.json' not found. Skip.
# Tweet 'data/./rawdata/126319186141130752.json' not found. Skip.
# Tweet 'data/./rawdata/126312877916307458.json' not found. Skip.
# Tweet 'data/./rawdata/126267185025916928.json' not found. Skip.
# Tweet 'data/./rawdata/126213333123743744.json' not found. Skip.
# Tweet 'data/./rawdata/126148685737361408.json' not found. Skip.
# Tweet 'data/./rawdata/126130991365500928.json' not found. Skip.
# Tweet 'data/./rawdata/126093298619252737.json' not found. Skip.
# Tweet 'data/./rawdata/126079414986485761.json' not found. Skip.
# Tweet 'data/./rawdata/126076743613284354.json' not found. Skip.
# Tweet 'data/./rawdata/126063569660936193.json' not found. Skip.
# Tweet 'data/./rawdata/126063358037340161.json' not found. Skip.
# Tweet 'data/./rawdata/126059399319003136.json' not found. Skip.
# Tweet 'data/./rawdata/126049183865114624.json' not found. Skip.
# Tweet 'data/./rawdata/126040352237961217.json' not found. Skip.
# Tweet 'data/./rawdata/126039929523404801.json' not found. Skip.
# Tweet 'data/./rawdata/126015087386431488.json' not found. Skip.
# Tweet 'data/./rawdata/126008369562652672.json' not found. Skip.
# Tweet 'data/./rawdata/125995158679461888.json' not found. Skip.
# Tweet 'data/./rawdata/125979338846900224.json' not found. Skip.
# Tweet 'data/./rawdata/125978473712979969.json' not found. Skip.
# Tweet 'data/./rawdata/125954443643588608.json' not found. Skip.
# Tweet 'data/./rawdata/125947232359948288.json' not found. Skip.
# Tweet 'data/./rawdata/125943290288803841.json' not found. Skip.
# Tweet 'data/./rawdata/125932869389524992.json' not found. Skip.
# Tweet 'data/./rawdata/125930171562852353.json' not found. Skip.
# Tweet 'data/./rawdata/125910633731461120.json' not found. Skip.
# Tweet 'data/./rawdata/125909565031198720.json' not found. Skip.
# Tweet 'data/./rawdata/125907732388790272.json' not found. Skip.
# Tweet 'data/./rawdata/125898611572740097.json' not found. Skip.
# Tweet 'data/./rawdata/125816853867151360.json' not found. Skip.
# Tweet 'data/./rawdata/125727629012770816.json' not found. Skip.
# Tweet 'data/./rawdata/125688922410975232.json' not found. Skip.
# Tweet 'data/./rawdata/125685656415510528.json' not found. Skip.
# Tweet 'data/./rawdata/125673004511412224.json' not found. Skip.
# Tweet 'data/./rawdata/125665606853861376.json' not found. Skip.
# Tweet 'data/./rawdata/125633065757310976.json' not found. Skip.
# Tweet 'data/./rawdata/125616280215617537.json' not found. Skip.
# Tweet 'data/./rawdata/125595292304281601.json' not found. Skip.
# Tweet 'data/./rawdata/125536884813336576.json' not found. Skip.
# Tweet 'data/./rawdata/125533599737978882.json' not found. Skip.
# Tweet 'data/./rawdata/125458901192810496.json' not found. Skip.
# Tweet 'data/./rawdata/125445056218923008.json' not found. Skip.
# Tweet 'data/./rawdata/125422502284505088.json' not found. Skip.
# Tweet 'data/./rawdata/125402636764712960.json' not found. Skip.
# Tweet 'data/./rawdata/125330595302744064.json' not found. Skip.
# Tweet 'data/./rawdata/125281706327552001.json' not found. Skip.
# Tweet 'data/./rawdata/125279447669669888.json' not found. Skip.
# Tweet 'data/./rawdata/125264731035537409.json' not found. Skip.
# Tweet 'data/./rawdata/125251672896323584.json' not found. Skip.
# Tweet 'data/./rawdata/125243911538098176.json' not found. Skip.
# Tweet 'data/./rawdata/126400637930979329.json' not found. Skip.
# Tweet 'data/./rawdata/126391082308206593.json' not found. Skip.
# Tweet 'data/./rawdata/126328782700285952.json' not found. Skip.
# Tweet 'data/./rawdata/126325125749542913.json' not found. Skip.
# Tweet 'data/./rawdata/126312535203921920.json' not found. Skip.
# Tweet 'data/./rawdata/126311879218966529.json' not found. Skip.
# Tweet 'data/./rawdata/126308005779210241.json' not found. Skip.
# Tweet 'data/./rawdata/126304942049853441.json' not found. Skip.
# Tweet 'data/./rawdata/126297241190281216.json' not found. Skip.
# Tweet 'data/./rawdata/126295434862936064.json' not found. Skip.
# Tweet 'data/./rawdata/126282994821509120.json' not found. Skip.
# Tweet 'data/./rawdata/126270073420791810.json' not found. Skip.
# Tweet 'data/./rawdata/126264313563459585.json' not found. Skip.
# Tweet 'data/./rawdata/126239832895795200.json' not found. Skip.
# Tweet 'data/./rawdata/126182880123695104.json' not found. Skip.
# Tweet 'data/./rawdata/126156590662422528.json' not found. Skip.
# Tweet 'data/./rawdata/126153311521996800.json' not found. Skip.
# Tweet 'data/./rawdata/126148955217203200.json' not found. Skip.
# Tweet 'data/./rawdata/126148565302128640.json' not found. Skip.
# Tweet 'data/./rawdata/126140389873827841.json' not found. Skip.
# Tweet 'data/./rawdata/126129938247061504.json' not found. Skip.
# Tweet 'data/./rawdata/126126605344047105.json' not found. Skip.
# Tweet 'data/./rawdata/126121175926571009.json' not found. Skip.
# Tweet 'data/./rawdata/126082198720888833.json' not found. Skip.
# Tweet 'data/./rawdata/126073788323479552.json' not found. Skip.
# Tweet 'data/./rawdata/126070647125327872.json' not found. Skip.
# Tweet 'data/./rawdata/126060639268507649.json' not found. Skip.
# Tweet 'data/./rawdata/126042137740574720.json' not found. Skip.
# Tweet 'data/./rawdata/126042022900547584.json' not found. Skip.
# Tweet 'data/./rawdata/126033747991736320.json' not found. Skip.
# Tweet 'data/./rawdata/126012404332113920.json' not found. Skip.
# Tweet 'data/./rawdata/126012089415380992.json' not found. Skip.
# Tweet 'data/./rawdata/126006088725303296.json' not found. Skip.
# Tweet 'data/./rawdata/126004661248471040.json' not found. Skip.
# Tweet 'data/./rawdata/125988395787882497.json' not found. Skip.
# Tweet 'data/./rawdata/125974810021998595.json' not found. Skip.
# Tweet 'data/./rawdata/125969502587465729.json' not found. Skip.
# Tweet 'data/./rawdata/125954651152592896.json' not found. Skip.
# Tweet 'data/./rawdata/125934808592433153.json' not found. Skip.
# Tweet 'data/./rawdata/125836461936361472.json' not found. Skip.
# Tweet 'data/./rawdata/125824054958637056.json' not found. Skip.
# Tweet 'data/./rawdata/125814380871946240.json' not found. Skip.
# Tweet 'data/./rawdata/125812985301172224.json' not found. Skip.
# Tweet 'data/./rawdata/125811345064067072.json' not found. Skip.
# Tweet 'data/./rawdata/125799384976863232.json' not found. Skip.
# Tweet 'data/./rawdata/125794882257305600.json' not found. Skip.
# Tweet 'data/./rawdata/125728250579259392.json' not found. Skip.
# Tweet 'data/./rawdata/125722610179907584.json' not found. Skip.
# Tweet 'data/./rawdata/125711996074209280.json' not found. Skip.
# Tweet 'data/./rawdata/125694815743651840.json' not found. Skip.
# Tweet 'data/./rawdata/125692685033021441.json' not found. Skip.
# Tweet 'data/./rawdata/125692532750430209.json' not found. Skip.
# Tweet 'data/./rawdata/125681375058735104.json' not found. Skip.
# Tweet 'data/./rawdata/125675806977556480.json' not found. Skip.
# Tweet 'data/./rawdata/125673358418391041.json' not found. Skip.
# Tweet 'data/./rawdata/125659125886623744.json' not found. Skip.
# Tweet 'data/./rawdata/125656618326175745.json' not found. Skip.
# Tweet 'data/./rawdata/125619303356710912.json' not found. Skip.
# Tweet 'data/./rawdata/125607492356018176.json' not found. Skip.
# Tweet 'data/./rawdata/125588697872728065.json' not found. Skip.
# Tweet 'data/./rawdata/125578269197217792.json' not found. Skip.
# Tweet 'data/./rawdata/125561930416013312.json' not found. Skip.
# Tweet 'data/./rawdata/125547255947198465.json' not found. Skip.
# Tweet 'data/./rawdata/125476730067615744.json' not found. Skip.
# Tweet 'data/./rawdata/125475953509015552.json' not found. Skip.
# Tweet 'data/./rawdata/125441732941840385.json' not found. Skip.
# Tweet 'data/./rawdata/125435218017525760.json' not found. Skip.
# Tweet 'data/./rawdata/125420263687995392.json' not found. Skip.
# Tweet 'data/./rawdata/125400161886277632.json' not found. Skip.
# Tweet 'data/./rawdata/125395636219678720.json' not found. Skip.
# Tweet 'data/./rawdata/125380163302199296.json' not found. Skip.
# Tweet 'data/./rawdata/125371779039502336.json' not found. Skip.
# Tweet 'data/./rawdata/125369698840887297.json' not found. Skip.
# Tweet 'data/./rawdata/125368089159286784.json' not found. Skip.
# Tweet 'data/./rawdata/125355139409252352.json' not found. Skip.
# Tweet 'data/./rawdata/125347619072512000.json' not found. Skip.
# Tweet 'data/./rawdata/125346783390990337.json' not found. Skip.
# Tweet 'data/./rawdata/125334519254482944.json' not found. Skip.
# Tweet 'data/./rawdata/125330337847975937.json' not found. Skip.
# Tweet 'data/./rawdata/125309427422203904.json' not found. Skip.
# Tweet 'data/./rawdata/125304159581900800.json' not found. Skip.
# Tweet 'data/./rawdata/125295729139908608.json' not found. Skip.
# Tweet 'data/./rawdata/125294978623746048.json' not found. Skip.
# Tweet 'data/./rawdata/125271422431014914.json' not found. Skip.
# Tweet 'data/./rawdata/125268117680160768.json' not found. Skip.
# Tweet 'data/./rawdata/125245246136258561.json' not found. Skip.
# Tweet 'data/./rawdata/125232266849947648.json' not found. Skip.
# Tweet 'data/./rawdata/125212404299735040.json' not found. Skip.
# Tweet 'data/./rawdata/125204228967903232.json' not found. Skip.
# Tweet 'data/./rawdata/126394795802370049.json' not found. Skip.
# Tweet 'data/./rawdata/126386085164101634.json' not found. Skip.
# Tweet 'data/./rawdata/126382776072146944.json' not found. Skip.
# Tweet 'data/./rawdata/126380323733909504.json' not found. Skip.
# Tweet 'data/./rawdata/126362867778859008.json' not found. Skip.
# Tweet 'data/./rawdata/126343124174901248.json' not found. Skip.
# Tweet 'data/./rawdata/126339328434651136.json' not found. Skip.
# Tweet 'data/./rawdata/126329388320043008.json' not found. Skip.
# Tweet 'data/./rawdata/126317201962700800.json' not found. Skip.
# Tweet 'data/./rawdata/126314701721309184.json' not found. Skip.
# Tweet 'data/./rawdata/126312423132102657.json' not found. Skip.
# Tweet 'data/./rawdata/126307117274644480.json' not found. Skip.
# Tweet 'data/./rawdata/126298592364331008.json' not found. Skip.
# Tweet 'data/./rawdata/126293725155569664.json' not found. Skip.
# Tweet 'data/./rawdata/126292233963053056.json' not found. Skip.
# Tweet 'data/./rawdata/126287512296632320.json' not found. Skip.
# Tweet 'data/./rawdata/126283639959990274.json' not found. Skip.
# Tweet 'data/./rawdata/126229089651654656.json' not found. Skip.
# Tweet 'data/./rawdata/126225922159427584.json' not found. Skip.
# Tweet 'data/./rawdata/126219340214304768.json' not found. Skip.
# Tweet 'data/./rawdata/126192452297170945.json' not found. Skip.
# Tweet 'data/./rawdata/126186955296878592.json' not found. Skip.
# Tweet 'data/./rawdata/126186795808456704.json' not found. Skip.
# Tweet 'data/./rawdata/126147867478982656.json' not found. Skip.
# Tweet 'data/./rawdata/126125799744094208.json' not found. Skip.
# Tweet 'data/./rawdata/126110770864979968.json' not found. Skip.
# Tweet 'data/./rawdata/126102213956337664.json' not found. Skip.
# Tweet 'data/./rawdata/126082898783780864.json' not found. Skip.
# Tweet 'data/./rawdata/126081812236738560.json' not found. Skip.
# Tweet 'data/./rawdata/126065983138955265.json' not found. Skip.
# Tweet 'data/./rawdata/126054725727698944.json' not found. Skip.
# Tweet 'data/./rawdata/126044185815040000.json' not found. Skip.
# Tweet 'data/./rawdata/126043954641780736.json' not found. Skip.
# Tweet 'data/./rawdata/126039090578735104.json' not found. Skip.
# Tweet 'data/./rawdata/126029114850295809.json' not found. Skip.
# Tweet 'data/./rawdata/126021436149211136.json' not found. Skip.
# Tweet 'data/./rawdata/126017685246050304.json' not found. Skip.
# Tweet 'data/./rawdata/126014277814468608.json' not found. Skip.
# Tweet 'data/./rawdata/126012833128390656.json' not found. Skip.
# Tweet 'data/./rawdata/126010471202566144.json' not found. Skip.
# Tweet 'data/./rawdata/126009386022879232.json' not found. Skip.
# Tweet 'data/./rawdata/126006669535744000.json' not found. Skip.
# Tweet 'data/./rawdata/125998732046123009.json' not found. Skip.
# Tweet 'data/./rawdata/125996412252078080.json' not found. Skip.
# Tweet 'data/./rawdata/125994997609803776.json' not found. Skip.
# Tweet 'data/./rawdata/125992594395250688.json' not found. Skip.
# Tweet 'data/./rawdata/125988651426512899.json' not found. Skip.
# Tweet 'data/./rawdata/125981074114359297.json' not found. Skip.
# Tweet 'data/./rawdata/125980615664336896.json' not found. Skip.
# Tweet 'data/./rawdata/125974497546338304.json' not found. Skip.
# Tweet 'data/./rawdata/125971256335024128.json' not found. Skip.
# Tweet 'data/./rawdata/125958702455988225.json' not found. Skip.
# Tweet 'data/./rawdata/125957972466737152.json' not found. Skip.
# Tweet 'data/./rawdata/125950026181648385.json' not found. Skip.
# Tweet 'data/./rawdata/125949784677810176.json' not found. Skip.
# Tweet 'data/./rawdata/125947460592996352.json' not found. Skip.
# Tweet 'data/./rawdata/125932876721168384.json' not found. Skip.
# Tweet 'data/./rawdata/125930342891790337.json' not found. Skip.
# Tweet 'data/./rawdata/125922500839342080.json' not found. Skip.
# Tweet 'data/./rawdata/125922174648324096.json' not found. Skip.
# Tweet 'data/./rawdata/125921393350160384.json' not found. Skip.
# Tweet 'data/./rawdata/125920729194704896.json' not found. Skip.
# Tweet 'data/./rawdata/125920725595983874.json' not found. Skip.
# Tweet 'data/./rawdata/125920721200361472.json' not found. Skip.
# Tweet 'data/./rawdata/125920717966544896.json' not found. Skip.
# Tweet 'data/./rawdata/125920716297211904.json' not found. Skip.
# Tweet 'data/./rawdata/125919221845721090.json' not found. Skip.
# Tweet 'data/./rawdata/125918906215968771.json' not found. Skip.
# Tweet 'data/./rawdata/125918450920062977.json' not found. Skip.
# Tweet 'data/./rawdata/125918447979872258.json' not found. Skip.
# Tweet 'data/./rawdata/125918444762828800.json' not found. Skip.
# Tweet 'data/./rawdata/125918441013133312.json' not found. Skip.
# Tweet 'data/./rawdata/125917264267579393.json' not found. Skip.
# Tweet 'data/./rawdata/125917174618525696.json' not found. Skip.
# Tweet 'data/./rawdata/125917170571026432.json' not found. Skip.
# Tweet 'data/./rawdata/125917164535418880.json' not found. Skip.
# Tweet 'data/./rawdata/125917160982855680.json' not found. Skip.
# Tweet 'data/./rawdata/125915210337890304.json' not found. Skip.
# Tweet 'data/./rawdata/125908946702696448.json' not found. Skip.
# Tweet 'data/./rawdata/125907633466130432.json' not found. Skip.
# Tweet 'data/./rawdata/125892140940267522.json' not found. Skip.
# Tweet 'data/./rawdata/125891898517889024.json' not found. Skip.
# Tweet 'data/./rawdata/125887065861787648.json' not found. Skip.
# Tweet 'data/./rawdata/125882473312817152.json' not found. Skip.
# Tweet 'data/./rawdata/125878880916611072.json' not found. Skip.
# Tweet 'data/./rawdata/125866627337162752.json' not found. Skip.
# Tweet 'data/./rawdata/125866368758333440.json' not found. Skip.
# Tweet 'data/./rawdata/125859792802693120.json' not found. Skip.
# Tweet 'data/./rawdata/125859488728236032.json' not found. Skip.
# Tweet 'data/./rawdata/125854430171111424.json' not found. Skip.
# Tweet 'data/./rawdata/125840474132066304.json' not found. Skip.
# Tweet 'data/./rawdata/125830917578162176.json' not found. Skip.
# Tweet 'data/./rawdata/125829040740368384.json' not found. Skip.
# Tweet 'data/./rawdata/125828984293425152.json' not found. Skip.
# Tweet 'data/./rawdata/125826820057731074.json' not found. Skip.
# Tweet 'data/./rawdata/125824709421039616.json' not found. Skip.
# Tweet 'data/./rawdata/125823389804929024.json' not found. Skip.
# Tweet 'data/./rawdata/125821979797364736.json' not found. Skip.
# Tweet 'data/./rawdata/125821218258550784.json' not found. Skip.
# Tweet 'data/./rawdata/125817967240949760.json' not found. Skip.
# Tweet 'data/./rawdata/125815990620659713.json' not found. Skip.
# Tweet 'data/./rawdata/125811943054393344.json' not found. Skip.
# Tweet 'data/./rawdata/125807897568481280.json' not found. Skip.
# Tweet 'data/./rawdata/125804983185719297.json' not found. Skip.
# Tweet 'data/./rawdata/125803571601080320.json' not found. Skip.
# Tweet 'data/./rawdata/125803457155301376.json' not found. Skip.
# Tweet 'data/./rawdata/125801811817922561.json' not found. Skip.
# Tweet 'data/./rawdata/125793487479259136.json' not found. Skip.
# Tweet 'data/./rawdata/125792596114161665.json' not found. Skip.
# Tweet 'data/./rawdata/125792107930714113.json' not found. Skip.
# Tweet 'data/./rawdata/125727869363163137.json' not found. Skip.
# Tweet 'data/./rawdata/125727349034598401.json' not found. Skip.
# Tweet 'data/./rawdata/125727044263874560.json' not found. Skip.
# Tweet 'data/./rawdata/125726769297891330.json' not found. Skip.
# Tweet 'data/./rawdata/125725274317914112.json' not found. Skip.
# Tweet 'data/./rawdata/125725019178409984.json' not found. Skip.
# Tweet 'data/./rawdata/125724524732882944.json' not found. Skip.
# Tweet 'data/./rawdata/125721197437648896.json' not found. Skip.
# Tweet 'data/./rawdata/125714971261812736.json' not found. Skip.
# Tweet 'data/./rawdata/125708425752612864.json' not found. Skip.
# Tweet 'data/./rawdata/125708240225959936.json' not found. Skip.
# Tweet 'data/./rawdata/125706125764083712.json' not found. Skip.
# Tweet 'data/./rawdata/125703536632807424.json' not found. Skip.
# Tweet 'data/./rawdata/125698733768843264.json' not found. Skip.
# Tweet 'data/./rawdata/125695449423286272.json' not found. Skip.
# Tweet 'data/./rawdata/125695107734319104.json' not found. Skip.
# Tweet 'data/./rawdata/125694587313467393.json' not found. Skip.
# Tweet 'data/./rawdata/125692890474233856.json' not found. Skip.
# Tweet 'data/./rawdata/125692845054115842.json' not found. Skip.
# Tweet 'data/./rawdata/125691975474229248.json' not found. Skip.
# Tweet 'data/./rawdata/125690764331196416.json' not found. Skip.
# Tweet 'data/./rawdata/125689905954299904.json' not found. Skip.
# Tweet 'data/./rawdata/125687710705926144.json' not found. Skip.
# Tweet 'data/./rawdata/125686643960193024.json' not found. Skip.
# Tweet 'data/./rawdata/125685016389894144.json' not found. Skip.
# Tweet 'data/./rawdata/125679996420374530.json' not found. Skip.
# Tweet 'data/./rawdata/125677838295764992.json' not found. Skip.
# Tweet 'data/./rawdata/125674121722998785.json' not found. Skip.
# Tweet 'data/./rawdata/125669834922008576.json' not found. Skip.
# Tweet 'data/./rawdata/125667332931596290.json' not found. Skip.
# Tweet 'data/./rawdata/125667159547461633.json' not found. Skip.
# Tweet 'data/./rawdata/125666909080387584.json' not found. Skip.
# Tweet 'data/./rawdata/125665930339565568.json' not found. Skip.
# Tweet 'data/./rawdata/125664999036301312.json' not found. Skip.
# Tweet 'data/./rawdata/125664891691474944.json' not found. Skip.
# Tweet 'data/./rawdata/125663967296229376.json' not found. Skip.
# Tweet 'data/./rawdata/125663914552868864.json' not found. Skip.
# Tweet 'data/./rawdata/125661036891226113.json' not found. Skip.
# Tweet 'data/./rawdata/125660067482697729.json' not found. Skip.
# Tweet 'data/./rawdata/125657950185463808.json' not found. Skip.
# Tweet 'data/./rawdata/125647236418912256.json' not found. Skip.
# Tweet 'data/./rawdata/125645376790331392.json' not found. Skip.
# Tweet 'data/./rawdata/125643523792969728.json' not found. Skip.
# Tweet 'data/./rawdata/125642256114909184.json' not found. Skip.
# Tweet 'data/./rawdata/125642161659199488.json' not found. Skip.
# Tweet 'data/./rawdata/125642041140060160.json' not found. Skip.
# Tweet 'data/./rawdata/125641351848136704.json' not found. Skip.
# Tweet 'data/./rawdata/125640758966484992.json' not found. Skip.
# Tweet 'data/./rawdata/125640679325052929.json' not found. Skip.
# Tweet 'data/./rawdata/125640515021578240.json' not found. Skip.
# Tweet 'data/./rawdata/125638955952640000.json' not found. Skip.
# Tweet 'data/./rawdata/125633549847117824.json' not found. Skip.
# Tweet 'data/./rawdata/125633468708302848.json' not found. Skip.
# Tweet 'data/./rawdata/125633233982459904.json' not found. Skip.
# Tweet 'data/./rawdata/125632687879884800.json' not found. Skip.
# Tweet 'data/./rawdata/125632582795804672.json' not found. Skip.
# Tweet 'data/./rawdata/125631556051140608.json' not found. Skip.
# Tweet 'data/./rawdata/125630955154190336.json' not found. Skip.
# Tweet 'data/./rawdata/125630836245676033.json' not found. Skip.
# Tweet 'data/./rawdata/125630016485732352.json' not found. Skip.
# Tweet 'data/./rawdata/125629788563050496.json' not found. Skip.
# Tweet 'data/./rawdata/125627732032888833.json' not found. Skip.
# Tweet 'data/./rawdata/125626286939979776.json' not found. Skip.
# Tweet 'data/./rawdata/125625630254567424.json' not found. Skip.
# Tweet 'data/./rawdata/125625566203346944.json' not found. Skip.
# Tweet 'data/./rawdata/125620113582993408.json' not found. Skip.
# Tweet 'data/./rawdata/125617451705712640.json' not found. Skip.
# Tweet 'data/./rawdata/125617133123153921.json' not found. Skip.
# Tweet 'data/./rawdata/125616747863736320.json' not found. Skip.
# Tweet 'data/./rawdata/125614951787266048.json' not found. Skip.
# Tweet 'data/./rawdata/125614910804738049.json' not found. Skip.
# Tweet 'data/./rawdata/125607526967410689.json' not found. Skip.
# Tweet 'data/./rawdata/125598495137726464.json' not found. Skip.
# Tweet 'data/./rawdata/125596991290998784.json' not found. Skip.
# Tweet 'data/./rawdata/125595669145722880.json' not found. Skip.
# Tweet 'data/./rawdata/125595441562783744.json' not found. Skip.
# Tweet 'data/./rawdata/125591434056318977.json' not found. Skip.
# Tweet 'data/./rawdata/125589884445536257.json' not found. Skip.
# Tweet 'data/./rawdata/125589258898644992.json' not found. Skip.
# Tweet 'data/./rawdata/125588749454278656.json' not found. Skip.
# Tweet 'data/./rawdata/125588587180863489.json' not found. Skip.
# Tweet 'data/./rawdata/125587186723725312.json' not found. Skip.
# Tweet 'data/./rawdata/125586682790674434.json' not found. Skip.
# Tweet 'data/./rawdata/125585063327956992.json' not found. Skip.
# Tweet 'data/./rawdata/125583717354831872.json' not found. Skip.
# Tweet 'data/./rawdata/125581507355086848.json' not found. Skip.
# Tweet 'data/./rawdata/125581280430669824.json' not found. Skip.
# Tweet 'data/./rawdata/125564573167263746.json' not found. Skip.
# Tweet 'data/./rawdata/125559846870323200.json' not found. Skip.
# Tweet 'data/./rawdata/125559232157327360.json' not found. Skip.
# Tweet 'data/./rawdata/125551370676862976.json' not found. Skip.
# Tweet 'data/./rawdata/125546017205665792.json' not found. Skip.
# Tweet 'data/./rawdata/125545914864640000.json' not found. Skip.
# Tweet 'data/./rawdata/125544363945230336.json' not found. Skip.
# Tweet 'data/./rawdata/125541112491425792.json' not found. Skip.
# Tweet 'data/./rawdata/125538769632886784.json' not found. Skip.
# Tweet 'data/./rawdata/125537487455137793.json' not found. Skip.
# Tweet 'data/./rawdata/125532364406398977.json' not found. Skip.
# Tweet 'data/./rawdata/125532202057482240.json' not found. Skip.
# Tweet 'data/./rawdata/125528344480587776.json' not found. Skip.
# Tweet 'data/./rawdata/125527718203887616.json' not found. Skip.
# Tweet 'data/./rawdata/125512197135806464.json' not found. Skip.
# Tweet 'data/./rawdata/125498684401135616.json' not found. Skip.
# Tweet 'data/./rawdata/125496516000485376.json' not found. Skip.
# Tweet 'data/./rawdata/125493419522002944.json' not found. Skip.
# Tweet 'data/./rawdata/125493125098635265.json' not found. Skip.
# Tweet 'data/./rawdata/125489264157917184.json' not found. Skip.
# Tweet 'data/./rawdata/125486845768368128.json' not found. Skip.
# Tweet 'data/./rawdata/125460019859820544.json' not found. Skip.
# Tweet 'data/./rawdata/125459423870197760.json' not found. Skip.
# Tweet 'data/./rawdata/125459375245635584.json' not found. Skip.
# Tweet 'data/./rawdata/125457535951060993.json' not found. Skip.
# Tweet 'data/./rawdata/125448837404954624.json' not found. Skip.
# Tweet 'data/./rawdata/125433354488254464.json' not found. Skip.
# Tweet 'data/./rawdata/125432626482917376.json' not found. Skip.
# Tweet 'data/./rawdata/125432518324400128.json' not found. Skip.
# Tweet 'data/./rawdata/125425087800291328.json' not found. Skip.
# Tweet 'data/./rawdata/125424738662223872.json' not found. Skip.
# Tweet 'data/./rawdata/125419216227667968.json' not found. Skip.
# Tweet 'data/./rawdata/125417324621737985.json' not found. Skip.
# Tweet 'data/./rawdata/125416866243018753.json' not found. Skip.
# Tweet 'data/./rawdata/125416811490578435.json' not found. Skip.
# Tweet 'data/./rawdata/125410153196560384.json' not found. Skip.
# Tweet 'data/./rawdata/125409201907437569.json' not found. Skip.
# Tweet 'data/./rawdata/125406528487424003.json' not found. Skip.
# Tweet 'data/./rawdata/125406003863883776.json' not found. Skip.
# Tweet 'data/./rawdata/125405939015757824.json' not found. Skip.
# Tweet 'data/./rawdata/125402652610797569.json' not found. Skip.
# Tweet 'data/./rawdata/125398913313284096.json' not found. Skip.
# Tweet 'data/./rawdata/125398813543374848.json' not found. Skip.
# Tweet 'data/./rawdata/125394805449699329.json' not found. Skip.
# Tweet 'data/./rawdata/125379023307153408.json' not found. Skip.
# Tweet 'data/./rawdata/125374041556127744.json' not found. Skip.
# Tweet 'data/./rawdata/125373658389692416.json' not found. Skip.
# Tweet 'data/./rawdata/125373427661029376.json' not found. Skip.
# Tweet 'data/./rawdata/125372628746768384.json' not found. Skip.
# Tweet 'data/./rawdata/125369026351349760.json' not found. Skip.
# Tweet 'data/./rawdata/125368381728763904.json' not found. Skip.
# Tweet 'data/./rawdata/125367492976717824.json' not found. Skip.
# Tweet 'data/./rawdata/125366519680086016.json' not found. Skip.
# Tweet 'data/./rawdata/125365963972542464.json' not found. Skip.
# Tweet 'data/./rawdata/125365264656236544.json' not found. Skip.
# Tweet 'data/./rawdata/125364154629492737.json' not found. Skip.
# Tweet 'data/./rawdata/125364122853453824.json' not found. Skip.
# Tweet 'data/./rawdata/125361209137565696.json' not found. Skip.
# Tweet 'data/./rawdata/125360952878182400.json' not found. Skip.
# Tweet 'data/./rawdata/125360877359742976.json' not found. Skip.
# Tweet 'data/./rawdata/125359697770450944.json' not found. Skip.
# Tweet 'data/./rawdata/125359622193295360.json' not found. Skip.
# Tweet 'data/./rawdata/125357901580746752.json' not found. Skip.
# Tweet 'data/./rawdata/125354296752619520.json' not found. Skip.
# Tweet 'data/./rawdata/125351067620880385.json' not found. Skip.
# Tweet 'data/./rawdata/125350537821569024.json' not found. Skip.
# Tweet 'data/./rawdata/125347828754169856.json' not found. Skip.
# Tweet 'data/./rawdata/125347618862792705.json' not found. Skip.
# Tweet 'data/./rawdata/125345723020607488.json' not found. Skip.
# Tweet 'data/./rawdata/125344722196766720.json' not found. Skip.
# Tweet 'data/./rawdata/125344351218974720.json' not found. Skip.
# Tweet 'data/./rawdata/125338231280644096.json' not found. Skip.
# Tweet 'data/./rawdata/125336929825849344.json' not found. Skip.
# Tweet 'data/./rawdata/125336798690942977.json' not found. Skip.
# Tweet 'data/./rawdata/125335012961828866.json' not found. Skip.
# Tweet 'data/./rawdata/125332871174037504.json' not found. Skip.
# Tweet 'data/./rawdata/125332609428496384.json' not found. Skip.
# Tweet 'data/./rawdata/125327281181835264.json' not found. Skip.
# Tweet 'data/./rawdata/125326760769372160.json' not found. Skip.
# Tweet 'data/./rawdata/125325397712846848.json' not found. Skip.
# Tweet 'data/./rawdata/125324916009615360.json' not found. Skip.
# Tweet 'data/./rawdata/125321084525490176.json' not found. Skip.
# Tweet 'data/./rawdata/125318029390249984.json' not found. Skip.
# Tweet 'data/./rawdata/125317541504626688.json' not found. Skip.
# Tweet 'data/./rawdata/125317300860620801.json' not found. Skip.
# Tweet 'data/./rawdata/125315460030922752.json' not found. Skip.
# Tweet 'data/./rawdata/125315263183851521.json' not found. Skip.
# Tweet 'data/./rawdata/125315080081518592.json' not found. Skip.
# Tweet 'data/./rawdata/125312789345599489.json' not found. Skip.
# Tweet 'data/./rawdata/125312357797863425.json' not found. Skip.
# Tweet 'data/./rawdata/125309663913840640.json' not found. Skip.
# Tweet 'data/./rawdata/125305567148388352.json' not found. Skip.
# Tweet 'data/./rawdata/125300705836793856.json' not found. Skip.
# Tweet 'data/./rawdata/125300603059576833.json' not found. Skip.
# Tweet 'data/./rawdata/125287442407362560.json' not found. Skip.
# Tweet 'data/./rawdata/125283873331494913.json' not found. Skip.
# Tweet 'data/./rawdata/125281502866059264.json' not found. Skip.
# Tweet 'data/./rawdata/125278676949544960.json' not found. Skip.
# Tweet 'data/./rawdata/125276525472911360.json' not found. Skip.
# Tweet 'data/./rawdata/125275795252977664.json' not found. Skip.
# Tweet 'data/./rawdata/125275280678993920.json' not found. Skip.
# Tweet 'data/./rawdata/125273317673414656.json' not found. Skip.
# Tweet 'data/./rawdata/125270965268643840.json' not found. Skip.
# Tweet 'data/./rawdata/125267017942052866.json' not found. Skip.
# Tweet 'data/./rawdata/125266503657472000.json' not found. Skip.
# Tweet 'data/./rawdata/125261029834899456.json' not found. Skip.
# Tweet 'data/./rawdata/125260105154437121.json' not found. Skip.
# Tweet 'data/./rawdata/125257803790159873.json' not found. Skip.
# Tweet 'data/./rawdata/125252442836320256.json' not found. Skip.
# Tweet 'data/./rawdata/125250721280040961.json' not found. Skip.
# Tweet 'data/./rawdata/125250617911418881.json' not found. Skip.
# Tweet 'data/./rawdata/125250078108684288.json' not found. Skip.
# Tweet 'data/./rawdata/125246898830458880.json' not found. Skip.
# Tweet 'data/./rawdata/125245892814045184.json' not found. Skip.
# Tweet 'data/./rawdata/125244798671142912.json' not found. Skip.
# Tweet 'data/./rawdata/125231250247135233.json' not found. Skip.
# Tweet 'data/./rawdata/125227689895407616.json' not found. Skip.
# Tweet 'data/./rawdata/125222749034659840.json' not found. Skip.
# Tweet 'data/./rawdata/125218106778992640.json' not found. Skip.
# Tweet 'data/./rawdata/125211793655218178.json' not found. Skip.
# Tweet 'data/./rawdata/125206271560384512.json' not found. Skip.
# Tweet 'data/./rawdata/125196751387889665.json' not found. Skip.
# Tweet 'data/./rawdata/125193298624258049.json' not found. Skip.
# Tweet 'data/./rawdata/125184976579862530.json' not found. Skip.
# Tweet 'data/./rawdata/125085987431923713.json' not found. Skip.
# Tweet 'data/./rawdata/126405660308021248.json' not found. Skip.
# Tweet 'data/./rawdata/126403953058529280.json' not found. Skip.
# Tweet 'data/./rawdata/126402391259103232.json' not found. Skip.
# Tweet 'data/./rawdata/126399172495679488.json' not found. Skip.
# Tweet 'data/./rawdata/126394266145665025.json' not found. Skip.
# Tweet 'data/./rawdata/126391727408947200.json' not found. Skip.
# Tweet 'data/./rawdata/126387209824776192.json' not found. Skip.
# Tweet 'data/./rawdata/126385587740610563.json' not found. Skip.
# Tweet 'data/./rawdata/126381904621600768.json' not found. Skip.
# Tweet 'data/./rawdata/126379095004160001.json' not found. Skip.
# Tweet 'data/./rawdata/126373281099026432.json' not found. Skip.
# Tweet 'data/./rawdata/126367728754884609.json' not found. Skip.
# Tweet 'data/./rawdata/126362562865528832.json' not found. Skip.
# Tweet 'data/./rawdata/126360606042374144.json' not found. Skip.
# Tweet 'data/./rawdata/126355839274594304.json' not found. Skip.
# Tweet 'data/./rawdata/126355573586399232.json' not found. Skip.
# Tweet 'data/./rawdata/126352049070809089.json' not found. Skip.
# Tweet 'data/./rawdata/126346705292640257.json' not found. Skip.
# Tweet 'data/./rawdata/126346563147673600.json' not found. Skip.
# Tweet 'data/./rawdata/126346004688674816.json' not found. Skip.
# Tweet 'data/./rawdata/126342441057001472.json' not found. Skip.
# Tweet 'data/./rawdata/126340074777489408.json' not found. Skip.
# Tweet 'data/./rawdata/126332817134190592.json' not found. Skip.
# Tweet 'data/./rawdata/126331879883415552.json' not found. Skip.
# Tweet 'data/./rawdata/126329876935479296.json' not found. Skip.
# Tweet 'data/./rawdata/126319126913363968.json' not found. Skip.
# Tweet 'data/./rawdata/126313259572793345.json' not found. Skip.
# Tweet 'data/./rawdata/126312509983559681.json' not found. Skip.
# Tweet 'data/./rawdata/126310736577298432.json' not found. Skip.
# Tweet 'data/./rawdata/126307114959372289.json' not found. Skip.
# Tweet 'data/./rawdata/126304243144597505.json' not found. Skip.
# Tweet 'data/./rawdata/126303928039116800.json' not found. Skip.
# Tweet 'data/./rawdata/126303310054559744.json' not found. Skip.
# Tweet 'data/./rawdata/126298834203713536.json' not found. Skip.
# Tweet 'data/./rawdata/126298134212120577.json' not found. Skip.
# Tweet 'data/./rawdata/126297754799587328.json' not found. Skip.
# Tweet 'data/./rawdata/126290039138291712.json' not found. Skip.
# Tweet 'data/./rawdata/126271901340401665.json' not found. Skip.
# Tweet 'data/./rawdata/126270990459219968.json' not found. Skip.
# Tweet 'data/./rawdata/126264647652343808.json' not found. Skip.
# Tweet 'data/./rawdata/126264035007143936.json' not found. Skip.
# Tweet 'data/./rawdata/126263600548556800.json' not found. Skip.
# Tweet 'data/./rawdata/126260304819662849.json' not found. Skip.
# Tweet 'data/./rawdata/126252530819809280.json' not found. Skip.
# Tweet 'data/./rawdata/126236984644612096.json' not found. Skip.
# Tweet 'data/./rawdata/126232767821381632.json' not found. Skip.
# Tweet 'data/./rawdata/126228762596618240.json' not found. Skip.
# Tweet 'data/./rawdata/126215978341236736.json' not found. Skip.
# Tweet 'data/./rawdata/126195701704163328.json' not found. Skip.
# Tweet 'data/./rawdata/126186608113356800.json' not found. Skip.
# Tweet 'data/./rawdata/126175729024122880.json' not found. Skip.
# Tweet 'data/./rawdata/126173465253384193.json' not found. Skip.
# Tweet 'data/./rawdata/126164921485492224.json' not found. Skip.
# Tweet 'data/./rawdata/126149195957673984.json' not found. Skip.
# Tweet 'data/./rawdata/126138637652992001.json' not found. Skip.
# Tweet 'data/./rawdata/126131070050639874.json' not found. Skip.
# Tweet 'data/./rawdata/126111632773480448.json' not found. Skip.
# Tweet 'data/./rawdata/126097345124368385.json' not found. Skip.
# Tweet 'data/./rawdata/126093841232166912.json' not found. Skip.
# Tweet 'data/./rawdata/126061579233017856.json' not found. Skip.
# Tweet 'data/./rawdata/126054622564589569.json' not found. Skip.
# Tweet 'data/./rawdata/126054568273518592.json' not found. Skip.
# Tweet 'data/./rawdata/126052637014630400.json' not found. Skip.
# Tweet 'data/./rawdata/126042611709521921.json' not found. Skip.
# Tweet 'data/./rawdata/126024290201124864.json' not found. Skip.
# Tweet 'data/./rawdata/126022958710915072.json' not found. Skip.
# Tweet 'data/./rawdata/126022708524888064.json' not found. Skip.
# Tweet 'data/./rawdata/126007147199868928.json' not found. Skip.
# Tweet 'data/./rawdata/126005063595466753.json' not found. Skip.
# Tweet 'data/./rawdata/126001383869644800.json' not found. Skip.
# Tweet 'data/./rawdata/126000885485678592.json' not found. Skip.
# Tweet 'data/./rawdata/125998496535937024.json' not found. Skip.
# Tweet 'data/./rawdata/125996653990772737.json' not found. Skip.
# Tweet 'data/./rawdata/125993886249267200.json' not found. Skip.
# Tweet 'data/./rawdata/125993438205321218.json' not found. Skip.
# Tweet 'data/./rawdata/125993305325576193.json' not found. Skip.
# Tweet 'data/./rawdata/125992545552576512.json' not found. Skip.
# Tweet 'data/./rawdata/125991634855923712.json' not found. Skip.
# Tweet 'data/./rawdata/125990804488601600.json' not found. Skip.
# Tweet 'data/./rawdata/125990754769309696.json' not found. Skip.
# Tweet 'data/./rawdata/125982640263274496.json' not found. Skip.
# Tweet 'data/./rawdata/125973789526863872.json' not found. Skip.
# Tweet 'data/./rawdata/125970459404673026.json' not found. Skip.
# Tweet 'data/./rawdata/125968277083136000.json' not found. Skip.
# Tweet 'data/./rawdata/125967413299773440.json' not found. Skip.
# Tweet 'data/./rawdata/125967315488608257.json' not found. Skip.
# Tweet 'data/./rawdata/125965369532878849.json' not found. Skip.
# Tweet 'data/./rawdata/125965364667486209.json' not found. Skip.
# Tweet 'data/./rawdata/125959699089719297.json' not found. Skip.
# Tweet 'data/./rawdata/125959482588143616.json' not found. Skip.
# Tweet 'data/./rawdata/125957826500771840.json' not found. Skip.
# Tweet 'data/./rawdata/125957742698561537.json' not found. Skip.
# Tweet 'data/./rawdata/125948329694724097.json' not found. Skip.
# Tweet 'data/./rawdata/125930962545672192.json' not found. Skip.
# Tweet 'data/./rawdata/125928640394432513.json' not found. Skip.
# Tweet 'data/./rawdata/125910538550124545.json' not found. Skip.
# Tweet 'data/./rawdata/125909170074562561.json' not found. Skip.
# Tweet 'data/./rawdata/125877369796968448.json' not found. Skip.
# Tweet 'data/./rawdata/125873952953352192.json' not found. Skip.
# Tweet 'data/./rawdata/125862601677737985.json' not found. Skip.
# Tweet 'data/./rawdata/125857117407166464.json' not found. Skip.
# Tweet 'data/./rawdata/125827656238379008.json' not found. Skip.
# Tweet 'data/./rawdata/125826633713201152.json' not found. Skip.
# Tweet 'data/./rawdata/125825293473685505.json' not found. Skip.
# Tweet 'data/./rawdata/125815316596002816.json' not found. Skip.
# Tweet 'data/./rawdata/125797001337122817.json' not found. Skip.
# Tweet 'data/./rawdata/125724424774221826.json' not found. Skip.
# Tweet 'data/./rawdata/125707107495452673.json' not found. Skip.
# Tweet 'data/./rawdata/125705666592641024.json' not found. Skip.
# Tweet 'data/./rawdata/125705646942330880.json' not found. Skip.
# Tweet 'data/./rawdata/125699684693065728.json' not found. Skip.
# Tweet 'data/./rawdata/125695680135172096.json' not found. Skip.
# Tweet 'data/./rawdata/125695094836826112.json' not found. Skip.
# Tweet 'data/./rawdata/125653144993660928.json' not found. Skip.
# Tweet 'data/./rawdata/125650076759638016.json' not found. Skip.
# Tweet 'data/./rawdata/125647972087242754.json' not found. Skip.
# Tweet 'data/./rawdata/125641150186000384.json' not found. Skip.
# Tweet 'data/./rawdata/125622089502830592.json' not found. Skip.
# Tweet 'data/./rawdata/125621628917915648.json' not found. Skip.
# Tweet 'data/./rawdata/125602732278169601.json' not found. Skip.
# Tweet 'data/./rawdata/125595437938905088.json' not found. Skip.
# Tweet 'data/./rawdata/125590191502131200.json' not found. Skip.
# Tweet 'data/./rawdata/125580342244548608.json' not found. Skip.
# Tweet 'data/./rawdata/125568051277086721.json' not found. Skip.
# Tweet 'data/./rawdata/125542968844226560.json' not found. Skip.
# Tweet 'data/./rawdata/125542941287649280.json' not found. Skip.
# Tweet 'data/./rawdata/125534067495141376.json' not found. Skip.
# Tweet 'data/./rawdata/125526544377577472.json' not found. Skip.
# Tweet 'data/./rawdata/125521498055254016.json' not found. Skip.
# Tweet 'data/./rawdata/125521344342392832.json' not found. Skip.
# Tweet 'data/./rawdata/125516954407677952.json' not found. Skip.
# Tweet 'data/./rawdata/125495075504537600.json' not found. Skip.
# Tweet 'data/./rawdata/125490577130258432.json' not found. Skip.
# Tweet 'data/./rawdata/125485687339352064.json' not found. Skip.
# Tweet 'data/./rawdata/125447473786392576.json' not found. Skip.
# Tweet 'data/./rawdata/125445752083329025.json' not found. Skip.
# Tweet 'data/./rawdata/125445407592546304.json' not found. Skip.
# Tweet 'data/./rawdata/125421514928558080.json' not found. Skip.
# Tweet 'data/./rawdata/125411589905068033.json' not found. Skip.
# Tweet 'data/./rawdata/125409044222586880.json' not found. Skip.
# Tweet 'data/./rawdata/125406418777018368.json' not found. Skip.
# Tweet 'data/./rawdata/125405429583970305.json' not found. Skip.
# Tweet 'data/./rawdata/125375333162684416.json' not found. Skip.
# Tweet 'data/./rawdata/125361267555835905.json' not found. Skip.
# Tweet 'data/./rawdata/125353260520443904.json' not found. Skip.
# Tweet 'data/./rawdata/125352405482217473.json' not found. Skip.
# Tweet 'data/./rawdata/125346522618535937.json' not found. Skip.
# Tweet 'data/./rawdata/125339193802100736.json' not found. Skip.
# Tweet 'data/./rawdata/125336882862231552.json' not found. Skip.
# Tweet 'data/./rawdata/125333140414808065.json' not found. Skip.
# Tweet 'data/./rawdata/125325092841467904.json' not found. Skip.
# Tweet 'data/./rawdata/125321769203666944.json' not found. Skip.
# Tweet 'data/./rawdata/125319263027343360.json' not found. Skip.
# Tweet 'data/./rawdata/125305753903964161.json' not found. Skip.
# Tweet 'data/./rawdata/125301831286013952.json' not found. Skip.
# Tweet 'data/./rawdata/125287180561166336.json' not found. Skip.
# Tweet 'data/./rawdata/125275735815491584.json' not found. Skip.
# Tweet 'data/./rawdata/125232405517844481.json' not found. Skip.
# Tweet 'data/./rawdata/125228207002759168.json' not found. Skip.
# Tweet 'data/./rawdata/125219664488960000.json' not found. Skip.
# Tweet 'data/./rawdata/125209676416679936.json' not found. Skip.
# Tweet 'data/./rawdata/125206785584922624.json' not found. Skip.
# Tweet 'data/./rawdata/125184213342367744.json' not found. Skip.
# Tweet 'data/./rawdata/125082707389718529.json' not found. Skip.
# Tweet 'data/./rawdata/126534770095169536.json' not found. Skip.
# Tweet 'data/./rawdata/126534201880219648.json' not found. Skip.
# Tweet 'data/./rawdata/126534020367519744.json' not found. Skip.
# Tweet 'data/./rawdata/126533948925952000.json' not found. Skip.
# Tweet 'data/./rawdata/126533885109600256.json' not found. Skip.
# Tweet 'data/./rawdata/126533562781544448.json' not found. Skip.
# Tweet 'data/./rawdata/126533349727666176.json' not found. Skip.
# Tweet 'data/./rawdata/126533268119109632.json' not found. Skip.
# Tweet 'data/./rawdata/126533166352699392.json' not found. Skip.
# Tweet 'data/./rawdata/126532897715929088.json' not found. Skip.
# Tweet 'data/./rawdata/126531552367751169.json' not found. Skip.
# Tweet 'data/./rawdata/126531180907601920.json' not found. Skip.
# Tweet 'data/./rawdata/126530945976238080.json' not found. Skip.
# Tweet 'data/./rawdata/126530924576907264.json' not found. Skip.
# Tweet 'data/./rawdata/126530807891374082.json' not found. Skip.
# Tweet 'data/./rawdata/126530189579649024.json' not found. Skip.
# Tweet 'data/./rawdata/126530027939569665.json' not found. Skip.
# Tweet 'data/./rawdata/126529770778411008.json' not found. Skip.
# Tweet 'data/./rawdata/126528982807089152.json' not found. Skip.
# Tweet 'data/./rawdata/126528978239496194.json' not found. Skip.
# Tweet 'data/./rawdata/126528804192653312.json' not found. Skip.
# Tweet 'data/./rawdata/126528264117293056.json' not found. Skip.
# Tweet 'data/./rawdata/126526219587039233.json' not found. Skip.
# Tweet 'data/./rawdata/126525469897146368.json' not found. Skip.
# Tweet 'data/./rawdata/126525368860540928.json' not found. Skip.
# Tweet 'data/./rawdata/126525172969766912.json' not found. Skip.
# Tweet 'data/./rawdata/126524301259194368.json' not found. Skip.
# Tweet 'data/./rawdata/126523731710443521.json' not found. Skip.
# Tweet 'data/./rawdata/126523530903953408.json' not found. Skip.
# Tweet 'data/./rawdata/126523525598162944.json' not found. Skip.
# Tweet 'data/./rawdata/126522990585315328.json' not found. Skip.
# Tweet 'data/./rawdata/126522810821644288.json' not found. Skip.
# Tweet 'data/./rawdata/126522714713370624.json' not found. Skip.
# Tweet 'data/./rawdata/126522621251682304.json' not found. Skip.
# Tweet 'data/./rawdata/126522262768726016.json' not found. Skip.
# Tweet 'data/./rawdata/126521613259771904.json' not found. Skip.
# Tweet 'data/./rawdata/126521382220738560.json' not found. Skip.
# Tweet 'data/./rawdata/126521286053724160.json' not found. Skip.
# Tweet 'data/./rawdata/126520518609350656.json' not found. Skip.
# Tweet 'data/./rawdata/126520029410885632.json' not found. Skip.
# Tweet 'data/./rawdata/126519483752914944.json' not found. Skip.
# Tweet 'data/./rawdata/126519329025040384.json' not found. Skip.
# Tweet 'data/./rawdata/126519123772588032.json' not found. Skip.
# Tweet 'data/./rawdata/126519017405030400.json' not found. Skip.
# Tweet 'data/./rawdata/126518882939838464.json' not found. Skip.
# Tweet 'data/./rawdata/126516914678808578.json' not found. Skip.
# Tweet 'data/./rawdata/126516779886456832.json' not found. Skip.
# Tweet 'data/./rawdata/126516304336257025.json' not found. Skip.
# Tweet 'data/./rawdata/126515760855134208.json' not found. Skip.
# Tweet 'data/./rawdata/126514474378203136.json' not found. Skip.
# Tweet 'data/./rawdata/126513620686352384.json' not found. Skip.
# Tweet 'data/./rawdata/126513526385819648.json' not found. Skip.
# Tweet 'data/./rawdata/126513425043030016.json' not found. Skip.
# Tweet 'data/./rawdata/126512728297844736.json' not found. Skip.
# Tweet 'data/./rawdata/126512631937904640.json' not found. Skip.
# Tweet 'data/./rawdata/126512208451600384.json' not found. Skip.
# Tweet 'data/./rawdata/126511837796765696.json' not found. Skip.
# Tweet 'data/./rawdata/126511545160171520.json' not found. Skip.
# Tweet 'data/./rawdata/126511426926944256.json' not found. Skip.
# Tweet 'data/./rawdata/126511000907288576.json' not found. Skip.
# Tweet 'data/./rawdata/126510977335300096.json' not found. Skip.
# Tweet 'data/./rawdata/126510551789604864.json' not found. Skip.
# Tweet 'data/./rawdata/126509929619132417.json' not found. Skip.
# Tweet 'data/./rawdata/126509528287166464.json' not found. Skip.
# Tweet 'data/./rawdata/126508433582211072.json' not found. Skip.
# Tweet 'data/./rawdata/126508393203642368.json' not found. Skip.
# Tweet 'data/./rawdata/126507456019968000.json' not found. Skip.
# Tweet 'data/./rawdata/126507105023819776.json' not found. Skip.
# Tweet 'data/./rawdata/126506850781888512.json' not found. Skip.
# Tweet 'data/./rawdata/126506410195431424.json' not found. Skip.
# Tweet 'data/./rawdata/126506064387637249.json' not found. Skip.
# Tweet 'data/./rawdata/126505384428052481.json' not found. Skip.
# Tweet 'data/./rawdata/126505187752943616.json' not found. Skip.
# Tweet 'data/./rawdata/126505144878772224.json' not found. Skip.
# Tweet 'data/./rawdata/126504782465732608.json' not found. Skip.
# Tweet 'data/./rawdata/126504452680187905.json' not found. Skip.
# Tweet 'data/./rawdata/126504346639802368.json' not found. Skip.
# Tweet 'data/./rawdata/126504216004005888.json' not found. Skip.
# Tweet 'data/./rawdata/126504013939216384.json' not found. Skip.
# Tweet 'data/./rawdata/126503946092158976.json' not found. Skip.
# Tweet 'data/./rawdata/126503805369069568.json' not found. Skip.
# Tweet 'data/./rawdata/126503790412181504.json' not found. Skip.
# Tweet 'data/./rawdata/126503029548654593.json' not found. Skip.
# Tweet 'data/./rawdata/126502415322193920.json' not found. Skip.
# Tweet 'data/./rawdata/126502014560649216.json' not found. Skip.
# Tweet 'data/./rawdata/126501732443361280.json' not found. Skip.
# Tweet 'data/./rawdata/126501468902658048.json' not found. Skip.
# Tweet 'data/./rawdata/126500614552289282.json' not found. Skip.
# Tweet 'data/./rawdata/126499965869625345.json' not found. Skip.
# Tweet 'data/./rawdata/126499581520384001.json' not found. Skip.
# Tweet 'data/./rawdata/126499428965158912.json' not found. Skip.
# Tweet 'data/./rawdata/126499145014980608.json' not found. Skip.
# Tweet 'data/./rawdata/126499143282737152.json' not found. Skip.
# Tweet 'data/./rawdata/126498734409396224.json' not found. Skip.
# Tweet 'data/./rawdata/126498608815149056.json' not found. Skip.
# Tweet 'data/./rawdata/126498587499696128.json' not found. Skip.
# Tweet 'data/./rawdata/126497976314109952.json' not found. Skip.
# Tweet 'data/./rawdata/126497860752646146.json' not found. Skip.
# Tweet 'data/./rawdata/126497655785402368.json' not found. Skip.
# Tweet 'data/./rawdata/126496772586610688.json' not found. Skip.
# Tweet 'data/./rawdata/126496739531304960.json' not found. Skip.
# Tweet 'data/./rawdata/126496342901133313.json' not found. Skip.
# Tweet 'data/./rawdata/126496262668292096.json' not found. Skip.
# Tweet 'data/./rawdata/126496155856142336.json' not found. Skip.
# Tweet 'data/./rawdata/126496005809127424.json' not found. Skip.
# Tweet 'data/./rawdata/126495843116265475.json' not found. Skip.
# Tweet 'data/./rawdata/126495812724338688.json' not found. Skip.
# Tweet 'data/./rawdata/126495283176685569.json' not found. Skip.
# Tweet 'data/./rawdata/126495221373607936.json' not found. Skip.
# Tweet 'data/./rawdata/126494976396898305.json' not found. Skip.
# Tweet 'data/./rawdata/126494883367235585.json' not found. Skip.
# Tweet 'data/./rawdata/126494838689513473.json' not found. Skip.
# Tweet 'data/./rawdata/126494834449063936.json' not found. Skip.
# Tweet 'data/./rawdata/126494645281755136.json' not found. Skip.
# Tweet 'data/./rawdata/126494573966016512.json' not found. Skip.
# Tweet 'data/./rawdata/126494442290020352.json' not found. Skip.
# Tweet 'data/./rawdata/126494344566943744.json' not found. Skip.
# Tweet 'data/./rawdata/126494339248562176.json' not found. Skip.
# ...
# Tweet 'data/./rawdata/126866905096130560.json' not found. Skip.
# Tweet 'data/./rawdata/126866882979573760.json' not found. Skip.
# Tweet 'data/./rawdata/126866835449708544.json' not found. Skip.
# Tweet 'data/./rawdata/126866833537110016.json' not found. Skip.
# Tweet 'data/./rawdata/126866827715420160.json' not found. Skip.
# Tweet 'data/./rawdata/126866789962498048.json' not found. Skip.
# Tweet 'data/./rawdata/126866773705375744.json' not found. Skip.
# Tweet 'data/./rawdata/126866759792852992.json' not found. Skip.
# Tweet 'data/./rawdata/126866701877903361.json' not found. Skip.
# Tweet 'data/./rawdata/126866689236283392.json' not found. Skip.
# Tweet 'data/./rawdata/126866515122331648.json' not found. Skip.
# Tweet 'data/./rawdata/126866508818296832.json' not found. Skip.
# Tweet 'data/./rawdata/126866474806673408.json' not found. Skip.
# Tweet 'data/./rawdata/126866454845984768.json' not found. Skip.
# Tweet 'data/./rawdata/126866426521849857.json' not found. Skip.
# Tweet 'data/./rawdata/126866385757417472.json' not found. Skip.
# Tweet 'data/./rawdata/126866312130609152.json' not found. Skip.
# Tweet 'data/./rawdata/126866267998134272.json' not found. Skip.
# Tweet 'data/./rawdata/126866222355722240.json' not found. Skip.
# Tweet 'data/./rawdata/126866176889454592.json' not found. Skip.
# Tweet 'data/./rawdata/126866076016447489.json' not found. Skip.
# Tweet 'data/./rawdata/126866058337460224.json' not found. Skip.
# Tweet 'data/./rawdata/126866027316383744.json' not found. Skip.
# Tweet 'data/./rawdata/126866021402427392.json' not found. Skip.
# Tweet 'data/./rawdata/126865987365634048.json' not found. Skip.
# Tweet 'data/./rawdata/126865977970401280.json' not found. Skip.
# Tweet 'data/./rawdata/126865966624813057.json' not found. Skip.
# Tweet 'data/./rawdata/126865936115445761.json' not found. Skip.
# Tweet 'data/./rawdata/126865932806139904.json' not found. Skip.
# Tweet 'data/./rawdata/126865890665967618.json' not found. Skip.
# Tweet 'data/./rawdata/126865868599726080.json' not found. Skip.
# Tweet 'data/./rawdata/126865864086667264.json' not found. Skip.
# Tweet 'data/./rawdata/126865777423941633.json' not found. Skip.
# Tweet 'data/./rawdata/126865704380153856.json' not found. Skip.
# Tweet 'data/./rawdata/126865703969099776.json' not found. Skip.
# Tweet 'data/./rawdata/126865661602447362.json' not found. Skip.
# Tweet 'data/./rawdata/126865633869709312.json' not found. Skip.
# Tweet 'data/./rawdata/126865576093171712.json' not found. Skip.
# Tweet 'data/./rawdata/126865573228445696.json' not found. Skip.
# Tweet 'data/./rawdata/126865566236553216.json' not found. Skip.
# Tweet 'data/./rawdata/126865487584968704.json' not found. Skip.
# Tweet 'data/./rawdata/126865416671862785.json' not found. Skip.
# Tweet 'data/./rawdata/126865410598502400.json' not found. Skip.
# Tweet 'data/./rawdata/126865389861871617.json' not found. Skip.
# Tweet 'data/./rawdata/126865304277090304.json' not found. Skip.
# Tweet 'data/./rawdata/126865296463118337.json' not found. Skip.
# Tweet 'data/./rawdata/126865215492071424.json' not found. Skip.
# Tweet 'data/./rawdata/126865127977918464.json' not found. Skip.
# Tweet 'data/./rawdata/126865092565417984.json' not found. Skip.
# Tweet 'data/./rawdata/126865045949919233.json' not found. Skip.
# Tweet 'data/./rawdata/126865038676987904.json' not found. Skip.
# Tweet 'data/./rawdata/126865014215802880.json' not found. Skip.
# Tweet 'data/./rawdata/126864993760182272.json' not found. Skip.
# Tweet 'data/./rawdata/126864955285831680.json' not found. Skip.
# Tweet 'data/./rawdata/126864954140803072.json' not found. Skip.
# Tweet 'data/./rawdata/126864917566455809.json' not found. Skip.
# Tweet 'data/./rawdata/126864908582260736.json' not found. Skip.
# Tweet 'data/./rawdata/126864848649846784.json' not found. Skip.
# Tweet 'data/./rawdata/126864847399944192.json' not found. Skip.
# Tweet 'data/./rawdata/126864712766980096.json' not found. Skip.
# Tweet 'data/./rawdata/126864692470751232.json' not found. Skip.
# Tweet 'data/./rawdata/126864673416032256.json' not found. Skip.
# Tweet 'data/./rawdata/126864623252144128.json' not found. Skip.
# Tweet 'data/./rawdata/126864485943214080.json' not found. Skip.
# Tweet 'data/./rawdata/126864460957749248.json' not found. Skip.
# Tweet 'data/./rawdata/126864441999507456.json' not found. Skip.
# Tweet 'data/./rawdata/126864344125419520.json' not found. Skip.
# Tweet 'data/./rawdata/126864341071962112.json' not found. Skip.
# Tweet 'data/./rawdata/126864316120047617.json' not found. Skip.
# Tweet 'data/./rawdata/126864259027181568.json' not found. Skip.
# Tweet 'data/./rawdata/126864201804300289.json' not found. Skip.
# Tweet 'data/./rawdata/126864188969725953.json' not found. Skip.
# Tweet 'data/./rawdata/126864074045784064.json' not found. Skip.
# Tweet 'data/./rawdata/126864072447766528.json' not found. Skip.
# Tweet 'data/./rawdata/126864016613183489.json' not found. Skip.
# Tweet 'data/./rawdata/126863938339094531.json' not found. Skip.
# Tweet 'data/./rawdata/126863859075121152.json' not found. Skip.
# Tweet 'data/./rawdata/126863845326209024.json' not found. Skip.
# Tweet 'data/./rawdata/126863808177254400.json' not found. Skip.
# Tweet 'data/./rawdata/126863734265217025.json' not found. Skip.
# Tweet 'data/./rawdata/126863732931432448.json' not found. Skip.
# Tweet 'data/./rawdata/126863723179675648.json' not found. Skip.
# Tweet 'data/./rawdata/126863722412118017.json' not found. Skip.
# Tweet 'data/./rawdata/126863708889690112.json' not found. Skip.
# Tweet 'data/./rawdata/126863696726200320.json' not found. Skip.
# Tweet 'data/./rawdata/126863647845789696.json' not found. Skip.
# Tweet 'data/./rawdata/126863644968501250.json' not found. Skip.
# Tweet 'data/./rawdata/126863594850746369.json' not found. Skip.
# Tweet 'data/./rawdata/126863579914829824.json' not found. Skip.
# Tweet 'data/./rawdata/126863563133431809.json' not found. Skip.
# Tweet 'data/./rawdata/126863551355822080.json' not found. Skip.
# Tweet 'data/./rawdata/126863538626109440.json' not found. Skip.
# Tweet 'data/./rawdata/126863416211156992.json' not found. Skip.
# Tweet 'data/./rawdata/126863368492564481.json' not found. Skip.
# Tweet 'data/./rawdata/126863360779227136.json' not found. Skip.
# Tweet 'data/./rawdata/126863360686956544.json' not found. Skip.
# Tweet 'data/./rawdata/126863321327611904.json' not found. Skip.
# Tweet 'data/./rawdata/126863319226265600.json' not found. Skip.
# Tweet 'data/./rawdata/126863283658567680.json' not found. Skip.
# Tweet 'data/./rawdata/126863189844566016.json' not found. Skip.
# Tweet 'data/./rawdata/126863136111333376.json' not found. Skip.
# Tweet 'data/./rawdata/126863118398787584.json' not found. Skip.
# Tweet 'data/./rawdata/126863108802232320.json' not found. Skip.
# Tweet 'data/./rawdata/126863108688986112.json' not found. Skip.
# Tweet 'data/./rawdata/126863078112509952.json' not found. Skip.
# Tweet 'data/./rawdata/126863012433899520.json' not found. Skip.
# Tweet 'data/./rawdata/126862981333139457.json' not found. Skip.
# Tweet 'data/./rawdata/126862918921891840.json' not found. Skip.
# Tweet 'data/./rawdata/126862904514445312.json' not found. Skip.
# Tweet 'data/./rawdata/126862853822099456.json' not found. Skip.
# Tweet 'data/./rawdata/126862852681240576.json' not found. Skip.
# Tweet 'data/./rawdata/126862832489861121.json' not found. Skip.
# Tweet 'data/./rawdata/126862813355442176.json' not found. Skip.
# Tweet 'data/./rawdata/126862789649248256.json' not found. Skip.
# Tweet 'data/./rawdata/126862725933576192.json' not found. Skip.
# Tweet 'data/./rawdata/126862722028666880.json' not found. Skip.
# Tweet 'data/./rawdata/126862722007699456.json' not found. Skip.
# Tweet 'data/./rawdata/126862721793789953.json' not found. Skip.
# Tweet 'data/./rawdata/126862721609248769.json' not found. Skip.
# Tweet 'data/./rawdata/126862719927332864.json' not found. Skip.
# Tweet 'data/./rawdata/126862668039598080.json' not found. Skip.
# Tweet 'data/./rawdata/126862654324211713.json' not found. Skip.
# Tweet 'data/./rawdata/126862632648065025.json' not found. Skip.
# Tweet 'data/./rawdata/126862595117424641.json' not found. Skip.
# Tweet 'data/./rawdata/126862536162295808.json' not found. Skip.
# Tweet 'data/./rawdata/126862464003477504.json' not found. Skip.
# Tweet 'data/./rawdata/126862447041712128.json' not found. Skip.
# Tweet 'data/./rawdata/126862429912186880.json' not found. Skip.
# Tweet 'data/./rawdata/126862343148802048.json' not found. Skip.
# Tweet 'data/./rawdata/126862329269858305.json' not found. Skip.
# Tweet 'data/./rawdata/126862315990679552.json' not found. Skip.
# Tweet 'data/./rawdata/126862308302532608.json' not found. Skip.
# Tweet 'data/./rawdata/126862269148692481.json' not found. Skip.
# Tweet 'data/./rawdata/126862268725080065.json' not found. Skip.
# Tweet 'data/./rawdata/126862217013497856.json' not found. Skip.
# Tweet 'data/./rawdata/126862201440043008.json' not found. Skip.
# Tweet 'data/./rawdata/126862151393619968.json' not found. Skip.
# Tweet 'data/./rawdata/126862151343284224.json' not found. Skip.
# Tweet 'data/./rawdata/126862150265352193.json' not found. Skip.
# Tweet 'data/./rawdata/126862116874489856.json' not found. Skip.
# Tweet 'data/./rawdata/126861992001679360.json' not found. Skip.
# Tweet 'data/./rawdata/126861988004499457.json' not found. Skip.
# Tweet 'data/./rawdata/126861979762696192.json' not found. Skip.
# Tweet 'data/./rawdata/126861960137539585.json' not found. Skip.
# Tweet 'data/./rawdata/126861955762888706.json' not found. Skip.
# Tweet 'data/./rawdata/126861933071704065.json' not found. Skip.
# Tweet 'data/./rawdata/126861782378745856.json' not found. Skip.
# Tweet 'data/./rawdata/126861771314184192.json' not found. Skip.
# Tweet 'data/./rawdata/126861717790658561.json' not found. Skip.
# Tweet 'data/./rawdata/126861611741872128.json' not found. Skip.
# Tweet 'data/./rawdata/126861593249185793.json' not found. Skip.
# Tweet 'data/./rawdata/126861589122002944.json' not found. Skip.
# Tweet 'data/./rawdata/126861539511775232.json' not found. Skip.
# Tweet 'data/./rawdata/126861496109121536.json' not found. Skip.
# Tweet 'data/./rawdata/126861493059854336.json' not found. Skip.
# Tweet 'data/./rawdata/126861480128819201.json' not found. Skip.
# Tweet 'data/./rawdata/126861380992241664.json' not found. Skip.
# Tweet 'data/./rawdata/126861357831303168.json' not found. Skip.
# Tweet 'data/./rawdata/126861252134830080.json' not found. Skip.
# Tweet 'data/./rawdata/126861245109387264.json' not found. Skip.
# Tweet 'data/./rawdata/126861233138827264.json' not found. Skip.
# Tweet 'data/./rawdata/126861218592980992.json' not found. Skip.
# Tweet 'data/./rawdata/126861187605471232.json' not found. Skip.
# Tweet 'data/./rawdata/126861118684676096.json' not found. Skip.
# Tweet 'data/./rawdata/126861100120686592.json' not found. Skip.
# Tweet 'data/./rawdata/126860970583797760.json' not found. Skip.
# Tweet 'data/./rawdata/126860953450065920.json' not found. Skip.
# Tweet 'data/./rawdata/126860911557345280.json' not found. Skip.
# Tweet 'data/./rawdata/126860890749419521.json' not found. Skip.
# Tweet 'data/./rawdata/126860877344407552.json' not found. Skip.
# Tweet 'data/./rawdata/126860835892109312.json' not found. Skip.
# Tweet 'data/./rawdata/126860830942834689.json' not found. Skip.
# Tweet 'data/./rawdata/126860808251637762.json' not found. Skip.
# Tweet 'data/./rawdata/126860789536657408.json' not found. Skip.
# Tweet 'data/./rawdata/126860754912681985.json' not found. Skip.
# Tweet 'data/./rawdata/126860740689797120.json' not found. Skip.
# Tweet 'data/./rawdata/126860719860883458.json' not found. Skip.
# Tweet 'data/./rawdata/126860653167263744.json' not found. Skip.
# Tweet 'data/./rawdata/126860610020446209.json' not found. Skip.
# Tweet 'data/./rawdata/126860576600227841.json' not found. Skip.
# Tweet 'data/./rawdata/126860372987740160.json' not found. Skip.
# Tweet 'data/./rawdata/126860329463447552.json' not found. Skip.
# Tweet 'data/./rawdata/126860270181171201.json' not found. Skip.
# Tweet 'data/./rawdata/126860146289803265.json' not found. Skip.
# Tweet 'data/./rawdata/126860127167987712.json' not found. Skip.
# Tweet 'data/./rawdata/126860114610241536.json' not found. Skip.
# Tweet 'data/./rawdata/126860109090521088.json' not found. Skip.
# Tweet 'data/./rawdata/126859990513369088.json' not found. Skip.
# Tweet 'data/./rawdata/126859860640940032.json' not found. Skip.
# Tweet 'data/./rawdata/126859857604247552.json' not found. Skip.
# Tweet 'data/./rawdata/126859846506127360.json' not found. Skip.
# Tweet 'data/./rawdata/126859794383515649.json' not found. Skip.
# Tweet 'data/./rawdata/126859777308495872.json' not found. Skip.
# Tweet 'data/./rawdata/126859668151738368.json' not found. Skip.
# Tweet 'data/./rawdata/126859627051757568.json' not found. Skip.
# Tweet 'data/./rawdata/126859610006110208.json' not found. Skip.
# Tweet 'data/./rawdata/126859509414100992.json' not found. Skip.
# Tweet 'data/./rawdata/126859503495938048.json' not found. Skip.
# Tweet 'data/./rawdata/126859490061598720.json' not found. Skip.
# Tweet 'data/./rawdata/126859443127332864.json' not found. Skip.
# Tweet 'data/./rawdata/126859428455657472.json' not found. Skip.
# Tweet 'data/./rawdata/126859363079041024.json' not found. Skip.
# Tweet 'data/./rawdata/126859354614939648.json' not found. Skip.
# Tweet 'data/./rawdata/126859286558158849.json' not found. Skip.
# Tweet 'data/./rawdata/126859257856540672.json' not found. Skip.
# Tweet 'data/./rawdata/126859211593351168.json' not found. Skip.
# Tweet 'data/./rawdata/126859155175772161.json' not found. Skip.
# Tweet 'data/./rawdata/126859077304320001.json' not found. Skip.
# Tweet 'data/./rawdata/126858835058098176.json' not found. Skip.
# Tweet 'data/./rawdata/126858789868670976.json' not found. Skip.
# Tweet 'data/./rawdata/126858639855206400.json' not found. Skip.
# Tweet 'data/./rawdata/126858516655898625.json' not found. Skip.
# Tweet 'data/./rawdata/126858260216160256.json' not found. Skip.
# Tweet 'data/./rawdata/126858248325308416.json' not found. Skip.
# Tweet 'data/./rawdata/126858186962644992.json' not found. Skip.
# Tweet 'data/./rawdata/126858148878368769.json' not found. Skip.
# Tweet 'data/./rawdata/126858034466131969.json' not found. Skip.
# Tweet 'data/./rawdata/126858032951996416.json' not found. Skip.
# Tweet 'data/./rawdata/126858004690767872.json' not found. Skip.
# Tweet 'data/./rawdata/126857921068941314.json' not found. Skip.
# Tweet 'data/./rawdata/126857918929838080.json' not found. Skip.
# Tweet 'data/./rawdata/126857746200014849.json' not found. Skip.
# Tweet 'data/./rawdata/126857736238530560.json' not found. Skip.
# Tweet 'data/./rawdata/126857518591901698.json' not found. Skip.
# Tweet 'data/./rawdata/126857511230902272.json' not found. Skip.
# Tweet 'data/./rawdata/126857421321797634.json' not found. Skip.
# Tweet 'data/./rawdata/126857383715676160.json' not found. Skip.
# Tweet 'data/./rawdata/126857361515216897.json' not found. Skip.
# Tweet 'data/./rawdata/126857211921174528.json' not found. Skip.
# Tweet 'data/./rawdata/126857080513638400.json' not found. Skip.
# Tweet 'data/./rawdata/126857071667847168.json' not found. Skip.
# Tweet 'data/./rawdata/126857049920385024.json' not found. Skip.
# Tweet 'data/./rawdata/126856764242137088.json' not found. Skip.
# Tweet 'data/./rawdata/126856732331884545.json' not found. Skip.
# Tweet 'data/./rawdata/126856603021484032.json' not found. Skip.
# Tweet 'data/./rawdata/126856425371746304.json' not found. Skip.
# Tweet 'data/./rawdata/126856274531991552.json' not found. Skip.
# Tweet 'data/./rawdata/126856135918620673.json' not found. Skip.
# Tweet 'data/./rawdata/126856097863708672.json' not found. Skip.
# Tweet 'data/./rawdata/126856097431699456.json' not found. Skip.
# Tweet 'data/./rawdata/126855687060987904.json' not found. Skip.
# Tweet 'data/./rawdata/126855171702661120.json' not found. Skip.
# Tweet 'data/./rawdata/126854999442587648.json' not found. Skip.
# Tweet 'data/./rawdata/126854818101858304.json' not found. Skip.
# Tweet 'data/./rawdata/126854423317188608.json' not found. Skip.
# #negative: 282
# #neutral: 253
# #positive: 131
# == Pos vs. neg ==
# 0.820	0.033	0.826	0.036
# == Pos/neg vs. irrelevant/neutral ==
# 0.743	0.018	0.877	0.012
# == Pos vs. rest ==
# 0.835	0.025	0.579	0.053
# == Neg vs. rest ==
# 0.779	0.021	0.824	0.027
# ('time spent:', 10.286588907241821)

# %%
imgshow('./charts/pr_neg_vs_rest_03.png')
imgshow('./charts/pr_pos_vs_neg_03.png')
imgshow('./charts/pr_pos_vs_rest_03.png')

# %%
# %load 04_sent.py

# %%
# This code is supporting material for the book
# Building Machine Learning Systems with Python
# by Willi Richert and Luis Pedro Coelho
# published by PACKT Publishing
#
# It is made available under the MIT License

#
# This script trains tries to tweak hyperparameters to improve P/R AUC
#

import time
start_time = time.time()
import re

import nltk

import numpy as np

from sklearn.metrics import precision_recall_curve, roc_curve, auc
from sklearn.cross_validation import ShuffleSplit

from utils import plot_pr
from utils import load_sanders_data
from utils import tweak_labels
from utils import log_false_positives

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.base import BaseEstimator

from sklearn.naive_bayes import MultinomialNB

from utils import load_sent_word_net

sent_word_net = load_sent_word_net()

phase = "04"

import json

poscache_filename = "poscache.json"
try:
    poscache = json.load(open(poscache_filename, "r"))
except IOError:
    poscache = {}


class LinguisticVectorizer(BaseEstimator):

    def get_feature_names(self):
        return np.array(['sent_neut', 'sent_pos', 'sent_neg',
                         'nouns', 'adjectives', 'verbs', 'adverbs',
                         'allcaps', 'exclamation', 'question'])

    def fit(self, documents, y=None):
        return self

    def _get_sentiments(self, d):
        # http://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
        sent = tuple(nltk.word_tokenize(d))
        if poscache is not None:
            if d in poscache:
                tagged = poscache[d]
            else:
                poscache[d] = tagged = nltk.pos_tag(sent)
        else:
            tagged = nltk.pos_tag(sent)

        pos_vals = []
        neg_vals = []

        nouns = 0.
        adjectives = 0.
        verbs = 0.
        adverbs = 0.

        for w, t in tagged:
            p, n = 0, 0
            sent_pos_type = None
            if t.startswith("NN"):
                sent_pos_type = "n"
                nouns += 1
            elif t.startswith("JJ"):
                sent_pos_type = "a"
                adjectives += 1
            elif t.startswith("VB"):
                sent_pos_type = "v"
                verbs += 1
            elif t.startswith("RB"):
                sent_pos_type = "r"
                adverbs += 1

            if sent_pos_type is not None:
                sent_word = "%s/%s" % (sent_pos_type, w)

                if sent_word in sent_word_net:
                    p, n = sent_word_net[sent_word]

            pos_vals.append(p)
            neg_vals.append(n)

        l = len(sent)
        avg_pos_val = np.mean(pos_vals)
        avg_neg_val = np.mean(neg_vals)

        return [1 - avg_pos_val - avg_neg_val, avg_pos_val, avg_neg_val,
                nouns / l, adjectives / l, verbs / l, adverbs / l]

    def transform(self, documents):
        obj_val, pos_val, neg_val, nouns, adjectives, verbs, adverbs = np.array(
            [self._get_sentiments(d) for d in documents]).T

        allcaps = []
        exclamation = []
        question = []

        for d in documents:
            allcaps.append(
                np.sum([t.isupper() for t in d.split() if len(t) > 2]))

            exclamation.append(d.count("!"))
            question.append(d.count("?"))

        result = np.array(
            [obj_val, pos_val, neg_val, nouns, adjectives, verbs, adverbs, allcaps,
             exclamation, question]).T

        return result

emo_repl = {
    # positive emoticons
    "&lt;3": " good ",
    ":d": " good ",  # :D in lower case
    ":dd": " good ",  # :DD in lower case
    "8)": " good ",
    ":-)": " good ",
    ":)": " good ",
    ";)": " good ",
    "(-:": " good ",
    "(:": " good ",

    # negative emoticons:
    ":/": " bad ",
    ":&gt;": " sad ",
    ":')": " sad ",
    ":-(": " bad ",
    ":(": " bad ",
    ":S": " bad ",
    ":-S": " bad ",
}

emo_repl_order = [k for (k_len, k) in reversed(
    sorted([(len(k), k) for k in list(emo_repl.keys())]))]

re_repl = {
    r"\br\b": "are",
    r"\bu\b": "you",
    r"\bhaha\b": "ha",
    r"\bhahaha\b": "ha",
    r"\bdon't\b": "do not",
    r"\bdoesn't\b": "does not",
    r"\bdidn't\b": "did not",
    r"\bhasn't\b": "has not",
    r"\bhaven't\b": "have not",
    r"\bhadn't\b": "had not",
    r"\bwon't\b": "will not",
    r"\bwouldn't\b": "would not",
    r"\bcan't\b": "can not",
    r"\bcannot\b": "can not",
}


def create_union_model(params=None):
    def preprocessor(tweet):
        tweet = tweet.lower()

        for k in emo_repl_order:
            tweet = tweet.replace(k, emo_repl[k])
        for r, repl in re_repl.items():
            tweet = re.sub(r, repl, tweet)

        return tweet.replace("-", " ").replace("_", " ")

    tfidf_ngrams = TfidfVectorizer(preprocessor=preprocessor,
                                   analyzer="word")
    ling_stats = LinguisticVectorizer()
    all_features = FeatureUnion(
        [('ling', ling_stats), ('tfidf', tfidf_ngrams)])
    #all_features = FeatureUnion([('tfidf', tfidf_ngrams)])
    #all_features = FeatureUnion([('ling', ling_stats)])
    clf = MultinomialNB()
    pipeline = Pipeline([('all', all_features), ('clf', clf)])

    if params:
        pipeline.set_params(**params)

    return pipeline


def __grid_search_model(clf_factory, X, Y):
    cv = ShuffleSplit(
        n=len(X), n_iter=10, test_size=0.3, random_state=0)

    param_grid = dict(vect__ngram_range=[(1, 1), (1, 2), (1, 3)],
                      vect__min_df=[1, 2],
                      vect__smooth_idf=[False, True],
                      vect__use_idf=[False, True],
                      vect__sublinear_tf=[False, True],
                      vect__binary=[False, True],
                      clf__alpha=[0, 0.01, 0.05, 0.1, 0.5, 1],
                      )

    grid_search = GridSearchCV(clf_factory(),
                               param_grid=param_grid,
                               cv=cv,
                               score_func=f1_score,
                               verbose=10)
    grid_search.fit(X, Y)
    clf = grid_search.best_estimator_
    print(clf)

    return clf


def train_model(clf, X, Y, name="NB ngram", plot=False):
    # create it again for plotting
    cv = ShuffleSplit(
        n=len(X), n_iter=10, test_size=0.3, random_state=0)

    train_errors = []
    test_errors = []

    scores = []
    pr_scores = []
    precisions, recalls, thresholds = [], [], []

    clfs = []  # just to later get the median

    for train, test in cv:
        X_train, y_train = X[train], Y[train]
        X_test, y_test = X[test], Y[test]

        clf.fit(X_train, y_train)
        clfs.append(clf)

        train_score = clf.score(X_train, y_train)
        test_score = clf.score(X_test, y_test)

        train_errors.append(1 - train_score)
        test_errors.append(1 - test_score)

        scores.append(test_score)
        proba = clf.predict_proba(X_test)

        fpr, tpr, roc_thresholds = roc_curve(y_test, proba[:, 1])
        precision, recall, pr_thresholds = precision_recall_curve(
            y_test, proba[:, 1])

        pr_scores.append(auc(recall, precision))
        precisions.append(precision)
        recalls.append(recall)
        thresholds.append(pr_thresholds)

    if plot:
        scores_to_sort = pr_scores
        median = np.argsort(scores_to_sort)[len(scores_to_sort) / 2]

        plot_pr(pr_scores[median], name, phase, precisions[median],
                recalls[median], label=name)

        log_false_positives(clfs[median], X_test, y_test, name)

    summary = (np.mean(scores), np.std(scores),
               np.mean(pr_scores), np.std(pr_scores))
    print("%.3f\t%.3f\t%.3f\t%.3f\t" % summary)

    return np.mean(train_errors), np.mean(test_errors)


def print_incorrect(clf, X, Y):
    Y_hat = clf.predict(X)
    wrong_idx = Y_hat != Y
    X_wrong = X[wrong_idx]
    Y_wrong = Y[wrong_idx]
    Y_hat_wrong = Y_hat[wrong_idx]
    for idx in range(len(X_wrong)):
        print("clf.predict('%s')=%i instead of %i" %
              (X_wrong[idx], Y_hat_wrong[idx], Y_wrong[idx]))


def get_best_model():
    best_params = dict(all__tfidf__ngram_range=(1, 2),
                       all__tfidf__min_df=1,
                       all__tfidf__stop_words=None,
                       all__tfidf__smooth_idf=False,
                       all__tfidf__use_idf=False,
                       all__tfidf__sublinear_tf=True,
                       all__tfidf__binary=False,
                       clf__alpha=0.01,
                       )

    best_clf = create_union_model(best_params)

    return best_clf

if __name__ == "__main__":
    X_orig, Y_orig = load_sanders_data()
    #from sklearn.utils import shuffle
    # print "shuffle, sample"
    #X_orig, Y_orig = shuffle(X_orig, Y_orig)
    #X_orig = X_orig[:100,]
    #Y_orig = Y_orig[:100,]
    classes = np.unique(Y_orig)
    for c in classes:
        print("#%s: %i" % (c, sum(Y_orig == c)))

    print("== Pos vs. neg ==")
    pos_neg = np.logical_or(Y_orig == "positive", Y_orig == "negative")
    X = X_orig[pos_neg]
    Y = Y_orig[pos_neg]
    Y = tweak_labels(Y, ["positive"])
    train_model(get_best_model(), X, Y, name="pos vs neg", plot=True)

    print("== Pos/neg vs. irrelevant/neutral ==")
    X = X_orig
    Y = tweak_labels(Y_orig, ["positive", "negative"])

    # best_clf = grid_search_model(create_union_model, X, Y, name="sent vs
    # rest", plot=True)
    train_model(get_best_model(), X, Y, name="pos+neg vs rest", plot=True)

    print("== Pos vs. rest ==")
    X = X_orig
    Y = tweak_labels(Y_orig, ["positive"])
    train_model(get_best_model(), X, Y, name="pos vs rest",
                plot=True)

    print("== Neg vs. rest ==")
    X = X_orig
    Y = tweak_labels(Y_orig, ["negative"])
    train_model(get_best_model(), X, Y, name="neg vs rest",
                plot=True)

    print("time spent:", time.time() - start_time)

    json.dump(poscache, open(poscache_filename, "w"))
# Out:
# Tweet 'data/./rawdata/126394830791254016.json' not found. Skip.
# Tweet 'data/./rawdata/126366123368267776.json' not found. Skip.
# Tweet 'data/./rawdata/126354605130002432.json' not found. Skip.
# Tweet 'data/./rawdata/126350948548354048.json' not found. Skip.
# Tweet 'data/./rawdata/126350302113824769.json' not found. Skip.
# Tweet 'data/./rawdata/126344048637259776.json' not found. Skip.
# Tweet 'data/./rawdata/126323785145126912.json' not found. Skip.
# Tweet 'data/./rawdata/126319186141130752.json' not found. Skip.
# Tweet 'data/./rawdata/126312877916307458.json' not found. Skip.
# Tweet 'data/./rawdata/126267185025916928.json' not found. Skip.
# Tweet 'data/./rawdata/126213333123743744.json' not found. Skip.
# Tweet 'data/./rawdata/126148685737361408.json' not found. Skip.
# Tweet 'data/./rawdata/126130991365500928.json' not found. Skip.
# Tweet 'data/./rawdata/126093298619252737.json' not found. Skip.
# Tweet 'data/./rawdata/126079414986485761.json' not found. Skip.
# Tweet 'data/./rawdata/126076743613284354.json' not found. Skip.
# Tweet 'data/./rawdata/126063569660936193.json' not found. Skip.
# Tweet 'data/./rawdata/126063358037340161.json' not found. Skip.
# Tweet 'data/./rawdata/126059399319003136.json' not found. Skip.
# Tweet 'data/./rawdata/126049183865114624.json' not found. Skip.
# Tweet 'data/./rawdata/126040352237961217.json' not found. Skip.
# Tweet 'data/./rawdata/126039929523404801.json' not found. Skip.
# Tweet 'data/./rawdata/126015087386431488.json' not found. Skip.
# Tweet 'data/./rawdata/126008369562652672.json' not found. Skip.
# Tweet 'data/./rawdata/125995158679461888.json' not found. Skip.
# Tweet 'data/./rawdata/125979338846900224.json' not found. Skip.
# Tweet 'data/./rawdata/125978473712979969.json' not found. Skip.
# Tweet 'data/./rawdata/125954443643588608.json' not found. Skip.
# Tweet 'data/./rawdata/125947232359948288.json' not found. Skip.
# Tweet 'data/./rawdata/125943290288803841.json' not found. Skip.
# Tweet 'data/./rawdata/125932869389524992.json' not found. Skip.
# Tweet 'data/./rawdata/125930171562852353.json' not found. Skip.
# Tweet 'data/./rawdata/125910633731461120.json' not found. Skip.
# Tweet 'data/./rawdata/125909565031198720.json' not found. Skip.
# Tweet 'data/./rawdata/125907732388790272.json' not found. Skip.
# Tweet 'data/./rawdata/125898611572740097.json' not found. Skip.
# Tweet 'data/./rawdata/125816853867151360.json' not found. Skip.
# Tweet 'data/./rawdata/125727629012770816.json' not found. Skip.
# Tweet 'data/./rawdata/125688922410975232.json' not found. Skip.
# Tweet 'data/./rawdata/125685656415510528.json' not found. Skip.
# Tweet 'data/./rawdata/125673004511412224.json' not found. Skip.
# Tweet 'data/./rawdata/125665606853861376.json' not found. Skip.
# Tweet 'data/./rawdata/125633065757310976.json' not found. Skip.
# Tweet 'data/./rawdata/125616280215617537.json' not found. Skip.
# Tweet 'data/./rawdata/125595292304281601.json' not found. Skip.
# Tweet 'data/./rawdata/125536884813336576.json' not found. Skip.
# Tweet 'data/./rawdata/125533599737978882.json' not found. Skip.
# Tweet 'data/./rawdata/125458901192810496.json' not found. Skip.
# Tweet 'data/./rawdata/125445056218923008.json' not found. Skip.
# Tweet 'data/./rawdata/125422502284505088.json' not found. Skip.
# Tweet 'data/./rawdata/125402636764712960.json' not found. Skip.
# Tweet 'data/./rawdata/125330595302744064.json' not found. Skip.
# Tweet 'data/./rawdata/125281706327552001.json' not found. Skip.
# Tweet 'data/./rawdata/125279447669669888.json' not found. Skip.
# Tweet 'data/./rawdata/125264731035537409.json' not found. Skip.
# Tweet 'data/./rawdata/125251672896323584.json' not found. Skip.
# Tweet 'data/./rawdata/125243911538098176.json' not found. Skip.
# Tweet 'data/./rawdata/126400637930979329.json' not found. Skip.
# Tweet 'data/./rawdata/126391082308206593.json' not found. Skip.
# Tweet 'data/./rawdata/126328782700285952.json' not found. Skip.
# Tweet 'data/./rawdata/126325125749542913.json' not found. Skip.
# Tweet 'data/./rawdata/126312535203921920.json' not found. Skip.
# Tweet 'data/./rawdata/126311879218966529.json' not found. Skip.
# Tweet 'data/./rawdata/126308005779210241.json' not found. Skip.
# Tweet 'data/./rawdata/126304942049853441.json' not found. Skip.
# Tweet 'data/./rawdata/126297241190281216.json' not found. Skip.
# Tweet 'data/./rawdata/126295434862936064.json' not found. Skip.
# Tweet 'data/./rawdata/126282994821509120.json' not found. Skip.
# Tweet 'data/./rawdata/126270073420791810.json' not found. Skip.
# Tweet 'data/./rawdata/126264313563459585.json' not found. Skip.
# Tweet 'data/./rawdata/126239832895795200.json' not found. Skip.
# Tweet 'data/./rawdata/126182880123695104.json' not found. Skip.
# Tweet 'data/./rawdata/126156590662422528.json' not found. Skip.
# Tweet 'data/./rawdata/126153311521996800.json' not found. Skip.
# Tweet 'data/./rawdata/126148955217203200.json' not found. Skip.
# Tweet 'data/./rawdata/126148565302128640.json' not found. Skip.
# Tweet 'data/./rawdata/126140389873827841.json' not found. Skip.
# Tweet 'data/./rawdata/126129938247061504.json' not found. Skip.
# Tweet 'data/./rawdata/126126605344047105.json' not found. Skip.
# Tweet 'data/./rawdata/126121175926571009.json' not found. Skip.
# Tweet 'data/./rawdata/126082198720888833.json' not found. Skip.
# Tweet 'data/./rawdata/126073788323479552.json' not found. Skip.
# Tweet 'data/./rawdata/126070647125327872.json' not found. Skip.
# Tweet 'data/./rawdata/126060639268507649.json' not found. Skip.
# Tweet 'data/./rawdata/126042137740574720.json' not found. Skip.
# Tweet 'data/./rawdata/126042022900547584.json' not found. Skip.
# Tweet 'data/./rawdata/126033747991736320.json' not found. Skip.
# Tweet 'data/./rawdata/126012404332113920.json' not found. Skip.
# Tweet 'data/./rawdata/126012089415380992.json' not found. Skip.
# Tweet 'data/./rawdata/126006088725303296.json' not found. Skip.
# Tweet 'data/./rawdata/126004661248471040.json' not found. Skip.
# Tweet 'data/./rawdata/125988395787882497.json' not found. Skip.
# Tweet 'data/./rawdata/125974810021998595.json' not found. Skip.
# Tweet 'data/./rawdata/125969502587465729.json' not found. Skip.
# Tweet 'data/./rawdata/125954651152592896.json' not found. Skip.
# Tweet 'data/./rawdata/125934808592433153.json' not found. Skip.
# Tweet 'data/./rawdata/125836461936361472.json' not found. Skip.
# Tweet 'data/./rawdata/125824054958637056.json' not found. Skip.
# Tweet 'data/./rawdata/125814380871946240.json' not found. Skip.
# Tweet 'data/./rawdata/125812985301172224.json' not found. Skip.
# Tweet 'data/./rawdata/125811345064067072.json' not found. Skip.
# Tweet 'data/./rawdata/125799384976863232.json' not found. Skip.
# Tweet 'data/./rawdata/125794882257305600.json' not found. Skip.
# Tweet 'data/./rawdata/125728250579259392.json' not found. Skip.
# Tweet 'data/./rawdata/125722610179907584.json' not found. Skip.
# Tweet 'data/./rawdata/125711996074209280.json' not found. Skip.
# Tweet 'data/./rawdata/125694815743651840.json' not found. Skip.
# Tweet 'data/./rawdata/125692685033021441.json' not found. Skip.
# Tweet 'data/./rawdata/125692532750430209.json' not found. Skip.
# Tweet 'data/./rawdata/125681375058735104.json' not found. Skip.
# Tweet 'data/./rawdata/125675806977556480.json' not found. Skip.
# Tweet 'data/./rawdata/125673358418391041.json' not found. Skip.
# Tweet 'data/./rawdata/125659125886623744.json' not found. Skip.
# Tweet 'data/./rawdata/125656618326175745.json' not found. Skip.
# Tweet 'data/./rawdata/125619303356710912.json' not found. Skip.
# Tweet 'data/./rawdata/125607492356018176.json' not found. Skip.
# Tweet 'data/./rawdata/125588697872728065.json' not found. Skip.
# Tweet 'data/./rawdata/125578269197217792.json' not found. Skip.
# Tweet 'data/./rawdata/125561930416013312.json' not found. Skip.
# Tweet 'data/./rawdata/125547255947198465.json' not found. Skip.
# Tweet 'data/./rawdata/125476730067615744.json' not found. Skip.
# Tweet 'data/./rawdata/125475953509015552.json' not found. Skip.
# Tweet 'data/./rawdata/125441732941840385.json' not found. Skip.
# Tweet 'data/./rawdata/125435218017525760.json' not found. Skip.
# Tweet 'data/./rawdata/125420263687995392.json' not found. Skip.
# Tweet 'data/./rawdata/125400161886277632.json' not found. Skip.
# Tweet 'data/./rawdata/125395636219678720.json' not found. Skip.
# Tweet 'data/./rawdata/125380163302199296.json' not found. Skip.
# Tweet 'data/./rawdata/125371779039502336.json' not found. Skip.
# Tweet 'data/./rawdata/125369698840887297.json' not found. Skip.
# Tweet 'data/./rawdata/125368089159286784.json' not found. Skip.
# Tweet 'data/./rawdata/125355139409252352.json' not found. Skip.
# Tweet 'data/./rawdata/125347619072512000.json' not found. Skip.
# Tweet 'data/./rawdata/125346783390990337.json' not found. Skip.
# Tweet 'data/./rawdata/125334519254482944.json' not found. Skip.
# Tweet 'data/./rawdata/125330337847975937.json' not found. Skip.
# Tweet 'data/./rawdata/125309427422203904.json' not found. Skip.
# Tweet 'data/./rawdata/125304159581900800.json' not found. Skip.
# Tweet 'data/./rawdata/125295729139908608.json' not found. Skip.
# Tweet 'data/./rawdata/125294978623746048.json' not found. Skip.
# Tweet 'data/./rawdata/125271422431014914.json' not found. Skip.
# Tweet 'data/./rawdata/125268117680160768.json' not found. Skip.
# Tweet 'data/./rawdata/125245246136258561.json' not found. Skip.
# Tweet 'data/./rawdata/125232266849947648.json' not found. Skip.
# Tweet 'data/./rawdata/125212404299735040.json' not found. Skip.
# Tweet 'data/./rawdata/125204228967903232.json' not found. Skip.
# Tweet 'data/./rawdata/126394795802370049.json' not found. Skip.
# Tweet 'data/./rawdata/126386085164101634.json' not found. Skip.
# Tweet 'data/./rawdata/126382776072146944.json' not found. Skip.
# Tweet 'data/./rawdata/126380323733909504.json' not found. Skip.
# Tweet 'data/./rawdata/126362867778859008.json' not found. Skip.
# Tweet 'data/./rawdata/126343124174901248.json' not found. Skip.
# Tweet 'data/./rawdata/126339328434651136.json' not found. Skip.
# Tweet 'data/./rawdata/126329388320043008.json' not found. Skip.
# Tweet 'data/./rawdata/126317201962700800.json' not found. Skip.
# Tweet 'data/./rawdata/126314701721309184.json' not found. Skip.
# Tweet 'data/./rawdata/126312423132102657.json' not found. Skip.
# Tweet 'data/./rawdata/126307117274644480.json' not found. Skip.
# Tweet 'data/./rawdata/126298592364331008.json' not found. Skip.
# Tweet 'data/./rawdata/126293725155569664.json' not found. Skip.
# Tweet 'data/./rawdata/126292233963053056.json' not found. Skip.
# Tweet 'data/./rawdata/126287512296632320.json' not found. Skip.
# Tweet 'data/./rawdata/126283639959990274.json' not found. Skip.
# Tweet 'data/./rawdata/126229089651654656.json' not found. Skip.
# Tweet 'data/./rawdata/126225922159427584.json' not found. Skip.
# Tweet 'data/./rawdata/126219340214304768.json' not found. Skip.
# Tweet 'data/./rawdata/126192452297170945.json' not found. Skip.
# Tweet 'data/./rawdata/126186955296878592.json' not found. Skip.
# Tweet 'data/./rawdata/126186795808456704.json' not found. Skip.
# Tweet 'data/./rawdata/126147867478982656.json' not found. Skip.
# Tweet 'data/./rawdata/126125799744094208.json' not found. Skip.
# Tweet 'data/./rawdata/126110770864979968.json' not found. Skip.
# Tweet 'data/./rawdata/126102213956337664.json' not found. Skip.
# Tweet 'data/./rawdata/126082898783780864.json' not found. Skip.
# Tweet 'data/./rawdata/126081812236738560.json' not found. Skip.
# Tweet 'data/./rawdata/126065983138955265.json' not found. Skip.
# Tweet 'data/./rawdata/126054725727698944.json' not found. Skip.
# Tweet 'data/./rawdata/126044185815040000.json' not found. Skip.
# Tweet 'data/./rawdata/126043954641780736.json' not found. Skip.
# Tweet 'data/./rawdata/126039090578735104.json' not found. Skip.
# Tweet 'data/./rawdata/126029114850295809.json' not found. Skip.
# Tweet 'data/./rawdata/126021436149211136.json' not found. Skip.
# Tweet 'data/./rawdata/126017685246050304.json' not found. Skip.
# Tweet 'data/./rawdata/126014277814468608.json' not found. Skip.
# Tweet 'data/./rawdata/126012833128390656.json' not found. Skip.
# Tweet 'data/./rawdata/126010471202566144.json' not found. Skip.
# Tweet 'data/./rawdata/126009386022879232.json' not found. Skip.
# Tweet 'data/./rawdata/126006669535744000.json' not found. Skip.
# Tweet 'data/./rawdata/125998732046123009.json' not found. Skip.
# Tweet 'data/./rawdata/125996412252078080.json' not found. Skip.
# Tweet 'data/./rawdata/125994997609803776.json' not found. Skip.
# Tweet 'data/./rawdata/125992594395250688.json' not found. Skip.
# Tweet 'data/./rawdata/125988651426512899.json' not found. Skip.
# Tweet 'data/./rawdata/125981074114359297.json' not found. Skip.
# Tweet 'data/./rawdata/125980615664336896.json' not found. Skip.
# Tweet 'data/./rawdata/125974497546338304.json' not found. Skip.
# Tweet 'data/./rawdata/125971256335024128.json' not found. Skip.
# Tweet 'data/./rawdata/125958702455988225.json' not found. Skip.
# Tweet 'data/./rawdata/125957972466737152.json' not found. Skip.
# Tweet 'data/./rawdata/125950026181648385.json' not found. Skip.
# Tweet 'data/./rawdata/125949784677810176.json' not found. Skip.
# Tweet 'data/./rawdata/125947460592996352.json' not found. Skip.
# Tweet 'data/./rawdata/125932876721168384.json' not found. Skip.
# Tweet 'data/./rawdata/125930342891790337.json' not found. Skip.
# Tweet 'data/./rawdata/125922500839342080.json' not found. Skip.
# Tweet 'data/./rawdata/125922174648324096.json' not found. Skip.
# Tweet 'data/./rawdata/125921393350160384.json' not found. Skip.
# Tweet 'data/./rawdata/125920729194704896.json' not found. Skip.
# Tweet 'data/./rawdata/125920725595983874.json' not found. Skip.
# Tweet 'data/./rawdata/125920721200361472.json' not found. Skip.
# Tweet 'data/./rawdata/125920717966544896.json' not found. Skip.
# Tweet 'data/./rawdata/125920716297211904.json' not found. Skip.
# Tweet 'data/./rawdata/125919221845721090.json' not found. Skip.
# Tweet 'data/./rawdata/125918906215968771.json' not found. Skip.
# Tweet 'data/./rawdata/125918450920062977.json' not found. Skip.
# Tweet 'data/./rawdata/125918447979872258.json' not found. Skip.
# Tweet 'data/./rawdata/125918444762828800.json' not found. Skip.
# Tweet 'data/./rawdata/125918441013133312.json' not found. Skip.
# Tweet 'data/./rawdata/125917264267579393.json' not found. Skip.
# Tweet 'data/./rawdata/125917174618525696.json' not found. Skip.
# Tweet 'data/./rawdata/125917170571026432.json' not found. Skip.
# Tweet 'data/./rawdata/125917164535418880.json' not found. Skip.
# Tweet 'data/./rawdata/125917160982855680.json' not found. Skip.
# Tweet 'data/./rawdata/125915210337890304.json' not found. Skip.
# Tweet 'data/./rawdata/125908946702696448.json' not found. Skip.
# Tweet 'data/./rawdata/125907633466130432.json' not found. Skip.
# Tweet 'data/./rawdata/125892140940267522.json' not found. Skip.
# Tweet 'data/./rawdata/125891898517889024.json' not found. Skip.
# Tweet 'data/./rawdata/125887065861787648.json' not found. Skip.
# Tweet 'data/./rawdata/125882473312817152.json' not found. Skip.
# Tweet 'data/./rawdata/125878880916611072.json' not found. Skip.
# Tweet 'data/./rawdata/125866627337162752.json' not found. Skip.
# Tweet 'data/./rawdata/125866368758333440.json' not found. Skip.
# Tweet 'data/./rawdata/125859792802693120.json' not found. Skip.
# Tweet 'data/./rawdata/125859488728236032.json' not found. Skip.
# Tweet 'data/./rawdata/125854430171111424.json' not found. Skip.
# Tweet 'data/./rawdata/125840474132066304.json' not found. Skip.
# Tweet 'data/./rawdata/125830917578162176.json' not found. Skip.
# Tweet 'data/./rawdata/125829040740368384.json' not found. Skip.
# Tweet 'data/./rawdata/125828984293425152.json' not found. Skip.
# Tweet 'data/./rawdata/125826820057731074.json' not found. Skip.
# Tweet 'data/./rawdata/125824709421039616.json' not found. Skip.
# Tweet 'data/./rawdata/125823389804929024.json' not found. Skip.
# Tweet 'data/./rawdata/125821979797364736.json' not found. Skip.
# Tweet 'data/./rawdata/125821218258550784.json' not found. Skip.
# Tweet 'data/./rawdata/125817967240949760.json' not found. Skip.
# Tweet 'data/./rawdata/125815990620659713.json' not found. Skip.
# Tweet 'data/./rawdata/125811943054393344.json' not found. Skip.
# Tweet 'data/./rawdata/125807897568481280.json' not found. Skip.
# Tweet 'data/./rawdata/125804983185719297.json' not found. Skip.
# Tweet 'data/./rawdata/125803571601080320.json' not found. Skip.
# Tweet 'data/./rawdata/125803457155301376.json' not found. Skip.
# Tweet 'data/./rawdata/125801811817922561.json' not found. Skip.
# Tweet 'data/./rawdata/125793487479259136.json' not found. Skip.
# Tweet 'data/./rawdata/125792596114161665.json' not found. Skip.
# Tweet 'data/./rawdata/125792107930714113.json' not found. Skip.
# Tweet 'data/./rawdata/125727869363163137.json' not found. Skip.
# Tweet 'data/./rawdata/125727349034598401.json' not found. Skip.
# Tweet 'data/./rawdata/125727044263874560.json' not found. Skip.
# Tweet 'data/./rawdata/125726769297891330.json' not found. Skip.
# Tweet 'data/./rawdata/125725274317914112.json' not found. Skip.
# Tweet 'data/./rawdata/125725019178409984.json' not found. Skip.
# Tweet 'data/./rawdata/125724524732882944.json' not found. Skip.
# Tweet 'data/./rawdata/125721197437648896.json' not found. Skip.
# Tweet 'data/./rawdata/125714971261812736.json' not found. Skip.
# Tweet 'data/./rawdata/125708425752612864.json' not found. Skip.
# Tweet 'data/./rawdata/125708240225959936.json' not found. Skip.
# Tweet 'data/./rawdata/125706125764083712.json' not found. Skip.
# Tweet 'data/./rawdata/125703536632807424.json' not found. Skip.
# Tweet 'data/./rawdata/125698733768843264.json' not found. Skip.
# Tweet 'data/./rawdata/125695449423286272.json' not found. Skip.
# Tweet 'data/./rawdata/125695107734319104.json' not found. Skip.
# Tweet 'data/./rawdata/125694587313467393.json' not found. Skip.
# Tweet 'data/./rawdata/125692890474233856.json' not found. Skip.
# Tweet 'data/./rawdata/125692845054115842.json' not found. Skip.
# Tweet 'data/./rawdata/125691975474229248.json' not found. Skip.
# Tweet 'data/./rawdata/125690764331196416.json' not found. Skip.
# Tweet 'data/./rawdata/125689905954299904.json' not found. Skip.
# Tweet 'data/./rawdata/125687710705926144.json' not found. Skip.
# Tweet 'data/./rawdata/125686643960193024.json' not found. Skip.
# Tweet 'data/./rawdata/125685016389894144.json' not found. Skip.
# Tweet 'data/./rawdata/125679996420374530.json' not found. Skip.
# Tweet 'data/./rawdata/125677838295764992.json' not found. Skip.
# Tweet 'data/./rawdata/125674121722998785.json' not found. Skip.
# Tweet 'data/./rawdata/125669834922008576.json' not found. Skip.
# Tweet 'data/./rawdata/125667332931596290.json' not found. Skip.
# Tweet 'data/./rawdata/125667159547461633.json' not found. Skip.
# Tweet 'data/./rawdata/125666909080387584.json' not found. Skip.
# Tweet 'data/./rawdata/125665930339565568.json' not found. Skip.
# Tweet 'data/./rawdata/125664999036301312.json' not found. Skip.
# Tweet 'data/./rawdata/125664891691474944.json' not found. Skip.
# Tweet 'data/./rawdata/125663967296229376.json' not found. Skip.
# Tweet 'data/./rawdata/125663914552868864.json' not found. Skip.
# Tweet 'data/./rawdata/125661036891226113.json' not found. Skip.
# Tweet 'data/./rawdata/125660067482697729.json' not found. Skip.
# Tweet 'data/./rawdata/125657950185463808.json' not found. Skip.
# Tweet 'data/./rawdata/125647236418912256.json' not found. Skip.
# Tweet 'data/./rawdata/125645376790331392.json' not found. Skip.
# Tweet 'data/./rawdata/125643523792969728.json' not found. Skip.
# Tweet 'data/./rawdata/125642256114909184.json' not found. Skip.
# Tweet 'data/./rawdata/125642161659199488.json' not found. Skip.
# Tweet 'data/./rawdata/125642041140060160.json' not found. Skip.
# Tweet 'data/./rawdata/125641351848136704.json' not found. Skip.
# Tweet 'data/./rawdata/125640758966484992.json' not found. Skip.
# Tweet 'data/./rawdata/125640679325052929.json' not found. Skip.
# Tweet 'data/./rawdata/125640515021578240.json' not found. Skip.
# Tweet 'data/./rawdata/125638955952640000.json' not found. Skip.
# Tweet 'data/./rawdata/125633549847117824.json' not found. Skip.
# Tweet 'data/./rawdata/125633468708302848.json' not found. Skip.
# Tweet 'data/./rawdata/125633233982459904.json' not found. Skip.
# Tweet 'data/./rawdata/125632687879884800.json' not found. Skip.
# Tweet 'data/./rawdata/125632582795804672.json' not found. Skip.
# Tweet 'data/./rawdata/125631556051140608.json' not found. Skip.
# Tweet 'data/./rawdata/125630955154190336.json' not found. Skip.
# Tweet 'data/./rawdata/125630836245676033.json' not found. Skip.
# Tweet 'data/./rawdata/125630016485732352.json' not found. Skip.
# Tweet 'data/./rawdata/125629788563050496.json' not found. Skip.
# Tweet 'data/./rawdata/125627732032888833.json' not found. Skip.
# Tweet 'data/./rawdata/125626286939979776.json' not found. Skip.
# Tweet 'data/./rawdata/125625630254567424.json' not found. Skip.
# Tweet 'data/./rawdata/125625566203346944.json' not found. Skip.
# Tweet 'data/./rawdata/125620113582993408.json' not found. Skip.
# Tweet 'data/./rawdata/125617451705712640.json' not found. Skip.
# Tweet 'data/./rawdata/125617133123153921.json' not found. Skip.
# Tweet 'data/./rawdata/125616747863736320.json' not found. Skip.
# Tweet 'data/./rawdata/125614951787266048.json' not found. Skip.
# Tweet 'data/./rawdata/125614910804738049.json' not found. Skip.
# Tweet 'data/./rawdata/125607526967410689.json' not found. Skip.
# Tweet 'data/./rawdata/125598495137726464.json' not found. Skip.
# Tweet 'data/./rawdata/125596991290998784.json' not found. Skip.
# Tweet 'data/./rawdata/125595669145722880.json' not found. Skip.
# Tweet 'data/./rawdata/125595441562783744.json' not found. Skip.
# Tweet 'data/./rawdata/125591434056318977.json' not found. Skip.
# Tweet 'data/./rawdata/125589884445536257.json' not found. Skip.
# Tweet 'data/./rawdata/125589258898644992.json' not found. Skip.
# Tweet 'data/./rawdata/125588749454278656.json' not found. Skip.
# Tweet 'data/./rawdata/125588587180863489.json' not found. Skip.
# Tweet 'data/./rawdata/125587186723725312.json' not found. Skip.
# Tweet 'data/./rawdata/125586682790674434.json' not found. Skip.
# Tweet 'data/./rawdata/125585063327956992.json' not found. Skip.
# Tweet 'data/./rawdata/125583717354831872.json' not found. Skip.
# Tweet 'data/./rawdata/125581507355086848.json' not found. Skip.
# Tweet 'data/./rawdata/125581280430669824.json' not found. Skip.
# Tweet 'data/./rawdata/125564573167263746.json' not found. Skip.
# Tweet 'data/./rawdata/125559846870323200.json' not found. Skip.
# Tweet 'data/./rawdata/125559232157327360.json' not found. Skip.
# Tweet 'data/./rawdata/125551370676862976.json' not found. Skip.
# Tweet 'data/./rawdata/125546017205665792.json' not found. Skip.
# Tweet 'data/./rawdata/125545914864640000.json' not found. Skip.
# Tweet 'data/./rawdata/125544363945230336.json' not found. Skip.
# Tweet 'data/./rawdata/125541112491425792.json' not found. Skip.
# Tweet 'data/./rawdata/125538769632886784.json' not found. Skip.
# Tweet 'data/./rawdata/125537487455137793.json' not found. Skip.
# Tweet 'data/./rawdata/125532364406398977.json' not found. Skip.
# Tweet 'data/./rawdata/125532202057482240.json' not found. Skip.
# Tweet 'data/./rawdata/125528344480587776.json' not found. Skip.
# Tweet 'data/./rawdata/125527718203887616.json' not found. Skip.
# Tweet 'data/./rawdata/125512197135806464.json' not found. Skip.
# Tweet 'data/./rawdata/125498684401135616.json' not found. Skip.
# Tweet 'data/./rawdata/125496516000485376.json' not found. Skip.
# Tweet 'data/./rawdata/125493419522002944.json' not found. Skip.
# Tweet 'data/./rawdata/125493125098635265.json' not found. Skip.
# Tweet 'data/./rawdata/125489264157917184.json' not found. Skip.
# Tweet 'data/./rawdata/125486845768368128.json' not found. Skip.
# Tweet 'data/./rawdata/125460019859820544.json' not found. Skip.
# Tweet 'data/./rawdata/125459423870197760.json' not found. Skip.
# Tweet 'data/./rawdata/125459375245635584.json' not found. Skip.
# Tweet 'data/./rawdata/125457535951060993.json' not found. Skip.
# Tweet 'data/./rawdata/125448837404954624.json' not found. Skip.
# Tweet 'data/./rawdata/125433354488254464.json' not found. Skip.
# Tweet 'data/./rawdata/125432626482917376.json' not found. Skip.
# Tweet 'data/./rawdata/125432518324400128.json' not found. Skip.
# Tweet 'data/./rawdata/125425087800291328.json' not found. Skip.
# Tweet 'data/./rawdata/125424738662223872.json' not found. Skip.
# Tweet 'data/./rawdata/125419216227667968.json' not found. Skip.
# Tweet 'data/./rawdata/125417324621737985.json' not found. Skip.
# Tweet 'data/./rawdata/125416866243018753.json' not found. Skip.
# Tweet 'data/./rawdata/125416811490578435.json' not found. Skip.
# Tweet 'data/./rawdata/125410153196560384.json' not found. Skip.
# Tweet 'data/./rawdata/125409201907437569.json' not found. Skip.
# Tweet 'data/./rawdata/125406528487424003.json' not found. Skip.
# Tweet 'data/./rawdata/125406003863883776.json' not found. Skip.
# Tweet 'data/./rawdata/125405939015757824.json' not found. Skip.
# Tweet 'data/./rawdata/125402652610797569.json' not found. Skip.
# Tweet 'data/./rawdata/125398913313284096.json' not found. Skip.
# Tweet 'data/./rawdata/125398813543374848.json' not found. Skip.
# Tweet 'data/./rawdata/125394805449699329.json' not found. Skip.
# Tweet 'data/./rawdata/125379023307153408.json' not found. Skip.
# Tweet 'data/./rawdata/125374041556127744.json' not found. Skip.
# Tweet 'data/./rawdata/125373658389692416.json' not found. Skip.
# Tweet 'data/./rawdata/125373427661029376.json' not found. Skip.
# Tweet 'data/./rawdata/125372628746768384.json' not found. Skip.
# Tweet 'data/./rawdata/125369026351349760.json' not found. Skip.
# Tweet 'data/./rawdata/125368381728763904.json' not found. Skip.
# Tweet 'data/./rawdata/125367492976717824.json' not found. Skip.
# Tweet 'data/./rawdata/125366519680086016.json' not found. Skip.
# Tweet 'data/./rawdata/125365963972542464.json' not found. Skip.
# Tweet 'data/./rawdata/125365264656236544.json' not found. Skip.
# Tweet 'data/./rawdata/125364154629492737.json' not found. Skip.
# Tweet 'data/./rawdata/125364122853453824.json' not found. Skip.
# Tweet 'data/./rawdata/125361209137565696.json' not found. Skip.
# Tweet 'data/./rawdata/125360952878182400.json' not found. Skip.
# Tweet 'data/./rawdata/125360877359742976.json' not found. Skip.
# Tweet 'data/./rawdata/125359697770450944.json' not found. Skip.
# Tweet 'data/./rawdata/125359622193295360.json' not found. Skip.
# Tweet 'data/./rawdata/125357901580746752.json' not found. Skip.
# Tweet 'data/./rawdata/125354296752619520.json' not found. Skip.
# Tweet 'data/./rawdata/125351067620880385.json' not found. Skip.
# Tweet 'data/./rawdata/125350537821569024.json' not found. Skip.
# Tweet 'data/./rawdata/125347828754169856.json' not found. Skip.
# Tweet 'data/./rawdata/125347618862792705.json' not found. Skip.
# Tweet 'data/./rawdata/125345723020607488.json' not found. Skip.
# Tweet 'data/./rawdata/125344722196766720.json' not found. Skip.
# Tweet 'data/./rawdata/125344351218974720.json' not found. Skip.
# Tweet 'data/./rawdata/125338231280644096.json' not found. Skip.
# Tweet 'data/./rawdata/125336929825849344.json' not found. Skip.
# Tweet 'data/./rawdata/125336798690942977.json' not found. Skip.
# Tweet 'data/./rawdata/125335012961828866.json' not found. Skip.
# Tweet 'data/./rawdata/125332871174037504.json' not found. Skip.
# Tweet 'data/./rawdata/125332609428496384.json' not found. Skip.
# Tweet 'data/./rawdata/125327281181835264.json' not found. Skip.
# Tweet 'data/./rawdata/125326760769372160.json' not found. Skip.
# Tweet 'data/./rawdata/125325397712846848.json' not found. Skip.
# Tweet 'data/./rawdata/125324916009615360.json' not found. Skip.
# Tweet 'data/./rawdata/125321084525490176.json' not found. Skip.
# Tweet 'data/./rawdata/125318029390249984.json' not found. Skip.
# Tweet 'data/./rawdata/125317541504626688.json' not found. Skip.
# Tweet 'data/./rawdata/125317300860620801.json' not found. Skip.
# Tweet 'data/./rawdata/125315460030922752.json' not found. Skip.
# Tweet 'data/./rawdata/125315263183851521.json' not found. Skip.
# Tweet 'data/./rawdata/125315080081518592.json' not found. Skip.
# Tweet 'data/./rawdata/125312789345599489.json' not found. Skip.
# Tweet 'data/./rawdata/125312357797863425.json' not found. Skip.
# Tweet 'data/./rawdata/125309663913840640.json' not found. Skip.
# Tweet 'data/./rawdata/125305567148388352.json' not found. Skip.
# Tweet 'data/./rawdata/125300705836793856.json' not found. Skip.
# Tweet 'data/./rawdata/125300603059576833.json' not found. Skip.
# Tweet 'data/./rawdata/125287442407362560.json' not found. Skip.
# Tweet 'data/./rawdata/125283873331494913.json' not found. Skip.
# Tweet 'data/./rawdata/125281502866059264.json' not found. Skip.
# Tweet 'data/./rawdata/125278676949544960.json' not found. Skip.
# Tweet 'data/./rawdata/125276525472911360.json' not found. Skip.
# Tweet 'data/./rawdata/125275795252977664.json' not found. Skip.
# Tweet 'data/./rawdata/125275280678993920.json' not found. Skip.
# Tweet 'data/./rawdata/125273317673414656.json' not found. Skip.
# Tweet 'data/./rawdata/125270965268643840.json' not found. Skip.
# Tweet 'data/./rawdata/125267017942052866.json' not found. Skip.
# Tweet 'data/./rawdata/125266503657472000.json' not found. Skip.
# Tweet 'data/./rawdata/125261029834899456.json' not found. Skip.
# Tweet 'data/./rawdata/125260105154437121.json' not found. Skip.
# Tweet 'data/./rawdata/125257803790159873.json' not found. Skip.
# Tweet 'data/./rawdata/125252442836320256.json' not found. Skip.
# Tweet 'data/./rawdata/125250721280040961.json' not found. Skip.
# Tweet 'data/./rawdata/125250617911418881.json' not found. Skip.
# Tweet 'data/./rawdata/125250078108684288.json' not found. Skip.
# Tweet 'data/./rawdata/125246898830458880.json' not found. Skip.
# Tweet 'data/./rawdata/125245892814045184.json' not found. Skip.
# Tweet 'data/./rawdata/125244798671142912.json' not found. Skip.
# Tweet 'data/./rawdata/125231250247135233.json' not found. Skip.
# Tweet 'data/./rawdata/125227689895407616.json' not found. Skip.
# Tweet 'data/./rawdata/125222749034659840.json' not found. Skip.
# Tweet 'data/./rawdata/125218106778992640.json' not found. Skip.
# Tweet 'data/./rawdata/125211793655218178.json' not found. Skip.
# Tweet 'data/./rawdata/125206271560384512.json' not found. Skip.
# Tweet 'data/./rawdata/125196751387889665.json' not found. Skip.
# Tweet 'data/./rawdata/125193298624258049.json' not found. Skip.
# Tweet 'data/./rawdata/125184976579862530.json' not found. Skip.
# Tweet 'data/./rawdata/125085987431923713.json' not found. Skip.
# Tweet 'data/./rawdata/126405660308021248.json' not found. Skip.
# Tweet 'data/./rawdata/126403953058529280.json' not found. Skip.
# Tweet 'data/./rawdata/126402391259103232.json' not found. Skip.
# Tweet 'data/./rawdata/126399172495679488.json' not found. Skip.
# Tweet 'data/./rawdata/126394266145665025.json' not found. Skip.
# Tweet 'data/./rawdata/126391727408947200.json' not found. Skip.
# Tweet 'data/./rawdata/126387209824776192.json' not found. Skip.
# Tweet 'data/./rawdata/126385587740610563.json' not found. Skip.
# Tweet 'data/./rawdata/126381904621600768.json' not found. Skip.
# Tweet 'data/./rawdata/126379095004160001.json' not found. Skip.
# Tweet 'data/./rawdata/126373281099026432.json' not found. Skip.
# Tweet 'data/./rawdata/126367728754884609.json' not found. Skip.
# Tweet 'data/./rawdata/126362562865528832.json' not found. Skip.
# Tweet 'data/./rawdata/126360606042374144.json' not found. Skip.
# Tweet 'data/./rawdata/126355839274594304.json' not found. Skip.
# Tweet 'data/./rawdata/126355573586399232.json' not found. Skip.
# Tweet 'data/./rawdata/126352049070809089.json' not found. Skip.
# Tweet 'data/./rawdata/126346705292640257.json' not found. Skip.
# Tweet 'data/./rawdata/126346563147673600.json' not found. Skip.
# Tweet 'data/./rawdata/126346004688674816.json' not found. Skip.
# Tweet 'data/./rawdata/126342441057001472.json' not found. Skip.
# Tweet 'data/./rawdata/126340074777489408.json' not found. Skip.
# Tweet 'data/./rawdata/126332817134190592.json' not found. Skip.
# Tweet 'data/./rawdata/126331879883415552.json' not found. Skip.
# Tweet 'data/./rawdata/126329876935479296.json' not found. Skip.
# Tweet 'data/./rawdata/126319126913363968.json' not found. Skip.
# Tweet 'data/./rawdata/126313259572793345.json' not found. Skip.
# Tweet 'data/./rawdata/126312509983559681.json' not found. Skip.
# Tweet 'data/./rawdata/126310736577298432.json' not found. Skip.
# Tweet 'data/./rawdata/126307114959372289.json' not found. Skip.
# Tweet 'data/./rawdata/126304243144597505.json' not found. Skip.
# Tweet 'data/./rawdata/126303928039116800.json' not found. Skip.
# Tweet 'data/./rawdata/126303310054559744.json' not found. Skip.
# Tweet 'data/./rawdata/126298834203713536.json' not found. Skip.
# Tweet 'data/./rawdata/126298134212120577.json' not found. Skip.
# Tweet 'data/./rawdata/126297754799587328.json' not found. Skip.
# Tweet 'data/./rawdata/126290039138291712.json' not found. Skip.
# Tweet 'data/./rawdata/126271901340401665.json' not found. Skip.
# Tweet 'data/./rawdata/126270990459219968.json' not found. Skip.
# Tweet 'data/./rawdata/126264647652343808.json' not found. Skip.
# Tweet 'data/./rawdata/126264035007143936.json' not found. Skip.
# Tweet 'data/./rawdata/126263600548556800.json' not found. Skip.
# Tweet 'data/./rawdata/126260304819662849.json' not found. Skip.
# Tweet 'data/./rawdata/126252530819809280.json' not found. Skip.
# Tweet 'data/./rawdata/126236984644612096.json' not found. Skip.
# Tweet 'data/./rawdata/126232767821381632.json' not found. Skip.
# Tweet 'data/./rawdata/126228762596618240.json' not found. Skip.
# Tweet 'data/./rawdata/126215978341236736.json' not found. Skip.
# Tweet 'data/./rawdata/126195701704163328.json' not found. Skip.
# Tweet 'data/./rawdata/126186608113356800.json' not found. Skip.
# Tweet 'data/./rawdata/126175729024122880.json' not found. Skip.
# Tweet 'data/./rawdata/126173465253384193.json' not found. Skip.
# Tweet 'data/./rawdata/126164921485492224.json' not found. Skip.
# Tweet 'data/./rawdata/126149195957673984.json' not found. Skip.
# Tweet 'data/./rawdata/126138637652992001.json' not found. Skip.
# Tweet 'data/./rawdata/126131070050639874.json' not found. Skip.
# Tweet 'data/./rawdata/126111632773480448.json' not found. Skip.
# Tweet 'data/./rawdata/126097345124368385.json' not found. Skip.
# Tweet 'data/./rawdata/126093841232166912.json' not found. Skip.
# Tweet 'data/./rawdata/126061579233017856.json' not found. Skip.
# Tweet 'data/./rawdata/126054622564589569.json' not found. Skip.
# Tweet 'data/./rawdata/126054568273518592.json' not found. Skip.
# Tweet 'data/./rawdata/126052637014630400.json' not found. Skip.
# Tweet 'data/./rawdata/126042611709521921.json' not found. Skip.
# Tweet 'data/./rawdata/126024290201124864.json' not found. Skip.
# Tweet 'data/./rawdata/126022958710915072.json' not found. Skip.
# Tweet 'data/./rawdata/126022708524888064.json' not found. Skip.
# Tweet 'data/./rawdata/126007147199868928.json' not found. Skip.
# Tweet 'data/./rawdata/126005063595466753.json' not found. Skip.
# Tweet 'data/./rawdata/126001383869644800.json' not found. Skip.
# Tweet 'data/./rawdata/126000885485678592.json' not found. Skip.
# Tweet 'data/./rawdata/125998496535937024.json' not found. Skip.
# Tweet 'data/./rawdata/125996653990772737.json' not found. Skip.
# Tweet 'data/./rawdata/125993886249267200.json' not found. Skip.
# Tweet 'data/./rawdata/125993438205321218.json' not found. Skip.
# Tweet 'data/./rawdata/125993305325576193.json' not found. Skip.
# Tweet 'data/./rawdata/125992545552576512.json' not found. Skip.
# Tweet 'data/./rawdata/125991634855923712.json' not found. Skip.
# Tweet 'data/./rawdata/125990804488601600.json' not found. Skip.
# Tweet 'data/./rawdata/125990754769309696.json' not found. Skip.
# Tweet 'data/./rawdata/125982640263274496.json' not found. Skip.
# Tweet 'data/./rawdata/125973789526863872.json' not found. Skip.
# Tweet 'data/./rawdata/125970459404673026.json' not found. Skip.
# Tweet 'data/./rawdata/125968277083136000.json' not found. Skip.
# Tweet 'data/./rawdata/125967413299773440.json' not found. Skip.
# Tweet 'data/./rawdata/125967315488608257.json' not found. Skip.
# Tweet 'data/./rawdata/125965369532878849.json' not found. Skip.
# Tweet 'data/./rawdata/125965364667486209.json' not found. Skip.
# Tweet 'data/./rawdata/125959699089719297.json' not found. Skip.
# Tweet 'data/./rawdata/125959482588143616.json' not found. Skip.
# Tweet 'data/./rawdata/125957826500771840.json' not found. Skip.
# Tweet 'data/./rawdata/125957742698561537.json' not found. Skip.
# Tweet 'data/./rawdata/125948329694724097.json' not found. Skip.
# Tweet 'data/./rawdata/125930962545672192.json' not found. Skip.
# Tweet 'data/./rawdata/125928640394432513.json' not found. Skip.
# Tweet 'data/./rawdata/125910538550124545.json' not found. Skip.
# Tweet 'data/./rawdata/125909170074562561.json' not found. Skip.
# Tweet 'data/./rawdata/125877369796968448.json' not found. Skip.
# Tweet 'data/./rawdata/125873952953352192.json' not found. Skip.
# Tweet 'data/./rawdata/125862601677737985.json' not found. Skip.
# Tweet 'data/./rawdata/125857117407166464.json' not found. Skip.
# Tweet 'data/./rawdata/125827656238379008.json' not found. Skip.
# Tweet 'data/./rawdata/125826633713201152.json' not found. Skip.
# Tweet 'data/./rawdata/125825293473685505.json' not found. Skip.
# Tweet 'data/./rawdata/125815316596002816.json' not found. Skip.
# Tweet 'data/./rawdata/125797001337122817.json' not found. Skip.
# Tweet 'data/./rawdata/125724424774221826.json' not found. Skip.
# Tweet 'data/./rawdata/125707107495452673.json' not found. Skip.
# Tweet 'data/./rawdata/125705666592641024.json' not found. Skip.
# Tweet 'data/./rawdata/125705646942330880.json' not found. Skip.
# Tweet 'data/./rawdata/125699684693065728.json' not found. Skip.
# Tweet 'data/./rawdata/125695680135172096.json' not found. Skip.
# Tweet 'data/./rawdata/125695094836826112.json' not found. Skip.
# Tweet 'data/./rawdata/125653144993660928.json' not found. Skip.
# Tweet 'data/./rawdata/125650076759638016.json' not found. Skip.
# Tweet 'data/./rawdata/125647972087242754.json' not found. Skip.
# Tweet 'data/./rawdata/125641150186000384.json' not found. Skip.
# Tweet 'data/./rawdata/125622089502830592.json' not found. Skip.
# Tweet 'data/./rawdata/125621628917915648.json' not found. Skip.
# Tweet 'data/./rawdata/125602732278169601.json' not found. Skip.
# Tweet 'data/./rawdata/125595437938905088.json' not found. Skip.
# Tweet 'data/./rawdata/125590191502131200.json' not found. Skip.
# Tweet 'data/./rawdata/125580342244548608.json' not found. Skip.
# Tweet 'data/./rawdata/125568051277086721.json' not found. Skip.
# Tweet 'data/./rawdata/125542968844226560.json' not found. Skip.
# Tweet 'data/./rawdata/125542941287649280.json' not found. Skip.
# Tweet 'data/./rawdata/125534067495141376.json' not found. Skip.
# Tweet 'data/./rawdata/125526544377577472.json' not found. Skip.
# Tweet 'data/./rawdata/125521498055254016.json' not found. Skip.
# Tweet 'data/./rawdata/125521344342392832.json' not found. Skip.
# Tweet 'data/./rawdata/125516954407677952.json' not found. Skip.
# Tweet 'data/./rawdata/125495075504537600.json' not found. Skip.
# Tweet 'data/./rawdata/125490577130258432.json' not found. Skip.
# Tweet 'data/./rawdata/125485687339352064.json' not found. Skip.
# Tweet 'data/./rawdata/125447473786392576.json' not found. Skip.
# Tweet 'data/./rawdata/125445752083329025.json' not found. Skip.
# Tweet 'data/./rawdata/125445407592546304.json' not found. Skip.
# Tweet 'data/./rawdata/125421514928558080.json' not found. Skip.
# Tweet 'data/./rawdata/125411589905068033.json' not found. Skip.
# Tweet 'data/./rawdata/125409044222586880.json' not found. Skip.
# Tweet 'data/./rawdata/125406418777018368.json' not found. Skip.
# Tweet 'data/./rawdata/125405429583970305.json' not found. Skip.
# Tweet 'data/./rawdata/125375333162684416.json' not found. Skip.
# Tweet 'data/./rawdata/125361267555835905.json' not found. Skip.
# Tweet 'data/./rawdata/125353260520443904.json' not found. Skip.
# Tweet 'data/./rawdata/125352405482217473.json' not found. Skip.
# Tweet 'data/./rawdata/125346522618535937.json' not found. Skip.
# Tweet 'data/./rawdata/125339193802100736.json' not found. Skip.
# Tweet 'data/./rawdata/125336882862231552.json' not found. Skip.
# Tweet 'data/./rawdata/125333140414808065.json' not found. Skip.
# Tweet 'data/./rawdata/125325092841467904.json' not found. Skip.
# Tweet 'data/./rawdata/125321769203666944.json' not found. Skip.
# Tweet 'data/./rawdata/125319263027343360.json' not found. Skip.
# Tweet 'data/./rawdata/125305753903964161.json' not found. Skip.
# Tweet 'data/./rawdata/125301831286013952.json' not found. Skip.
# Tweet 'data/./rawdata/125287180561166336.json' not found. Skip.
# Tweet 'data/./rawdata/125275735815491584.json' not found. Skip.
# Tweet 'data/./rawdata/125232405517844481.json' not found. Skip.
# Tweet 'data/./rawdata/125228207002759168.json' not found. Skip.
# Tweet 'data/./rawdata/125219664488960000.json' not found. Skip.
# Tweet 'data/./rawdata/125209676416679936.json' not found. Skip.
# Tweet 'data/./rawdata/125206785584922624.json' not found. Skip.
# Tweet 'data/./rawdata/125184213342367744.json' not found. Skip.
# Tweet 'data/./rawdata/125082707389718529.json' not found. Skip.
# Tweet 'data/./rawdata/126534770095169536.json' not found. Skip.
# Tweet 'data/./rawdata/126534201880219648.json' not found. Skip.
# Tweet 'data/./rawdata/126534020367519744.json' not found. Skip.
# Tweet 'data/./rawdata/126533948925952000.json' not found. Skip.
# Tweet 'data/./rawdata/126533885109600256.json' not found. Skip.
# Tweet 'data/./rawdata/126533562781544448.json' not found. Skip.
# Tweet 'data/./rawdata/126533349727666176.json' not found. Skip.
# Tweet 'data/./rawdata/126533268119109632.json' not found. Skip.
# Tweet 'data/./rawdata/126533166352699392.json' not found. Skip.
# Tweet 'data/./rawdata/126532897715929088.json' not found. Skip.
# Tweet 'data/./rawdata/126531552367751169.json' not found. Skip.
# Tweet 'data/./rawdata/126531180907601920.json' not found. Skip.
# Tweet 'data/./rawdata/126530945976238080.json' not found. Skip.
# Tweet 'data/./rawdata/126530924576907264.json' not found. Skip.
# Tweet 'data/./rawdata/126530807891374082.json' not found. Skip.
# Tweet 'data/./rawdata/126530189579649024.json' not found. Skip.
# Tweet 'data/./rawdata/126530027939569665.json' not found. Skip.
# Tweet 'data/./rawdata/126529770778411008.json' not found. Skip.
# Tweet 'data/./rawdata/126528982807089152.json' not found. Skip.
# Tweet 'data/./rawdata/126528978239496194.json' not found. Skip.
# Tweet 'data/./rawdata/126528804192653312.json' not found. Skip.
# Tweet 'data/./rawdata/126528264117293056.json' not found. Skip.
# Tweet 'data/./rawdata/126526219587039233.json' not found. Skip.
# Tweet 'data/./rawdata/126525469897146368.json' not found. Skip.
# Tweet 'data/./rawdata/126525368860540928.json' not found. Skip.
# Tweet 'data/./rawdata/126525172969766912.json' not found. Skip.
# Tweet 'data/./rawdata/126524301259194368.json' not found. Skip.
# Tweet 'data/./rawdata/126523731710443521.json' not found. Skip.
# Tweet 'data/./rawdata/126523530903953408.json' not found. Skip.
# Tweet 'data/./rawdata/126523525598162944.json' not found. Skip.
# Tweet 'data/./rawdata/126522990585315328.json' not found. Skip.
# Tweet 'data/./rawdata/126522810821644288.json' not found. Skip.
# Tweet 'data/./rawdata/126522714713370624.json' not found. Skip.
# Tweet 'data/./rawdata/126522621251682304.json' not found. Skip.
# Tweet 'data/./rawdata/126522262768726016.json' not found. Skip.
# Tweet 'data/./rawdata/126521613259771904.json' not found. Skip.
# Tweet 'data/./rawdata/126521382220738560.json' not found. Skip.
# Tweet 'data/./rawdata/126521286053724160.json' not found. Skip.
# Tweet 'data/./rawdata/126520518609350656.json' not found. Skip.
# Tweet 'data/./rawdata/126520029410885632.json' not found. Skip.
# Tweet 'data/./rawdata/126519483752914944.json' not found. Skip.
# Tweet 'data/./rawdata/126519329025040384.json' not found. Skip.
# Tweet 'data/./rawdata/126519123772588032.json' not found. Skip.
# Tweet 'data/./rawdata/126519017405030400.json' not found. Skip.
# Tweet 'data/./rawdata/126518882939838464.json' not found. Skip.
# Tweet 'data/./rawdata/126516914678808578.json' not found. Skip.
# Tweet 'data/./rawdata/126516779886456832.json' not found. Skip.
# Tweet 'data/./rawdata/126516304336257025.json' not found. Skip.
# Tweet 'data/./rawdata/126515760855134208.json' not found. Skip.
# Tweet 'data/./rawdata/126514474378203136.json' not found. Skip.
# Tweet 'data/./rawdata/126513620686352384.json' not found. Skip.
# Tweet 'data/./rawdata/126513526385819648.json' not found. Skip.
# Tweet 'data/./rawdata/126513425043030016.json' not found. Skip.
# Tweet 'data/./rawdata/126512728297844736.json' not found. Skip.
# Tweet 'data/./rawdata/126512631937904640.json' not found. Skip.
# Tweet 'data/./rawdata/126512208451600384.json' not found. Skip.
# Tweet 'data/./rawdata/126511837796765696.json' not found. Skip.
# Tweet 'data/./rawdata/126511545160171520.json' not found. Skip.
# Tweet 'data/./rawdata/126511426926944256.json' not found. Skip.
# Tweet 'data/./rawdata/126511000907288576.json' not found. Skip.
# Tweet 'data/./rawdata/126510977335300096.json' not found. Skip.
# Tweet 'data/./rawdata/126510551789604864.json' not found. Skip.
# Tweet 'data/./rawdata/126509929619132417.json' not found. Skip.
# Tweet 'data/./rawdata/126509528287166464.json' not found. Skip.
# Tweet 'data/./rawdata/126508433582211072.json' not found. Skip.
# Tweet 'data/./rawdata/126508393203642368.json' not found. Skip.
# Tweet 'data/./rawdata/126507456019968000.json' not found. Skip.
# Tweet 'data/./rawdata/126507105023819776.json' not found. Skip.
# Tweet 'data/./rawdata/126506850781888512.json' not found. Skip.
# Tweet 'data/./rawdata/126506410195431424.json' not found. Skip.
# Tweet 'data/./rawdata/126506064387637249.json' not found. Skip.
# Tweet 'data/./rawdata/126505384428052481.json' not found. Skip.
# Tweet 'data/./rawdata/126505187752943616.json' not found. Skip.
# Tweet 'data/./rawdata/126505144878772224.json' not found. Skip.
# Tweet 'data/./rawdata/126504782465732608.json' not found. Skip.
# Tweet 'data/./rawdata/126504452680187905.json' not found. Skip.
# Tweet 'data/./rawdata/126504346639802368.json' not found. Skip.
# Tweet 'data/./rawdata/126504216004005888.json' not found. Skip.
# Tweet 'data/./rawdata/126504013939216384.json' not found. Skip.
# Tweet 'data/./rawdata/126503946092158976.json' not found. Skip.
# Tweet 'data/./rawdata/126503805369069568.json' not found. Skip.
# Tweet 'data/./rawdata/126503790412181504.json' not found. Skip.
# Tweet 'data/./rawdata/126503029548654593.json' not found. Skip.
# Tweet 'data/./rawdata/126502415322193920.json' not found. Skip.
# Tweet 'data/./rawdata/126502014560649216.json' not found. Skip.
# Tweet 'data/./rawdata/126501732443361280.json' not found. Skip.
# Tweet 'data/./rawdata/126501468902658048.json' not found. Skip.
# Tweet 'data/./rawdata/126500614552289282.json' not found. Skip.
# Tweet 'data/./rawdata/126499965869625345.json' not found. Skip.
# Tweet 'data/./rawdata/126499581520384001.json' not found. Skip.
# Tweet 'data/./rawdata/126499428965158912.json' not found. Skip.
# Tweet 'data/./rawdata/126499145014980608.json' not found. Skip.
# Tweet 'data/./rawdata/126499143282737152.json' not found. Skip.
# Tweet 'data/./rawdata/126498734409396224.json' not found. Skip.
# Tweet 'data/./rawdata/126498608815149056.json' not found. Skip.
# Tweet 'data/./rawdata/126498587499696128.json' not found. Skip.
# Tweet 'data/./rawdata/126497976314109952.json' not found. Skip.
# Tweet 'data/./rawdata/126497860752646146.json' not found. Skip.
# Tweet 'data/./rawdata/126497655785402368.json' not found. Skip.
# Tweet 'data/./rawdata/126496772586610688.json' not found. Skip.
# Tweet 'data/./rawdata/126496739531304960.json' not found. Skip.
# Tweet 'data/./rawdata/126496342901133313.json' not found. Skip.
# Tweet 'data/./rawdata/126496262668292096.json' not found. Skip.
# Tweet 'data/./rawdata/126496155856142336.json' not found. Skip.
# Tweet 'data/./rawdata/126496005809127424.json' not found. Skip.
# Tweet 'data/./rawdata/126495843116265475.json' not found. Skip.
# Tweet 'data/./rawdata/126495812724338688.json' not found. Skip.
# Tweet 'data/./rawdata/126495283176685569.json' not found. Skip.
# Tweet 'data/./rawdata/126495221373607936.json' not found. Skip.
# Tweet 'data/./rawdata/126494976396898305.json' not found. Skip.
# Tweet 'data/./rawdata/126494883367235585.json' not found. Skip.
# Tweet 'data/./rawdata/126494838689513473.json' not found. Skip.
# Tweet 'data/./rawdata/126494834449063936.json' not found. Skip.
# Tweet 'data/./rawdata/126494645281755136.json' not found. Skip.
# Tweet 'data/./rawdata/126494573966016512.json' not found. Skip.
# Tweet 'data/./rawdata/126494442290020352.json' not found. Skip.
# Tweet 'data/./rawdata/126494344566943744.json' not found. Skip.
# Tweet 'data/./rawdata/126494339248562176.json' not found. Skip.
# ...
# Tweet 'data/./rawdata/126866905096130560.json' not found. Skip.
# Tweet 'data/./rawdata/126866882979573760.json' not found. Skip.
# Tweet 'data/./rawdata/126866835449708544.json' not found. Skip.
# Tweet 'data/./rawdata/126866833537110016.json' not found. Skip.
# Tweet 'data/./rawdata/126866827715420160.json' not found. Skip.
# Tweet 'data/./rawdata/126866789962498048.json' not found. Skip.
# Tweet 'data/./rawdata/126866773705375744.json' not found. Skip.
# Tweet 'data/./rawdata/126866759792852992.json' not found. Skip.
# Tweet 'data/./rawdata/126866701877903361.json' not found. Skip.
# Tweet 'data/./rawdata/126866689236283392.json' not found. Skip.
# Tweet 'data/./rawdata/126866515122331648.json' not found. Skip.
# Tweet 'data/./rawdata/126866508818296832.json' not found. Skip.
# Tweet 'data/./rawdata/126866474806673408.json' not found. Skip.
# Tweet 'data/./rawdata/126866454845984768.json' not found. Skip.
# Tweet 'data/./rawdata/126866426521849857.json' not found. Skip.
# Tweet 'data/./rawdata/126866385757417472.json' not found. Skip.
# Tweet 'data/./rawdata/126866312130609152.json' not found. Skip.
# Tweet 'data/./rawdata/126866267998134272.json' not found. Skip.
# Tweet 'data/./rawdata/126866222355722240.json' not found. Skip.
# Tweet 'data/./rawdata/126866176889454592.json' not found. Skip.
# Tweet 'data/./rawdata/126866076016447489.json' not found. Skip.
# Tweet 'data/./rawdata/126866058337460224.json' not found. Skip.
# Tweet 'data/./rawdata/126866027316383744.json' not found. Skip.
# Tweet 'data/./rawdata/126866021402427392.json' not found. Skip.
# Tweet 'data/./rawdata/126865987365634048.json' not found. Skip.
# Tweet 'data/./rawdata/126865977970401280.json' not found. Skip.
# Tweet 'data/./rawdata/126865966624813057.json' not found. Skip.
# Tweet 'data/./rawdata/126865936115445761.json' not found. Skip.
# Tweet 'data/./rawdata/126865932806139904.json' not found. Skip.
# Tweet 'data/./rawdata/126865890665967618.json' not found. Skip.
# Tweet 'data/./rawdata/126865868599726080.json' not found. Skip.
# Tweet 'data/./rawdata/126865864086667264.json' not found. Skip.
# Tweet 'data/./rawdata/126865777423941633.json' not found. Skip.
# Tweet 'data/./rawdata/126865704380153856.json' not found. Skip.
# Tweet 'data/./rawdata/126865703969099776.json' not found. Skip.
# Tweet 'data/./rawdata/126865661602447362.json' not found. Skip.
# Tweet 'data/./rawdata/126865633869709312.json' not found. Skip.
# Tweet 'data/./rawdata/126865576093171712.json' not found. Skip.
# Tweet 'data/./rawdata/126865573228445696.json' not found. Skip.
# Tweet 'data/./rawdata/126865566236553216.json' not found. Skip.
# Tweet 'data/./rawdata/126865487584968704.json' not found. Skip.
# Tweet 'data/./rawdata/126865416671862785.json' not found. Skip.
# Tweet 'data/./rawdata/126865410598502400.json' not found. Skip.
# Tweet 'data/./rawdata/126865389861871617.json' not found. Skip.
# Tweet 'data/./rawdata/126865304277090304.json' not found. Skip.
# Tweet 'data/./rawdata/126865296463118337.json' not found. Skip.
# Tweet 'data/./rawdata/126865215492071424.json' not found. Skip.
# Tweet 'data/./rawdata/126865127977918464.json' not found. Skip.
# Tweet 'data/./rawdata/126865092565417984.json' not found. Skip.
# Tweet 'data/./rawdata/126865045949919233.json' not found. Skip.
# Tweet 'data/./rawdata/126865038676987904.json' not found. Skip.
# Tweet 'data/./rawdata/126865014215802880.json' not found. Skip.
# Tweet 'data/./rawdata/126864993760182272.json' not found. Skip.
# Tweet 'data/./rawdata/126864955285831680.json' not found. Skip.
# Tweet 'data/./rawdata/126864954140803072.json' not found. Skip.
# Tweet 'data/./rawdata/126864917566455809.json' not found. Skip.
# Tweet 'data/./rawdata/126864908582260736.json' not found. Skip.
# Tweet 'data/./rawdata/126864848649846784.json' not found. Skip.
# Tweet 'data/./rawdata/126864847399944192.json' not found. Skip.
# Tweet 'data/./rawdata/126864712766980096.json' not found. Skip.
# Tweet 'data/./rawdata/126864692470751232.json' not found. Skip.
# Tweet 'data/./rawdata/126864673416032256.json' not found. Skip.
# Tweet 'data/./rawdata/126864623252144128.json' not found. Skip.
# Tweet 'data/./rawdata/126864485943214080.json' not found. Skip.
# Tweet 'data/./rawdata/126864460957749248.json' not found. Skip.
# Tweet 'data/./rawdata/126864441999507456.json' not found. Skip.
# Tweet 'data/./rawdata/126864344125419520.json' not found. Skip.
# Tweet 'data/./rawdata/126864341071962112.json' not found. Skip.
# Tweet 'data/./rawdata/126864316120047617.json' not found. Skip.
# Tweet 'data/./rawdata/126864259027181568.json' not found. Skip.
# Tweet 'data/./rawdata/126864201804300289.json' not found. Skip.
# Tweet 'data/./rawdata/126864188969725953.json' not found. Skip.
# Tweet 'data/./rawdata/126864074045784064.json' not found. Skip.
# Tweet 'data/./rawdata/126864072447766528.json' not found. Skip.
# Tweet 'data/./rawdata/126864016613183489.json' not found. Skip.
# Tweet 'data/./rawdata/126863938339094531.json' not found. Skip.
# Tweet 'data/./rawdata/126863859075121152.json' not found. Skip.
# Tweet 'data/./rawdata/126863845326209024.json' not found. Skip.
# Tweet 'data/./rawdata/126863808177254400.json' not found. Skip.
# Tweet 'data/./rawdata/126863734265217025.json' not found. Skip.
# Tweet 'data/./rawdata/126863732931432448.json' not found. Skip.
# Tweet 'data/./rawdata/126863723179675648.json' not found. Skip.
# Tweet 'data/./rawdata/126863722412118017.json' not found. Skip.
# Tweet 'data/./rawdata/126863708889690112.json' not found. Skip.
# Tweet 'data/./rawdata/126863696726200320.json' not found. Skip.
# Tweet 'data/./rawdata/126863647845789696.json' not found. Skip.
# Tweet 'data/./rawdata/126863644968501250.json' not found. Skip.
# Tweet 'data/./rawdata/126863594850746369.json' not found. Skip.
# Tweet 'data/./rawdata/126863579914829824.json' not found. Skip.
# Tweet 'data/./rawdata/126863563133431809.json' not found. Skip.
# Tweet 'data/./rawdata/126863551355822080.json' not found. Skip.
# Tweet 'data/./rawdata/126863538626109440.json' not found. Skip.
# Tweet 'data/./rawdata/126863416211156992.json' not found. Skip.
# Tweet 'data/./rawdata/126863368492564481.json' not found. Skip.
# Tweet 'data/./rawdata/126863360779227136.json' not found. Skip.
# Tweet 'data/./rawdata/126863360686956544.json' not found. Skip.
# Tweet 'data/./rawdata/126863321327611904.json' not found. Skip.
# Tweet 'data/./rawdata/126863319226265600.json' not found. Skip.
# Tweet 'data/./rawdata/126863283658567680.json' not found. Skip.
# Tweet 'data/./rawdata/126863189844566016.json' not found. Skip.
# Tweet 'data/./rawdata/126863136111333376.json' not found. Skip.
# Tweet 'data/./rawdata/126863118398787584.json' not found. Skip.
# Tweet 'data/./rawdata/126863108802232320.json' not found. Skip.
# Tweet 'data/./rawdata/126863108688986112.json' not found. Skip.
# Tweet 'data/./rawdata/126863078112509952.json' not found. Skip.
# Tweet 'data/./rawdata/126863012433899520.json' not found. Skip.
# Tweet 'data/./rawdata/126862981333139457.json' not found. Skip.
# Tweet 'data/./rawdata/126862918921891840.json' not found. Skip.
# Tweet 'data/./rawdata/126862904514445312.json' not found. Skip.
# Tweet 'data/./rawdata/126862853822099456.json' not found. Skip.
# Tweet 'data/./rawdata/126862852681240576.json' not found. Skip.
# Tweet 'data/./rawdata/126862832489861121.json' not found. Skip.
# Tweet 'data/./rawdata/126862813355442176.json' not found. Skip.
# Tweet 'data/./rawdata/126862789649248256.json' not found. Skip.
# Tweet 'data/./rawdata/126862725933576192.json' not found. Skip.
# Tweet 'data/./rawdata/126862722028666880.json' not found. Skip.
# Tweet 'data/./rawdata/126862722007699456.json' not found. Skip.
# Tweet 'data/./rawdata/126862721793789953.json' not found. Skip.
# Tweet 'data/./rawdata/126862721609248769.json' not found. Skip.
# Tweet 'data/./rawdata/126862719927332864.json' not found. Skip.
# Tweet 'data/./rawdata/126862668039598080.json' not found. Skip.
# Tweet 'data/./rawdata/126862654324211713.json' not found. Skip.
# Tweet 'data/./rawdata/126862632648065025.json' not found. Skip.
# Tweet 'data/./rawdata/126862595117424641.json' not found. Skip.
# Tweet 'data/./rawdata/126862536162295808.json' not found. Skip.
# Tweet 'data/./rawdata/126862464003477504.json' not found. Skip.
# Tweet 'data/./rawdata/126862447041712128.json' not found. Skip.
# Tweet 'data/./rawdata/126862429912186880.json' not found. Skip.
# Tweet 'data/./rawdata/126862343148802048.json' not found. Skip.
# Tweet 'data/./rawdata/126862329269858305.json' not found. Skip.
# Tweet 'data/./rawdata/126862315990679552.json' not found. Skip.
# Tweet 'data/./rawdata/126862308302532608.json' not found. Skip.
# Tweet 'data/./rawdata/126862269148692481.json' not found. Skip.
# Tweet 'data/./rawdata/126862268725080065.json' not found. Skip.
# Tweet 'data/./rawdata/126862217013497856.json' not found. Skip.
# Tweet 'data/./rawdata/126862201440043008.json' not found. Skip.
# Tweet 'data/./rawdata/126862151393619968.json' not found. Skip.
# Tweet 'data/./rawdata/126862151343284224.json' not found. Skip.
# Tweet 'data/./rawdata/126862150265352193.json' not found. Skip.
# Tweet 'data/./rawdata/126862116874489856.json' not found. Skip.
# Tweet 'data/./rawdata/126861992001679360.json' not found. Skip.
# Tweet 'data/./rawdata/126861988004499457.json' not found. Skip.
# Tweet 'data/./rawdata/126861979762696192.json' not found. Skip.
# Tweet 'data/./rawdata/126861960137539585.json' not found. Skip.
# Tweet 'data/./rawdata/126861955762888706.json' not found. Skip.
# Tweet 'data/./rawdata/126861933071704065.json' not found. Skip.
# Tweet 'data/./rawdata/126861782378745856.json' not found. Skip.
# Tweet 'data/./rawdata/126861771314184192.json' not found. Skip.
# Tweet 'data/./rawdata/126861717790658561.json' not found. Skip.
# Tweet 'data/./rawdata/126861611741872128.json' not found. Skip.
# Tweet 'data/./rawdata/126861593249185793.json' not found. Skip.
# Tweet 'data/./rawdata/126861589122002944.json' not found. Skip.
# Tweet 'data/./rawdata/126861539511775232.json' not found. Skip.
# Tweet 'data/./rawdata/126861496109121536.json' not found. Skip.
# Tweet 'data/./rawdata/126861493059854336.json' not found. Skip.
# Tweet 'data/./rawdata/126861480128819201.json' not found. Skip.
# Tweet 'data/./rawdata/126861380992241664.json' not found. Skip.
# Tweet 'data/./rawdata/126861357831303168.json' not found. Skip.
# Tweet 'data/./rawdata/126861252134830080.json' not found. Skip.
# Tweet 'data/./rawdata/126861245109387264.json' not found. Skip.
# Tweet 'data/./rawdata/126861233138827264.json' not found. Skip.
# Tweet 'data/./rawdata/126861218592980992.json' not found. Skip.
# Tweet 'data/./rawdata/126861187605471232.json' not found. Skip.
# Tweet 'data/./rawdata/126861118684676096.json' not found. Skip.
# Tweet 'data/./rawdata/126861100120686592.json' not found. Skip.
# Tweet 'data/./rawdata/126860970583797760.json' not found. Skip.
# Tweet 'data/./rawdata/126860953450065920.json' not found. Skip.
# Tweet 'data/./rawdata/126860911557345280.json' not found. Skip.
# Tweet 'data/./rawdata/126860890749419521.json' not found. Skip.
# Tweet 'data/./rawdata/126860877344407552.json' not found. Skip.
# Tweet 'data/./rawdata/126860835892109312.json' not found. Skip.
# Tweet 'data/./rawdata/126860830942834689.json' not found. Skip.
# Tweet 'data/./rawdata/126860808251637762.json' not found. Skip.
# Tweet 'data/./rawdata/126860789536657408.json' not found. Skip.
# Tweet 'data/./rawdata/126860754912681985.json' not found. Skip.
# Tweet 'data/./rawdata/126860740689797120.json' not found. Skip.
# Tweet 'data/./rawdata/126860719860883458.json' not found. Skip.
# Tweet 'data/./rawdata/126860653167263744.json' not found. Skip.
# Tweet 'data/./rawdata/126860610020446209.json' not found. Skip.
# Tweet 'data/./rawdata/126860576600227841.json' not found. Skip.
# Tweet 'data/./rawdata/126860372987740160.json' not found. Skip.
# Tweet 'data/./rawdata/126860329463447552.json' not found. Skip.
# Tweet 'data/./rawdata/126860270181171201.json' not found. Skip.
# Tweet 'data/./rawdata/126860146289803265.json' not found. Skip.
# Tweet 'data/./rawdata/126860127167987712.json' not found. Skip.
# Tweet 'data/./rawdata/126860114610241536.json' not found. Skip.
# Tweet 'data/./rawdata/126860109090521088.json' not found. Skip.
# Tweet 'data/./rawdata/126859990513369088.json' not found. Skip.
# Tweet 'data/./rawdata/126859860640940032.json' not found. Skip.
# Tweet 'data/./rawdata/126859857604247552.json' not found. Skip.
# Tweet 'data/./rawdata/126859846506127360.json' not found. Skip.
# Tweet 'data/./rawdata/126859794383515649.json' not found. Skip.
# Tweet 'data/./rawdata/126859777308495872.json' not found. Skip.
# Tweet 'data/./rawdata/126859668151738368.json' not found. Skip.
# Tweet 'data/./rawdata/126859627051757568.json' not found. Skip.
# Tweet 'data/./rawdata/126859610006110208.json' not found. Skip.
# Tweet 'data/./rawdata/126859509414100992.json' not found. Skip.
# Tweet 'data/./rawdata/126859503495938048.json' not found. Skip.
# Tweet 'data/./rawdata/126859490061598720.json' not found. Skip.
# Tweet 'data/./rawdata/126859443127332864.json' not found. Skip.
# Tweet 'data/./rawdata/126859428455657472.json' not found. Skip.
# Tweet 'data/./rawdata/126859363079041024.json' not found. Skip.
# Tweet 'data/./rawdata/126859354614939648.json' not found. Skip.
# Tweet 'data/./rawdata/126859286558158849.json' not found. Skip.
# Tweet 'data/./rawdata/126859257856540672.json' not found. Skip.
# Tweet 'data/./rawdata/126859211593351168.json' not found. Skip.
# Tweet 'data/./rawdata/126859155175772161.json' not found. Skip.
# Tweet 'data/./rawdata/126859077304320001.json' not found. Skip.
# Tweet 'data/./rawdata/126858835058098176.json' not found. Skip.
# Tweet 'data/./rawdata/126858789868670976.json' not found. Skip.
# Tweet 'data/./rawdata/126858639855206400.json' not found. Skip.
# Tweet 'data/./rawdata/126858516655898625.json' not found. Skip.
# Tweet 'data/./rawdata/126858260216160256.json' not found. Skip.
# Tweet 'data/./rawdata/126858248325308416.json' not found. Skip.
# Tweet 'data/./rawdata/126858186962644992.json' not found. Skip.
# Tweet 'data/./rawdata/126858148878368769.json' not found. Skip.
# Tweet 'data/./rawdata/126858034466131969.json' not found. Skip.
# Tweet 'data/./rawdata/126858032951996416.json' not found. Skip.
# Tweet 'data/./rawdata/126858004690767872.json' not found. Skip.
# Tweet 'data/./rawdata/126857921068941314.json' not found. Skip.
# Tweet 'data/./rawdata/126857918929838080.json' not found. Skip.
# Tweet 'data/./rawdata/126857746200014849.json' not found. Skip.
# Tweet 'data/./rawdata/126857736238530560.json' not found. Skip.
# Tweet 'data/./rawdata/126857518591901698.json' not found. Skip.
# Tweet 'data/./rawdata/126857511230902272.json' not found. Skip.
# Tweet 'data/./rawdata/126857421321797634.json' not found. Skip.
# Tweet 'data/./rawdata/126857383715676160.json' not found. Skip.
# Tweet 'data/./rawdata/126857361515216897.json' not found. Skip.
# Tweet 'data/./rawdata/126857211921174528.json' not found. Skip.
# Tweet 'data/./rawdata/126857080513638400.json' not found. Skip.
# Tweet 'data/./rawdata/126857071667847168.json' not found. Skip.
# Tweet 'data/./rawdata/126857049920385024.json' not found. Skip.
# Tweet 'data/./rawdata/126856764242137088.json' not found. Skip.
# Tweet 'data/./rawdata/126856732331884545.json' not found. Skip.
# Tweet 'data/./rawdata/126856603021484032.json' not found. Skip.
# Tweet 'data/./rawdata/126856425371746304.json' not found. Skip.
# Tweet 'data/./rawdata/126856274531991552.json' not found. Skip.
# Tweet 'data/./rawdata/126856135918620673.json' not found. Skip.
# Tweet 'data/./rawdata/126856097863708672.json' not found. Skip.
# Tweet 'data/./rawdata/126856097431699456.json' not found. Skip.
# Tweet 'data/./rawdata/126855687060987904.json' not found. Skip.
# Tweet 'data/./rawdata/126855171702661120.json' not found. Skip.
# Tweet 'data/./rawdata/126854999442587648.json' not found. Skip.
# Tweet 'data/./rawdata/126854818101858304.json' not found. Skip.
# Tweet 'data/./rawdata/126854423317188608.json' not found. Skip.
# #negative: 282
# #neutral: 253
# #positive: 131
# == Pos vs. neg ==
# 0.819	0.029	0.812	0.045
# == Pos/neg vs. irrelevant/neutral ==
# 0.751	0.017	0.883	0.013
# == Pos vs. rest ==
# 0.831	0.025	0.577	0.039
# == Neg vs. rest ==
# 0.776	0.017	0.808	0.029
# ('time spent:', 38.848644971847534)

# %%
imgshow('./charts/pr_neg_vs_rest_04.png')
imgshow('./charts/pr_pos_vs_neg_04.png')
imgshow('./charts/pr_pos_vs_rest_04.png')
