# %% [markdown]
# #### import scipy as sp
# relPath = "/home/python/notebook_root/build_machine_learning_system_with_python/data/ch01/data/"
# dataPath = relPath + "web_traffic.tsv"
# print dataPath
# data = sp.genfromtxt(dataPath,delimiter = "\t")
# print(data[:10])

# %%
print(data.shape)
# Out:
# (743, 2)

# %% [markdown]
# scipy에서 데이터를 2개의 벡터로 나눔

# %% [markdown]
# 첫번째 벡터 x는 시간을 나타냄.

# %% [markdown]
# 두번째 벡터 y는 특정 시간의 요청 수를

# %% [markdown]
# 나누는 방법 : 개별적으로 열을 선택할 수 있는 scipy의 특수 인덱스 표기를 사용

# %%
x = data[:,0]
y = data[:,1]

# %% [markdown]
# y 값 중에 일부 값이 잘못 된 값 확인

# %%
sp.sum(sp.isnan(y))
# Out:
# 8

# %%
sp.sum(sp.isnan(x))
# Out:
# 0

# %%
x = x[~sp.isnan(y)]
y = y[~sp.isnan(y)]

# %% [markdown]
# 데이터 정제

# %% [markdown]
# 데이터 형태를 파악하기 위해 matplotlib를 이용하여 점도표(scatter) 표시

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.title("web traffic over the last month")
plt.xlabel("Time")
plt.ylabel("Hits/hour")
plt.xticks([w*7*24 for w in range(10)],['week %i for w in range(10)'])
plt.autoscale(tight=True)
plt.grid()
plt.show()
